# %%
import matplotlib.pyplot as pl
import random
import numpy as np
import pandas as pd
# %matplotlib inline

# a=np.array([random.randint(1,100) for i in range(10)])
# b=np.array([random.randint(1,100) for i in range(10)])
a=np.array([1,2,3,4,5])
b=np.array([4,3,4,2,5])
df=pd.DataFrame({"X":a,"Y":b,"x-x'":x_xbar,"y-y'":y_ybar,"(x-x')^2":x_xbar_sq,"(y-y')^2":y_ybar_sq,"(x-x')(y-y')":x_y_bar})
df
# Out:
#    X  Y  x-x'  y-y'  (x-x')^2  (y-y')^2  (x-x')(y-y')
# 0  1  4  -2.0   0.4       4.0      0.16          -0.8
# 1  2  3  -1.0  -0.6       1.0      0.36           0.6
# 2  3  4   0.0   0.4       0.0      0.16           0.0
# 3  4  2   1.0  -1.6       1.0      2.56          -1.6
# 4  5  5   2.0   1.4       4.0      1.96           2.8

# %%
y_y=np.subtract(mainslope,y_mean)
y_ysq=np.square(y_y)
subm1=np.sum(y_ysq)
df2=pd.DataFrame({"x":a,"y":b,"Y~":mainslope,"(y-Y~)":y_y,"(y-y')":y_ybar,"(y-Y~)^2":y_ysq,"(y-y')^2":y_ybar_sq})
df2
# Out:
#    x  y   Y~        (y-Y~)  (y-y')      (y-Y~)^2  (y-y')^2
# 0  1  4  3.4 -2.000000e-01     0.4  4.000000e-02      0.16
# 1  2  3  3.5 -1.000000e-01    -0.6  1.000000e-02      0.36
# 2  3  4  3.6 -4.440892e-16     0.4  1.972152e-31      0.16
# 3  4  2  3.7  1.000000e-01    -1.6  1.000000e-02      2.56
# 4  5  5  3.8  2.000000e-01     1.4  4.000000e-02      1.96

# %%
LSE=subm1/(np.sum(y_ybar_sq))
print(LSE)
# Out:
# 0.01923076923076921

# %%
x_mean=a.mean()
y_mean=b.mean()
print(x_mean,y_mean)
# x-xbar
x_xbar=np.subtract(a,x_mean)

#y-ybar
y_ybar=np.subtract(b,y_mean)

# x-xbar square
x_xbar_sq=np.square(x_xbar)

#y-ybar square
y_ybar_sq=np.square(y_ybar)

#(x-xbar)(y-ybar)
x_y_bar=np.multiply(x_xbar,y_ybar)

sumx_xbar=np.sum(x_xbar)
sumy_ybar=np.sum(y_ybar)
sumx_xbarsquare=np.sum(x_xbar_sq)
x_xbar_y_ybar=np.sum(x_y_bar)

slope=x_xbar_y_ybar/sumx_xbarsquare
y_intercept=y_mean-slope*x_mean
print(a)
print(b)
print(x_xbar)
print(y_ybar)
print(x_xbar_sq)
print(y_ybar_sq)
print(x_y_bar)
print("Slope=",slope)
print("Y intercept=",y_intercept)
print("y=",slope,"x +",y_intercept)

mainslope=[]
for i in range(len(a)):
    y=slope*a[i]+y_intercept
    mainslope.append(y)

pl.scatter(a,b,marker='o')
pl.plot(mainslope)
pl.plot(np.array([3.2,3.1,3.0,2.9,2.8]))
pl.legend(["Slope","Dummy Slope"],loc='best')
pl.grid()
pl.show()
# Out:
# 3.0 3.6
# [1 2 3 4 5]
# [4 3 4 2 5]
# [-2. -1.  0.  1.  2.]
# [ 0.4 -0.6  0.4 -1.6  1.4]
# [4. 1. 0. 1. 4.]
# [0.16 0.36 0.16 2.56 1.96]
# [-0.8  0.6  0.  -1.6  2.8]
# Slope= 0.1
# Y intercept= 3.3
# y= 0.1 x + 3.3
