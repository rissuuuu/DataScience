# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
a=np.arange(100)
b=np.random.randint(1,100,100)

# %%
pl.scatter(a,b)
pl.plot(a,2*a+2)
pl.plot(a,0.2*a+0.2)
pl.plot(a,4*a+4)

# %%
from sklearn.datasets import make_blobs
X,y=make_blobs(n_samples=100,centers=3)

# %%
import mglearn
mglearn.discrete_scatter(X[:,0],X[:,1],y)
# Out:
# [<matplotlib.lines.Line2D at 0x211e94facc8>,
#  <matplotlib.lines.Line2D at 0x211e8d434c8>,
#  <matplotlib.lines.Line2D at 0x211e94fac88>]

# %%
from sklearn.svm import SVC
sv_m=SVC(kernel='linear')
sv_m.fit(X,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pl.scatter(X[:,0],X[:,1],c=y)
line=np.linspace(-5,5,10)
for coef,intercept in zip(sv_m.coef_,sv_m.intercept_):
    pl.plot(line,-(line*coef[0]+intercept)/coef[1])

# %%
sv_m.coef_[0][0]
# Out:
# -0.14650974227549085

# %%
a=np.arange(10)
pl.plot(a,np.log(a))
# Out:
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
a=np.arange(10)
pl.plot(a,-np.log(a))
# Out:
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
np.log(a)
# Out:
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# array([      -inf, 0.        , 0.69314718, 1.09861229, 1.38629436,
#        1.60943791, 1.79175947, 1.94591015, 2.07944154, 2.19722458])
