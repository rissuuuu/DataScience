# %%
# underfitting:
#     sometime models learn only from some part of training dataset. they may not perform well for other datasets. Here 
#     points are in huge bias or are separated with a huge gap with the straight line.
    
# overfitting:
#     when a model memorizes each and everything and becomes perfect for the particular training set and it can perform well
#     in that particular known set only. whenever any new data set is provided which is unknown to the model it may not 
#     predict well or give the solution. in this case the line covers all the points. here it may also consider noise or 
#     error points. noise may be caused during the collection of data 

# bestfitting:
#     When a line or a curve considers all the points around itself without a huge bias. its called as best fit.

from PIL import Image
img=Image.open("fit.png")
height,width=img.size
print(height,width)
img
# Out:
# 1212 786
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1212x786 at 0x15C328F0>
