# %%
import pandas as pd

# %%
df=pd.read_csv("sms_file.csv")
df
# Out:
#        from          to                                               text  \
# 0   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 1   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 2   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 3   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 4   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 5   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 6   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 7   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 8   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 9   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 10  InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# ...

# %%
df.columns
# Out:
# Index(['from', 'to', 'text', 'token'], dtype='object')

# %%
df="s"
i=0
while len(df)!=0:
    try:
        df=pd.read_csv("sms_data.txt",delimiter=',')
        from_info=df.loc[0][0]
        to=df.loc[0][1]
        text=df.loc[0][2]
        app_id=df.loc[0][3]
        print(from_info,to,text,app_id)
        print()
        df.drop(0,inplace=True)
        df.reset_index(drop=True)
        df.to_csv('sms_data.txt',index=False)
    except Exception:
        pass
# Out:
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 1
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 1
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 1
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 1
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 1
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 2
#
# InfoSMS 9865111909 Hi Rishav.. Sparrow sms heredd This is for checking only 3
#
# ...

# %%
df=pd.read_csv("sms_data.txt",delimiter=',')
df
# Out:
# Empty DataFrame
# Columns: [from, to, text, token]
# Index: []

# %%
fo = open("sms_data.txt", "r+")
print ("Name of the file: ", fo.name)

# Assuming file has following 5 lines
# This is 1st line
# This is 2nd line
# This is 3rd line
# This is 4th line
# This is 5th line

line = fo.readline()
print ("Read Line: %s" % (line))

# Now truncate remaining file.
fo.truncate()

# Try to read file now
line = fo.readline()
print ("Read Line: %s" % (line))

# Close opend file
fo.close()
# Out:
# Name of the file:  sms_data.txt
# Read Line: InfoSMS	9865111909	Hi Rishav.. Sparrow sms heredd This is for checking only	1
#
# Read Line: InfoSMS	9865111909	Hi Rishav.. Sparrow sms heredd This is for checking only	1

# %%
pd.read_csv('sms_data.txt',delimiter=',')
# Out:
#        from          to                                               text  \
# 0   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 1   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 2   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 3   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 4   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 5   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 6   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 7   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 8   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 9   InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# 10  InfoSMS  9865111909  Hi Rishav.. Sparrow sms heredd This is for che...
# ...
