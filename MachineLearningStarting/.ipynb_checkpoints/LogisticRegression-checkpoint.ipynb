# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from sklearn.datasets import make_blobs
import mglearn
from sklearn.datasets import load_iris

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %%
# X,y=make_blobs(n_samples=1000,centers=2,n_features=2,cluster_std=2)

# %%
mglearn.discrete_scatter(X[:,0],X[:,1],y)
# Out:
# [<matplotlib.lines.Line2D at 0x15a41aff988>,
#  <matplotlib.lines.Line2D at 0x15a406a44c8>]

# %%
y=y.reshape(-1,1)

# %%
def sigmoid(m,X,c):
    z=np.dot(X,m)+c
    sigm=1/(1+np.exp(-z))
    return sigm

# %%
def cost(y,y_pred):
    return -1*sum(y*np.log(y_pred)+(1-y)*np.log(1-y_pred))

# %%
m=np.random.rand(4).reshape(-1,1)
c=np.random.rand(1).reshape(-1,1)
lr=0.1
epochs=100
err=[]
y=y.reshape(-1,1)
for i in range(1000):
    y_pred=sigmoid(m,X,c)
    d_m=-1*(np.dot(X.T,y*(1-y_pred))-np.dot(X.T,y_pred*(1-y)))
    d_c=-1*sum(y*(1-y_pred)-(1-y)*y_pred)
    m=m-lr*d_m
    c=c-lr*d_c
    error=cost(y,y_pred)
    err.append(error)
# Out:
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
m,c
# Out:
# (array([[ 7910.82404088],
#         [-2268.82278235],
#         [20450.47501177],
#         [ 8900.54420419]]),
#  array([[0.2155574]]))

# %%
pl.plot(err)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic=LogisticRegression()
logistic.fit(X,y)
# Out:
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\rissu\anaconda3\envs\Flask_app\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logistic.intercept_,logistic.coef_
# Out:
# (array([  9.83776831,   2.21827742, -12.05604573]),
#  array([[-0.41813284,  0.96633399, -2.52102777, -1.08409539],
#         [ 0.53029432, -0.31442411, -0.19947604, -0.94816287],
#         [-0.11216148, -0.65190988,  2.72050381,  2.03225827]]))

# %%
data=np.array([4,5.1,3,4.6]).reshape(1,-1)

# %%
logistic.predict(data)
# Out:
# array([2])

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(X,y)
np.round(linear.predict(data))
# Out:
# array([[3.]])
