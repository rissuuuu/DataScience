# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df=pd.read_csv('OnlineRetail.csv',encoding='latin1')
import seaborn as sns

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['Description']=df['Description'].str.strip()
df.dropna(axis=0,subset=['InvoiceNo'],inplace=True)
df['InvoiceNo']=df['InvoiceNo'].astype(str)
df=df[~df['InvoiceNo'].str.contains('C')]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
france=df[df['Country']=='France']
grouped=france.groupby(['InvoiceNo','Description'])['Quantity'].sum()
grouped=grouped.unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
grouped
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
def encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1
basket=grouped.applymap(encode_units)

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# ...

# %%
frequent_items=apriori(basket,min_support=0.07,use_colnames=True)
rules=association_rules(frequent_items,metric='lift',min_threshold=1)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 2    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 4                     (POSTAGE)  (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.102041            0.096939  0.073980    0.725000  7.478947
# 1            0.096939            0.102041  0.073980    0.763158  7.478947
# 2            0.094388            0.096939  0.079082    0.837838  8.642959
# 3            0.096939            0.094388  0.079082    0.815789  8.642959
# 4            0.765306            0.096939  0.084184    0.110000  1.134737
#
#    leverage  conviction
# 0  0.064088    3.283859
# 1  0.064088    3.791383
# 2  0.069932    5.568878
# 3  0.069932    4.916181
# ...

# %%
rules[(rules['lift']>=6) & (rules['confidence']>=0.8)]
# Out:
#                                            antecedents  \
# 2                           (ALARM CLOCK BAKELIKE RED)
# 3                         (ALARM CLOCK BAKELIKE GREEN)
# 75                     (SET/6 RED SPOTTY PAPER PLATES)
# 76                     (SET/6 RED SPOTTY PAPER PLATES)
# 77                       (SET/6 RED SPOTTY PAPER CUPS)
# 78                 (ALARM CLOCK BAKELIKE RED, POSTAGE)
# 80               (POSTAGE, ALARM CLOCK BAKELIKE GREEN)
# 114           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 116             (POSTAGE, SET/6 RED SPOTTY PAPER CUPS)
# 117                    (SET/6 RED SPOTTY PAPER PLATES)
# 120  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 121  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 122  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 126  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 128  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
#
#                                 consequents  antecedent support  \
# ...
