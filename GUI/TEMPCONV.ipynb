# %%
from tkinter import *
root=Tk()

old_d=0
old_f=0
old_k=0
def Convert():
    global old_d
    global old_f
    global old_k
    degree=int(entry1.get())
    farh=int(entry2.get())
    kelvin=int(entry3.get())
    if degree!=0:
        degree_farh=int(degree*(9/5)+32)
        val_f.set(degree_farh)
        degree_k=int(degree+273)
        val_k.set(degree_k)
        if old_d!=degree:
            degree_farh=int(degree*(9/5)+32)
            val_f.set(degree_farh)
            degree_k=int(degree+273)
            val_k.set(degree_k)
        old_d=degree
           
#     if farh!=0:
#         degree_cel=int((farh - 32) * 5/9)
#         val_d.set(degree_cel)
#         degree_kel=int((farh - 32) * 5/9 + 273.15 )
#         val_k.set(degree_kel)
        
#         if old_f!=farh:
#             degree_cel=int((farh - 32) * 5/9)
#             val_d.set(degree_cel)
#             degree_kel=int((farh - 32) * 5/9 + 273.15 )
#             val_k.set(degree_kel)
#         old_f=farh
   
#     if kelvin!=0:
#         degree_celc=int(kelvin - 273.15)
#         val_d.set(degree_celc)
#         degree_fa=int((kelvin - 273.15) * 9/5 + 32)
#         val_f.set(degree_fa)
#         if old_k!=kelvin:
#             degree_celc=int(kelvin - 273.15)
#             val_d.set(degree_celc)
#             degree_fa=int((kelvin - 273.15) * 9/5 + 32)
#             val_f.set(degree_fa)
#         old_k=kelvin
   
       
   
def reset():
    val_f.set(0)
    val_d.set(0)
    val_k.set(0)
   
val_f=IntVar()
val_f.set(0)

val_d=IntVar()
val_d.set(0)

val_k=IntVar()
val_k.set(0)

root.title("Temperature Converter")
root.geometry('400x625')

topframe=Frame(root,height=100,width=400,bg='gainsboro',relief=RIDGE,bd=10)
topframe.grid(row=0,column=1)

text=Label(topframe,text='Welcome to Temperature Converter',
          font=('ariel',15,'bold'))
text.grid(row=0,column=0)

middleFrame=Frame(root,height=600,width=400,bg='lightsteelblue',relief=RIDGE,bd=10)
middleFrame.grid(row=1,column=1)

bottomframe=Frame(root,height=100,width=400,bg='white',relief=RIDGE,bd=10)
bottomframe.grid(row=2,column=1)

entry1=Entry(middleFrame,width=10,font=('arial',30,'bold'),bd=30,justify=CENTER,textvariable=val_d)
entry1.grid(row=0,column=0)

text1=Label(middleFrame,text='Degree👆',font=('Comic Sans MS',20,'bold'))
text1.grid(row=1,column=0)

entry2=Entry(middleFrame,width=10,font=('arial',30,'bold'),bd=30,justify=CENTER,textvariable=val_f)
entry2.grid(row=2,column=0)

text2=Label(middleFrame,text="Fahrenheit👆",font=('Comic Sans MS',20,'bold'))
text2.grid(row=3,column=0)

entry3=Entry(middleFrame,width=10,font=('ariel',30,'bold'),bd=30,justify=CENTER,textvariable=val_k)
entry3.grid(row=4,column=0)

text3=Label(middleFrame,text="Kelvin👆",font=('Comic Sans MS',20,'bold'))
text3.grid(row=5,column=0)

button1=Button(bottomframe,width=7,height=1,text='convert',font=('Comic Sans MS',20,'bold'),command=Convert)
button1.grid(row=0,column=1)

button2=Button(bottomframe,width=7,height=1,text='reset',font=('Comic Sans MS',20,'bold'),command=reset)
button2.grid(row=0,column=2)
root.mainloop()
