# %%
import tkinter.messagebox
from tkinter import *
root=Tk()
root.geometry("1300x750")
root.title('Tic Tac Toe')
root.configure(background='royal blue')



Tops=Frame(root,bg='Cadet Blue',pady=2,width=1300,height=100,relief=RIDGE)
Tops.grid(row=0,column=0)

lblTitle=Label(Tops,text='Tic Tac Toe',justify=CENTER,
              bd=21 ,bg='royalblue',fg='Cornsilk',
              font=('arial',50,'bold'))
lblTitle.grid(row=0,column=0)

Mainframe=Frame(root,bg='Powder Blue',bd=10,width=1350,height=600,relief=RIDGE)
Mainframe.grid(row=1,column=0)

LeftFrame=Frame(Mainframe,bg='Cadet Blue',
                bd=10,width=750,height=500,relief=RIDGE,
               pady=2,padx=10
               )
LeftFrame.pack(side=LEFT)

RightFrame=Frame(Mainframe,bg='Cadet Blue',
                bd=10,width=560,height=500,relief=RIDGE,
               pady=2,padx=10
               )
RightFrame.pack(side=RIGHT)

RightFrame1=Frame(RightFrame,bg='Powder Blue',
                  
                  bd=10,width=560,height=200,relief=RIDGE)
RightFrame1.grid(row=0,column=0)

RightFrame2=Frame(RightFrame,bg='Powder Blue',bd=10,
                  
                  width=560,height=200,relief=RIDGE)
RightFrame2.grid(row=1,column=0)

PlayerX=IntVar()
PlayerO=IntVar()

PlayerX.set(0)
PlayerO.set(0)

buttom1=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom1)
              )
buttom1.grid(row=1,column=0)

buttom2=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom2)
              )
buttom2.grid(row=1,column=1)


buttom3=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom3)
              )
buttom3.grid(row=1,column=2)

buttom4=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom4)
              )
buttom4.grid(row=2,column=0)

buttom5=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom5)
              )
buttom5.grid(row=2,column=1)


buttom6=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom6)
              )
buttom6.grid(row=2,column=2)

buttom7=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom7)
              )
buttom7.grid(row=3,column=0)

buttom8=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom8)
              )
buttom8.grid(row=3,column=1)
    

buttom9=Button(LeftFrame,text=" ",font=('Times 26 bold'),
              height=3,
              width=8,
              bg='gainsboro',command=lambda: checker(buttom9)
              )
buttom9.grid(row=3,column=2)

lbl=Label(RightFrame1,text='Player O: ',font=('ariel',40,'bold'),bg='Cadet Blue',
         padx=2,pady=2)
lbl.grid(row=0,column=0,sticky=W)
lbl=Label(RightFrame1,text='Player X: ',font=('ariel',40,'bold'),bg='Cadet Blue',
         padx=2,pady=2)
lbl.grid(row=1,column=0,sticky=W+E)

txtPlayerO=Entry(RightFrame1,justify=CENTER,
                font=('ariel',40,'bold'),
                 bd=2,fg='black',
                 width=13,
                 textvariable=PlayerO
                ).grid(row=0,column=1)
txtPlayerX=Entry(RightFrame1,justify=CENTER,
                font=('ariel',40,'bold'),
                 bd=2,fg='black',
                 width=13,textvariable=PlayerX
                ).grid(row=1,column=1)


buttonReset=Button(RightFrame2,text='Reset',font=('ariel',26,'bold'),
                  height=2,width=29,bg='gainsboro',
                   command=reset
                  
                  ).grid(row=2,column=0, padx=6,pady=11)

buttonNewgame=Button(RightFrame2,text='New Game',font=('ariel',26,'bold'),
                  height=2,width=29,bg='gainsboro',
                    command=newgame
                  ).grid(row=3,column=0,padx=6,pady=10)

Bottom=Frame(root,bg='royal Blue',pady=2,width=1300,height=100,relief=RIDGE)
Bottom.grid(row=2,column=0)

lblTitle=Label(Bottom,text='By: Rishav Paudel',justify=CENTER,
              bd=21 ,bg='royalBlue',fg='Cornsilk',
              font=('arial',30,'bold'))
lblTitle.grid(row=0,column=0)

# Main code:

# buttons=StringVar()
click=True

def checker(buttons):
    global click
    if buttons["text"]==" " and click==True:
        buttons['text']='X'
        click=False
        scorekeeper()
    elif buttons["text"]==" " and click==False:
        buttons['text']='O'
        click=True
        scorekeeper()
        
        
def reset():
    buttom1['text']=" "
    buttom2['text']=" "
    buttom3['text']=" "
    buttom4['text']=" "
    buttom5['text']=" "
    buttom6['text']=" "
    buttom7['text']=" "
    buttom8['text']=" "
    buttom9['text']=" "
    
    buttom1.configure(background='gainsboro')
    buttom2.configure(background='gainsboro')
    buttom3.configure(background='gainsboro')
    buttom4.configure(background='gainsboro')
    buttom5.configure(background='gainsboro')
    buttom6.configure(background='gainsboro')
    buttom7.configure(background='gainsboro')
    buttom8.configure(background='gainsboro')
    buttom9.configure(background='gainsboro')
    
def newgame():
    reset()
    PlayerX.set(0)
    PlayerO.set(0)

    
def scorekeeper():
    if(buttom1['text']=='X' and buttom2['text']=='X' and buttom3['text']=='X'):
        buttom1.configure(background='powder blue')
        buttom2.configure(background='powder blue')
        buttom3.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    
    if(buttom4['text']=='X' and buttom5['text']=='X' and buttom6['text']=='X'):
        buttom4.configure(background='powder blue')
        buttom5.configure(background='powder blue')
        buttom6.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom7['text']=='X' and buttom8['text']=='X' and buttom9['text']=='X'):
        buttom7.configure(background='powder blue')
        buttom8.configure(background='powder blue')
        buttom9.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom1['text']=='X' and buttom4['text']=='X' and buttom7['text']=='X'):
        buttom1.configure(background='powder blue')
        buttom4.configure(background='powder blue')
        buttom7.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom2['text']=='X' and buttom5['text']=='X' and buttom8['text']=='X'):
        buttom2.configure(background='powder blue')
        buttom5.configure(background='powder blue')
        buttom8.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom3['text']=='X' and buttom6['text']=='X' and buttom9['text']=='X'):
        buttom3.configure(background='powder blue')
        buttom6.configure(background='powder blue')
        buttom9.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom1['text']=='X' and buttom5['text']=='X' and buttom9['text']=='X'):
        buttom1.configure(background='powder blue')
        buttom5.configure(background='powder blue')
        buttom9.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
    if(buttom3['text']=='X' and buttom5['text']=='X' and buttom7['text']=='X'):
        buttom3.configure(background='powder blue')
        buttom5.configure(background='powder blue')
        buttom7.configure(background='powder blue')
        n=int(PlayerX.get())
        score=n+1
        PlayerX.set(score)
        tkinter.messagebox.showinfo('Winner X','You have just won a game')
   #_____________________________Button O________________________________________

    if(buttom1['text']=='O' and buttom2['text']=='O' and buttom3['text']=='O'):
        buttom1.configure(background='red')
        buttom2.configure(background='red')
        buttom3.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom4['text']=='O' and buttom5['text']=='O' and buttom6['text']=='O'):
        buttom4.configure(background='red')
        buttom5.configure(background='red')
        buttom6.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
        
    if(buttom7['text']=='O' and buttom8['text']=='O' and buttom9['text']=='O'):
        buttom7.configure(background='red')
        buttom8.configure(background='red')
        buttom9.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom1['text']=='O' and buttom4['text']=='O' and buttom7['text']=='O'):
        buttom1.configure(background='red')
        buttom4.configure(background='red')
        buttom7.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom2['text']=='O' and buttom5['text']=='O' and buttom8['text']=='O'):
        buttom2.configure(background='red')
        buttom5.configure(background='red')
        buttom8.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom3['text']=='O' and buttom6['text']=='O' and buttom9['text']=='O'):
        buttom3.configure(background='red')
        buttom6.configure(background='red')
        buttom9.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom1['text']=='O' and buttom5['text']=='O' and buttom9['text']=='O'):
        buttom1.configure(background='red')
        buttom5.configure(background='red')
        buttom9.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    if(buttom3['text']=='O' and buttom5['text']=='O' and buttom7['text']=='O'):
        buttom3.configure(background='red')
        buttom5.configure(background='red')
        buttom7.configure(background='red')
        n=int(PlayerO.get())
        score=n+1
        PlayerO.set(score)
        tkinter.messagebox.showinfo('Winner O','You have just won a game')
    
    
    
root.mainloop()
