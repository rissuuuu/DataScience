# %%
import matplotlib.pyplot as pl
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random

df=pd.read_csv("trainnew.csv")
reg=linear_model.LinearRegression()
df=df.drop(columns={"Unnamed: 0"})
x=pd.DataFrame(df.iloc[:,:-1])
y=pd.DataFrame(df.iloc[:,-1])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print("The shapes or train test",x_train.shape,x_test.shape,y_train.shape,y_test.shape)
reg.fit(x_train,y_train)

# reg.fit(df[["class","area","lotfrontage","quality","year_built","living_area","garage_area","year_sold"]],df["price"])
# print(x_train.size,x_test.size,y_train.size,y_test.size)
predicted=1

coef=[i for i in reg.coef_]
print(coef)
    
intercept=pd.DataFrame(coef)
print("Prediction",reg.predict([[20,9600,80,6,1976,1262,460,2007]]))
finaldf=pd.DataFrame({"before":df["price"],
                      })
# Out:
# The shapes or train test (1168, 8) (292, 8) (1168, 1) (292, 1)
# [array([-2.09862123e+02,  7.20185278e-01,  6.03718537e+01,  2.21767546e+04,
#         4.32805577e+02,  5.81422540e+01,  5.16150249e+01,  2.05079096e+02])]
# Prediction [[172886.81643269]]

# %%
pl.figure(figsize=(15,7))
pl.scatter(df["garage_area"],df["price"])
pl.show()

# %%
pl.figure(figsize=(15,7))

pl.bar(df["garage_area"],df["price"])
pl.show()
