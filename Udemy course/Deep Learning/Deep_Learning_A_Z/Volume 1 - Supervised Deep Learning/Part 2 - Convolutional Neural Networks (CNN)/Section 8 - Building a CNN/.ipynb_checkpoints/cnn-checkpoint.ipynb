# %%
import keras
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator

from keras.backend.tensorflow_backend import set_session
import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
classifier=Sequential()

# %%
classifier.add(Convolution2D(32,3,3,
                  input_shape=(64,64,3),
                    activation='relu'))
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(64, 64, 3..., activation="relu")`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
classifier.add(Convolution2D(32,3,3,activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(output_dim=128,
                    activation='relu'))
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`

# %%
classifier.add(Dense(output_dim=1,
                    activation='sigmoid'))
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`

# %%
classifier.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
        'dataset/training_set/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 459 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
        'dataset/test_set/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 121 images belonging to 2 classes.

# %%
classifier.fit_generator(
        training_set,
        steps_per_epoch=459,
        epochs=25,
        validation_data=test_set,
        validation_steps=121)
# Out:
# Epoch 1/25
# 459/459 [==============================] - 834s 2s/step - loss: 0.2303 - accuracy: 0.9077 - val_loss: 2.3813 - val_accuracy: 0.5866
# Epoch 2/25
# 459/459 [==============================] - 822s 2s/step - loss: 0.0471 - accuracy: 0.9837 - val_loss: 2.7985 - val_accuracy: 0.6131
# Epoch 3/25
# 459/459 [==============================] - 810s 2s/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 1.9407 - val_accuracy: 0.6425
# Epoch 4/25
# 459/459 [==============================] - 805s 2s/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 1.8225 - val_accuracy: 0.6785
# Epoch 5/25
# 459/459 [==============================] - 821s 2s/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 2.3202 - val_accuracy: 0.5942
# Epoch 6/25
# 459/459 [==============================] - 844s 2s/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 2.7237 - val_accuracy: 0.6786
# Epoch 7/25
# 459/459 [==============================] - 848s 2s/step - loss: 5.8860e-04 - accuracy: 0.9999 - val_loss: 3.0965 - val_accuracy: 0.6371
# Epoch 8/25
# 459/459 [==============================] - 865s 2s/step - loss: 1.3716e-04 - accuracy: 1.0000 - val_loss: 4.6428 - val_accuracy: 0.6276
# Epoch 9/25
# 459/459 [==============================] - 834s 2s/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 4.4275 - val_accuracy: 0.6029
# Epoch 10/25
# 459/459 [==============================] - 804s 2s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 2.4246 - val_accuracy: 0.5860
# Epoch 11/25
# 459/459 [==============================] - 838s 2s/step - loss: 7.5193e-04 - accuracy: 0.9999 - val_loss: 5.3011 - val_accuracy: 0.6210
# Epoch 12/25
# 459/459 [==============================] - 841s 2s/step - loss: 1.0499e-04 - accuracy: 1.0000 - val_loss: 5.9121 - val_accuracy: 0.6115
# Epoch 13/25
# 459/459 [==============================] - 838s 2s/step - loss: 3.5624e-05 - accuracy: 1.0000 - val_loss: 6.0844 - val_accuracy: 0.6109
# Epoch 14/25
# 459/459 [==============================] - 868s 2s/step - loss: 2.4354e-05 - accuracy: 1.0000 - val_loss: 4.8608 - val_accuracy: 0.6133
# Epoch 15/25
# 459/459 [==============================] - 863s 2s/step - loss: 1.3054e-05 - accuracy: 1.0000 - val_loss: 6.4298 - val_accuracy: 0.6341
# Epoch 16/25
# 459/459 [==============================] - 854s 2s/step - loss: 0.0229 - accuracy: 0.9923 - val_loss: 2.2837 - val_accuracy: 0.6460
# Epoch 17/25
# 459/459 [==============================] - 866s 2s/step - loss: 5.6090e-04 - accuracy: 0.9999 - val_loss: 4.0615 - val_accuracy: 0.6365
# Epoch 18/25
# 459/459 [==============================] - 899s 2s/step - loss: 6.9096e-05 - accuracy: 1.0000 - val_loss: 6.4600 - val_accuracy: 0.6262
# Epoch 19/25
# 459/459 [==============================] - 979s 2s/step - loss: 3.9377e-05 - accuracy: 1.0000 - val_loss: 4.4551 - val_accuracy: 0.6300
# Epoch 20/25
# 459/459 [==============================] - 846s 2s/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 2.7473 - val_accuracy: 0.6194
# Epoch 21/25
# 459/459 [==============================] - 835s 2s/step - loss: 7.6241e-04 - accuracy: 0.9998 - val_loss: 4.0712 - val_accuracy: 0.6532
# Epoch 22/25
# 459/459 [==============================] - 841s 2s/step - loss: 7.6026e-05 - accuracy: 1.0000 - val_loss: 5.1719 - val_accuracy: 0.6106
# Epoch 23/25
# 459/459 [==============================] - 887s 2s/step - loss: 2.6061e-05 - accuracy: 1.0000 - val_loss: 6.1188 - val_accuracy: 0.6292
# Epoch 24/25
# 459/459 [==============================] - 807s 2s/step - loss: 1.2462e-05 - accuracy: 1.0000 - val_loss: 7.8596 - val_accuracy: 0.6197
# Epoch 25/25
# 459/459 [==============================] - 809s 2s/step - loss: 7.3228e-06 - accuracy: 1.0000 - val_loss: 3.8163 - val_accuracy: 0.6199

# %%
import numpy as np
from keras.preprocessing import image

# %%
test_image1=image.load_img('dataset/single_prediction/cat_or_dog_1.jpg',target_size=(64,64))
test_image2=image.load_img('dataset/single_prediction/cat_or_dog_2.jpg',target_size=(64,64))
test_image1
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x25119074088>

# %%
test_image2
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x25108C68808>

# %%
test_image1=image.img_to_array(test_image1)
test_image2=image.img_to_array(test_image2)

# %%
test_image1=np.expand_dims(test_image1,axis=0)
test_image2=np.expand_dims(test_image2,axis=0)

# %%
training_set.class_indices
# Out:
# {'nisu': 0, 'risu': 1}

# %%
prediction=classifier.predict(test_image2)
if prediction[0,0]==1:
    prediction='risu'
else:
    prediction='nisu'
prediction
# Out:
# 'risu'
