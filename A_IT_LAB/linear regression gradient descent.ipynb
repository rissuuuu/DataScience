# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as pl
import numpy as np 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
x,y=make_regression(n_samples=1000,n_features=1,noise=10)
pl.figure(figsize=(10,7))
pl.scatter(x,y,c=y)
pl.show()

# %%
# df=pd.read_csv("brain.csv")
# x=np.array(df["wt"],dtype='float')
# y=np.array(df["size"],dtype='float')
# pl.scatter(x,y)

# %%
m=0
c=0
L=0.01
reps=1000
n=len(x)
x=x.flatten()
err=[]
for i in range(reps):
    y_pred=m*x+c
    d_m=(-2/n)*sum(x*(y-y_pred))
    d_c=(-2/n)*sum(y-y_pred)
    m=m-L*d_m
    c=c-L*d_c
    er=np.mean(np.square(y-y_pred))
    err.append(er)
print(m,c)
# Out:
# 16.02574460651566 0.46588781108690275

# %%
# # x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01)
# pl.figure(figsize=(10,8))
# reg=LinearRegression()
# x=x.reshape(-1,1)
# y=y.reshape(-1,1)
# # x_test=x_test.reshape(-1,1)
# # y_test=y_test.reshape(-1,1)
# reg.fit(x,y)
# y_pred=reg.predict(x)
# pl.plot(x,y_pred,c="black")
# pl.scatter(x,y,c='r')
# print(reg.coef_,reg.intercept_)

# %%
pl.figure(figsize=(10,7))
y_pred=m*x+c
pl.scatter(x,y,c=y)
pl.plot(x,m*x*1.2+c,c="r")
pl.show()

# %%
pl.plot(err)
pl.grid()
pl.show()
