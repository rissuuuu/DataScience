# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
x,y=make_regression(n_samples=1000,n_features=3,noise=10)
df=pd.DataFrame(x)
df["Target"]=pd.DataFrame(y)

# %%
dff=df.rename(columns={0:"A",
                      1:"B",
                      2:"C"})
dff
# Out:
#             A         B         C      Target
# 0   -0.836277  1.382798  0.799529   88.090937
# 1   -0.202237  0.142421  1.060660   55.195340
# 2    0.612617  0.637432 -1.070451   22.277356
# 3    0.113285 -1.795593 -0.724554 -153.182534
# 4    0.574114 -0.543530  0.555123    6.085289
# ..        ...       ...       ...         ...
# 995 -1.286009 -1.768480  0.114006 -164.562709
# 996  1.189917  0.474081  0.386550  121.298957
# 997 -0.243606 -1.119643  0.691644  -46.860020
# 998 -0.229172 -1.764344 -0.704321 -175.693238
# 999  0.006803  1.217517  1.389505  167.467711
#
# [1000 rows x 4 columns]

# %%
pl.figure(figsize=(15,8))
for i in range(3):
    pl.scatter(dff.iloc[:,i],dff["Target"])
print(x.shape)
y=y.reshape(-1,1)
print(y.shape)
# Out:
# (1000, 3)
# (1000, 1)

# %%
m=np.zeros(3).reshape(-1,1)
c=0
L=0.01
reps=1000
n=1000
error=[]
d_m=[0,0,0]
d_c=0
for i in range(reps):
    y_pred=np.dot(x,m)+c
    d_m=(-2/n)*np.sum((y-y_pred)*x,axis=0).reshape(-1,1)
    d_c=(-2/n)*sum(y-y_pred)
    m=m-L*d_m
    c=c-L*d_c
    er=np.mean(np.square(y-y_pred))
    error.append(er)
print(m,c)
# Out:
# [[52.34771365]
#  [65.64134369]
#  [55.6813534 ]] [0.09743761]

# %%
pl.plot(error)
