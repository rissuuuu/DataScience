# %%
import matplotlib.pyplot as pl
import numpy as np
pl.style.use('classic')

# %%
x=np.linspace(0,10,1000)
I=np.sin(x)*np.cos(x[:,np.newaxis])
pl.imshow(I)

# %%
y=x[:,np.newaxis]
y.shape
# Out:
# (1000, 1)

# %%
x.shape
# Out:
# (1000,)

# %%
z=x*y

# %%
z.shape
# Out:
# (1000, 1000)

# %%
pl.plot(z)
pl.show()

# %%
pl.imshow(z)

# %%
pl.imshow(I)

# %%
z=np.sin(x)+np.cos(y)
z.shape
pl.imshow(z)

# %%
pl.plot(I)
pl.show()

# %%
x=np.random.randn(100,100)

pl.imshow(np.sin(x)+np.cos(x))

# %%
pl.imshow(I,cmap='gray')
