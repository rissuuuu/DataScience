# %%
import numpy as np
import matplotlib.pyplot as pl
fig,axes=pl.subplots()
lines=[]
styles=['-','--','-.',':']
x=np.linspace(0,10,1000)
for i in range(4):
    lines+=axes.plot(x,np.sin(x-i*np.pi/2),styles[i],color='black')
axes.axis('equal')
# Out:
# (-0.5, 10.5, -1.1, 1.1)
