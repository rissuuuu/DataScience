# %%
import pandas as pd
df=pd.read_csv("prec_h.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
# order         42 non-null int64
# name          42 non-null object
# height(cm)    42 non-null int64
# Unnamed: 3    0 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.2+ KB
#     order                    name  height(cm)  Unnamed: 3
# 0       1       George Washington         189         NaN
# 1       2              John Adams         170         NaN
# 2       3        Thomas Jefferson         189         NaN
# 3       4           James Madison         163         NaN
# 4       5            James Monroe         183         NaN
# 5       6       John Quincy Adams         171         NaN
# 6       7          Andrew Jackson         185         NaN
# 7       8        Martin Van Buren         168         NaN
# 8       9  William Henry Harrison         173         NaN
# 9      10              John Tyler         183         NaN
# ...

# %%
df.head()
df=df.drop(columns={"Unnamed: 3"})
df
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %%
import matplotlib.pyplot as pl
import seaborn as sns
import numpy as np
pl.figure(figsize=(8,15))
pl.grid()
pl.barh(list(df["name"]),list(df["height(cm)"]))
# Out:
# <BarContainer object of 42 artists>

# %%
pl.figure(figsize=(15,8))
pl.grid()
sns.countplot(x="height(cm)",data=df)

# %%
heights=np.array(df["height(cm)"])
heights
# Out:
# array([189, 170, 189, 163, 183, 171, 185, 168, 173, 183, 173, 173, 175,
#        178, 183, 193, 178, 173, 174, 183, 183, 168, 170, 178, 182, 180,
#        183, 178, 182, 188, 175, 179, 183, 193, 182, 183, 177, 185, 188,
#        188, 182, 185], dtype=int64)

# %%
print(np.mean(heights))
print(np.median(heights))
print(np.std(heights))
print(np.corrcoef(heights))
print(np.max(heights))
print(np.min(heights))
# Out:
# 179.73809523809524
# 182.0
# 6.931843442745892
# 1.0
# 193
# 163

# %%
print(np.percentile(heights,100))
pl.hist(heights)
# Out:
# 193.0
# (array([ 1.,  2.,  3.,  5.,  3.,  6., 12.,  3.,  5.,  2.]),
#  array([163., 166., 169., 172., 175., 178., 181., 184., 187., 190., 193.]),
#  <a list of 10 Patch objects>)

# %%
a=np.array([0,1,2])
b=np.array([5,5,5])
a+b
# Out:
# array([5, 6, 7])

# %%
a+10
# Out:
# array([10, 11, 12])

# %%
m=np.full((3,3),10)
m+np.full((3,3),15)
# Out:
# array([[25, 25, 25],
#        [25, 25, 25],
#        [25, 25, 25]])

# %%
a=np.full((3,1),5)
a+np.arange(3)
# Out:
# array([[5, 6, 7],
#        [5, 6, 7],
#        [5, 6, 7]])

# %%
a=np.arange(100,120)
print(np.mean(a))
a.mean()
# Out:
# 109.5
# 109.5

# %%
heights=pd.Series(df["height(cm)"])
heights.value_counts()
# Out:
# 183    8
# 173    4
# 182    4
# 178    4
# 185    3
# 188    3
# 189    2
# 168    2
# 170    2
# 193    2
# 175    2
# 174    1
# 171    1
# 179    1
# 180    1
# 163    1
# 177    1
# Name: height(cm), dtype: int64
