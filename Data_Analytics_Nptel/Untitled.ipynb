# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.randint(1,4,(8,4)),columns={'a','b','c','d'})

# %%
df
# Out:
#    d  b  a  c
# 0  1  2  3  1
# 1  2  2  3  2
# 2  2  3  1  2
# 3  3  1  1  1
# 4  2  3  3  2
# 5  1  1  2  3
# 6  2  3  1  3
# 7  3  2  1  2

# %%
df.iloc[:,[1,3]]
# Out:
#    b  c
# 0  2  1
# 1  2  2
# 2  3  2
# 3  1  1
# 4  3  2
# 5  1  3
# 6  3  3
# 7  2  2

# %%
df.loc[:,['a','d']]
# Out:
#    a  d
# 0  3  1
# 1  3  2
# 2  1  2
# 3  1  3
# 4  3  2
# 5  2  1
# 6  1  2
# 7  1  3

# %%
df.iloc[[0,1,4,7],[1,3]]
# Out:
#    b  c
# 0  2  1
# 1  2  2
# 4  3  2
# 7  2  2

# %%
df
# Out:
#    d  b  a  c
# 0  1  2  3  1
# 1  2  2  3  2
# 2  2  3  1  2
# 3  3  1  1  1
# 4  2  3  3  2
# 5  1  1  2  3
# 6  2  3  1  3
# 7  3  2  1  2

# %%
df.groupby(['a','b'])['c'].nunique()
# Out:
# a  b
# 1  1    1
#    2    1
#    3    2
# 2  1    1
# 3  2    2
#    3    1
# Name: c, dtype: int64

# %%
df.corr()
# Out:
#           d         b         a         c
# d  1.000000  0.000000 -0.572078 -0.250000
# b  0.000000  1.000000  0.021592  0.226455
# a -0.572078  0.021592  1.000000 -0.190693
# c -0.250000  0.226455 -0.190693  1.000000

# %%
import matplotlib.pyplot as pl
pl.scatter(df.a,df.c)

# %%
df.pivot_table(columns='c',index=['a','b'],aggfunc='mean')
# Out:
#        d
# c      1    2    3
# a b
# 1 1  3.0  NaN  NaN
#   2  NaN  3.0  NaN
#   3  NaN  2.0  2.0
# 2 1  NaN  NaN  1.0
# 3 2  1.0  2.0  NaN
#   3  NaN  2.0  NaN
