# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.randint(1,4,(8,4)),columns={'a','b','c','d'})

# %%
df
# Out:
#    b  c  a  d
# 0  2  1  2  1
# 1  1  1  3  1
# 2  3  2  3  2
# 3  3  2  3  3
# 4  3  1  3  3
# 5  3  1  1  2
# 6  2  3  1  2
# 7  3  3  3  1

# %%
df.iloc[:,[1,3]]
# Out:
#    c  d
# 0  1  1
# 1  1  1
# 2  2  2
# 3  2  3
# 4  1  3
# 5  1  2
# 6  3  2
# 7  3  1

# %%
df.loc[:,['a','d']]
# Out:
#    a  d
# 0  2  1
# 1  3  1
# 2  3  2
# 3  3  3
# 4  3  3
# 5  1  2
# 6  1  2
# 7  3  1

# %%
df.iloc[[0,1,4,7],[1,3]]
# Out:
#    c  d
# 0  1  1
# 1  1  1
# 4  1  3
# 7  3  1

# %%
df
# Out:
#    b  c  a  d
# 0  2  1  2  1
# 1  1  1  3  1
# 2  3  2  3  2
# 3  3  2  3  3
# 4  3  1  3  3
# 5  3  1  1  2
# 6  2  3  1  2
# 7  3  3  3  1

# %%
df.groupby(['a','b'])['c'].nunique()
# Out:
# a  b
# 1  2    1
#    3    1
# 2  2    1
# 3  1    1
#    3    3
# Name: c, dtype: int64

# %%
df.corr()
# Out:
#           b         c         a         d
# b  1.000000  0.213201  0.103142  0.566139
# c  0.213201  1.000000 -0.043980 -0.048280
# a  0.103142 -0.043980  1.000000  0.070071
# d  0.566139 -0.048280  0.070071  1.000000

# %%
import matplotlib.pyplot as pl
pl.scatter(df.a,df.c)

# %%
df.pivot_table(columns='c',index=['a','b'],aggfunc='mean')
# Out:
#        d
# c      1    2    3
# a b
# 1 2  NaN  NaN  2.0
#   3  2.0  NaN  NaN
# 2 2  1.0  NaN  NaN
# 3 1  1.0  NaN  NaN
#   3  3.0  2.5  1.0
