# %%
import numpy as np
import matplotlib.pyplot as pl
from sklearn.datasets import make_blobs
X,y=make_blobs(n_samples=1000,n_features=2,centers=4,random_state=0)
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
y=y%2

# %%
pl.figure(figsize=(10,7))
pl.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y, random_state=0)
from sklearn.metrics import mean_squared_error

# %%
model=Sequential()
model.add(Dense(input_dim=2,units=20,activation='sigmoid'))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer=keras.optimizers.,loss=keras.losses.binary_crossentropy,metrics=['binary_crossentropy'])
# Out:
# WARNING:tensorflow:From C:\Users\rissu\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 20)                60
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 21
# ...
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
h=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10000)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/10000
# 750/750 [==============================] - 0s 196us/step - loss: 0.2137 - binary_crossentropy: 0.2137 - val_loss: 0.0449 - val_binary_crossentropy: 0.0449
# Epoch 2/10000
# 750/750 [==============================] - 0s 36us/step - loss: -0.1108 - binary_crossentropy: -0.1108 - val_loss: -0.2679 - val_binary_crossentropy: -0.2679
# Epoch 3/10000
# 750/750 [==============================] - 0s 29us/step - loss: -0.4134 - binary_crossentropy: -0.4134 - val_loss: -0.5596 - val_binary_crossentropy: -0.5596
# Epoch 4/10000
# 750/750 [==============================] - 0s 29us/step - loss: -0.7025 - binary_crossentropy: -0.7025 - val_loss: -0.8382 - val_binary_crossentropy: -0.8382
# Epoch 5/10000
# 750/750 [==============================] - 0s 31us/step - loss: -0.9850 - binary_crossentropy: -0.9850 - val_loss: -1.1071 - val_binary_crossentropy: -1.1071
# Epoch 6/10000
# ...

# %%
pl.plot(h.history['loss'])
