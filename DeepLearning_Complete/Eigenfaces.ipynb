# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as pl
from PIL import Image

# %%
a=Image.open('risu.jpg')

# %%
img=np.array(a)

# %%
img.shape
# Out:
# (1113, 1000, 3)

# %%
img2=img.copy()
img2=img2/255.

# %%
pl.imshow(img2)

# %%
# pca=PCA(n_components=100).fit_transform(img2)
