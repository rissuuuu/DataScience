# %%
import matplotlib.pyplot as pl
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([4,3,4,2,5])
print(np.mean(x),np.mean(y))
pl.figure(figsize=(10,5))
pl.title("Linear regression")
pl.xlabel("X Values")
pl.ylabel("Y Values")
pl.scatter(x,y,marker='o',color="r",)
pl.show()
# Out:
# 3.0 3.6
