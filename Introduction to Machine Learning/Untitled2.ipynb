# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs
import matplotlib.pyplot as pl

# %%
X,y=make_blobs(n_samples=1000,centers=5,cluster_std=2)
pl.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.cluster import hierarchical
