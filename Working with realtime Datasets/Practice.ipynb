# %%
import numpy as np
from sklearn.datasets import make_regression
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns
pl.rcParams['figure.figsize']=8,6

# %%
data=np.random.randn(100)
data2=np.random.randint(1,10,100)

# %%
sns.distplot(data2,bins=30)

# %%
X,y=make_regression(n_features=2,n_samples=1000)
pl.scatter(X[:,0],y)

# %%
df=pd.DataFrame(X[:,0],columns=["A","B"])
df
# Out:
#             A         B
# 0   -0.973917 -0.627518
# 1   -0.320189 -1.749370
# 2   -0.070601  0.067311
# 3    0.351622  0.320629
# 4   -0.831143 -0.970809
# ..        ...       ...
# 995  0.247120 -1.103185
# 996  0.844929  0.420631
# 997  0.121497 -0.906082
# 998  2.920797  0.069089
# 999 -0.721036  3.543505
#
# [1000 rows x 2 columns]

# %%
sns.lmplot(data=df,x='A',y='B')
