# %%
from textblob import TextBlob
words = ["Data Scence", "Mahine Learnin"]
corrected_words = []
for i in words:
    corrected_words.append(TextBlob(i))
print("Wrong words :", words)
print("Corrected Words are :")
for i in corrected_words:
    print(i.correct(), end=" ")
# Out:
# Wrong words : ['Data Scence', 'Mahine Learnin']
# Corrected Words are :
# Data Science Machine Learning

# %%
words = ["Mltiple", "Big buldin"]
corrected_words = []
for i in words:
    corrected_words.append(TextBlob(i))
print("Wrong words :", words)
print("Corrected Words are :")
for i in corrected_words:
    print(i.correct(), end=" ")
# Out:
# Wrong words : ['Mltiple', 'Big buldin']
# Corrected Words are :
# Multiple Fig building

# %%
import pandas as pd

# %%
data = [{'name':'Rishav','address':'Kathmandu','broker':1},{'name':'Rejina','address':'Duwakot','broker':2}]

# %%
data
# Out:
# [{'name': 'Rishav', 'address': 'Kathmandu', 'broker': 1},
#  {'name': 'Rejina', 'address': 'Duwakot', 'broker': 2}]

# %%
df = pd.DataFrame(data)
df['full'] = df['name']+df['address']
df
# Out:
#      name    address  broker             full
# 0  Rishav  Kathmandu       1  RishavKathmandu
# 1  Rejina    Duwakot       2    RejinaDuwakot

# %%
from fastapi.encoders import jsonable_encoder
import json

# %%
to_json = json.loads(df.to_json(orient = 'records'))
to_json
# Out:
# [{'name': 'Rishav', 'address': 'Kathmandu', 'full': 'RishavKathmandu'},
#  {'name': 'Rejina', 'address': 'Duwakot', 'full': 'RejinaDuwakot'}]

# %%
jsonable_encoder(df)
# Out:
# {'name': {0: 'Rishav', 1: 'Rejina'},
#  'address': {0: 'Kathmandu', 1: 'Duwakot'},
#  'full': {0: 'RishavKathmandu', 1: 'RejinaDuwakot'}}

# %%
df2 =pd.DataFrame([{'fame':'Rishav','address':'Kathmandu','broker':1},{'fame':'Rejina','address':'Duwakot','broker':2}])
df2
# Out:
#      fame    address  broker
# 0  Rishav  Kathmandu       1
# 1  Rejina    Duwakot       2

# %%
df3=pd.merge(df,df2,on = "broker")
df3
# Out:
#      name  address_x  broker             full    fame  address_y
# 0  Rishav  Kathmandu       1  RishavKathmandu  Rishav  Kathmandu
# 1  Rejina    Duwakot       2    RejinaDuwakot  Rejina    Duwakot

# %%
df3['broker']/sum(df3['broker'])
# Out:
# 0    0.333333
# 1    0.666667
# Name: broker, dtype: float64

# %%
500/1000
# Out:
# 0.5

# %%
data = [
  {
    "broker_number": 45,
    "hold_qty": 156900,
    "percent_weight": 5.5070022112,
    "trades": 7
  },
  {
    "broker_number": 49,
    "hold_qty": 128141,
    "percent_weight": 4.497595732,
    "trades": 5
  },
  {
    "broker_number": 53,
    "hold_qty": 94493,
    "percent_weight": 3.3165912042,
    "trades": 5
  },
  {
    "broker_number": 11,
    "hold_qty": 91098,
    "percent_weight": 3.1974307676,
    "trades": 4
  },
  {
    "broker_number": 41,
    "hold_qty": -72199,
    "percent_weight": -2.5340984872,
    "trades": 3
  },
  {
    "broker_number": 54,
    "hold_qty": -93908,
    "percent_weight": -3.2960584044,
    "trades": 5
  },
  {
    "broker_number": 14,
    "hold_qty": -137429,
    "percent_weight": -4.8235934155,
    "trades": 4
  },
  {
    "broker_number": 1,
    "hold_qty": -189676,
    "percent_weight": -6.6574005826,
    "trades": 8
  }
]

# %%
df_temp = pd.DataFrame(data)

# %%
df_temp.head()
# Out:
#    broker_number  hold_qty  percent_weight  trades
# 0             45    156900        5.507002       7
# 1             49    128141        4.497596       5
# 2             53     94493        3.316591       5
# 3             11     91098        3.197431       4
# 4             41     78339        2.749605       4

# %%
df_temp['hold_qty']/df_temp['hold_qty'].sum()
# Out:
# 0     5.507002
# 1     4.497596
# 2     3.316591
# 3     3.197431
# 4     2.749605
# 5     2.457969
# 6     2.431119
# 7     2.419255
# 8     1.826436
# 9     1.699730
# 10    1.204872
# 11    0.852410
# 12    0.791022
# 13    0.759468
# 14    0.589906
# 15    0.309466
# 16   -0.239304
# 17   -0.505317
# 18   -0.641115
# 19   -0.866133
# 20   -0.904321
# 21   -0.970692
# 22   -0.978941
# 23   -1.106244
# 24   -1.203713
# 25   -1.354673
# 26   -1.378435
# 27   -1.378435
# 28   -2.297638
# 29   -2.473764
# 30   -2.534098
# 31   -3.296058
# 32   -4.823593
# 33   -6.657401
# Name: hold_qty, dtype: float64

# %%
df_temp.to_dict(orient="records")
# Out:
# [{'broker_number': 45,
#   'hold_qty': 156900,
#   'percent_weight': 5.5070022112,
#   'trades': 7},
#  {'broker_number': 49,
#   'hold_qty': 128141,
#   'percent_weight': 4.497595732,
#   'trades': 5},
#  {'broker_number': 53,
#   'hold_qty': 94493,
#   'percent_weight': 3.3165912042,
#   'trades': 5},
#  {'broker_number': 11,
#   'hold_qty': 91098,
#   'percent_weight': 3.1974307676,
#   'trades': 4},
#  {'broker_number': 41,
#   'hold_qty': 78339,
#   'percent_weight': 2.7496051385,
#   'trades': 4},
#  {'broker_number': 8,
#   'hold_qty': 70030,
#   'percent_weight': 2.4579691833,
#   'trades': 4},
#  {'broker_number': 20,
#   'hold_qty': 69265,
#   'percent_weight': 2.4311185989,
#   'trades': 3},
#  {'broker_number': 3,
#   'hold_qty': 68927,
#   'percent_weight': 2.4192552034,
#   'trades': 6},
#  {'broker_number': 46,
#   'hold_qty': 52037,
#   'percent_weight': 1.8264364185,
#   'trades': 2},
#  {'broker_number': 28,
#   'hold_qty': 48427,
# ...

# %%
holdings = [{
      "broker_number": 57,
      "hold_qty": 622084,
      "percent_weight": 0,
      "trades": 35
    },
    {
      "broker_number": 23,
      "hold_qty": 605524,
      "percent_weight": 0,
      "trades": 41
    },
    {
      "broker_number": 4,
      "hold_qty": 576742,
      "percent_weight": 0,
      "trades": 43
    },
    {
      "broker_number":