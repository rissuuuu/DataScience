# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

# %%
letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
company_symbol = [''.join(np.random.choice(letters,5)) for i in range(20)]

# %%
df = pd.DataFrame({
    'contract no':np.random.randint(111111,999999,(10000)),
    'stock_symbol':np.random.choice(company_symbol,10000),
    'buyer_broker':np.random.randint(1,20,10000),
    'seller_broker':np.random.randint(1,20,10000),
    'quantity':np.random.randint(50,1000,10000),
    'rate':np.random.randint(100,10000,10000),
    'date':[f"20{k}-{i}-{j}" for k in range(10,50) for i in range(1,11) for j in range(1,29)][:10000]
}).reset_index().rename(columns={'index':'sn'})

# %%
df["amount"] = df["quantity"]* df["rate"]
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 0   0       626111        LMUGK            17             10       542  2671
# 1   1       521341        EZVEP            15              6       290  4921
# 2   2       147902        IZZKO             8             18       684  7231
# 3   3       359109        IZZKO            19              8       730  2205
# 4   4       407936        LRZRD             3              2       391  1241
#
#         date   amount
# 0 2010-01-01  1447682
# 1 2010-01-02  1427090
# 2 2010-01-03  4946004
# 3 2010-01-04  1609650
# 4 2010-01-05   485231

# %%
df.tail()
# Out:
#         sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 9995  9995       850457        XOEDI             2              9       311
# 9996  9996       112074        LMUGK             6              1       793
# 9997  9997       900533        PHFQN             4              1       881
# 9998  9998       229902        MZKAP            14              9       703
# 9999  9999       409035        YSKQR             2              6       395
#
#       rate       date   amount
# 9995  7668 2045-07-28  2384748
# 9996  6659 2045-08-01  5280587
# 9997  3763 2045-08-02  3315203
# 9998  2854 2045-08-03  2006362
# 9999  5616 2045-08-04  2218320

# %% [markdown]
# # Single Broker Details

# %%
df[df['buyer_broker']==1].head(10)
# Out:
#       sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 14    14       222102        EXYFX             1             18       870
# 16    16       243871        LMUGK             1              5       680
# 27    27       945375        YSKQR             1             17       780
# 38    38       331989        CGBQM             1              4       845
# 46    46       344303        OCKSB             1              2       448
# 89    89       564683        LMUGK             1             16       617
# 107  107       923540        DUGQO             1             15       818
# 146  146       283835        CGBQM             1              3       421
# 174  174       501324        LRZRD             1             14       758
# 198  198       111163        MZKAP             1              9       122
#
#      rate       date   amount
# 14   3806 2010-01-15  3311220
# 16   7708 2010-01-17  5241440
# 27   9383 2010-01-28  7318740
# 38   1063 2010-02-11   898235
# 46   5352 2010-02-19  2397696
# 89   4720 2010-04-06  2912240
# 107  9067 2010-04-24  7416806
# 146  3824 2010-06-07  1609904
# 174  4874 2010-07-07  3694492
# 198  3118 2010-08-03   380396

# %%
df[df['buyer_broker']==2].head(10)
# Out:
#       sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 9      9       211765        EXYFX             2             10       242
# 34    34       477874        PHFQN             2             11       588
# 75    75       591782        NFZWQ             2              4       447
# 76    76       153356        YSKQR             2              1       121
# 95    95       667830        MXVDF             2             12       444
# 103  103       680858        LMUGK             2              9       179
# 104  104       364983        MZKAP             2              5       256
# 112  112       807851        EXYFX             2              9       908
# 161  161       596833        NFZWQ             2              4       347
# 185  185       547356        EXYFX             2             11       151
#
#      rate       date   amount
# 9    9780 2010-01-10  2366760
# 34   3797 2010-02-07  2232636
# 75   4383 2010-03-20  1959201
# 76    300 2010-03-21    36300
# 95   6844 2010-04-12  3038736
# 103  2334 2010-04-20   417786
# 104  8168 2010-04-21  2091008
# 112   337 2010-05-01   305996
# 161  9466 2010-06-22  3284702
# 185  7057 2010-07-18  1065607

# %% [markdown]
# # data between date ranges

# %%
year_range = df[(df['date']>'2010-01-04')&(df['date']<'2011-01-04')]
year_range.head(10)
# Out:
#     sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 4    4       407936        LRZRD             3              2       391  1241
# 5    5       455794        IZZKO            17              3       584  4007
# 6    6       634675        PAVBA             8              1       134   207
# 7    7       989813        LRZRD            13              1       537  5634
# 8    8       636531        LMUGK             4              4       893  5773
# 9    9       211765        EXYFX             2             10       242  9780
# 10  10       179666        XOEDI             8              3       882  5493
# 11  11       638288        LMUGK             5             16       588  3392
# 12  12       703491        CGBQM            13             12       488  3795
# 13  13       289008        IZZKO            16              6       202  1774
#
#          date   amount
# 4  2010-01-05   485231
# 5  2010-01-06  2340088
# 6  2010-01-07    27738
# 7  2010-01-08  3025458
# 8  2010-01-09  5155289
# 9  2010-01-10  2366760
# 10 2010-01-11  4844826
# 11 2010-01-12  1994496
# 12 2010-01-13  1851960
# 13 2010-01-14   358348

# %%
year_range.groupby(["buyer_broker"])["quantity"].sum().sort_values(ascending= False)
# Out:
# buyer_broker
# 16    14096
# 15    10545
# 5      9934
# 1      9852
# 12     9810
# 7      9724
# 13     8804
# 8      8343
# 6      8166
# 17     8138
# 11     8076
# 4      7204
# 18     7125
# 10     6792
# 2      6003
# 3      5739
# 9      5528
# 19     5431
# 14     3586
# Name: quantity, dtype: int32

# %% [markdown]
# ### Broker 17 was max stock buyer

# %%
year_range.groupby(["seller_broker"])["quantity"].sum().sort_values(ascending= False)
# Out:
# seller_broker
# 5     12948
# 6     12395
# 8     12382
# 9      9863
# 2      9166
# 3      8867
# 17     8013
# 10     7933
# 15     7752
# 19     7602
# 4      7268
# 12     7159
# 13     6931
# 14     6638
# 7      6452
# 1      6118
# 11     5828
# 16     5751
# 18     3830
# Name: quantity, dtype: int32

# %% [markdown]
# ### broker 5 was most stock seller

# %% [markdown]
# # Top buyer broker

# %%
df.groupby(["buyer_broker"])["amount"].sum().sort_values(ascending= False)
# Out:
# buyer_broker
# 1     1582878991
# 8     1511535262
# 16    1504048101
# 13    1451134411
# 19    1449389135
# 3     1432015869
# 12    1423485840
# 17    1406898076
# 6     1396097680
# 5     1391025232
# 10    1386869662
# 18    1380206813
# 7     1377473373
# 2     1375331695
# 11    1328149480
# 14    1327164945
# 15    1248954199
# 9     1238628052
# 4     1236790497
# Name: amount, dtype: int32

# %% [markdown]
# # top seller broker

# %%
df.groupby(["seller_broker"])["amount"].sum().sort_values(ascending= False)
# Out:
# seller_broker
# 14    1498288152
# 2     1485021283
# 3     1484389509
# 16    1468462542
# 4     1447755603
# 19    1439447869
# 15    1435099481
# 6     1428447403
# 11    1426038201
# 9     1418948135
# 17    1410422661
# 10    1406995817
# 13    1349972677
# 8     1345475017
# 12    1322194864
# 1     1284816019
# 7     1279302214
# 5     1278542205
# 18    1238457661
# Name: amount, dtype: int32

# %%
pl.figure(figsize=(15,7))
sns.countplot(x=df['stock_symbol'])
pl.show()

# %%
df.head()
# Out:
#    sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 0   0       626111        LMUGK            17             10       542  2671
# 1   1       521341        EZVEP            15              6       290  4921
# 2   2       147902        IZZKO             8             18       684  7231
# 3   3       359109        IZZKO            19              8       730  2205
# 4   4       407936        LRZRD             3              2       391  1241
#
#         date   amount
# 0 2010-01-01  1447682
# 1 2010-01-02  1427090
# 2 2010-01-03  4946004
# 3 2010-01-04  1609650
# 4 2010-01-05   485231

# %%
df.shape
# Out:
# (10000, 9)

# %%
df_buyer_= df[df['buyer_broker']>df['seller_broker']]
df_buyer_.head()
# Out:
#    sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 0   0       626111        LMUGK            17             10       542  2671
# 1   1       521341        EZVEP            15              6       290  4921
# 3   3       359109        IZZKO            19              8       730  2205
# 4   4       407936        LRZRD             3              2       391  1241
# 5   5       455794        IZZKO            17              3       584  4007
#
#         date   amount
# 0 2010-01-01  1447682
# 1 2010-01-02  1427090
# 3 2010-01-04  1609650
# 4 2010-01-05   485231
# 5 2010-01-06  2340088

# %% [markdown]
# # Top turnover

# %%
df_buyer_.groupby(['stock_symbol'])['amount'].sum().sort_values(ascending=False)
# Out:
# stock_symbol
# YSKQR    783986471
# LRZRD    719323618
# OCKSB    670189599
# LMUGK    669304371
# XOEDI    658789591
# IZZKO    653370627
# NFZWQ    632633053
# EXYFX    626771511
# PHFQN    618642751
# QQRER    611575080
# RVNGK    595792693
# EUFZE    594897210
# EZVEP    594260160
# PAVBA    585048883
# DUGQO    579769629
# CGBQM    573609949
# MXVDF    564564352
# MZKAP    545809743
# ALVNH    543429745
# TKHMS    538578463
# Name: amount, dtype: int32

# %%
df_seller_= df[df['seller_broker']>df['buyer_broker']]
df_seller_.head()
# Out:
#     sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 2    2       147902        IZZKO             8             18       684  7231
# 9    9       211765        EXYFX             2             10       242  9780
# 11  11       638288        LMUGK             5             16       588  3392
# 14  14       222102        EXYFX             1             18       870  3806
# 16  16       243871        LMUGK             1              5       680  7708
#
#          date   amount
# 2  2010-01-03  4946004
# 9  2010-01-10  2366760
# 11 2010-01-12  1994496
# 14 2010-01-15  3311220
# 16 2010-01-17  5241440

# %%
df_seller_.groupby(['stock_symbol'])['amount'].sum().sort_values(ascending=False)
# Out:
# stock_symbol
# DUGQO    768169386
# IZZKO    722158210
# YSKQR    705530547
# TKHMS    700488002
# PHFQN    697914150
# MZKAP    663239879
# EZVEP    654940085
# RVNGK    645371993
# LMUGK    633842290
# PAVBA    633606023
# EXYFX    631932566
# MXVDF    630431072
# NFZWQ    615913096
# CGBQM    596960301
# XOEDI    582242367
# ALVNH    579040989
# LRZRD    575886207
# QQRER    571142029
# OCKSB    539861708
# EUFZE    514433390
# Name: amount, dtype: int32

# %%
df.head()
# Out:
#    sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 0   0       626111        LMUGK            17             10       542  2671
# 1   1       521341        EZVEP            15              6       290  4921
# 2   2       147902        IZZKO             8             18       684  7231
# 3   3       359109        IZZKO            19              8       730  2205
# 4   4       407936        LRZRD             3              2       391  1241
#
#         date   amount
# 0 2010-01-01  1447682
# 1 2010-01-02  1427090
# 2 2010-01-03  4946004
# 3 2010-01-04  1609650
# 4 2010-01-05   485231

# %% [markdown]
# # Top buyer broker

# %%
df.groupby('buyer_broker')['quantity'].sum().sort_values(ascending=False)
# Out:
# buyer_broker
# 1     307369
# 8     296008
# 16    294154
# 13    289993
# 19    282837
# 3     281421
# 12    280652
# 17    275831
# 5     274232
# 7     272782
# 18    271580
# 11    271445
# 6     270703
# 10    269865
# 2     266340
# 14    257095
# 9     254298
# 15    247418
# 4     246181
# Name: quantity, dtype: int32

# %% [markdown]
# # topseller broker

# %%
df.groupby('seller_broker')['quantity'].sum().sort_values(ascending=False)
# Out:
# seller_broker
# 14    289105
# 6     287398
# 2     287192
# 3     286005
# 17    285252
# 4     284298
# 13    284268
# 16    284149
# 9     282842
# 10    281310
# 19    280543
# 15    271779
# 11    267048
# 12    266661
# 5     260802
# 7     258389
# 8     256655
# 1     248863
# 18    247645
# Name: quantity, dtype: int32
