# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

# %%
letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
company_symbol = [''.join(np.random.choice(letters,5)) for i in range(20)]

# %%
df = pd.DataFrame({
    'contract no':np.random.randint(111111,999999,(10000)),
    'stock_symbol':np.random.choice(company_symbol,10000),
    'buyer_broker':np.random.randint(1,20,10000),
    'seller_broker':np.random.randint(1,20,10000),
    'quantity':np.random.randint(50,1000,10000),
    'rate':np.random.randint(100,10000,10000),
    'date':[f"20{k}-{i}-{j}" for k in range(10,50) for i in range(1,11) for j in range(1,29)][:10000]
}).reset_index().rename(columns={'index':'sn'})

# %%
df["amount"] = df["quantity"]* df["rate"]
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 0   0       329959        RHOJT            11             11       685  2116
# 1   1       812023        EUJUM            15              9       876   902
# 2   2       452934        EUJUM            12              7       192  3142
# 3   3       843132        UFBVX             2             14       189  9095
# 4   4       422959        TNAYA            13             15       434   677
#
#         date   amount
# 0 2010-01-01  1449460
# 1 2010-01-02   790152
# 2 2010-01-03   603264
# 3 2010-01-04  1718955
# 4 2010-01-05   293818

# %%
df.tail()
# Out:
#         sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 9995  9995       710423        ODBOP             4             12       242
# 9996  9996       743310        EHCDN             8             16       140
# 9997  9997       733326        OLAFT            13              4       575
# 9998  9998       353662        OLAFT             9              2       901
# 9999  9999       164123        OLAFT            16             16       849
#
#       rate       date   amount
# 9995  7477 2045-07-28  1809434
# 9996  1967 2045-08-01   275380
# 9997  7224 2045-08-02  4153800
# 9998  6953 2045-08-03  6264653
# 9999  6101 2045-08-04  5179749

# %% [markdown]
# # Single Broker Details

# %%
df[df['buyer_broker']==1].head(10)
# Out:
#       sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 10    10       943620        OLAFT             1             13       370
# 18    18       174469        VKNTK             1             17       346
# 55    55       335389        RHOJT             1             14       379
# 85    85       947823        OLAFT             1              2        72
# 96    96       276794        TWDLP             1              7       918
# 111  111       579270        WOXYC             1             17       168
# 122  122       579641        MVYIR             1             18        98
# 127  127       870344        UGQEY             1             10       466
# 141  141       819530        WOXYC             1              8       536
# 142  142       571182        JEOWQ             1             15       449
#
#      rate       date   amount
# 10   9094 2010-01-11  3364780
# 18   5678 2010-01-19  1964588
# 55   1511 2010-02-28   572669
# 85   9549 2010-04-02   687528
# 96   4511 2010-04-13  4141098
# 111   199 2010-04-28    33432
# 122  2023 2010-05-11   198254
# 127  2732 2010-05-16  1273112
# 141  7931 2010-06-02  4251016
# 142  9823 2010-06-03  4410527

# %%
df[df['buyer_broker']==2].head(10)
# Out:
#       sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  \
# 3      3       843132        UFBVX             2             14       189
# 37    37       243390        VNSVJ             2             13       372
# 70    70       992079        MVYIR             2              3       194
# 76    76       849913        UFBVX             2              5       863
# 81    81       442809        TWDLP             2             10       410
# 93    93       401477        UFBVX             2              3       809
# 116  116       910056        RHOJT             2             17       534
# 126  126       674273        UFBVX             2              1       804
# 132  132       574733        UFBVX             2              9       981
# 181  181       889854        MVYIR             2              8       798
#
#      rate       date   amount
# 3    9095 2010-01-04  1718955
# 37   3035 2010-02-10  1129020
# 70   3660 2010-03-15   710040
# 76   9449 2010-03-21  8154487
# 81   7782 2010-03-26  3190620
# 93   2982 2010-04-10  2412438
# 116  7403 2010-05-05  3953202
# 126  8147 2010-05-15  6550188
# 132  2647 2010-05-21  2596707
# 181  6509 2010-07-14  5194182

# %% [markdown]
# # data between date ranges

# %%
year_range = df[(df['date']>'2010-01-04')&(df['date']<'2011-01-04')]
year_range.head(10)
# Out:
#     sn  contract no stock_symbol  buyer_broker  seller_broker  quantity  rate  \
# 4    4       422959        TNAYA            13             15       434   677
# 5    5       931775        UGQEY            16              1       731  4786
# 6    6       572626        MVYIR            13             14        97  9914
# 7    7       752662        RHOJT            15              4       610  2931
# 8    8       743343        UGQEY             4              6       544  1991
# 9    9       315131        RHOJT             6              5       801   810
# 10  10       943620        OLAFT             1             13       370  9094
# 11  11       733748        JIXOR             5              2       838  9124
# 12  12       315954        OLAFT             5             15       607  1765
# 13  13       602099        WOXYC             8              4       392  7079
#
#          date   amount
# 4  2010-01-05   293818
# 5  2010-01-06  3498566
# 6  2010-01-07   961658
# 7  2010-01-08  1787910
# 8  2010-01-09  1083104
# 9  2010-01-10   648810
# 10 2010-01-11  3364780
# 11 2010-01-12  7645912
# 12 2010-01-13  1071355
# 13 2010-01-14  2774968

# %%
year_range.groupby(["buyer_broker"])["quantity"].sum().sort_values(ascending= False)
# Out:
# buyer_broker
# 17    15443
# 4     11580
# 16    11399
# 10    10858
# 8      9277
# 2      9035
# 12     8795
# 18     8252
# 19     7580
# 14     7431
# 1      7173
# 5      6209
# 11     6150
# 15     5881
# 3      5852
# 7      5307
# 9      5117
# 6      4690
# 13     3201
# Name: quantity, dtype: int32

# %% [markdown]
# ### Broker 17 was max stock buyer

# %%
year_range.groupby(["seller_broker"])["quantity"].sum().sort_values(ascending= False)
# Out:
# seller_broker
# 5     11583
# 17    11453
# 18    10135
# 10     9948
# 13     9853
# 11     9108
# 14     8514
# 19     8078
# 4      8011
# 15     7957
# 1      7714
# 2      7516
# 6      7356
# 8      6064
# 16     5762
# 7      5611
# 9      5466
# 12     4828
# 3      4273
# Name: quantity, dtype: int32

# %% [markdown]
# ### broker 5 was most stock seller

# %% [markdown]
# # Top buyer broker

# %%
df.groupby(["buyer_broker"])["amount"].sum().sort_values(ascending= False)
# Out:
# buyer_broker
# 8     1582031885
# 9     1541855712
# 2     1512994774
# 17    1476912559
# 11    1467407449
# 14    1444798450
# 4     1440018318
# 1     1436416845
# 18    1426268014
# 5     1393602932
# 15    1377201745
# 12    1374469027
# 16    1359395692
# 6     1345442413
# 7     1337705534
# 10    1294931419
# 13    1268520384
# 19    1265351505
# 3     1247323361
# Name: amount, dtype: int32

# %% [markdown]
# # top seller broker

# %%
df.groupby(["seller_broker"])["amount"].sum().sort_values(ascending= False)
# Out:
# seller_broker
# 17    1562631211
# 16    1551919200
# 1     1457126533
# 18    1455785684
# 11    1444243766
# 10    1433109259
# 4     1410597942
# 9     1400606828
# 13    1399059026
# 6     1384632021
# 8     1378400789
# 14    1371353202
# 2     1364031185
# 19    1361692352
# 3     1345339819
# 5     1338078362
# 12    1328563614
# 7     1324141637
# 15    1281335588
# Name: amount, dtype: int32

# %%
pl.figure(figsize=(15,7))
sns.countplot(x=df['stock_symbol'])
pl.show()
