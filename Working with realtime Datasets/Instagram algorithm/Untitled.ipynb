# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pl

# %%
df=pd.read_csv('untitled.txt',sep=',').drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#    S.No              USERNAME  \
# 0     1         mikequindazzi
# 1     2       drgorillapaints
# 2     3    aitrading_official
# 3     4  opensourcedworkplace
# 4     5           crea.vision
#
#                                              Caption  Followers  \
# 0  Who are #DataScientist and what do they do? >>...       1600
# 1  We all know where it’s going. We just have to ...        880
# 2  Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                               sfad        340
# 4  Ever missed a call while your phone was chargi...        304
#
#                                             Hashtags Time since posted  Likes
# 0  #MachineLearning #AI #DataAnalytics #DataScien...          11 hours    139
# 1   #deck .#mac #macintosh#sayhello #apple #steve...           2 hours     23
# 2  #whoiswho #aitrading #ai #aitradingteam#instat...           2 hours     25
# 3  #iot #cre#workplace #CDO #bigdata #technology#...           3 hours     49
# 4  #instamachinelearning #instabigdata#instamarke...           3 hours     30

# %%
sns.heatmap(df.isnull())

# %%
df.isna().sum()
# Out:
# S.No                 0
# USERNAME             0
# Caption              6
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
pl.figure(figsize=(10,7))
sns.countplot(df['Time since posted'])
pl.xticks(rotation=-60)
pl.show()

# %%
df.describe()
# Out:
#             S.No    Followers       Likes
# count  94.000000    94.000000   94.000000
# mean   16.117021   942.627660   47.882979
# std     7.481671  1023.894946   56.501757
# min     1.000000    11.000000    8.000000
# 25%    10.000000   231.000000   19.000000
# 50%    16.000000   593.500000   29.500000
# 75%    22.000000  1177.000000   46.000000
# max    30.000000  4496.000000  349.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No               94 non-null     int64
#  1   USERNAME           94 non-null     object
#  2   Caption            94 non-null     object
#  3   Followers          94 non-null     int64
#  4   Hashtags           94 non-null     object
#  5   Time since posted  94 non-null     object
#  6   Likes              94 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 8.4+ KB

# %%
pl.figure(figsize=(10,7))
sns.distplot(df['Likes'],bins=20)
pl.xticks(rotation=-60)
pl.show()

# %%
hashtags=[]
for txt in df['Hashtags']:
    items=txt.split('#')
    items= [x for x in items if x !='']
    hashtags.extend(items)
hashtags[:10]
# Out:
# ['MachineLearning ',
#  'AI ',
#  'DataAnalytics ',
#  'DataScienc ',
#  'DataLake',
#  ' ',
#  'deck .',
#  'mac ',
#  'macintosh',
#  'sayhello ']

# %%
captions=[]
for txt in df['Caption']:
    items=txt.split('#')
    items= [x for x in items if x !='']
    captions.extend(items)
captions[:10]
# Out:
# ['Who are ',
#  'DataScientist and what do they do? >> @MikeQuindazzi >> ',
#  'MachineLearning ',
#  'AI ',
#  'DataAnalytics ',
#  'DataScienc ',
#  'DataLake >> https://buff.ly/2kYmF0s',
#  'We all know where it’s going. We just have to ',
#  'workresponsibly to postpone the date. This actually made into a business slide ',
#  'deck .']

# %%
captions=' '.join(captions)
captions[:100]
# Out:
# 'Who are  DataScientist and what do they do? >> @MikeQuindazzi >>  MachineLearning  AI  DataAnalytics'

# %%
hashtags=' '.join(hashtags)
hashtags[:100]
# Out:
# 'MachineLearning  AI  DataAnalytics  DataScienc  DataLake   deck . mac  macintosh sayhello  apple  st'

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wc=WordCloud(height=800,width=800,
            stopwords=STOPWORDS,
             background_color='white',
             min_font_size=10
            ).generate(hashtags)
pl.figure(figsize=(10,8),facecolor=None)
pl.title("Hashtag wordcloud")
pl.grid(False)
pl.imshow(wc)
pl.style.use('seaborn-whitegrid')
pl.rcParams.update({'font.size':25})
pl.axis('off')
pl.show()

# %%
wc=WordCloud(height=800,width=800,
            stopwords=STOPWORDS,
             background_color='white',
             min_font_size=10
            ).generate(captions)
pl.figure(figsize=(10,8),facecolor=None)
pl.title("Caption wordcloud")
pl.grid(False)
pl.imshow(wc)
pl.style.use('seaborn-whitegrid')
pl.rcParams.update({'font.size':25})
pl.axis('off')
pl.show()

# %%
df['Time since posted']=df['Time since posted'].apply(lambda x: int(re.findall(r'\d+',x)[0]))

# %%
def PlotData(features):
    plt.figure(figsize= (20, 10))    
    pltNum = 1
    for mem in features:
        plt.subplot(1, 2 , pltNum)
        plt.style.use('seaborn-whitegrid')
        plt.grid(True)
        plt.title('Regplot Plot for '+ str(mem))
        sns.regplot(data = df, x = mem, y = 'Likes' , color = 'green')
        pltNum += 1
    
    plt.show()
    
PlotData(['Followers', 'Time since posted'])

# %%
df.head()
# Out:
#    S.No              USERNAME  \
# 0     1         mikequindazzi
# 1     2       drgorillapaints
# 2     3    aitrading_official
# 3     4  opensourcedworkplace
# 4     5           crea.vision
#
#                                              Caption  Followers  \
# 0  Who are #DataScientist and what do they do? >>...       1600
# 1  We all know where it’s going. We just have to ...        880
# 2  Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                               sfad        340
# 4  Ever missed a call while your phone was chargi...        304
#
#                                             Hashtags  Time since posted  Likes
# 0  #MachineLearning #AI #DataAnalytics #DataScien...                 11    139
# 1   #deck .#mac #macintosh#sayhello #apple #steve...                  2     23
# 2  #whoiswho #aitrading #ai #aitradingteam#instat...                  2     25
# 3  #iot #cre#workplace #CDO #bigdata #technology#...                  3     49
# 4  #instamachinelearning #instabigdata#instamarke...                  3     30

# %%
df['Time since posted'][0]
# Out:
# 11

# %%
import numpy as np
features = np.array(df[['Followers', 'Time since posted']], dtype = 'float32')
targets = np.array(df['Likes'], dtype = 'float32')
maxValLikes = max(targets)
print('Max value of target is {}'.format(maxValLikes))
# Out:
# Max value of target is 349.0

# %%
targets = targets/maxValLikes
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

xTrain, xTest, yTrain, yTest = train_test_split(features, targets, test_size = 0.1, random_state = 42)

stdSc = StandardScaler()
xTrain = stdSc.fit_transform(xTrain)
xTest = stdSc.transform(xTest)

from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(xTrain, yTrain)
# Out:
# GradientBoostingRegressor()

# %%
predictions = gbr.predict(xTest)
plt.scatter(yTest, predictions)
plt.style.use('seaborn-whitegrid')
plt.xlabel('true values')
plt.ylabel('predicted values')
plt.title('GradientRegressor')
plt.plot(np.arange(0,0.4, 0.01), np.arange(0, 0.4, 0.01), color = 'green')
plt.grid(True)

# %%
def PredictionsWithConstantFollowers(model, followerCount, scaller, maxVal):
    followers = followerCount * np.ones(24)
    hours = np.arange(1, 25)
    
    # defining vector 
    featureVector = np.zeros((24, 2))
    featureVector[:, 0] = followers
    featureVector [:, 1] = hours
    
    # doing scalling
    featureVector = scaller.transform(featureVector)
    predictions = model.predict(featureVector)
    predictions = (maxValLikes * predictions).astype('int')
    
    plt.figure(figsize= (10, 10))
    plt.plot(hours, predictions)
    plt.style.use('seaborn-whitegrid')
    plt.scatter(hours, predictions, color = 'g')
    plt.grid(True)
    plt.xlabel('hours since posted')
    plt.ylabel('Likes')
    plt.title('Likes progression with ' + str(followerCount) +' followers')
    plt.show()
    
PredictionsWithConstantFollowers(gbr, 100, stdSc, maxValLikes)

# %%
PredictionsWithConstantFollowers(gbr, 200, stdSc, maxValLikes)

# %%
PredictionsWithConstantFollowers(gbr, 1000, stdSc, maxValLikes)

# %%
PredictionsWithConstantFollowers(gbr, 10000, stdSc, maxValLikes)
