# %%
import random

class Process(object):
    def __init__(self, pid, start_time):
        self.start_time = start_time #when process is added to memory
        self.run_progress = 0
        self.pid = pid
        self.time_req = random.randint(500,7500)
        self.priority = random.randint(0,4)
        self.initwait = 0
        self.totwait = 0
        self.turnaround = 0
    def run(self, runtime):
        self.run_progress += runtime
    def isDone(self):
        return self.run_progress >= self.time_req

# %%
import copy

timeCS = 8
timeSlice = 100

class algoClass(object):
    def __init__(self, type, procList, rtime, stats):
        self.stats = copy.deepcopy(stats)
        self.type = type
        self.inMemProcs = []
        self.time = rtime
        self.toAddProcs = copy.deepcopy(procList)
        self.currentSlice = 0
        
    def start(self):
        self.organizeProcs()
        self.currentProc = self.inMemProcs[0]
        
    #runs the current process in cpu
    def run(self):
        #if new to CPU, output so
        if self.currentProc != "IDLE":
            if self.currentProc.run_progress == 0:
                self.output(["started", self.currentProc])
            if not self.currentProc.isDone():
                self.currentProc.run(1)
        self.time[0] += 1
        
    def allDone(self):
        maxStartTime = max([x.start_time for x in self.toAddProcs])
        return self.time[0] > maxStartTime and len(self.inMemProcs) == 0
        
    #outputs information 
    def output(self, args):
        #possible, cs(Context Switch), started(New to CPU), created(Added to CPU Queue), finished (completed by CPU)
        if args[0] == "created":
            proc = args[1]
            print("[time: %dms] Process %d created (requiring %dms CPU time)" 
                    %(self.time[0], proc.pid, proc.time_req))
        elif args[0] == "started":
            proc = args[1]
            print("[time: %dms] Process %d accessed CPU for the first time (initial wait time %dms)" 
                    %(self.time[0], proc.pid, (self.time[0] - proc.start_time)))
            #track initial wait time
            self.stats[self.currentProc.pid][1] = self.time[0] - proc.start_time
        elif args[0] == "cs":
            proc1 = args[1]
            proc2 = args[2]
            print("[time: %dms] Context switch (swapped out process %d for process %d)" 
                    %(self.time[0], proc1.pid, proc2.pid))
        elif args[0] == "finished":
            proc = args[1]
            print("[time: %dms] Process %d terminated (turnaround time %dms, total wait time %dms)"
                    %(self.time[0], proc.pid, (self.time[0]-proc.start_time), (self.time[0]-proc.start_time-proc.time_req)))
            #track turnaround time
            self.stats[self.currentProc.pid][0] = self.time[0] - self.currentProc.start_time
            #track total wait time
            self.stats[self.currentProc.pid][2] = (self.time[0]  - self.currentProc.start_time) - self.currentProc.time_req
    
    #sorts ready queue by the current algorithm
    def organizeProcs(self):
    
        #adds jobs to queue as they arrive
        for proc in self.toAddProcs:
            if proc.start_time == self.time[0]:
                self.output(["created", proc])
                self.inMemProcs.append(proc)
                
                
        if self.type == "FCFS" or self.type == "RR":
            pass
            
        #sorting according to what the algo cares about, shortest remaining run time or priority
        elif self.type == "SJF" or self.type == "PSJF":
            self.inMemProcs = sorted(self.inMemProcs, key=lambda Process: Process.time_req - Process.run_progress)
        elif self.type == "PRI":
            self.inMemProcs = sorted(self.inMemProcs, key=lambda Process: Process.priority)
            
    #finds the process given in the self.inMemProcs list
    #return -1 if not found
    def findProc(self, givenProc):  
        for i in range(0, len(self.inMemProcs)):
            if self.inMemProcs[i].pid == givenProc.pid:
                return i
        return -1
    
    #switch from current process to the next
    def contextSwitch(self, nextProc):
    
        #display a process termination
        if self.currentProc.isDone():
            self.output(["finished", self.currentProc])
            
        #display a context switch
        self.output(["cs", self.currentProc, nextProc])
            
        #go to the next process, increment the time
        self.currentProc = nextProc
        self.time[0] += timeCS
        
    #checks if process needs to be switched based on the algorithm
    def checkSwitch(self):
        #only do stuff if there are processes in the ready queue
        if len(self.inMemProcs) != 0:
            if self.currentProc == "IDLE":
                pass
            elif self.currentProc.isDone():
                    
                #switch to the next best thing, or go idle if there isnt one
                if len(self.inMemProcs) > 1:
                    self.contextSwitch(self.inMemProcs[1])
                    self.inMemProcs.remove(self.inMemProcs[0])
                else:
                    self.output(["finished", self.currentProc])
                    self.inMemProcs.remove(self.inMemProcs[0])
                    self.currentProc = "IDLE"
                    
            elif self.type == "FCFS" or self.type == "SJF":
                return;
                
            #round robin wait till the time slice expires to force a context switch
            elif self.type == "RR":
                if self.currentSlice >= timeSlice and len(self.inMemProcs)>1:
                    self.contextSwitch(self.inMemProcs[1])
                    self.currentSlice = 0
                    
                    #round robin cycles the list
                    tempProc = self.inMemProcs[0]
                    self.inMemProcs.remove(self.inMemProcs[0])
                    self.inMemProcs.append(tempProc)
                else:
                    self.currentSlice += 1
            
            #if something more important tops the list, the preempt out the current process
            elif self.type == "PRI" or self.type == "PSJF":
                if self.currentProc != self.inMemProcs[0]:
                    self.contextSwitch(self.inMemProcs[0])
                
            else:
                print("error, invalid algorithm\n choices are FCFS SJF PSJF RR PRI\n")

# %%
import random
time = [0]
procs = []
numProcs = 5

#holds turnaround, initial wait, and total wait per process
stats = [[0, 0, 0] for i in range(numProcs)]

#outputs useful statistics about the algo
def outputStats(stats):
    turnarounds = [x[0] for x in stats]
    initwaits = [x[1] for x in stats]
    totwaits = [x[2] for x in stats]
    
    #fancy output
    print("               Max        Min        Avg")
    print("Turnaround     %dms       %dms       %.3fms"
        %(max(turnarounds), min(turnarounds), float(sum(turnarounds))/len(turnarounds)))
    print("Initial Wait   %dms       %dms       %.3fms"
        %(max(initwaits), min(initwaits), float(sum(initwaits))/len(initwaits)))
    print("Total Wait     %dms       %dms       %.3fms"
        %(max(totwaits), min(totwaits), float(sum(totwaits))/len(totwaits)))

def makeProcs():
    global procs
    #all processes come in at time 0
    #procs = [Process(i, 0) for i in range(numProcs)]
    
    #75% of processes come in at random times
    procs = [Process(i, 0) for i in range(numProcs//4)] + [Process(i + numProcs//4, random.randint(100,2500)) for i in range(3*numProcs//4)]
    
    
makeProcs()
    
def runAlgo( algo, stats ):
    time[0] = 0
    print("Beginning a run of %s" % algo.type)
    algo.start()
    while( not algo.allDone() ):
        algo.run()
        algo.organizeProcs()
        algo.checkSwitch()
    outputStats(algo.stats)
    time[0] = 0
        
    
algoFCFS = algoClass("FCFS", procs, time, stats) 
algoSJF = algoClass("SJF", procs, time, stats)  
algoPSJF = algoClass("PSJF", procs, time, stats) 
algoRR = algoClass("RR", procs, time, stats)   
algoPRI = algoClass("PRI", procs, time, stats)

#these lines can be commented to only run certain algorithms
runAlgo(algoFCFS, stats)
runAlgo(algoSJF, stats)   
runAlgo(algoPSJF, stats)    
runAlgo(algoRR, stats)  
runAlgo(algoPRI, stats)

print("\nOverall Stats:\n")
print("\nFirst Come First Serve:")
outputStats(algoFCFS.stats)
print("\nShortest Job First:")
outputStats(algoSJF.stats)
print("\nPreemptive Shortest Job First:")
outputStats(algoPSJF.stats)
print("\nRound Robin:")
outputStats(algoRR.stats)
print("\nPreemptive Priority:")
outputStats(algoPRI.stats)
# Out:
# Beginning a run of FCFS
# [time: 0ms] Process 0 created (requiring 3711ms CPU time)
# [time: 0ms] Process 0 accessed CPU for the first time (initial wait time 0ms)
# [time: 381ms] Process 1 created (requiring 698ms CPU time)
# [time: 1347ms] Process 3 created (requiring 6059ms CPU time)
# [time: 2410ms] Process 2 created (requiring 663ms CPU time)
# [time: 3711ms] Process 0 terminated (turnaround time 3711ms, total wait time 0ms)
# [time: 3711ms] Context switch (swapped out process 0 for process 1)
# [time: 3719ms] Process 1 accessed CPU for the first time (initial wait time 3338ms)
# [time: 4417ms] Process 1 terminated (turnaround time 4036ms, total wait time 3338ms)
# [time: 4417ms] Context switch (swapped out process 1 for process 3)
# [time: 4425ms] Process 3 accessed CPU for the first time (initial wait time 3078ms)
# [time: 10484ms] Process 3 terminated (turnaround time 9137ms, total wait time 3078ms)
# [time: 10484ms] Context switch (swapped out process 3 for process 2)
# [time: 10492ms] Process 2 accessed CPU for the first time (initial wait time 8082ms)
# [time: 11155ms] Process 2 terminated (turnaround time 8745ms, total wait time 8082ms)
#                Max        Min        Avg
# Turnaround     9137ms       0ms       5125.800ms
# Initial Wait   8082ms       0ms       2899.600ms
# Total Wait     8082ms       0ms       2899.600ms
# Beginning a run of SJF
# [time: 0ms] Process 0 created (requiring 3711ms CPU time)
# [time: 0ms] Process 0 accessed CPU for the first time (initial wait time 0ms)
# [time: 381ms] Process 1 created (requiring 698ms CPU time)
# [time: 1347ms] Process 3 created (requiring 6059ms CPU time)
# [time: 2410ms] Process 2 created (requiring 663ms CPU time)
# [time: 3711ms] Process 0 terminated (turnaround time 3711ms, total wait time 0ms)
# [time: 3711ms] Context switch (swapped out process 0 for process 2)
# [time: 3719ms] Process 2 accessed CPU for the first time (initial wait time 1309ms)
# [time: 4382ms] Process 2 terminated (turnaround time 1972ms, total wait time 1309ms)
# [time: 4382ms] Context switch (swapped out process 2 for process 1)
# [time: 4390ms] Process 1 accessed CPU for the first time (initial wait time 4009ms)
# [time: 5088ms] Process 1 terminated (turnaround time 4707ms, total wait time 4009ms)
# [time: 5088ms] Context switch (swapped out process 1 for process 3)
# [time: 5096ms] Process 3 accessed CPU for the first time (initial wait time 3749ms)
# [time: 11155ms] Process 3 terminated (turnaround time 9808ms, total wait time 3749ms)
#                Max        Min        Avg
# Turnaround     9808ms       0ms       4039.600ms
# Initial Wait   4009ms       0ms       1813.400ms
# Total Wait     4009ms       0ms       1813.400ms
# Beginning a run of PSJF
# [time: 0ms] Process 0 created (requiring 3711ms CPU time)
# [time: 0ms] Process 0 accessed CPU for the first time (initial wait time 0ms)
# [time: 381ms] Process 1 created (requiring 698ms CPU time)
# [time: 381ms] Context switch (swapped out process 0 for process 1)
# [time: 389ms] Process 1 accessed CPU for the first time (initial wait time 8ms)
# [time: 1087ms] Process 1 terminated (turnaround time 706ms, total wait time 8ms)
# [time: 1087ms] Context switch (swapped out process 1 for process 0)
# [time: 1347ms] Process 3 created (requiring 6059ms CPU time)
# [time: 2410ms] Process 2 created (requiring 663ms CPU time)
# [time: 2410ms] Context switch (swapped out process 0 for process 2)
# [time: 2418ms] Process 2 accessed CPU for the first time (initial wait time 8ms)
# [time: 3081ms] Process 2 terminated (turnaround time 671ms, total wait time 8ms)
# [time: 3081ms] Context switch (swapped out process 2 for process 0)
# [time: 5104ms] Process 0 terminated (turnaround time 5104ms, total wait time 1393ms)
# [time: 5104ms] Context switch (swapped out process 0 for process 3)
# [time: 5112ms] Process 3 accessed CPU for the first time (initial wait time 3765ms)
# [time: 11171ms] Process 3 terminated (turnaround time 9824ms, total wait time 3765ms)
#                Max        Min        Avg
# Turnaround     9824ms       0ms       3261.000ms
# Initial Wait   3765ms       0ms       756.200ms
# Total Wait     3765ms       0ms       1034.800ms
# Beginning a run of RR
# [time: 0ms] Process 0 created (requiring 3711ms CPU time)
# [time: 0ms] Process 0 accessed CPU for the first time (initial wait time 0ms)
# [time: 381ms] Process 1 created (requiring 698ms CPU time)
# [time: 381ms] Context switch (swapped out process 0 for process 1)
# [time: 389ms] Process 1 accessed CPU for the first time (initial wait time 8ms)
# [time: 490ms] Context switch (swapped out process 1 for process 0)
# [time: 599ms] Context switch (swapped out process 0 for process 1)
# [time: 708ms] Context switch (swapped out process 1 for process 0)
# [time: 817ms] Context switch (swapped out process 0 for process 1)
# [time: 926ms] Context switch (swapped out process 1 for process 0)
# [time: 1035ms] Context switch (swapped out process 0 for process 1)
# [time: 1144ms] Context switch (swapped out process 1 for process 0)
# [time: 1253ms] Context switch (swapped out process 0 for process 1)
# [time: 1347ms] Process 3 created (requiring 6059ms CPU time)
# [time: 1362ms] Context switch (swapped out process 1 for process 0)
# [time: 1471ms] Context switch (swapped out process 0 for process 3)
# [time: 1479ms] Process 3 accessed CPU for the first time (initial wait time 132ms)
# [time: 1580ms] Context switch (swapped out process 3 for process 1)
# [time: 1689ms] Context switch (swapped out process 1 for process 0)
# [time: 1798ms] Context switch (swapped out process 0 for process 3)
# [time: 1907ms] Context switch (swapped out process 3 for process 1)
# [time: 2007ms] Process 1 terminated (turnaround time 1626ms, total wait time 928ms)
# [time: 2007ms] Context switch (swapped out process 1 for process 0)
# [time: 2025ms] Context switch (swapped out process 0 for process 3)
# [time: 2134ms] Context switch (swapped out process 3 for process 0)
# [time: 2243ms] Context switch (swapped out process 0 for process 3)
# [time: 2352ms] Context switch (swapped out process 3 for process 0)
# [time: 2410ms] Process 2 created (requiring 663ms CPU time)
# [time: 2461ms] Context switch (swapped out process 0 for process 3)
# [time: 2570ms] Context switch (swapped out process 3 for process 2)
# [time: 2578ms] Process 2 accessed CPU for the first time (initial wait time 168ms)
# [time: 2679ms] Context switch (swapped out process 2 for process 0)
# [time: 2788ms] Context switch (swapped out process 0 for process 3)
# [time: 2897ms] Context switch (swapped out process 3 for process 2)
# [time: 3006ms] Context switch (swapped out process 2 for process 0)
# [time: 3115ms] Context switch (swapped out process 0 for process 3)
# [time: 3224ms] Context switch (swapped out process 3 for process 2)
# [time: 3333ms] Context switch (swapped out process 2 for process 0)
# [time: 3442ms] Context switch (swapped out process 0 for process 3)
# [time: 3551ms] Context switch (swapped out process 3 for process 2)
# [time: 3660ms] Context switch (swapped out process 2 for process 0)
# [time: 3769ms] Context switch (swapped out process 0 for process 3)
# [time: 3878ms] Context switch (swapped out process 3 for process 2)
# [time: 3987ms] Context switch (swapped out process 2 for process 0)
# [time: 4096ms] Context switch (swapped out process 0 for process 3)
# [time: 4205ms] Context switch (swapped out process 3 for process 2)
# [time: 4314ms] Context switch (swapped out process 2 for process 0)
# [time: 4423ms] Context switch (swapped out process 0 for process 3)
# [time: 4532ms] Context switch (swapped out process 3 for process 2)
# [time: 4597ms] Process 2 terminated (turnaround time 2187ms, total wait time 1524ms)
# [time: 4597ms] Context switch (swapped out process 2 for process 0)
# [time: 4650ms] Context switch (swapped out process 0 for process 3)
# [time: 4759ms] Context switch (swapped out process 3 for process 0)
# [time: 4868ms] Context switch (swapped out process 0 for process 3)
# [time: 4977ms] Context switch (swapped out process 3 for process 0)
# [time: 5086ms] Context switch (swapped out process 0 for process 3)
# [time: 5195ms] Context switch (swapped out process 3 for process 0)
# [time: 5304ms] Context switch (swapped out process 0 for process 3)
# [time: 5413ms] Context switch (swapped out process 3 for process 0)
# [time: 5522ms] Context switch (swapped out process 0 for process 3)
# [time: 5631ms] Context switch (swapped out process 3 for process 0)
# [time: 5740ms] Context switch (swapped out process 0 for process 3)
# [time: 5849ms] Context switch (swapped out process 3 for process 0)
# [time: 5958ms] Context switch (swapped out process 0 for process 3)
# [time: 6067ms] Context switch (swapped out process 3 for process 0)
# [time: 6176ms] Context switch (swapped out process 0 for process 3)
# [time: 6285ms] Context switch (swapped out process 3 for process 0)
# [time: 6394ms] Context switch (swapped out process 0 for process 3)
# [time: 6503ms] Context switch (swapped out process 3 for process 0)
# [time: 6612ms] Context switch (swapped out process 0 for process 3)
# [time: 6721ms] Context switch (swapped out process 3 for process 0)
# [time: 6830ms] Context switch (swapped out process 0 for process 3)
# [time: 6939ms] Context switch (swapped out process 3 for process 0)
# [time: 7048ms] Context switch (swapped out process 0 for process 3)
# [time: 7157ms] Context switch (swapped out process 3 for process 0)
# [time: 7266ms] Context switch (swapped out process 0 for process 3)
# [time: 7375ms] Context switch (swapped out process 3 for process 0)
# [time: 7484ms] Context switch (swapped out process 0 for process 3)
# [time: 7593ms] Context switch (swapped out process 3 for process 0)
# [time: 7702ms] Context switch (swapped out process 0 for process 3)
# [time: 7811ms] Context switch (swapped out process 3 for process 0)
# [time: 7920ms] Context switch (swapped out process 0 for process 3)
# [time: 8029ms] Context switch (swapped out process 3 for process 0)
# [time: 8138ms] Context switch (swapped out process 0 for process 3)
# [time: 8247ms] Context switch (swapped out process 3 for process 0)
# [time: 8356ms] Context switch (swapped out process 0 for process 3)
# [time: 8465ms] Context switch (swapped out process 3 for process 0)
# [time: 8574ms] Context switch (swapped out process 0 for process 3)
# [time: 8683ms] Context switch (swapped out process 3 for process 0)
# [time: 8734ms] Process 0 terminated (turnaround time 8734ms, total wait time 5023ms)
# [time: 8734ms] Context switch (swapped out process 0 for process 3)
# [time: 11771ms] Process 3 terminated (turnaround time 10424ms, total wait time 4365ms)
#                Max        Min        Avg
# Turnaround     10424ms       0ms       4594.200ms
# Initial Wait   168ms       0ms       61.600ms
# Total Wait     5023ms       0ms       2368.000ms
# Beginning a run of PRI
# [time: 0ms] Process 0 created (requiring 3711ms CPU time)
# [time: 0ms] Process 0 accessed CPU for the first time (initial wait time 0ms)
# [time: 381ms] Process 1 created (requiring 698ms CPU time)
# [time: 1347ms] Process 3 created (requiring 6059ms CPU time)
# [time: 2410ms] Process 2 created (requiring 663ms CPU time)
# [time: 3711ms] Process 0 terminated (turnaround time 3711ms, total wait time 0ms)
# [time: 3711ms] Context switch (swapped out process 0 for process 1)
# [time: 3719ms] Process 1 accessed CPU for the first time (initial wait time 3338ms)
# [time: 4417ms] Process 1 terminated (turnaround time 4036ms, total wait time 3338ms)
# [time: 4417ms] Context switch (swapped out process 1 for process 2)
# [time: 4425ms] Process 2 accessed CPU for the first time (initial wait time 2015ms)
# [time: 5088ms] Process 2 terminated (turnaround time 2678ms, total wait time 2015ms)
# [time: 5088ms] Context switch (swapped out process 2 for process 3)
# [time: 5096ms] Process 3 accessed CPU for the first time (initial wait time 3749ms)
# [time: 11155ms] Process 3 terminated (turnaround time 9808ms, total wait time 3749ms)
#                Max        Min        Avg
# Turnaround     9808ms       0ms       4046.600ms
# Initial Wait   3749ms       0ms       1820.400ms
# Total Wait     3749ms       0ms       1820.400ms
#
# Overall Stats:
#
#
# First Come First Serve:
#                Max        Min        Avg
# Turnaround     9137ms       0ms       5125.800ms
# Initial Wait   8082ms       0ms       2899.600ms
# Total Wait     8082ms       0ms       2899.600ms
#
# Shortest Job First:
#                Max        Min        Avg
# Turnaround     9808ms       0ms       4039.600ms
# Initial Wait   4009ms       0ms       1813.400ms
# Total Wait     4009ms       0ms       1813.400ms
#
# Preemptive Shortest Job First:
#                Max        Min        Avg
# Turnaround     9824ms       0ms       3261.000ms
# Initial Wait   3765ms       0ms       756.200ms
# Total Wait     3765ms       0ms       1034.800ms
#
# Round Robin:
#                Max        Min        Avg
# Turnaround     10424ms       0ms       4594.200ms
# Initial Wait   168ms       0ms       61.600ms
# Total Wait     5023ms       0ms       2368.000ms
#
# Preemptive Priority:
#                Max        Min        Avg
# Turnaround     9808ms       0ms       4046.600ms
# Initial Wait   3749ms       0ms       1820.400ms
# Total Wait     3749ms       0ms       1820.400ms
