# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as pl
import numpy as np
import pandas as pd

# %%
data=load_iris()
df=pd.DataFrame(data=data["data"],columns=data["feature_names"])
df["Target"]=pd.DataFrame(data["target"])
setosa=df[df["Target"]==0]

# %%
counts,bin_edges=np.histogram(setosa['petal length (cm)'],bins=10,density=True)
pdf=counts/(sum(counts))
print(counts)
print(pdf)
print(bin_edges)
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.88888889 2.88888889
#  1.55555556 0.88888889 0.         0.44444444]
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
cdf=np.cumsum(pdf)
# pl.axes((1,1.5,1,1))
pl.plot(bin_edges[1:],pdf,label="PDF")
pl.plot(bin_edges[1:],cdf,label="CDF")
pl.grid()
pl.legend()
