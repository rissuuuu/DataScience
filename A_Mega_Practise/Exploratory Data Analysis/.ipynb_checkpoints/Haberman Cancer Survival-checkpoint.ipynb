# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns
import warnings
sns.set_style("whitegrid")

# %%
df=pd.read_csv("haberman.csv")
df.shape
# Out:
# (306, 4)

# %%
df.Survival_status[df["Survival_status"]==1]="Yes"
df.Survival_status[df["Survival_status"]==2]="No"

# %%
df["Survival_status"].value_counts()
# Out:
# Yes    225
# No      81
# Name: Survival_status, dtype: int64

# %%
df.head()
# Out:
#    Age  Year_of_operations  Axillary_nodes Survival_status
# 0   30                  64               1             Yes
# 1   30                  62               3             Yes
# 2   30                  65               0             Yes
# 3   31                  59               2             Yes
# 4   31                  65               4             Yes

# %%
pl.hist(df["Age"],bins=50)
# Out:
# (array([ 5.,  0.,  2.,  7.,  2.,  2.,  6., 10.,  6.,  3., 10.,  9., 11.,
#          7.,  9.,  7., 18., 10., 12.,  6., 14., 11., 13., 10.,  7., 11.,
#          7.,  8.,  6.,  9.,  7.,  8.,  5., 15.,  6.,  2.,  4.,  7.,  1.,
#          4.,  2.,  2.,  1.,  1.,  1.,  1.,  0.,  0.,  0.,  1.]),
#  array([30.  , 31.06, 32.12, 33.18, 34.24, 35.3 , 36.36, 37.42, 38.48,
#         39.54, 40.6 , 41.66, 42.72, 43.78, 44.84, 45.9 , 46.96, 48.02,
#         49.08, 50.14, 51.2 , 52.26, 53.32, 54.38, 55.44, 56.5 , 57.56,
#         58.62, 59.68, 60.74, 61.8 , 62.86, 63.92, 64.98, 66.04, 67.1 ,
#         68.16, 69.22, 70.28, 71.34, 72.4 , 73.46, 74.52, 75.58, 76.64,
#         77.7 , 78.76, 79.82, 80.88, 81.94, 83.  ]),
#  <a list of 50 Patch objects>)

# %%
pl.hist(df["Year_of_operations"],bins=50)
# Out:
# (array([36.,  0.,  0.,  0., 27.,  0.,  0.,  0.,  0., 28.,  0.,  0.,  0.,
#         26.,  0.,  0.,  0.,  0., 23.,  0.,  0.,  0., 30.,  0.,  0.,  0.,
#          0., 31.,  0.,  0.,  0., 28.,  0.,  0.,  0.,  0., 28.,  0.,  0.,
#          0., 25.,  0.,  0.,  0.,  0., 13.,  0.,  0.,  0., 11.]),
#  array([58.  , 58.22, 58.44, 58.66, 58.88, 59.1 , 59.32, 59.54, 59.76,
#         59.98, 60.2 , 60.42, 60.64, 60.86, 61.08, 61.3 , 61.52, 61.74,
#         61.96, 62.18, 62.4 , 62.62, 62.84, 63.06, 63.28, 63.5 , 63.72,
#         63.94, 64.16, 64.38, 64.6 , 64.82, 65.04, 65.26, 65.48, 65.7 ,
#         65.92, 66.14, 66.36, 66.58, 66.8 , 67.02, 67.24, 67.46, 67.68,
#         67.9 , 68.12, 68.34, 68.56, 68.78, 69.  ]),
#  <a list of 50 Patch objects>)

# %%
pl.figure(figsize=(10,8))
sns.countplot(x="Age",data=df)

# %%
sns.countplot(x="Survival_status",data=df)

# %%
df.columns
# Out:
# Index(['Age', 'Year_of_operations', 'Axillary_nodes', 'Survival_status'], dtype='object')

# %%
pl.scatter(df["Age"],df["Year_of_operations"])

# %%
sns.pairplot(df,hue="Survival_status")

# %%
sns.boxplot(y=df["Age"],x=df["Survival_status"],showmeans=True)

# %%
sns.boxplot(x=df["Survival_status"],y=df["Axillary_nodes"],showmeans=True)

# %%
sns.boxplot(x=df["Survival_status"],y=df["Year_of_operations"],showmeans=True)

# %%
sns.violinplot(x=df["Survival_status"],y=df["Age"],showmeans=True)

# %%
sns.violinplot(x=df["Survival_status"],y=df["Year_of_operations"],showmeans=True)

# %%
sns.violinplot(x=df["Survival_status"],y=df["Axillary_nodes"],showmeans=True)

# %%
np.percentile(df["Age"],[25,50,75,100])
# Out:
# array([44.  , 52.  , 60.75, 83.  ])

# %%
pl.barh(df["Age"],df["Survival_status"])
# Out:
# <BarContainer object of 306 artists>

# %%
sns.FacetGrid(df,hue="Survival_status",size=5)\
        .map(pl.hist,"Age")\
        .add_legend()

# %%
sns.FacetGrid(df,hue="Survival_status",size=5)\
        .map(pl.scatter,"Age","Axillary_nodes")\
        .add_legend()

# %%
sns.FacetGrid(df,hue="Survival_status",height=5)\
        .map(sns.distplot,"Age")\
        .add_legend()
