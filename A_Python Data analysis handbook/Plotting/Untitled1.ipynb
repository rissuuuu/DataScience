# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips['tips_pct']=tips['tip']/(tips['total_bill']-tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069

# %%
sns.barplot('tips_pct','day',data=tips)

# %%
sns.barplot(x='tips_pct',y='day',hue='time',data=tips)

# %%
sns.set(style='whitegrid')
tips['tips_pct'].plot.hist(bins=50)

# %%
tips['tips_pct'].plot()

# %%
import numpy as np
import pandas as pd
comp1=np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)
values=pd.Series(np.concatenate([comp1,comp2]))
sns.distplot(values,bins=100,color='k')

# %%
import matplotlib.pyplot as pl
macro=pd.read_csv('maacrodata.csv')
data=macro[['cpi','m1','tbilrate','unemp']]
trans_data=np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot('m1','unemp',data=trans_data)
pl.title("Changes in log %s versus log %s"%('m1','unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data,diag_kind='kde')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.172069
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.190114
#
# [244 rows x 8 columns]

# %%
sns.factorplot(x='day', y='tips_pct', hue='time', col='smoker',
    kind='bar', data=tips[tips.tips_pct < 1])
# Out:
# C:\Users\RINSU\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='tips_pct',row='time',col='smoker',kind='bar',
              data=tips[tips.tips_pct<1])

# %%
sns.factorplot(x='tips_pct',y='day',kind='box',data=tips[tips.tips_pct<0.5])
# Out:
# C:\Users\RINSU\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.pairplot(tips)
