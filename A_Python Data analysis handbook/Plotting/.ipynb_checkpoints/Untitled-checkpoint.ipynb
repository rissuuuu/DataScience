# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd
from numpy import nan as na

# %%
data=np.arange(10)
data
pl.plot(data)

# %%
fig=pl.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.plot(data)
pl.show()

# %%
fig,ax=pl.subplots(3)
ax[0].plot(data)
ax[1].plot(data)
ax[2].plot(data)

# %%
fig = pl.figure(figsize=(10,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
pl.plot(np.random.randn(50).cumsum(),'k--')

# %%
fig,ax=pl.subplots(nrows=2,ncols=3)
ax
# or directly(subplots(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000279DD02DC08>,
# ...
#       dtype=object)

# %%
fig,axes=pl.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=20,color='k',alpha=0.5)
pl.subplots_adjust(wspace=0,hspace=0)

# %%
from numpy.random import randn
pl.figure(figsize=(8,8))
pl.plot(randn(30).cumsum(),'ko:')

# %%
pl.figure(figsize=(8,8))
pl.plot(randn(30).cumsum(),color='k',linestyle='dotted',marker='o')

# %%
data=randn(30).cumsum()
pl.figure(figsize=(8,8))
pl.plot(data,'k--',label='Default')
pl.plot(data,'k-',drawstyle='steps-post',label='steps-post')
pl.legend(loc='best')

# %%
fig=pl.figure(figsize=(10,6))
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
ticks=ax.set_xticks([0,250,500,750,1000])
labels=ax.set_xticklabels(['one','two','three','four','five'])
ax.set_title("My plot with ticks")
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
from numpy.random import randn
fig=pl.figure(figsize=(10,8));
ax=fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')
ax.legend()

# %%
from datetime import datetime
fig=pl.figure(figsize=(10,8))
ax=fig.add_subplot(1,1,1)
data=pd.read_csv('dates.csv',names=['Spx'],index_col=0,parse_dates=True)
spx=data['Spx']
spx.plot()
crisis_data = [
(datetime(2007, 10, 11), 'Peak of bull market'),
(datetime(2008, 3, 12), 'Bear Stearns Fails'),
(datetime(2008, 9, 15), 'Lehman Bankruptcy')
]
for date,label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
    xytext=(date, spx.asof(date) +200),
    arrowprops=dict(facecolor='black', headwidth=6, width=0.2,
    headlength=4),
    horizontalalignment='left', verticalalignment='top')

ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in the 2008-2009 financial crisis')


data.head()
# Out:
#                Spx
# 1990-02-02  330.92
# 1990-02-05  331.85
# 1990-02-06  329.66
# 1990-02-07  333.75
# 1990-02-08  332.96

# %%
fig = pl.figure()
ax = fig.add_subplot(1, 1, 1)
rect = pl.Rectangle((0.2, 0.75), 0.3, 0.2, color='k', alpha=0.3)
circ = pl.Circle((0.7, 0.2), 0.1, color='b', alpha=0.3)
pgon = pl.Polygon([[0.16, 0.25], [0.5, 0.4], [0.2, 0.6]],
color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
pl.savefig('figpath.svg')

# %%
from io import BytesIO
buffer=BytesIO()
pl.savefig(buffer)
plot_data=buffer.getvalue()

# %%
# pl.rc('figure', figsize=(10, 10))
# font_options = {'family' : 'monospace',
# 'weight' : 'bold',
# 'size' : 'small'}
# # pl.rc('font', **font_options)

# %%
s=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot()

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),
                columns=["A","B","C","D"],
                index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0   0.228811  0.024600  0.514464  1.556182
# 10 -0.319956 -0.751834  1.259381  4.337321
# 20 -2.583884 -0.482725 -0.173608  3.902504
# 30 -2.674672 -2.112081  0.220545  4.734165
# 40 -3.820807 -1.456855  0.854910  6.253653
# 50 -2.737076 -1.952268  0.587664  6.655969
# 60 -3.943364 -1.545669  1.851661  7.210946
# 70 -3.386390 -0.762988  2.606133  7.847679
# 80 -2.067488 -1.255575  3.638199  9.660086
# 90 -2.690408 -1.511242  3.218691  8.316230

# %%
df.plot()

# %%
fig,axes=pl.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='k',alpha=0.8)
data.plot.barh(ax=axes[1],color='k',alpha=0.8)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
 index=['one', 'two', 'three', 'four', 'five', 'six'],
 columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.881634  0.092354  0.579904  0.218019
# two    0.504727  0.071060  0.028441  0.066443
# three  0.897106  0.945698  0.558612  0.967260
# four   0.220495  0.644797  0.978318  0.911481
# five   0.123919  0.402643  0.512568  0.408796
# six    0.652724  0.545813  0.787754  0.780849

# %%
df.plot.barh()

# %%
df.plot.bar()

# %%
df.plot.area()

# %%
df.plot.box()

# %%
df.plot.density()

# %%
df.plot.kde()
