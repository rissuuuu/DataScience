# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.random.randn(9),
              index=[["Risu","Risu","Risu","Risu","Risu","Sanu","Sanu","Sanu","Sanu",],
                     ['a','a','a','b','b','c','c','d','d'],
                    [1,2,3,1,3,1,2,2,3]])
data
# Out:
# Risu  a  1    0.660054
#          2    0.227775
#          3    0.348046
#       b  1   -1.068430
#          3   -0.027939
# Sanu  c  1   -0.591164
#          2    0.900937
#       d  2   -0.460023
#          3   -0.209799
# dtype: float64

# %%
pd.DataFrame(data)
# Out:
#                  0
# Risu a 1  0.660054
#        2  0.227775
#        3  0.348046
#      b 1 -1.068430
#        3 -0.027939
# Sanu c 1 -0.591164
#        2  0.900937
#      d 2 -0.460023
#        3 -0.209799

# %%
data.index
# Out:
# MultiIndex([('Risu', 'a', 1),
#             ('Risu', 'a', 2),
#             ('Risu', 'a', 3),
#             ('Risu', 'b', 1),
#             ('Risu', 'b', 3),
#             ('Sanu', 'c', 1),
#             ('Sanu', 'c', 2),
#             ('Sanu', 'd', 2),
#             ('Sanu', 'd', 3)],
#            )

# %%
data['Risu'],data['Risu']['a']
# Out:
# (a  1    0.660054
#     2    0.227775
#     3    0.348046
#  b  1   -1.068430
#     3   -0.027939
#  dtype: float64,
#  1    0.660054
#  2    0.227775
#  3    0.348046
#  dtype: float64)

# %%
data["Risu":"Sanu"]
# Out:
# Risu  a  1    0.660054
#          2    0.227775
#          3    0.348046
#       b  1   -1.068430
#          3   -0.027939
# Sanu  c  1   -0.591164
#          2    0.900937
#       d  2   -0.460023
#          3   -0.209799
# dtype: float64

# %%
data=pd.Series(np.random.randn(9),
              index=[['a','a','a','b','b','c','c','d','d'],
                    [1,2,3,1,3,1,2,2,3]])
data
# Out:
# a  1   -0.271227
#    2    0.963999
#    3    0.387730
# b  1   -0.113166
#    3   -0.854534
# c  1   -1.526632
#    2   -0.981821
# d  2   -0.922664
#    3   -2.559180
# dtype: float64

# %%
data['b':'d']
# Out:
# b  1   -0.113166
#    3   -0.854534
# c  1   -1.526632
#    2   -0.981821
# d  2   -0.922664
#    3   -2.559180
# dtype: float64

# %%
data.loc[['a','c']]
# Out:
# a  1   -0.271227
#    2    0.963999
#    3    0.387730
# c  1   -1.526632
#    2   -0.981821
# dtype: float64

# %%
data.iloc[1],data.iloc[8],data.iloc[3],data.iloc[5]
# this will locate element from 0 index to ....
# Out:
# (0.9639993685135325,
#  -2.559180174562577,
#  -0.11316580372717332,
#  -1.5266318791937148)

# %%
data.loc[:,2]
# all columns with row number of index 2
# Out:
# a    0.963999
# c   -0.981821
# d   -0.922664
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a -0.271227  0.963999  0.387730
# b -0.113166       NaN -0.854534
# c -1.526632 -0.981821       NaN
# d       NaN -0.922664 -2.559180

# %%
data.unstack().stack()
# Out:
# a  1   -0.271227
#    2    0.963999
#    3    0.387730
# b  1   -0.113166
#    3   -0.854534
# c  1   -1.526632
#    2   -0.981821
# d  2   -0.922664
#    3   -2.559180
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
         index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
         columns=[['Ohio', 'Ohio', 'Colorado'],
         ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.stack()
# Out:
#            Colorado  Ohio
# a 1 Green       2.0     0
#     Red         NaN     1
#   2 Green       5.0     3
#     Red         NaN     4
# b 1 Green       8.0     6
#     Red         NaN     7
#   2 Green      11.0     9
#     Red         NaN    10

# %%
frame.unstack()
# Out:
#    Ohio            Colorado
#   Green    Red        Green
#       1  2   1   2        1   2
# a     0  3   1   4        2   5
# b     6  9   7  10        8  11

# %%
frame.index.names=['key1','key2']

# %%
frame
# Out:
#            Ohio     Colorado
#           Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.columns.names=['state','color']

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame['Colorado']
# Out:
# color      Green
# key1 key2
# a    1         2
#      2         5
# b    1         8
#      2        11

# %%
# MultiIndex.from_arrays([['Ohio', 'Ohio', 'Colorado'], ['Green', 'Red', 'Green']],
# names=['state', 'color'])

# %%
frame.swaplevel('key1','key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.swapaxes(1,0)
# Out:
# key1            a     b
# key2            1  2  1   2
# state    color
# Ohio     Green  0  3  6   9
#          Red    1  4  7  10
# Colorado Green  2  5  8  11

# %%
frame.sort_index(level=1)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level=0)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level='key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.sum(level='key1')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
frame.sum(level='key2')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level=0)
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
frame.sum(level=1)
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level='color',axis=1)
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='state',axis=1)
# Out:
# state      Ohio  Colorado
# key1 key2
# a    1        1         2
#      2        7         5
# b    1       13         8
#      2       19        11

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),
        'c': ['one', 'one', 'one', 'two', 'two',
        'two', 'two'],
        'd': [0, 1, 2, 0, 1, 2, 3]})
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3
