# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.random.randn(9),
              index=[["Risu","Risu","Risu","Risu","Risu","Sanu","Sanu","Sanu","Sanu",],
                     ['a','a','a','b','b','c','c','d','d'],
                    [1,2,3,1,3,1,2,2,3]])
data
# Out:
# Risu  a  1    0.785267
#          2   -0.545617
#          3    0.687327
#       b  1    0.904782
#          3   -0.090433
# Sanu  c  1   -1.681994
#          2   -0.325604
#       d  2    0.637370
#          3   -0.608732
# dtype: float64

# %%
pd.DataFrame(data)
# Out:
#                  0
# Risu a 1  0.785267
#        2 -0.545617
#        3  0.687327
#      b 1  0.904782
#        3 -0.090433
# Sanu c 1 -1.681994
#        2 -0.325604
#      d 2  0.637370
#        3 -0.608732

# %%
data.index
# Out:
# MultiIndex([('Risu', 'a', 1),
#             ('Risu', 'a', 2),
#             ('Risu', 'a', 3),
#             ('Risu', 'b', 1),
#             ('Risu', 'b', 3),
#             ('Sanu', 'c', 1),
#             ('Sanu', 'c', 2),
#             ('Sanu', 'd', 2),
#             ('Sanu', 'd', 3)],
#            )

# %%
data['Risu'],data['Risu']['a']
# Out:
# (a  1    0.785267
#     2   -0.545617
#     3    0.687327
#  b  1    0.904782
#     3   -0.090433
#  dtype: float64,
#  1    0.785267
#  2   -0.545617
#  3    0.687327
#  dtype: float64)

# %%
data["Risu":"Sanu"]
# Out:
# Risu  a  1    0.785267
#          2   -0.545617
#          3    0.687327
#       b  1    0.904782
#          3   -0.090433
# Sanu  c  1   -1.681994
#          2   -0.325604
#       d  2    0.637370
#          3   -0.608732
# dtype: float64

# %%
data=pd.Series(np.random.randn(9),
              index=[['a','a','a','b','b','c','c','d','d'],
                    [1,2,3,1,3,1,2,2,3]])
data
# Out:
# a  1   -0.044405
#    2    0.016657
#    3    0.037911
# b  1   -1.810070
#    3    0.145300
# c  1    1.281522
#    2    0.290286
# d  2    1.156552
#    3    0.468132
# dtype: float64

# %%
data['b':'d']
# Out:
# b  1   -1.810070
#    3    0.145300
# c  1    1.281522
#    2    0.290286
# d  2    1.156552
#    3    0.468132
# dtype: float64

# %%
data.loc[['a','c']]
# Out:
# a  1   -0.044405
#    2    0.016657
#    3    0.037911
# c  1    1.281522
#    2    0.290286
# dtype: float64

# %%
data.iloc[1],data.iloc[8],data.iloc[3],data.iloc[5]
# this will locate element from 0 index to ....
# Out:
# (0.016656825675563418,
#  0.4681319022848221,
#  -1.8100701429852455,
#  1.2815218011920808)

# %%
data.loc[:,2]
# all columns with row number of index 2
# Out:
# a    0.016657
# c    0.290286
# d    1.156552
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a -0.044405  0.016657  0.037911
# b -1.810070       NaN  0.145300
# c  1.281522  0.290286       NaN
# d       NaN  1.156552  0.468132

# %%
data.unstack().stack()
# Out:
# a  1   -0.044405
#    2    0.016657
#    3    0.037911
# b  1   -1.810070
#    3    0.145300
# c  1    1.281522
#    2    0.290286
# d  2    1.156552
#    3    0.468132
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
         index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
         columns=[['Ohio', 'Ohio', 'Colorado'],
         ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.stack()
# Out:
#            Colorado  Ohio
# a 1 Green       2.0     0
#     Red         NaN     1
#   2 Green       5.0     3
#     Red         NaN     4
# b 1 Green       8.0     6
#     Red         NaN     7
#   2 Green      11.0     9
#     Red         NaN    10

# %%
frame.unstack()
# Out:
#    Ohio            Colorado
#   Green    Red        Green
#       1  2   1   2        1   2
# a     0  3   1   4        2   5
# b     6  9   7  10        8  11

# %%
frame.index.names=['key1','key2']

# %%
frame
# Out:
#            Ohio     Colorado
#           Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.columns.names=['state','color']

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame['Colorado']
# Out:
# color      Green
# key1 key2
# a    1         2
#      2         5
# b    1         8
#      2        11

# %%
# MultiIndex.from_arrays([['Ohio', 'Ohio', 'Colorado'], ['Green', 'Red', 'Green']],
# names=['state', 'color'])

# %%
frame.swaplevel('key1','key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.swapaxes(1,0)
# Out:
# key1            a     b
# key2            1  2  1   2
# state    color
# Ohio     Green  0  3  6   9
#          Red    1  4  7  10
# Colorado Green  2  5  8  11

# %%
frame.sort_index(level=1)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level=0)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level='key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.sum(level='key1')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
frame.sum(level='key2')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level=0)
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
frame.sum(level=1)
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level='color',axis=1)
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='state',axis=1)
# Out:
# state      Ohio  Colorado
# key1 key2
# a    1        1         2
#      2        7         5
# b    1       13         8
#      2       19        11

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),
        'c': ['one', 'one', 'one', 'two', 'two',
        'two', 'two'],
        'd': [0, 1, 2, 0, 1, 2, 3]})
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2=frame.copy()

# %%
frame2=frame.set_index(['c','d'])
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame.set_index(['c','d'],drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame.set_index(['c','d'],drop=True)
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame2.reset_index(drop=False)
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1

# %%
# Cobmining and Merging Datasets
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
        'data1': range(7)})
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
        'data2': range(3)})
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1,df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
'data1': range(7)})
df4 = pd.DataFrame({'rkey': ['a', 'b','d'],
    'data2': range(3)})
df3
# Out:
#   lkey  data1
# 0    b      0
# 1    b      1
# 2    a      2
# 3    c      3
# 4    a      4
# 5    a      5
# 6    b      6

# %%
df4
# Out:
#   rkey  data2
# 0    a      0
# 1    b      1
# 2    d      2

# %%
pd.merge(df3,df4,left_on='lkey',right_on='rkey')
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df4,df3,left_on='rkey',right_on='lkey')
# Out:
#   rkey  data2 lkey  data1
# 0    a      0    a      2
# 1    a      0    a      4
# 2    a      0    a      5
# 3    b      1    b      0
# 4    b      1    b      1
# 5    b      1    b      6

# %%
df1,df2
# Out:
# (  key  data1
#  0   b      0
#  1   b      1
#  2   a      2
#  3   c      3
#  4   a      4
#  5   a      5
#  6   b      6,
#    key  data2
#  0   a      0
#  1   b      1
#  2   d      2)

# %%
pd.merge(df1,df2,how='outer')
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],
    'data1': range(6)})
df2 = pd.DataFrame({'key': ['a', 'b', 'a', 'b', 'd'],
    'data2': range(5)})

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#    key  data1  data2
# 0    b    0.0      1
# 1    b    1.0      1
# 2    b    5.0      1
# 3    b    0.0      3
# 4    b    1.0      3
# 5    b    5.0      3
# 6    a    2.0      0
# 7    a    4.0      0
# 8    a    2.0      2
# 9    a    4.0      2
# 10   d    NaN      4

# %%
pd.merge(df1,df2,how='left')
# Out:
#    key  data1  data2
# 0    b      0    1.0
# 1    b      0    3.0
# 2    b      1    1.0
# 3    b      1    3.0
# 4    a      2    0.0
# 5    a      2    2.0
# 6    c      3    NaN
# 7    a      4    0.0
# 8    a      4    2.0
# 9    b      5    1.0
# 10   b      5    3.0

# %%
pd.merge(df1,df2,how='inner')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      0      3
# 2   b      1      1
# 3   b      1      3
# 4   b      5      1
# 5   b      5      3
# 6   a      2      0
# 7   a      2      2
# 8   a      4      0
# 9   a      4      2

# %%
pd.merge(df1,df2,how='outer')
# Out:
#    key  data1  data2
# 0    b    0.0    1.0
# 1    b    0.0    3.0
# 2    b    1.0    1.0
# 3    b    1.0    3.0
# 4    b    5.0    1.0
# 5    b    5.0    3.0
# 6    a    2.0    0.0
# 7    a    2.0    2.0
# 8    a    4.0    0.0
# 9    a    4.0    2.0
# 10   c    3.0    NaN
# 11   d    NaN    4.0

# %%
left = pd.DataFrame({'key1': ['foo', 'foo', 'bar'],
    'key2': ['one', 'two', 'one'],
    'lval': [1, 2, 3]})
right = pd.DataFrame({'key1': ['foo', 'foo', 'bar', 'bar'],
    'key2': ['one', 'one', 'one', 'two'],
    'rval': [4, 5, 6, 7]})
left
# Out:
#   key1 key2  lval
# 0  foo  one     1
# 1  foo  two     2
# 2  bar  one     3

# %%
right
# Out:
#   key1 key2  rval
# 0  foo  one     4
# 1  foo  one     5
# 2  bar  one     6
# 3  bar  two     7

# %%
pd.merge(left,right,how='outer')
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %%
pd.merge(left,right,on=['key1','key2'],how='outer')
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %%
pd.merge(left,right,on='key1')
# Out:
#   key1 key2_x  lval key2_y  rval
# 0  foo    one     1    one     4
# 1  foo    one     1    one     5
# 2  foo    two     2    one     4
# 3  foo    two     2    one     5
# 4  bar    one     3    one     6
# 5  bar    one     3    two     7

# %%
pd.merge(left,right,on='key1',suffixes=('_left','_right'))
# Out:
#   key1 key2_left  lval key2_right  rval
# 0  foo       one     1        one     4
# 1  foo       one     1        one     5
# 2  foo       two     2        one     4
# 3  foo       two     2        one     5
# 4  bar       one     3        one     6
# 5  bar       one     3        two     7

# %%
left1 = pd.DataFrame({'key': ['a', 'b', 'a', 'a', 'b', 'c'],
        'value': range(6)})
right1 = pd.DataFrame({'group_val': [3.5, 7]}, index=['a', 'b'])

# %%
left1
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5

# %%
right1
# Out:
#    group_val
# a        3.5
# b        7.0

# %%
pd.merge(left1,right1,left_on='key',right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(left1,right1,left_on='key',how='outer',right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0
# 5   c      5        NaN

# %%
lefth = pd.DataFrame({'key1': ['Ohio', 'Ohio', 'Ohio',
'Nevada', 'Nevada'],
'key2': [2000, 2001, 2002, 2001, 2002],
'data': np.arange(5.)})
righth = pd.DataFrame(np.arange(12).reshape((6, 2)),
index=[['Nevada', 'Nevada', 'Ohio', 'Ohio',
'Ohio', 'Ohio'],
 [2001, 2000, 2000, 2000, 2001, 2002]],
 columns=['event1', 'event2'])

# %%
lefth
# Out:
#      key1  key2  data
# 0    Ohio  2000   0.0
# 1    Ohio  2001   1.0
# 2    Ohio  2002   2.0
# 3  Nevada  2001   3.0
# 4  Nevada  2002   4.0

# %%
righth
# Out:
#              event1  event2
# Nevada 2001       0       1
#        2000       2       3
# Ohio   2000       4       5
#        2000       6       7
#        2001       8       9
#        2002      10      11
