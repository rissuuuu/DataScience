# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/32903',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/32903/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/32903/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/32903/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/32903',
#   'id': 585653161,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzkxOTYxODg3',
#   'number': 32903,
#   'title': 'EHN: to_html col_space col specific',
#   'user': {'login': 'quangngd',
#    'id': 30631476,
#    'node_id': 'MDQ6VXNlcjMwNjMxNDc2',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/30631476?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quangngd',
#    'html_url': 'https://github.com/quangngd',
# ...

# %%
data[0]['title']
# Out:
# 'EHN: to_html col_space col specific'

# %%
import pandas as pd
issues=pd.DataFrame(data,columns=['number', 'title',
'labels', 'state','node_id','user'])
issues.head(3)
# Out:
#    number                                              title labels state  \
# 0   32903                EHN: to_html col_space col specific     []  open
# 1   32902  MultiIndex has problem selecting columns if on...     []  open
# 2   32901           DOC: Fix EX02 in pandas.Series.factorize     []  open
#
#                             node_id  \
# 0  MDExOlB1bGxSZXF1ZXN0MzkxOTYxODg3
# 1          MDU6SXNzdWU1ODU2NDU5NzY=
# 2  MDExOlB1bGxSZXF1ZXN0MzkxOTU2NjE0
#
#                                                 user
# 0  {'login': 'quangngd', 'id': 30631476, 'node_id...
# 1  {'login': 'zachary822', 'id': 4814373, 'node_i...
# 2  {'login': 'farhanreynaldo', 'id': 8732795, 'no...
