# %%
import matplotlib.pyplot as pl
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
digit=load_digits()

# %%
ax1=pl.axes()
ax2=pl.axes([0.65,0.65,0.2,0.2])

# %%
fig=pl.figure()
ax1=fig.add_axes([0.1,0.5,0.8,0.4],
                xticklabels=[],ylim=(-1.2,1.2))
ax2=fig.add_axes([0.1,0.1,0.8,0.4],
                xticklabels=[],ylim=(-1.5,1.5))
x=np.linspace(0,10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1,7):
    pl.subplot(2,3,i)
    pl.text(0.5,0.5,str((2,3,i)),
           fontsize=18,ha='center')

# %%
data=digit.data
pl.figure(figsize=(5,5))
fig,ax=pl.subplots(8)
for i in range(8):
    ax[i].imshow(digit.images[i])

# %%
fig,ax=pl.subplots(2,3,sharex='col',sharey='row')

# %%
grid = pl.GridSpec(2, 3, wspace=0.4, hspace=0.3)
pl.subplot(grid[0,0])
pl.subplot(grid[0,1:
               ])
pl.subplot(grid[1,:2])
pl.subplot(grid[1,2])

# %%
mean=[0,0]
cov=[[1,1],[1,2]]
x,y=np.random.multivariate_normal(mean,cov,3000).T
fig=pl.figure(figsize=(6,6))
grid=pl.GridSpec(4,4,hspace=0.2,wspace=0.2)
main_ax=fig.add_subplot(grid[:-1,1:])
y_hist=fig.add_subplot(grid[:-1,0],xticklabels=[],sharey=main_ax)
x_hist=fig.add_subplot(grid[-1,1:])

main_ax.plot(x,y,'ok',markersize=1,alpha=0.4)
x_hist.hist(x,40,histtype='stepfilled',orientation='vertical',
           color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
orientation='horizontal', color='gray')
y_hist.invert_xaxis()
pl.show()
