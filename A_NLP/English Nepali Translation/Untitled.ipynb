# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
eng=pd.read_csv('train.en',error_bad_lines=False)
nep=pd.read_csv('train.ne',error_bad_lines=False)
# Out:
# b'Skipping line 163: expected 8 fields, saw 9\nSkipping line 192: expected 8 fields, saw 9\nSkipping line 228: expected 8 fields, saw 10\nSkipping line 344: expected 8 fields, saw 9\nSkipping line 465: expected 8 fields, saw 9\nSkipping line 674: expected 8 fields, saw 9\nSkipping line 750: expected 8 fields, saw 10\nSkipping line 998: expected 8 fields, saw 9\nSkipping line 1074: expected 8 fields, saw 9\nSkipping line 1153: expected 8 fields, saw 9\nSkipping line 1202: expected 8 fields, saw 9\nSkipping line 1212: expected 8 fields, saw 9\nSkipping line 1260: expected 8 fields, saw 10\nSkipping line 1268: expected 8 fields, saw 10\nSkipping line 1283: expected 8 fields, saw 9\nSkipping line 1296: expected 8 fields, saw 9\nSkipping line 1330: expected 8 fields, saw 9\nSkipping line 1421: expected 8 fields, saw 11\nSkipping line 1540: expected 8 fields, saw 10\nSkipping line 1542: expected 8 fields, saw 9\nSkipping line 1597: expected 8 fields, saw 10\nSkipping line 1599: expected 8 
# ...

# %%
eng.head()
