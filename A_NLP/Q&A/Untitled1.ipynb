# %%
import pandas as pd
import matplotlib.pyplot as pl
# Out:
# C:\Users\rissu\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df=pd.read_json('train-v2.0.json')

# %%
df.head()
# Out:
#   version                                               data
# 0    v2.0  {'title': 'Beyoncé', 'paragraphs': [{'qas': [{...
# 1    v2.0  {'title': 'Frédéric_Chopin', 'paragraphs': [{'...
# 2    v2.0  {'title': 'Sino-Tibetan_relations_during_the_M...
# 3    v2.0  {'title': 'IPod', 'paragraphs': [{'qas': [{'qu...
# 4    v2.0  {'title': 'The_Legend_of_Zelda:_Twilight_Princ...

# %%
temp=df['data'][0]

# %%
par=temp['paragraphs']

# %%
ques=par[0]['qas']
ques
# Out:
# [{'question': 'When did Beyonce start becoming popular?',
#   'id': '56be85543aeaaa14008c9063',
#   'answers': [{'text': 'in the late 1990s', 'answer_start': 269}],
#   'is_impossible': False},
#  {'question': 'What areas did Beyonce compete in when she was growing up?',
#   'id': '56be85543aeaaa14008c9065',
#   'answers': [{'text': 'singing and dancing', 'answer_start': 207}],
#   'is_impossible': False},
#  {'question': "When did Beyonce leave Destiny's Child and become a solo singer?",
#   'id': '56be85543aeaaa14008c9066',
#   'answers': [{'text': '2003', 'answer_start': 526}],
#   'is_impossible': False},
#  {'question': 'In what city and state did Beyonce  grow up? ',
#   'id': '56bf6b0f3aeaaa14008c9601',
#   'answers': [{'text': 'Houston, Texas', 'answer_start': 166}],
#   'is_impossible': False},
#  {'question': 'In which decade did Beyonce become famous?',
#   'id': '56bf6b0f3aeaaa14008c9602',
#   'answers': [{'text': 'late 1990s', 'answer_start': 276}],
#   'is_impossible': False},
#  {'question': 'In what R&B group was she the lead singer?',
#   'id': '56bf6b0f3aeaaa14008c9603',
#   'answers': [{'text': "Destiny's Child", 'answer_start': 320}],
#   'is_impossible': False},
#  {'question': 'What album made her a worldwide known artist?',
#   'id': '56bf6b0f3aeaaa14008c9604',
#   'answers': [{'text': 'Dangerously in Love', 'answer_start': 505}],
#   'is_impossible': False},
#  {'question': "Who managed the Destiny's Child group?",
#   'id': '56bf6b0f3aeaaa14008c9605',
#   'answers': [{'text': 'Mathew Knowles', 'answer_start': 360}],
#   'is_impossible': False},
#  {'question': 'When did Beyoncé rise to fame?',
#   'id': '56d43c5f2ccc5a1400d830a9',
#   'answers': [{'text': 'late 1990s', 'answer_start': 276}],
#   'is_impossible': False},
#  {'question': "What role did Beyoncé have in Destiny's Child?",
#   'id': '56d43c5f2ccc5a1400d830aa',
#   'answers': [{'text': 'lead singer', 'answer_start': 290}],
#   'is_impossible': False},
#  {'question': 'What was the first album Beyoncé released as a solo artist?',
#   'id': '56d43c5f2ccc5a1400d830ab',
#   'answers': [{'text': 'Dangerously in Love', 'answer_start': 505}],
#   'is_impossible': False},
#  {'question': 'When did Beyoncé release Dangerously in Love?',
#   'id': '56d43c5f2ccc5a1400d830ac',
#   'answers': [{'text': '2003', 'answer_start': 526}],
#   'is_impossible': False},
#  {'question': 'How many Grammy awards did Beyoncé win for her first solo album?',
#   'id': '56d43c5f2ccc5a1400d830ad',
#   'answers': [{'text': 'five', 'answer_start': 590}],
#   'is_impossible': False},
#  {'question': "What was Beyoncé's role in Destiny's Child?",
#   'id': '56d43ce42ccc5a1400d830b4',
#   'answers': [{'text': 'lead singer', 'answer_start': 290}],
#   'is_impossible': False},
#  {'question': "What was the name of Beyoncé's first solo album?",
#   'id': '56d43ce42ccc5a1400d830b5',
#   'answers': [{'text': 'Dangerously in Love', 'answer_start': 505}],
#   'is_impossible': False}]

# %%
for i in ques:
    print(i)
    print()
# Out:
# {'question': 'What category of game is Legend of Zelda: Twilight Princess?', 'id': '56cd8a5f62d2951400fa668e', 'answers': [{'text': 'action-adventure', 'answer_start': 128}], 'is_impossible': False}
#
# {'question': 'What consoles can be used to play Twilight Princess?', 'id': '56cd8a5f62d2951400fa668f', 'answers': [{'text': 'GameCube and Wii', 'answer_start': 194}], 'is_impossible': False}
#
# {'question': 'When was Twilight Princess launched in North America?', 'id': '56cd8a5f62d2951400fa6691', 'answers': [{'text': 'November 2006', 'answer_start': 569}], 'is_impossible': False}
#
# {'question': 'When could GameCube owners purchase Twilight Princess?', 'id': '56cd8a5f62d2951400fa6692', 'answers': [{'text': 'December 2006', 'answer_start': 688}], 'is_impossible': False}
#
# {'question': 'What company developed Legend of Zelda: Twilight Princess?', 'id': '56d1159e17492d1400aab8cc', 'answers': [{'text': 'Nintendo', 'answer_start': 177}], 'is_impossible': False}
#
# {'question': 'What year was the Legend of Zelda:Twilight Princess originally planned for release?', 'id': '56d1159e17492d1400aab8ce', 'answers': [{'text': '2005', 'answer_start': 364}], 'is_impossible': False}
#
# {'question': 'What year was the Wii version of Legend of Zelda: Twilight Princess released?', 'id': '56d1159e17492d1400aab8cf', 'answers': [{'text': '2006', 'answer_start': 578}], 'is_impossible': False}
#
# {'plausible_answers': [{'text': 'action-adventure', 'answer_start': 128}], 'question': 'What category of game is Legend of Zelda: Australia Twilight?', 'id': '5a8d7bf7df8bba001a0f9ab1', 'answers': [], 'is_impossible': True}
#
# {'plausible_answers': [{'text': 'GameCube and Wii', 'answer_start': 194}], 'question': 'What consoles can be used to play Australia Twilight?', 'id': '5a8d7bf7df8bba001a0f9ab2', 'answers': [], 'is_impossible': True}
#
# {'plausible_answers': [{'text': 'November 2006', 'answer_start': 569}], 'question': 'When was Australia Twilight launched in North America?', 'id': '5a8d7bf7df8bba001a0f9ab3', 'answers': [], 'is_impossible': True}
#
# {'plausible_answers': [{'text': 'November 2006', 'answer_start': 569}], 'question': 'When could GameCube owners purchase Australian Princess?', 'id': '5a8d7bf7df8bba001a0f9ab4', 'answers': [], 'is_impossible': True}
#
# {'plausible_answers': [{'text': '2005', 'answer_start': 364}], 'question': 'What year was the Legend of Zelda: Australian Princess originally planned for release?', 'id': '5a8d7bf7df8bba001a0f9ab5', 'answers': [], 'is_impossible': True}

# %%
questions=[]
answers=[]
answer_start=[]
is_answerable=[]

# %%
for sample in df['data']:
    par=sample['paragraphs']
    ques=par[0]['qas']
    for i in ques:
        questions.append(i['question'])
        if i['answers']:
            answers.append(i['answers'][0]['text'])
        else:
            answers.append('Null')
        is_answerable.append(i['is_impossible'])

# %%
answers
# Out:
# ['in the late 1990s',
#  'singing and dancing',
#  '2003',
#  'Houston, Texas',
#  'late 1990s',
#  "Destiny's Child",
#  'Dangerously in Love',
#  'Mathew Knowles',
#  'late 1990s',
#  'lead singer',
#  'Dangerously in Love',
#  '2003',
#  'five',
#  'lead singer',
#  'Dangerously in Love',
#  'Polish and French',
#  'Romantic era',
#  'solo piano',
#  'Duchy of Warsaw',
#  '20',
#  '1810',
#  'Romantic era',
#  'Warsaw',
#  'solo piano',
#  '20',
#  '17 October 1849',
#  'Fryderyk Franciszek Chopin',
#  'solo piano',
#  'Romantic era',
#  '1810',
#  'Warsaw',
#  '20',
#  'Romantic',
#  '1849',
#  'Mainland Chinese scholars',
#  'Apple',
#  'October 23, 2001',
#  'three',
#  'portable media players',
#  'touchscreen',
#  '2001',
#  'Apple',
#  '3',
#  'Shuffle',
#  '2015',
#  'action-adventure',
#  'GameCube and Wii',
#  'November 2006',
#  'December 2006',
#  'Nintendo',
#  '2005',
#  '2006',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Eon Productions',
#  'Daniel Craig',
#  'James Bond',
#  'Skyfall',
#  '$245',
#  'twenty-four',
#  'Spectre',
#  'four',
#  'Metro-Goldwyn-Mayer and Columbia Pictures',
#  'Sam Mendes',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '2008',
#  'the Great Sichuan earthquake',
#  '69,197',
#  '2008',
#  '8.0 Ms and 7.9 Mw',
#  'May 12',
#  '02:28:01 PM China Standard Time',
#  '69,197',
#  'New York',
#  'New York',
#  'New York',
#  'New York',
#  'New York City',
#  'New York City',
#  '1960',
#  'Pulitzer Prize',
#  'Harper Lee',
#  'Harper Lee',
#  '1960',
#  'her family and neighbors',
#  'the Sun',
#  'Solar energy',
#  'solar heating, photovoltaics, solar thermal energy, solar architecture and artificial photosynthesis',
#  'radiant light and heat from the Sun',
#  '1977',
#  'hip hop',
#  'Omari',
#  'June 8, 1977',
#  'nontheistic',
#  'teachings attributed to Gautama Buddha',
#  'present-day Nepal',
#  'through the direct understanding and perception of dependent origination and the Four Noble Truths',
#  'ignorance and craving',
#  'nontheistic religion',
#  'Gautama Buddha',
#  'between the 6th and 4th centuries BCE',
#  'present-day Nepal',
#  'Gautama Buddha',
#  'Nepal',
#  'sometime between the 6th and 4th centuries BCE',
#  'Gautama Buddha',
#  '4',
#  'Indian',
#  'Buddha',
#  'Simon Fuller',
#  '19 Entertainment',
#  '2002',
#  'Pop Idol',
#  'Fox',
#  '19 Entertainment',
#  'Pop Idol',
#  'Simon Fuller',
#  '19 Entertainment',
#  'June 11, 2002',
#  'Pop Idol',
#  'Canis lupus familiaris',
#  'domestic dog',
#  'millennia',
#  'sensory capabilities',
#  '1936 Summer Olympics.',
#  '129 days',
#  'one world, one dream',
#  'Journey of Harmony',
#  'one world, one dream',
#  'Beijing, China.',
#  '"Journey of Harmony"',
#  '85,000 mi',
#  'molecular biology and genetics',
#  'DNA',
#  'RNA',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'comprehensive school',
#  'selective school system',
#  'England and Wales',
#  '90%',
#  'Gesamtschule',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'République du Congo',
#  'Central African Republic',
#  'Gabon',
#  'Cameroon',
#  'Central Africa',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'executive',
#  'cabinet',
#  'civil service',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'IT',
#  'World Wide Web',
#  'Internet Archive',
#  'San Francisco',
#  'Brewster Kahle and Bruce Gilliat',
#  'three dimensional index',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'the United Provinces (Verenigde Provinciën), Federated Dutch Provinces (Foederatae Belgii Provinciae), and Dutch Federation (Belgica Foederata)',
#  'from 1581, when part of the Netherlands separated from Spanish rule, until 1795',
#  'Batavian Republic, the Kingdom of Holland, the United Kingdom of the Netherlands, and ultimately the modern Kingdom of the Netherlands',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Greek',
#  'lichens',
#  'German',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Forces armées canadiennes',
#  'the National Defence Act',
#  'Her Majesty',
#  'Forces canadiennes',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'the principal clergy of Rome and the bishops of the seven suburbicarian sees.',
#  'a church in Rome as his titular church or linked with one of the suburbicarian dioceses',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Iranic languages',
#  'Indo-Iranian languages',
#  'Indo-European language family',
#  '400 BCE',
#  'Middle Persian',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Daylighting',
#  'positive',
#  'energy consumption',
#  'artificial light sources',
#  'Lighting or illumination',
#  'Daylighting',
#  'Lighting',
#  'positive',
#  'energy consumption',
#  'Lighting or illumination',
#  'Separation of powers',
#  'three',
#  'United States Constitution',
#  'checks and balances',
#  'separation of powers',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Architectural',
#  'Greek',
#  'ἀρχι- "chief" and τέκτων "builder"',
#  'buildings and other physical structures',
#  'as works of art',
#  'Historical civilizations',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'life expectancy, education, and income per capita',
#  'longer',
#  'Mahbub ul Haq',
#  'United Nations Development Programme',
#  'longer',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Mediterranean Europe',
#  'Iberian peninsula',
#  'Balkan countries',
#  'southern France',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'BBC',
#  'Royal charter',
#  '1932',
#  '2 November 1936',
#  'United Kingdom',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'July 30, 1947',
#  'Alois',
#  'two',
#  '60',
#  '190',
#  'Tamar',
#  'Devon',
#  'Plymouth Sound',
#  'established beliefs or customs',
#  'A heretic',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '1955',
#  'Soviet Union',
#  'the Cold War',
#  'seven',
#  'West Germany',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'a form of philosophical monism',
#  'matter',
#  'Null',
#  'Null',
#  'Null',
#  'Christian',
#  'Jesus Christ',
#  'Christós',
#  'mashiach',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'American Record Corporation',
#  '1938',
#  '1966',
#  '1987',
#  'Universal Music Group.',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Oklahoma City',
#  'Oklahoma City',
#  '1,322,429',
#  'hunter-gatherer',
#  'agricultural',
#  'domesticated species',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'United Nations Population Fund',
#  'reproductive health',
#  'wanted',
#  'safe',
#  'female genital mutilation',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'the Pacific Ocean',
#  'the Soviet Union',
#  '91',
#  'sixteen',
#  'forty',
#  'five',
#  'six',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'telephone',
#  '1922',
#  'practical',
#  'Alexander Graham Bell',
#  'telephone',
#  'public house',
#  'New England',
#  'Denmark',
#  'Canada',
#  'Samuel Pepys',
#  'Internet service provider',
#  'provides services for accessing, using, the Internet',
#  'commercial, community-owned, non-profit, or otherwise privately owned',
#  'Null',
#  'Null',
#  'Null',
#  'fumetti',
#  'speech balloons',
#  'online webcomics',
#  'narrative pacing',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Saint Helena of Constantinople',
#  'South Atlantic Ocean',
#  '4,255',
#  '16 by 8 kilometres',
#  'phonetics',
#  'allophones',
#  'Indian and East Asian',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'H',
#  '1',
#  '7000100794000000000♠1.00794 u',
#  'Hydrogen',
#  'August 2, 1955',
#  'October 4, 1957',
#  'Yuri Gagarin',
#  'April 12, 1961',
#  'browser',
#  'World Wide Web',
#  'Uniform Resource Identifier',
#  'Hyperlinks',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'a Chinese satellite navigation system',
#  'two separate satellite constellations',
#  'a limited test system that has been operating since 2000, and a full-scale global navigation system',
#  'since 2000',
#  '北斗衛星導航系統',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Canon law',
#  'Christian',
#  'Latin Church and Eastern Catholic Churches',
#  'church council',
#  'canons',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'two',
#  'private',
#  'Print media',
#  '2013',
#  'National Communications Act',
#  'private',
#  'private',
#  'two',
#  'Print media',
#  'radio stations and online portals',
#  '2013',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Catalonia',
#  'Romance language',
#  'Valencian',
#  'Andorra',
#  'Massachusetts',
#  '48',
#  'Greater Boston',
#  '4.7 million people',
#  'Boston',
#  'Universal Pictures',
#  'Comcast',
#  '100 Universal City Plaza Drive',
#  'Universal City, California',
#  'New York City',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Estonian',
#  '1.1 million',
#  'Uralic',
#  'Finnic',
#  'tens of thousands',
#  'wood',
#  'writing',
#  'drying',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'easy listening',
#  'soft rock',
#  'vocal',
#  'Adult contemporary',
#  'soft rock',
#  'summer time',
#  'one hour',
#  'daylight',
#  'autumn',
#  'sunrise',
#  'Royal Institute of British Architects',
#  'the advancement of architecture',
#  '1837',
#  '1971',
#  'United Kingdom',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'National Archives',
#  'National Archives and Records Administration',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'volcanic',
#  'south Atlantic Ocean',
#  '98',
#  'archipelago',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'KU',
#  'Lawrence',
#  'Mount Oread',
#  'the Kansas State Legislature',
#  '1861',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Nanjing',
#  'lower Yangtze River region',
#  'Ming dynasty',
#  'Jin dynasty',
#  '"Southern Capital"',
#  'Jim Foster',
#  '1987',
#  'third',
#  '68',
#  'half',
#  'Latin',
#  'Greek',
#  'discourse',
#  'two',
#  'two',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Switzerland',
#  '36',
#  'Canton of Bern',
#  'second',
#  'the Collegiate Church of St Peter at Westminster',
#  'City of Westminster, London',
#  'Between 1540 and 1556',
#  'Church of England "Royal Peculiar"',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Political corruption',
#  'the Classical period',
#  '1400–1600',
#  '1600–1750',
#  'Romantic',
#  'Western music',
#  'Western',
#  'the Classical period',
#  'between 1550 and 1900',
#  '1890–1930',
#  'Slavs are the largest Indo-European ethno-linguistic group in Europe.',
#  'They inhabit Central Europe, Eastern Europe, Southeast Europe, North Asia and Central Asia.',
#  'The East Slavs colonised Siberia and Central Asia.',
#  "Presently over half of Europe's territory is inhabited by Slavic-speaking communities",
#  'Slavic mercenaries fighting for the Byzantines and Arabs settled Asia Minor and even as far as Syria.',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '253,651',
#  'Sotonian',
#  'Hampshire',
#  '75',
#  'north-west',
#  'sovereign states and international organizations',
#  'A treaty',
#  'equally',
#  'the rules are the same',
#  '1980',
#  'the Partisans,',
#  'Yugoslavia',
#  'Gamal Abdel Nasser',
#  'Sukarno',
#  'Aolepān Aorōkin M̧ajeļ',
#  'the equator',
#  '53,158',
#  'the Federated States of Micronesia',
#  'Majuro',
#  'Republic of the Marshall Islands',
#  'Pacific Ocean',
#  '53,158',
#  '29',
#  'Majuro',
#  'noble class',
#  'King Casimir III the Great',
#  'Grand Duchy of Lithuania and the Crown Kingdom of Poland',
#  '1569–1795',
#  'Ducal Prussia',
#  'Augustan',
#  'three',
#  'Aeneid',
#  'Publius Vergilius Maro',
#  'Appendix Vergiliana',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Europe',
#  '1,200 kilometres',
#  'over tens of millions of years',
#  'Mont Blanc',
#  'the "four-thousanders"',
#  'a locus (or region) of DNA that encodes a functional RNA or protein product',
#  "The transmission of genes to an organism's offspring",
#  'polygenes (many different genes)',
#  'eye colour or number of limbs',
#  'blood type, risk for specific diseases, or the thousands of basic biochemical processes that comprise life',
#  'the Republic of Guinea-Bissau',
#  'West Africa',
#  '13,948 sq mi',
#  '1,704,000',
#  '36,125',
#  'Hudson River',
#  '29',
#  'east-west',
#  'Major streets',
#  'The brain',
#  'The brain',
#  '15–33 billion',
#  'axons',
#  'sponges, jellyfish, adult sea squirts',
#  'Near East (French: Proche-Orient)',
#  'Ottoman Empire',
#  'English',
#  'Middle East',
#  'Chekiang',
#  'Anhui',
#  'Jiangxi',
#  'Fujian',
#  'East China Sea',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'British',
#  'Ministry of Defence',
#  "Her Majesty's Government",
#  'British Armed Forces',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '1936',
#  'mechanical systems with as few as 30 lines of resolution',
#  '20th',
#  '21st',
#  '8K',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'fuel',
#  'cellulose',
#  'lignin',
#  'support',
#  'nutrients',
#  'Afro-Asiatic',
#  'Cushitic',
#  'Sunni Muslim',
#  '12.3 million',
#  'Ethiopia',
#  '5th',
#  '15th',
#  'the collapse of the Western Roman Empire',
#  'Age of Discovery',
#  'Antiquity',
#  'linguistics',
#  'phonemes',
#  'Phonology',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'central processing unit',
#  'Peripheral devices',
#  '(CPU), and some form of memory',
#  'communities and countries, "black" is also perceived as a derogatory,',
#  'racial classification or of ethnicity',
#  'the meaning of the expression varies widely both between and within societies',
#  ', "black" is also perceived as a derogatory, outdated, reductive or otherwise unrepresentative label,',
#  'the meaning of the expression varies widely both between and within societies, and depends significantly on context.',
#  'London',
#  '1785',
#  'The Daily Universal Register',
#  'News Corp group',
#  'Times Newspapers',
#  '1788',
#  '1785',
#  'Delhi',
#  'New Delhi',
#  'Delhi',
#  'New Delhi',
#  'New Delhi',
#  'the northern hemisphere',
#  'availability of food',
#  'Many species',
#  'the regular seasonal movement, often north and south along a flyway, between breeding and wintering grounds',
#  'humans',
#  'Absecon Island',
#  '1854',
#  'Egg Harbor Township and Galloway Township',
#  'Absecon, Brigantine, Pleasantville, Ventnor City and West Atlantic City',
#  'Atlantic',
#  'immune systems in all organisms',
#  'both health and diseases',
#  'autoimmune diseases, hypersensitivities, immune deficiency, and transplant rejection',
#  'in vitro, in situ, and in vivo',
#  'organ transplantation, oncology, virology, bacteriology, parasitology, psychiatry, and dermatology',
#  'MP3',
#  'digital',
#  'consumer audio streaming',
#  'lossy data compression',
#  'digital audio players',
#  'Chicago',
#  '1980s',
#  '1984',
#  'electronic dance music',
#  '"Pump Up The Volume"',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'shallow',
#  'hyphen',
#  'located above',
#  'taller',
#  'Jornado',
#  'Rio Grande',
#  'hunting, gathering, and farming',
#  'Tepehuan',
#  'rock',
#  'Shias',
#  'Ghadir Khumm',
#  '4:165',
#  'Allah',
#  'guide the people',
#  'auditory',
#  'frequency',
#  'Pitch',
#  '1189',
#  'lions',
#  'a crown',
#  '1949',
#  '1966',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'New York',
#  '6,642',
#  'founding a city',
#  'Sam Houston',
#  '1836',
#  'Allen brothers',
#  '6,642 acres',
#  'Sam Houston',
#  'forty-nine percent',
#  'tripled',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Cyprus',
#  'сuprum',
#  'copper(II) salts',
#  'blue',
#  'green verdigris',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'A psychological identity',
#  'ethnic identity',
#  'identity',
#  "one's self-construal",
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Himachal Pradesh',
#  'fourth',
#  'Abundance of perennial rivers',
#  'hydroelectric power, tourism, and agriculture',
#  'Delhi, Punjab, and Rajasthan',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'conveying meaning in the form of non-word messages',
#  'body language',
#  'shaking a hand',
#  'sweating',
#  '55%',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'green',
#  'anthocyanins',
#  'prolate spheroid',
#  'fruit',
#  '15 to 300',
#  'secure procedures',
#  'cybersecurity or IT security',
#  'Computer security',
#  'intentional, accidental, or due to them being tricked',
#  'Computer security',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Orthodox',
#  'Torah',
#  'Talmudic',
#  'Haredi Judaism',
#  'pre-modern Judaism',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Latin animalis',
#  'having breath, having soul or living being',
#  'non-human members of the kingdom Animalia',
#  'Animalia',
#  'sponges, jellyfish, insects, and humans',
#  'brewing',
#  'a brewery',
#  'a brewing company',
#  'homebrewing',
#  '1963',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Mulatto',
#  'Negro',
#  'Neg',
#  'one-drop rule',
#  'their father',
#  'a decimal system of values',
#  'one-tenth of a dollar',
#  'one hundred dollars',
#  '$20',
#  'Coinage Act of 1792',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '1845',
#  'Benjamin Disraeli, William Gladstone and Robert Peel',
#  'August Wilhelm von Hofmann',
#  'in the United Kingdom the teaching of chemistry in particular had fallen behind that in Germany',
#  'Prince Albert',
#  '1845',
#  'practical aspects of the experimental sciences',
#  'Germany',
#  'Prince Albert',
#  'August Wilhelm von Hofmann',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Hanover',
#  'Holy Roman Emperor',
#  'Imperial Diet',
#  'Great Britain',
#  'George I Louis',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'nervous',
#  'Extroverted',
#  'introverted',
#  'motivation',
#  'psychological',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '1992',
#  '1990',
#  'Mike Walker',
#  '1994',
#  '2–0',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Old English',
#  'southern and eastern',
#  'the early Middle Ages',
#  'Anglo-Saxon settlers',
#  'Middle English',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'fleet carrier',
#  'offensive',
#  'to provide defense for convoys of ships',
#  'mercantile hulls',
#  'heavy aviation cruisers',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '2007',
#  '46',
#  '$10.2 million',
#  'Jim Oberstar',
#  '117',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  '1998',
#  '1994',
#  'Warrington and Widnes',
#  'Merseyside',
#  'Simonswood',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Early Triassic',
#  'deserts',
#  'Pangaea',
#  '95%',
#  'Temnospondyli',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'Null',
#  'the 1980s',
#  '128 kilobits/s',
#  ...]
