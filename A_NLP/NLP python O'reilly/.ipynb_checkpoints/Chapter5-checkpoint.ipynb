# %%
import nltk

# %%
text=nltk.word_tokenize("And now for something completely different")

# %%
text
# Out:
# ['And', 'now', 'for', 'something', 'completely', 'different']

# %%
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")

# %%
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())

# %%
text.similar('woman')
# Out:
# man time day year car moment world house family child country boy
# state job place way war girl work word

# %%
text.similar('jump')
# Out:
# be see look run move break find take do go kill change me hide them
# follow one work hold pay

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')

# %%
tagged_token
# Out:
# ('fly', 'NN')

# %%
>>> sent = '''
 The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
 other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
 Fulton/NP-tl County/NN-tl purchasing/VBG departments/NNS which/WDT it/PPS
 said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
 accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
 interest/NN of/IN both/ABX governments/NNS ''/'' ./.
'''

# %%
print(sent)
# Out:
#  The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
#  other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
#  Fulton/NP-tl County/NN-tl purchasing/VBG departments/NNS which/WDT it/PPS
#  said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
#  accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
#  interest/NN of/IN both/ABX governments/NNS ''/'' ./.

# %%
[nltk.tag.str2tuple(tg) for tg in sent.split()]
# Out:
# [('The', 'AT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'AT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'AP'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('AMONG', 'IN'),
#  ('them', 'PPO'),
#  ('the', 'AT'),
#  ('Atlanta', 'NP'),
#  ('and', 'CC'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('purchasing', 'VBG'),
#  ('departments', 'NNS'),
#  ('which', 'WDT'),
#  ('it', 'PPS'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('ARE', 'BER'),
#  ('well', 'QL'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VB'),
#  ('to', 'IN'),
#  ('the', 'AT'),
#  ('best', 'JJT'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'ABX'),
#  ('governments', 'NNS'),
#  ("''", "''"),
#  ('.', '.')]

# %%
nltk.corpus.brown.tagged_words()[:5]
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL')]

# %%
sent.split()[0].split('/')
# Out:
# ['The', 'AT']

# %%
nltk.corpus.indian.tagged_words()[:10]
# Out:
# [('মহিষের', 'NN'),
#  ('সন্তান', 'NN'),
#  (':', 'SYM'),
#  ('তোড়া', 'NNP'),
#  ('উপজাতি', 'NN'),
#  ('৷', 'SYM'),
#  ('বাসস্থান-ঘরগৃহস্থালি', 'NN'),
#  ('তোড়া', 'NNP'),
#  ('ভাষায়', 'NN'),
#  ('গ্রামকেও', 'NN')]

# %%
freq=nltk.defaultdict(int)
freq['colorless']='R'
freq['ideas']=2

# %%
freq
# Out:
# defaultdict(int, {'colorless': 'R', 'ideas': 2})

# %%
pos=nltk.defaultdict(list)
pos['sleep']=['M',1]
pos
# Out:
# defaultdict(list, {'sleep': ['M', 1]})

# %%
pos['sleep']
# Out:
# ['M', 1]

# %%
pos = nltk.defaultdict(lambda: 'N')
pos['colourless']='ADJ'

pos
# Out:
# defaultdict(<function __main__.<lambda>()>, {'colourless': 'ADJ'})

# %%
pos['colourless']
# Out:
# 'ADJ'

# %%
pos['Hir']
# Out:
# 'N'

# %%
alice=nltk.corpus.gutenberg.words('carroll-alice.txt')

# %%
vocab=nltk.FreqDist(alice)
v1000=list(vocab)[:1000]
mapping=nltk.defaultdict(lambda :'UNK')

# %%
for v in v1000:
    mapping[v]=v
    
alice2=[mapping[v] for v in alice]

# %%
alice2
# Out:
# ['[',
#  'Alice',
#  "'",
#  's',
#  'Adventures',
#  'in',
#  'Wonderland',
#  'by',
#  'UNK',
#  'UNK',
#  'UNK',
#  'UNK',
#  'CHAPTER',
#  'I',
#  '.',
#  'Down',
#  'the',
#  'Rabbit',
#  '-',
#  'UNK',
#  'Alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by',
#  'her',
#  'sister',
#  'on',
#  'the',
#  'bank',
#  ',',
#  'and',
#  'of',
#  'having',
#  'nothing',
#  'to',
#  'do',
#  ':',
#  'once',
#  'or',
#  'twice',
#  'she',
#  'had',
#  'peeped',
#  'into',
#  'the',
#  'book',
#  'her',
#  'sister',
#  'was',
#  'reading',
#  ',',
#  'but',
#  'it',
#  'had',
#  'no',
#  'pictures',
#  'or',
#  'UNK',
#  'in',
#  'it',
#  ',',
#  "'",
#  'and',
#  'what',
#  'is',
#  'the',
#  'use',
#  'of',
#  'a',
#  'book',
#  ",'",
#  'thought',
#  'Alice',
#  "'",
#  'without',
#  'pictures',
#  'or',
#  'conversation',
#  "?'",
#  'So',
#  'she',
#  'was',
#  'considering',
#  'in',
#  'her',
#  'own',
#  'mind',
#  '(',
#  'as',
#  'well',
#  'as',
#  'she',
#  'could',
#  ',',
#  'for',
#  'the',
#  'hot',
#  'day',
#  'made',
#  'her',
#  'feel',
#  'very',
#  'sleepy',
#  'and',
#  'stupid',
#  '),',
#  'whether',
#  'the',
#  'UNK',
#  'of',
#  'making',
#  'a',
#  'UNK',
#  '-',
#  'UNK',
#  'would',
#  'be',
#  'worth',
#  'the',
#  'trouble',
#  'of',
#  'getting',
#  'up',
#  'and',
#  'UNK',
#  'the',
#  'UNK',
#  ',',
#  'when',
#  'suddenly',
#  'a',
#  'White',
#  'Rabbit',
#  'with',
#  'UNK',
#  'eyes',
#  'ran',
#  'close',
#  'by',
#  'her',
#  '.',
#  'There',
#  'was',
#  'nothing',
#  'so',
#  'VERY',
#  'UNK',
#  'in',
#  'that',
#  ';',
#  'UNK',
#  'did',
#  'Alice',
#  'think',
#  'it',
#  'so',
#  'VERY',
#  'much',
#  'out',
#  'of',
#  'the',
#  'way',
#  'to',
#  'hear',
#  'the',
#  'Rabbit',
#  'say',
#  'to',
#  'itself',
#  ',',
#  "'",
#  'Oh',
#  'dear',
#  '!',
#  'Oh',
#  'dear',
#  '!',
#  'I',
#  'shall',
#  'be',
#  'late',
#  "!'",
#  '(',
#  'when',
#  'she',
#  'thought',
#  'it',
#  'over',
#  'UNK',
#  ',',
#  'it',
#  'UNK',
#  'to',
#  'her',
#  'that',
#  'she',
#  'ought',
#  'to',
#  'have',
#  'UNK',
#  'at',
#  'this',
#  ',',
#  'but',
#  'at',
#  'the',
#  'time',
#  'it',
#  'all',
#  'seemed',
#  'quite',
#  'natural',
#  'UNK',
#  'but',
#  'when',
#  'the',
#  'Rabbit',
#  'UNK',
#  'UNK',
#  'A',
#  'UNK',
#  'UNK',
#  'OF',
#  'UNK',
#  'UNK',
#  '-',
#  'UNK',
#  ',',
#  'and',
#  'looked',
#  'at',
#  'it',
#  ',',
#  'and',
#  'then',
#  'hurried',
#  'on',
#  ',',
#  'Alice',
#  'UNK',
#  'to',
#  'her',
#  'feet',
#  ',',
#  'for',
#  'it',
#  'UNK',
#  'across',
#  'her',
#  'mind',
#  'that',
#  'she',
#  'had',
#  'never',
#  'before',
#  'seen',
#  'a',
#  'rabbit',
#  'with',
#  'either',
#  'a',
#  'UNK',
#  '-',
#  'pocket',
#  ',',
#  'or',
#  'a',
#  'watch',
#  'to',
#  'take',
#  'out',
#  'of',
#  'it',
#  ',',
#  'and',
#  'UNK',
#  'with',
#  'curiosity',
#  ',',
#  'she',
#  'ran',
#  'across',
#  'the',
#  'UNK',
#  'after',
#  'it',
#  ',',
#  'and',
#  'UNK',
#  'was',
#  'just',
#  'in',
#  'time',
#  'to',
#  'see',
#  'it',
#  'UNK',
#  'down',
#  'a',
#  'large',
#  'rabbit',
#  '-',
#  'hole',
#  'under',
#  'the',
#  'UNK',
#  '.',
#  'In',
#  'another',
#  'moment',
#  'down',
#  'went',
#  'Alice',
#  'after',
#  'it',
#  ',',
#  'never',
#  'once',
#  'considering',
#  'how',
#  'in',
#  'the',
#  'world',
#  'she',
#  'was',
#  'to',
#  'get',
#  'out',
#  'again',
#  '.',
#  'The',
#  'rabbit',
#  '-',
#  'hole',
#  'went',
#  'UNK',
#  'on',
#  'like',
#  'a',
#  'UNK',
#  'for',
#  'some',
#  'way',
#  ',',
#  'and',
#  'then',
#  'UNK',
#  'suddenly',
#  'down',
#  ',',
#  'so',
#  'suddenly',
#  'that',
#  'Alice',
#  'had',
#  'not',
#  'a',
#  'moment',
#  'to',
#  'think',
#  'about',
#  'UNK',
#  'herself',
#  'before',
#  'she',
#  'found',
#  'herself',
#  'UNK',
#  'down',
#  'a',
#  'very',
#  'deep',
#  'well',
#  '.',
#  'UNK',
#  'the',
#  'well',
#  'was',
#  'very',
#  'deep',
#  ',',
#  'or',
#  'she',
#  'fell',
#  'very',
#  'slowly',
#  ',',
#  'for',
#  'she',
#  'had',
#  'UNK',
#  'of',
#  'time',
#  'as',
#  'she',
#  'went',
#  'down',
#  'to',
#  'look',
#  'about',
#  'her',
#  'and',
#  'to',
#  'wonder',
#  'what',
#  'was',
#  'going',
#  'to',
#  'happen',
#  'next',
#  '.',
#  'First',
#  ',',
#  'she',
#  'tried',
#  'to',
#  'look',
#  'down',
#  'and',
#  'make',
#  'out',
#  'what',
#  'she',
#  'was',
#  'coming',
#  'to',
#  ',',
#  'but',
#  'it',
#  'was',
#  'too',
#  'dark',
#  'to',
#  'see',
#  'anything',
#  ';',
#  'then',
#  'she',
#  'looked',
#  'at',
#  'the',
#  'sides',
#  'of',
#  'the',
#  'well',
#  ',',
#  'and',
#  'noticed',
#  'that',
#  'they',
#  'were',
#  'filled',
#  'with',
#  'UNK',
#  'and',
#  'book',
#  '-',
#  'UNK',
#  ';',
#  'here',
#  'and',
#  'there',
#  'she',
#  'saw',
#  'UNK',
#  'and',
#  'pictures',
#  'UNK',
#  'upon',
#  'UNK',
#  '.',
#  'She',
#  'took',
#  'down',
#  'a',
#  'UNK',
#  'from',
#  'one',
#  'of',
#  'the',
#  'UNK',
#  'as',
#  'she',
#  'passed',
#  ';',
#  'it',
#  'was',
#  'UNK',
#  "'",
#  'UNK',
#  'UNK',
#  'UNK',
#  'but',
#  'to',
#  'her',
#  'great',
#  'UNK',
#  'it',
#  'was',
#  'UNK',
#  ':',
#  'she',
#  'did',
#  'not',
#  'like',
#  'to',
#  'UNK',
#  'the',
#  'UNK',
#  'for',
#  'fear',
#  'of',
#  'UNK',
#  'somebody',
#  ',',
#  'so',
#  'managed',
#  'to',
#  'put',
#  'it',
#  'into',
#  'one',
#  'of',
#  'the',
#  'UNK',
#  'as',
#  'she',
#  'fell',
#  'past',
#  'it',
#  '.',
#  "'",
#  'Well',
#  "!'",
#  'thought',
#  'Alice',
#  'to',
#  'herself',
#  ',',
#  "'",
#  'after',
#  'such',
#  'a',
#  'fall',
#  'as',
#  'this',
#  ',',
#  'I',
#  'shall',
#  'think',
#  'nothing',
#  'of',
#  'UNK',
#  'down',
#  'stairs',
#  '!',
#  'How',
#  'UNK',
#  'they',
#  "'",
#  'll',
#  'all',
#  'think',
#  'me',
#  'at',
#  'home',
#  '!',
#  'Why',
#  ',',
#  'I',
#  'wouldn',
#  "'",
#  't',
#  'say',
#  'anything',
#  'about',
#  'it',
#  ',',
#  'even',
#  'if',
#  'I',
#  'fell',
#  'off',
#  'the',
#  'top',
#  'of',
#  'the',
#  'house',
#  "!'",
#  '(',
#  'Which',
#  'was',
#  'very',
#  'likely',
#  'true',
#  '.)',
#  'Down',
#  ',',
#  'down',
#  ',',
#  'down',
#  '.',
#  'Would',
#  'the',
#  'fall',
#  'UNK',
#  'come',
#  'to',
#  'an',
#  'end',
#  '!',
#  "'",
#  'I',
#  'wonder',
#  'how',
#  'many',
#  'miles',
#  'I',
#  "'",
#  've',
#  'fallen',
#  'by',
#  'this',
#  'time',
#  "?'",
#  'she',
#  'said',
#  'aloud',
#  '.',
#  "'",
#  'I',
#  'must',
#  'be',
#  'getting',
#  'UNK',
#  'near',
#  'the',
#  'UNK',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'Let',
#  'me',
#  'see',
#  ':',
#  'that',
#  'would',
#  'be',
#  'four',
#  'UNK',
#  'miles',
#  'down',
#  ',',
#  'I',
#  'think',
#  "--'",
#  '(',
#  'for',
#  ',',
#  'you',
#  'see',
#  ',',
#  'Alice',
#  'had',
#  'UNK',
#  'several',
#  'things',
#  'of',
#  'this',
#  'sort',
#  'in',
#  'her',
#  'lessons',
#  'in',
#  'the',
#  'UNK',
#  ',',
#  'and',
#  'though',
#  'this',
#  'was',
#  'not',
#  'a',
#  'VERY',
#  'good',
#  'opportunity',
#  'for',
#  'UNK',
#  'off',
#  'her',
#  'knowledge',
#  ',',
#  'as',
#  'there',
#  'was',
#  'no',
#  'one',
#  'to',
#  'listen',
#  'to',
#  'her',
#  ',',
#  'still',
#  'it',
#  'was',
#  'good',
#  'UNK',
#  'to',
#  'say',
#  'it',
#  'over',
#  ')',
#  "'--",
#  'UNK',
#  ',',
#  'that',
#  "'",
#  's',
#  'about',
#  'the',
#  'right',
#  'distance',
#  '--',
#  'but',
#  'then',
#  'I',
#  'wonder',
#  'what',
#  'UNK',
#  'or',
#  'UNK',
#  'I',
#  "'",
#  've',
#  'got',
#  'to',
#  "?'",
#  '(',
#  'Alice',
#  'had',
#  'no',
#  'idea',
#  'what',
#  'UNK',
#  'was',
#  ',',
#  'or',
#  'UNK',
#  'either',
#  ',',
#  'but',
#  'thought',
#  'they',
#  'were',
#  'nice',
#  'grand',
#  'words',
#  'to',
#  'say',
#  '.)',
#  'UNK',
#  'she',
#  'began',
#  'again',
#  '.',
#  "'",
#  'I',
#  'wonder',
#  'if',
#  'I',
#  'shall',
#  'fall',
#  'right',
#  'UNK',
#  'the',
#  'earth',
#  '!',
#  'How',
#  'funny',
#  'it',
#  "'",
#  'll',
#  'seem',
#  'to',
#  'come',
#  'out',
#  'among',
#  'the',
#  'people',
#  'that',
#  'walk',
#  'with',
#  'their',
#  'heads',
#  'UNK',
#  '!',
#  'The',
#  'UNK',
#  ',',
#  'I',
#  'think',
#  "--'",
#  '(',
#  'she',
#  'was',
#  'rather',
#  'glad',
#  'there',
#  'WAS',
#  'no',
#  'one',
#  'listening',
#  ',',
#  'this',
#  'time',
#  ',',
#  'as',
#  'it',
#  'didn',
#  "'",
#  't',
#  'sound',
#  'at',
#  'all',
#  'the',
#  'right',
#  'word',
#  ')',
#  "'--",
#  'but',
#  'I',
#  'shall',
#  'have',
#  'to',
#  'ask',
#  'them',
#  'what',
#  'the',
#  'name',
#  'of',
#  'the',
#  'UNK',
#  'is',
#  ',',
#  'you',
#  'know',
#  '.',
#  'Please',
#  ',',
#  'UNK',
#  "'",
#  'am',
#  ',',
#  'is',
#  'this',
#  'UNK',
#  'UNK',
#  'or',
#  'UNK',
#  "?'",
#  '(',
#  'and',
#  'she',
#  'tried',
#  'to',
#  'UNK',
#  'as',
#  'she',
#  'spoke',
#  '--',
#  'fancy',
#  'UNK',
#  'as',
#  'you',
#  "'",
#  're',
#  'UNK',
#  'through',
#  'the',
#  'air',
#  '!',
#  'Do',
#  'you',
#  'think',
#  'you',
#  'could',
#  'manage',
#  'it',
#  'UNK',
#  "'",
#  'And',
#  'what',
#  'an',
#  'UNK',
#  'little',
#  'girl',
#  'she',
#  "'",
#  'll',
#  'think',
#  'me',
#  'for',
#  'asking',
#  '!',
#  'No',
#  ',',
#  'it',
#  "'",
#  'll',
#  'never',
#  'do',
#  'to',
#  'ask',
#  ':',
#  'perhaps',
#  'I',
#  'shall',
#  'see',
#  'it',
#  'written',
#  'up',
#  'UNK',
#  ".'",
#  'Down',
#  ',',
#  'down',
#  ',',
#  'down',
#  '.',
#  'There',
#  'was',
#  'nothing',
#  'else',
#  'to',
#  'do',
#  ',',
#  'so',
#  'Alice',
#  'soon',
#  'began',
#  'talking',
#  'again',
#  '.',
#  "'",
#  'Dinah',
#  "'",
#  'll',
#  'UNK',
#  'me',
#  'very',
#  'much',
#  'to',
#  '-',
#  'night',
#  ',',
#  'I',
#  'should',
#  'think',
#  "!'",
#  '(',
#  'Dinah',
#  'was',
#  'the',
#  'cat',
#  '.)',
#  "'",
#  'I',
#  'hope',
#  'they',
#  "'",
#  'll',
#  'remember',
#  'her',
#  'UNK',
#  'of',
#  'UNK',
#  'at',
#  'tea',
#  '-',
#  'time',
#  '.',
#  'Dinah',
#  'my',
#  'dear',
#  '!',
#  'I',
#  'wish',
#  'you',
#  'were',
#  'down',
#  'here',
#  'with',
#  'me',
#  ...]

# %%
mapping
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {',': ',',
#              "'": "'",
#              'the': 'the',
#              'and': 'and',
#              '.': '.',
#              'to': 'to',
#              'a': 'a',
#              'I': 'I',
#              'it': 'it',
#              'she': 'she',
#              'of': 'of',
#              'said': 'said',
#              ",'": ",'",
#              'Alice': 'Alice',
#              'in': 'in',
#              'was': 'was',
#              'you': 'you',
#              "!'": "!'",
#              'that': 'that',
#              'as': 'as',
#              'her': 'her',
#              ':': ':',
#              't': 't',
#              'at': 'at',
#              's': 's',
#              'on': 'on',
#              ".'": ".'",
#              ';': ';',
#              'had': 'had',
#              'with': 'with',
#              'all': 'all',
#              '!': '!',
#              "?'": "?'",
#              'be': 'be',
#              '-': '-',
#              'for': 'for',
#              '--': '--',
#              'but': 'but',
#              'not': 'not',
#              'they': 'they',
#              'very': 'very',
#              'little': 'little',
#              'so': 'so',
#              'out': 'out',
#              'this': 'this',
#              'The': 'The',
#              'he': 'he',
#              'down': 'down',
#              'up': 'up',
#              'is': 'is',
#              'about': 'about',
#              'one': 'one',
#              'his': 'his',
#              'what': 'what',
#              'them': 'them',
#              'know': 'know',
#              'were': 'were',
#              'like': 'like',
#              'went': 'went',
#              'again': 'again',
#              'herself': 'herself',
#              'if': 'if',
#              'or': 'or',
#              'thought': 'thought',
#              'Queen': 'Queen',
#              'could': 'could',
#              'have': 'have',
#              'then': 'then',
#              'would': 'would',
#              'no': 'no',
#              'when': 'when',
#              'do': 'do',
#              'time': 'time',
#              'into': 'into',
#              'And': 'And',
#              'see': 'see',
#              'there': 'there',
#              'It': 'It',
#              'off': 'off',
#              'me': 'me',
#              'King': 'King',
#              'did': 'did',
#              '*': '*',
#              'Turtle': 'Turtle',
#              'began': 'began',
#              'm': 'm',
#              'can': 'can',
#              'way': 'way',
#              'll': 'll',
#              'its': 'its',
#              'Mock': 'Mock',
#              'by': 'by',
#              'my': 'my',
#              'Hatter': 'Hatter',
#              'Gryphon': 'Gryphon',
#              'quite': 'quite',
#              'your': 'your',
#              'an': 'an',
#              'much': 'much',
#              'say': 'say',
#              "--'": "--'",
#              'don': 'don',
#              'You': 'You',
#              '(': '(',
#              'think': 'think',
#              'their': 'their',
#              'head': 'head',
#              'thing': 'thing',
#              'some': 'some',
#              '"': '"',
#              'who': 'who',
#              'now': 'now',
#              'go': 'go',
#              'only': 'only',
#              'more': 'more',
#              'voice': 'voice',
#              'Rabbit': 'Rabbit',
#              'looked': 'looked',
#              'just': 'just',
#              'got': 'got',
#              'get': 'get',
#              'are': 'are',
#              'first': 'first',
#              've': 've',
#              'never': 'never',
#              'What': 'What',
#              'Duchess': 'Duchess',
#              'must': 'must',
#              'which': 'which',
#              'round': 'round',
#              'well': 'well',
#              'over': 'over',
#              'how': 'how',
#              'such': 'such',
#              'came': 'came',
#              'other': 'other',
#              'tone': 'tone',
#              'Dormouse': 'Dormouse',
#              'here': 'here',
#              'She': 'She',
#              'great': 'great',
#              'any': 'any',
#              'him': 'him',
#              're': 're',
#              'been': 'been',
#              'back': 'back',
#              'after': 'after',
#              'But': 'But',
#              'before': 'before',
#              'Oh': 'Oh',
#              '?': '?',
#              'from': 'from',
#              'March': 'March',
#              'There': 'There',
#              'large': 'large',
#              'two': 'two',
#              'looking': 'looking',
#              'last': 'last',
#              'once': 'once',
#              'moment': 'moment',
#              'put': 'put',
#              'things': 'things',
#              'long': 'long',
#              'Hare': 'Hare',
#              'nothing': 'nothing',
#              'made': 'made',
#              'found': 'found',
#              'right': 'right',
#              'door': 'door',
#              'heard': 'heard',
#              'Mouse': 'Mouse',
#              'day': 'day',
#              'eyes': 'eyes',
#              'replied': 'replied',
#              'dear': 'dear',
#              'look': 'look',
#              'next': 'next',
#              'might': 'might',
#              'three': 'three',
#              'So': 'So',
#              'seemed': 'seemed',
#              'going': 'going',
#              'make': 'make',
#              'How': 'How',
#              'Why': 'Why',
#              'should': 'should',
#              'tell': 'tell',
#              'That': 'That',
#              'd': 'd',
#              'Caterpillar': 'Caterpillar',
#              'without': 'without',
#              'upon': 'upon',
#              'good': 'good',
#              'won': 'won',
#              'course': 'course',
#              'Cat': 'Cat',
#              'too': 'too',
#              'come': 'come',
#              'rather': 'rather',
#              'away': 'away',
#              'poor': 'poor',
#              'soon': 'soon',
#              'will': 'will',
#              'shall': 'shall',
#              'took': 'took',
#              'Well': 'Well',
#              'felt': 'felt',
#              'than': 'than',
#              'same': 'same',
#              'we': 'we',
#              'added': 'added',
#              'getting': 'getting',
#              'White': 'White',
#              'another': 'another',
#              'half': 'half',
#              'jury': 'jury',
#              'words': 'words',
#              'wish': 'wish',
#              'find': 'find',
#              'Come': 'Come',
#              'minute': 'minute',
#              'They': 'They',
#              'till': 'till',
#              'yet': 'yet',
#              'Then': 'Then',
#              'sort': 'sort',
#              'No': 'No',
#              'hand': 'hand',
#              'ever': 'ever',
#              'while': 'while',
#              'cried': 'cried',
#              'sure': 'sure',
#              'He': 'He',
#              'feet': 'feet',
#              'tried': 'tried',
#              'anything': 'anything',
#              'curious': 'curious',
#              'being': 'being',
#              'use': 'use',
#              'take': 'take',
#              'wonder': 'wonder',
#              'house': 'house',
#              "'--": "'--",
#              'tea': 'tea',
#              'enough': 'enough',
#              'A': 'A',
#              'even': 'even',
#              'end': 'end',
#              'spoke': 'spoke',
#              'eat': 'eat',
#              'question': 'question',
#              'side': 'side',
#              'table': 'table',
#              'sat': 'sat',
#              'As': 'As',
#              'something': 'something',
#              'old': 'old',
#              'This': 'This',
#              'asked': 'asked',
#              'court': 'court',
#              'ran': 'ran',
#              'under': 'under',
#              '.)': '.)',
#              'am': 'am',
#              'talking': 'talking',
#              'bit': 'bit',
#              'turned': 'turned',
#              'garden': 'garden',
#              'hastily': 'hastily',
#              'If': 'If',
#              'doesn': 'doesn',
#              'Bill': 'Bill',
#              'seen': 'seen',
#              'idea': 'idea',
#              'air': 'air',
#              'saying': 'saying',
#              'low': 'low',
#              'high': 'high',
#              'indeed': 'indeed',
#              'face': 'face',
#              'Who': 'Who',
#              ':--': ':--',
#              'done': 'done',
#              'YOU': 'YOU',
#              'called': 'called',
#              'arm': 'arm',
#              'beginning': 'beginning',
#              'hear': 'hear',
#              'itself': 'itself',
#              'ought': 'ought',
#              'saw': 'saw',
#              'near': 'near',
#              'didn': 'didn',
#              'perhaps': 'perhaps',
#              'Dinah': 'Dinah',
#              'remember': 'remember',
#              'mouse': 'mouse',
#              'trying': 'trying',
#              'because': 'because',
#              'left': 'left',
#              'anxiously': 'anxiously',
#              'set': 'set',
#              'knew': 'knew',
#              'sea': 'sea',
#              'talk': 'talk',
#              'us': 'us',
#              'better': 'better',
#              'both': 'both',
#              'baby': 'baby',
#              'mad': 'mad',
#              'close': 'close',
#              'VERY': 'VERY',
#              'people': 'people',
#              'through': 'through',
#              'Do': 'Do',
#              'cats': 'cats',
#              'behind': 'behind',
#              'However': 'However',
#              'For': 'For',
#              'certainly': 'certainly',
#              'THAT': 'THAT',
#              'size': 'size',
#              'gave': 'gave',
#              'grow': 'grow',
#              'speak': 'speak',
#              'far': 'far',
#              'kept': 'kept',
#              'please': 'please',
#              'used': 'used',
#              'change': 'change',
#              'why': 'why',
#              'Dodo': 'Dodo',
#              'whole': 'whole',
#              '--"': '--"',
#              'room': 'room',
#              'gone': 'gone',
#              'cook': 'cook',
#              'Soup': 'Soup',
#              'dance': 'dance',
#              'CHAPTER': 'CHAPTER',
#              'suddenly': 'suddenly',
#              'wouldn': 'wouldn',
#              'many': 'many',
#              'still': 'still',
#              'among': 'among',
#              'else': 'else',
#              'afraid': 'afraid',
#              'Now': 'Now',
#              'every': 'every',
#              'begin': 'begin',
#              'finished': 'finished',
#              'game': 'game',
#              'life': 'life',
#              'deal': 'deal',
#              'queer': 'queer',
#              'everything': 'everything',
#              'try': 'try',
#              'hands': 'hands',
#              'suppose': 'suppose',
#              'always': 'always',
#              'turning': 'turning',
#              'Yes': 'Yes',
#              'Majesty': 'Majesty',
#              'book': 'book',
#              'whether': 'whether',
#              'hurried': 'hurried',
#              'In': 'In',
#              'Let': 'Let',
#              'glad': 'glad',
#              'ask': 'ask',
#              'cat': 'cat',
#              'really': 'really',
#              'hurry': 'hurry',
#              'waited': 'waited',
#              'minutes': 'minutes',
#              'child': 'child',
#              'hardly': 'hardly',
#              'makes': 'makes',
#              'growing': 'growing',
#              'gloves': 'gloves',
#              'let': 'let',
#              'these': 'these',
#              'silence': 'silence',
#              'Of': 'Of',
#              'wasn': 'wasn',
#              'Here': 'Here',
#              'may': 'may',
#              'Pigeon': 'Pigeon',
#              'Footman': 'Footman',
#              'Off': 'Off',
#              'sitting': 'sitting',
#              'having': 'having',
#              'conversation': 'conversation',
#              'own': 'own',
#              'lessons': 'lessons',
#              'though': 'though',
#              'word': 'word',
#              'name': 'name',
#              'sight': 'sight',
#              'walked': 'walked',
#              'glass': 'glass',
#              'small': 'small',
#              'opened': 'opened',
#              'bottle': 'bottle',
#              'read': 'read',
#              'children': 'children',
#              'best': 'best',
#              'tears': 'tears',
#              'box': 'box',
#              'yourself': 'yourself',
#              'pool': 'pool',
#              'fan': 'fan',
#              'thinking': 'thinking',
#              'oh': 'oh',
#              'nearly': 'nearly',
#              'offended': 'offended',
#              'We': 'We',
#              'When': 'When',
#              'creatures': 'creatures',
#              'rest': 'rest',
#              'trial': 'trial',
#              'mean': 'mean',
#              'mouth': 'mouth',
#              'where': 'where',
#              'repeated': 'repeated',
#              'remarked': 'remarked',
#              'remark': 'remark',
#              'soldiers': 'soldiers',
#              'witness': 'witness',
#              'sister': 'sister',
#              'mind': 'mind',
#              'either': 'either',
#              'heads': 'heads',
#              'couldn': 'couldn',
#              'answer': 'answer',
#              'matter': 'matter',
#              'hall': 'hall',
#              'key': 'key',
#              'rate': 'rate',
#              'those': 'those',
#              'few': 'few',
#              ',)': ',)',
#              'against': 'against',
#              'want': 'want',
#              'give': 'give',
#              'help': 'help',
#              'different': 'different',
#              'tail': 'tail',
#              'foot': 'foot',
#              'Not': 'Not',
#              'Don': 'Don',
#              'birds': 'birds',
#              'party': 'party',
#              'At': 'At',
#              'continued': 'continued',
#              'believe': 'believe',
#              'angrily': 'angrily',
#              'shook': 'shook',
#              'least': 'least',
#              'reason': 'reason',
#              'together': 'together',
#              'shouted': 'shouted',
#              'keep': 'keep',
#              'timidly': 'timidly',
#              'puzzled': 'puzzled',
#              'pig': 'pig',
#              'butter': 'butter',
#              'interrupted': 'interrupted',
#              'Knave': 'Knave',
#              'join': 'join',
#              'feel': 'feel',
#              '),': '),',
#              'making': 'making',
#              'slowly': 'slowly',
#              'happen': 'happen',
#              'coming': 'coming',
#              'noticed': 'noticed',
#              'top': 'top',
#              'Which': 'Which',
#              'Would': 'Would',
#              'four': 'four',
#              'opportunity': 'opportunity',
#              ')': ')',
#              'distance': 'distance',
#              'seem': 'seem',
#              'dry': 'dry',
#              'bright': 'bright',
#              'waiting': 'waiting',
#              'fact': 'fact',
#              'followed': 'followed',
#              'croquet': 'croquet',
#              'lying': 'lying',
#              'work': 'work',
#              'white': 'white',
#              'ready': 'ready',
#              'hard': 'hard',
#              'changed': 'changed',
#              'live': 'live',
#              'play': 'play',
#              'eagerly': 'eagerly',
#              'meaning': 'meaning',
#              'IS': 'IS',
#              'explain': 'explain',
#              'running': 'running',
#              'window': 'window',
#              'place': 'place',
#              'appeared': 'appeared',
#              'wood': 'wood',
#              'mushroom': 'mushroom',
#              'haven': 'haven',
#              'turn': 'turn',
#              'most': 'most',
#              'nose': 'nose',
#              'tree': 'tree',
#              'beautiful': 'beautiful',
#              'asleep': 'asleep',
#              'gardeners': 'gardeners',
#              'moral': 'moral',
#              'whiting': 'whiting',
#              'slates': 'slates',
#              'tired': 'tired',
#              'hot': 'hot',
#              'watch': 'watch',
#              'world': 'world',
#              'deep': 'deep',
#              'First': 'First',
#              'fall': 'fall',
#              'listen': 'listen',
#              'fancy': 'fancy',
#              'manage': 'manage',
#              'begun': 'begun',
#              'dream': 'dream',
#              'middle': 'middle',
#              'wondering': 'wondering',
#              'golden': 'golden',
#              'open': 'open',
#              'larger': 'larger',
#              'happened': 'happened',
#              'neck': 'neck',
#              'ME': 'ME',
#              'NOT': 'NOT',
#              'feeling': 'feeling',
#              'however': 'however',
#              'leave': 'leave',
#              'generally': 'generally',
#              'eye': 'eye',
#              'surprised': 'surprised',
#              'kind': 'kind',
#              'THE': 'THE',
#              'Just': 'Just',
#              'hair': 'hair',
#              'goes': 'goes',
#              'mine': 'mine',
#              'learn': 'learn',
#              'frightened': 'frightened',
#              'chin': 'chin',
#              'hadn': 'hadn',
#              'history': 'history',
#              'beg': 'beg',
#              'our': 'our',
#              'Lory': 'Lory',
#              'important': 'important',
#              '."\'': '."\'',
#              'story': 'story',
#              'others': 'others',
#              'YOUR': 'YOUR',
#              'stood': 'stood',
#              'grown': 'grown',
#              'business': 'business',
#              'trees': 'trees',
#              'puppy': 'puppy',
#              'each': 'each',
#              'isn': 'isn',
#              'draw': 'draw',
#              'silent': 'silent',
#              'ground': 'ground',
#              'Cheshire': 'Cheshire',
#              'pleased': 'pleased',
#              'song': 'song',
#              'bread': 'bread',
#              'Five': 'Five',
#              'hedgehog': 'hedgehog',
#              'lobsters': 'lobsters',
#              'Soo': 'Soo',
#              'oop': 'oop',
#              'trouble': 'trouble',
#              'late': 'late',
#              'pocket': 'pocket',
#              'fell': 'fell',
#              'nice': 'nice',
#              'written': 'written',
#              'leaves': 'leaves',
#              'jumped': 'jumped',
#              'roof': 'roof',
#              'inches': 'inches',
#              'along': 'along',
#              'marked': 'marked',
#              'hold': 'hold',
#              'forgotten': 'forgotten',
#              'almost': 'almost',
#              'After': 'After',
#              'English': 'English',
#              'shoes': 'shoes',
#              'myself': 'myself',
#              'S': 'S',
#              'nonsense': 'nonsense',
#              'himself': 'himself',
#              'sir': 'sir',
#              'times': 'times',
#              'repeat': 'repeat',
#              'grin': 'grin',
#              '!"': '!"',
#              'understand': 'understand',
#              'William': 'William',
#              'pardon': 'pardon',
#              'trembling': 'trembling',
#              'subject': 'subject',
#              'fetch': 'fetch',
#              'sit': 'sit',
#              'politely': 'politely',
#              'WHAT': 'WHAT',
#              'melancholy': 'melancholy',
#              'One': 'One',
#              'liked': 'liked',
#              'has': 'has',
#              'piece': 'piece',
#              'executed': 'executed',
#              'ARE': 'ARE',
#              'does': 'does',
#              'broken': 'broken',
#              'chimney': 'chimney',
#              'full': 'full',
#              'Will': 'Will',
#              'loud': 'loud',
#              'sharp': 'sharp',
#              'Lizard': 'Lizard',
#              'guinea': 'guinea',
#              'pigs': 'pigs',
#              'arms': 'arms',
#              'youth': 'youth',
#              'serpent': 'serpent',
#              'sleep': 'sleep',
#              'fish': 'fish',
#              'sneezing': 'sneezing',
#              'told': 'told',
#              'pepper': 'pepper',
#              'ear': 'ear',
#              'dreadfully': 'dreadfully',
#              'writing': 'writing',
#              'Two': 'Two',
#              'Hearts': 'Hearts',
#              'exclaimed': 'exclaimed',
#              'executioner': 'executioner',
#              'school': 'school',
#              'e': 'e',
#              'tarts': 'tarts',
#              'evidence': 'evidence',
#              'twice': 'twice',
#              'sleepy': 'sleepy',
#              'stupid': 'stupid',
#              'across': 'across',
#              'rabbit': 'rabbit',
#              'curiosity': 'curiosity',
#              'passed': 'passed',
#              'somebody': 'somebody',
#              'home': 'home',
#              'likely': 'likely',
#              'aloud': 'aloud',
#              'walk': 'walk',
#              'Please': 'Please',
#              'asking': 'asking',
#              'night': 'night',
#              'sometimes': 'sometimes',
#              'walking': 'walking',
#              'ears': 'ears',
#              'sadly': 'sadly',
#              'shut': 'shut',
#              "('": "('",
#              "';": "';",
#              'WOULD': 'WOULD',
#              'simple': 'simple',
#              'cut': 'cut',
#              'finger': 'finger',
#              'ten': 'ten',
#              'nervous': 'nervous',
#              'altogether': 'altogether',
#              'remembered': 'remembered',
#              'happens': 'happens',
#              'shan': 'shan',
#              'pair': 'pair',
#              'nine': 'nine',
#              'until': 'until',
#              'kid': 'kid',
#              'dropped': 'dropped',
#              'usual': 'usual',
#              'morning': 'morning',
#              'Ah': 'Ah',
#              'SHE': 'SHE',
#              'wrong': 'wrong',
#              'sounded': 'sounded',
#              'strange': 'strange',
#              'seems': 'seems',
#              'stay': 'stay',
#              'Tell': 'Tell',
#              'sudden': 'sudden',
#              'water': 'water',
#              'case': 'case',
#              'swam': 'swam',
#              'nearer': 'nearer',
#              'speaking': 'speaking',
#              'sentence': 'sentence',
#              'shrill': 'shrill',
#              'angry': 'angry',
#              'crowded': 'crowded',
#              'means': 'means',
#              'notice': 'notice',
#              'race': 'race',
#              'exactly': 'exactly',
#              'dare': 'dare',
#              'confusion': 'confusion',
#              'call': 'call',
#              'reply': 'reply',
#              'finish': 'finish',
#              'impatiently': 'impatiently',
#              'sighed': 'sighed',
#              'temper': 'temper',
#              'young': 'young',
#              'nobody': 'nobody',
#              'moved': 'moved',
#              'Where': 'Where',
#              'Very': 'Very',
#              'doing': 'doing',
#              'direction': 'direction',
#              'stop': 'stop',
#              'interesting': 'interesting',
#              'become': 'become',
#              'write': 'write',
#              'shouldn': 'shouldn',
#              'taking': 'taking',
#              'shriek': 'shriek',
#              'An': 'An',
#              'drew': 'drew',
#              'sky': 'sky',
#              'instantly': 'instantly',
#              'surprise': 'surprise',
#              'height': 'height',
#              'quietly': 'quietly',
#              'hookah': 'hookah',
#              'man': 'man',
#              'stand': 'stand',
#              'often': 'often',
#              'eggs': 'eggs',
#              'between': 'between',
#              'While': 'While',
#              'everybody': 'everybody',
#              'meant': 'meant',
#              'waving': 'waving',
#              'All': 'All',
#              'clock': 'clock',
#              'sing': 'sing',
#              'twinkle': 'twinkle',
#              'treacle': 'treacle',
#              'M': 'M',
#              'Seven': 'Seven',
#              'faces': 'faces',
#              'procession': 'procession',
#              'pack': 'pack',
#              'knee': 'knee',
#              'whispered': 'whispered',
#              'flamingo': 'flamingo',
#              'Lobster': 'Lobster',
#              'Beautiful': 'Beautiful',
#              'evening': 'evening',
#              'pictures': 'pictures',
#              'worth': 'worth',
#              'natural': 'natural',
#              'hole': 'hole',
#              'sides': 'sides',
#              'fear': 'fear',
#              'managed': 'managed',
#              'fallen': 'fallen',
#              'earth': 'earth',
#              'several': 'several',
#              'WAS': 'WAS',
#              'sound': 'sound',
#              'girl': 'girl',
#              'mice': 'mice',
#              'bats': 'bats',
#              'passage': 'passage',
#              'corner': 'corner',
#              'except': 'except',
#              'tiny': 'tiny',
#              'second': 'second',
#              'led': 'led',
#              'shoulders': 'shoulders',
#              'paper': 'paper',
#              'taught': 'taught',
#              'deeply': 'deeply',
#              'drink': 'drink',
#              'ventured': 'ventured',
#              'reach': 'reach',
#              'sharply': 'sharply',
#              'severely': 'severely',
#              'fond': 'fond',
#              'ONE': 'ONE',
#              'person': 'person',
#              'care': 'care',
#              ').': ').',
#              'new': 'new',
#              'savage': 'savage',
#              'violently': 'violently',
#              'age': 'age',
#              'Mabel': 'Mabel',
#              'puzzling': 'puzzling',
#              'twelve': 'twelve',
#              'capital': 'capital',
#              '--"\'': '--"\'',
#              'On': 'On',
#              'With': 'With',
#              '"--': '"--',
#              'alone': 'alone',
#              'CAN': 'CAN',
#              'shrinking': 'shrinking',
#              'escape': 'escape',
#              'number': 'number',
#              'French': 'French',
#              'fire': 'fire',
#              'paws': 'paws',
#              'Are': 'Are',
#              'says': 'says',
#              'pale': 'pale',
#              'shore': 'shore',
#              'animals': 'animals',
#              'uncomfortable': 'uncomfortable',
#              'argument': 'argument',
#              'wanted': 'wanted',
#              'frowning': 'frowning',
#              'IT': 'IT',
#              'solemnly': 'solemnly',
#              'pointing': 'pointing',
#              'confused': 'confused',
#              'thimble': 'thimble',
#              'short': 'short',
#              'bowed': 'bowed',
#              '."': '."',
#              'Said': 'Said',
#              'judge': 'judge',
#              'breath': 'breath',
#              ',"': ',"',
#              'Hold': 'Hold',
#              'tongue': 'tongue',
#              'particular': 'particular',
#              'since': 'since',
#              'vanished': 'vanished',
#              'Mary': 'Mary',
#              'Ann': 'Ann',
#              '\'"': '\'"',
#              'By': 'By',
#              'chance': 'chance',
#              'ordered': 'ordered',
#              'answered': 'answered',
#              'Sure': 'Sure',
#              'yer': 'yer',
#              'honour': 'honour',
#              'THIS': 'THIS',
#              'COULD': 'COULD',
#              'hearing': 'hearing',
#              '?--': '?--',
#              'slate': 'slate',
#              'master': 'master',
#              'fellow': 'fellow',
#              'dead': 'dead',
#              'doubt': 'doubt',
#              'lay': 'lay',
#              'crowd': 'crowd',
#              'held': 'held',
#              'plan': 'plan',
#              'difficulty': 'difficulty',
#              'stick': 'stick',
#              'grass': 'grass',
#              ',"\'': ',"\'',
#              'perfectly': 'perfectly',
#              'none': 'none',
#              'questions': 'questions',
#              'decidedly': 'decidedly',
#              'thoughtfully': 'thoughtfully',
#              'green': 'green',
#              'HAVE': 'HAVE',
#              'screamed': 'screamed',
#              'indignantly': 'indignantly',
#              'taken': 'taken',
#              'lives': 'lives',
#              'otherwise': 'otherwise',
#              'dish': 'dish',
#              'days': 'days',
#              'kitchen': 'kitchen',
#              'soup': 'soup',
#              'jumping': 'jumping',
#              'carried': 'carried',
#              'hours': 'hours',
#              'busily': 'busily',
#              'beat': 'beat',
#              'wow': 'wow',
#              'verse': 'verse',
#              'creature': 'creature',
#              'grunted': 'grunted',
#              'Call': 'Call',
#              'fast': 'fast',
#              'crumbs': 'crumbs',
#              'shoulder': 'shoulder',
#              'twinkling': 'twinkling',
#              'HE': 'HE',
#              'sigh': 'sigh',
#              'bottom': 'bottom',
#              'Take': 'Take',
#              'begins': 'begins',
#              'rose': 'rose',
#              'rule': 'rule',
#              'arches': 'arches',
#              'players': 'players',
#              'ALL': 'ALL',
#              'Never': 'Never',
#              'hers': 'hers',
#              'Quadrille': 'Quadrille',
#              'sobs': 'sobs',
#              'porpoise': 'porpoise',
#              'mouths': 'mouths',
#              'adventures': 'adventures',
#              'Beau': 'Beau',
#              'ootiful': 'ootiful',
#              'jurors': 'jurors',
#              'verdict': 'verdict',
#              'officers': 'officers',
#              'suppressed': 'suppressed',
#              'jurymen': 'jurymen',
#              'Nothing': 'Nothing',
#              'verses': 'verses',
#              '[': '[',
#              'Adventures': 'Adventures',
#              'Wonderland': 'Wonderland',
#              'Down': 'Down',
#              'bank': 'bank',
#              'peeped': 'peeped',
#              'reading': 'reading',
#              'considering': 'considering',
#              'OF': 'OF',
#              'dark': 'dark',
#              'filled': 'filled',
#              'past': 'past',
#              'stairs': 'stairs',
#              'true': 'true',
#              'miles': 'miles',
#              'knowledge': 'knowledge',
#              'grand': 'grand',
#              'funny': 'funny',
#              'listening': 'listening',
#              'hope': 'hope',
#              'catch': 'catch',
#              'bat': 'bat',
#              'hurt': 'hurt',
#              'lost': 'lost',
#              'whiskers': 'whiskers',
#              'longer': 'longer',
#              'hanging': 'hanging',
#              'alas': 'alas',
#              'delight': 'delight',
#              'telescope': 'telescope',
#              'impossible': 'impossible',
#              'hoping': 'hoping',
#              'rules': 'rules',
#              'poison': 'poison',
#              'knife': 'knife',
#              'certain': 'certain',
#              'later': 'later',
#              'finding': 'finding',
#              'further': 'further',
#              'candle': 'candle',
#              'decided': 'decided',
#              'possibly': 'possibly',
#              'legs': 'legs',
#              'cake': 'cake',
#              'smaller': 'smaller',
#              'holding': 'holding',
#              'remained': 'remained',
#              'expecting': 'expecting',
#              'dull': 'dull',
#              'opening': 'opening',
#              'dears': 'dears',
#              'directions': 'directions',
#              'cry': 'cry',
#              'pattering': 'pattering',
#              'muttering': 'muttering',
#              'timid': 'timid',
#              'yesterday': 'yesterday',
#              'sorts': 'sorts',
#              'crossed': 'crossed',
#              'hoarse': 'hoarse',
#              'spread': 'spread',
#              'gently': 'gently',
#              'putting': 'putting',
#              ...})

# %%
last_letters=nltk.defaultdict(list)
words=nltk.corpus.words.words('en')
for word in words:
    key=word[-2:]
    last_letters[key].append(word)

# %%
last_letters
# Out:
# defaultdict(list,
#             {'A': ['A'],
#              'a': ['a'],
#              'aa': ['aa',
#               'assbaa',
#               'baa',
#               'chaa',
#               'mushaa',
#               'naa',
#               'saa',
#               'taa'],
#              'al': ['aal',
#               'Aaronical',
#               'abactinal',
#               'abaxial',
#               'abbatial',
#               'abbatical',
#               'abdal',
#               'abdominal',
#               'abdominogenital',
#               'abdominovaginal',
#               'abdominovesical',
#               'aberrational',
#               'abettal',
#               'abidal',
#               'abiogenetical',
#               'abiological',
#               'ablatival',
#               'ableptical',
#               'abnerval',
#               'abneural',
#               'abnormal',
#               'aboral',
#               'aboriginal',
#               'abortional',
#               'abranchial',
#               'absinthial',
#               'abstinential',
#               'abstractional',
#               'abterminal',
#               'abuttal',
#               'abysmal',
#               'abyssal',
#               'academial',
#               'academical',
#               'acalycal',
#               'acanonical',
#               'acanthial',
#               'acanthological',
#               'acapnial',
#               'acaricidal',
#               'acategorical',
#               'acaudal',
#               'accentual',
#               'accessional',
#               'accessorial',
#               'accidental',
#               'accidential',
#               'accipitral',
#               'acclinal',
#               'accommodational',
#               'accompanimental',
#               'accrementitial',
#               'accretal',
#               'accrual',
#               'accultural',
#               'accusal',
#               'accusatival',
#               'accusatorial',
#               'acephal',
#               'acetal',
#               'acetochloral',
#               'acetometrical',
#               'achenial',
#               'Acherontical',
#               'achordal',
#               'achronical',
#               'acidimetrical',
#               'Acieral',
#               'aclinal',
#               'acnodal',
#               'aconital',
#               'acoustical',
#               'acousticolateral',
#               'acquittal',
#               'acranial',
#               'acritical',
#               'acrobatical',
#               'acromial',
#               'acromiohumeral',
#               'acromiosternal',
#               'acronical',
#               'acropetal',
#               'acrostical',
#               'acrostichal',
#               'acrotarsial',
#               'acroterial',
#               'actinal',
#               'actinometrical',
#               'actinostomal',
#               'actinozoal',
#               'actional',
#               'activital',
#               'actual',
#               'actuarial',
#               'acutilingual',
#               'acyrological',
#               'adagial',
#               'adambulacral',
#               'Adamical',
#               'Adamitical',
#               'adaptational',
#               'adaptional',
#               'adaptorial',
#               'adaxial',
#               'additional',
#               'adenographical',
#               'adenoidal',
#               'adenological',
#               'adenomeningeal',
#               'adenoneural',
#               'adenopharyngeal',
#               'adhesional',
#               'adiaphoral',
#               'adiathermal',
#               'adiposogenital',
#               'adital',
#               'adjectional',
#               'adjectival',
#               'adjournal',
#               'admedial',
#               'administerial',
#               'administrational',
#               'admiral',
#               'admonitorial',
#               'adnerval',
#               'adneural',
#               'adnexal',
#               'adnominal',
#               'adoptional',
#               'adoral',
#               'adradial',
#               'adrectal',
#               'adrenal',
#               'adrenocortical',
#               'adrostral',
#               'adterminal',
#               'adulticidal',
#               'adumbral',
#               'advential',
#               'adventual',
#               'adverbial',
#               'advisal',
#               'aecial',
#               'aecidial',
#               'aeonial',
#               'aequoreal',
#               'aerial',
#               'aerical',
#               'aerobiological',
#               'aerodynamical',
#               'aerographical',
#               'aerological',
#               'aeromechanical',
#               'aeronautical',
#               'aerophysical',
#               'aerostatical',
#               'aerotechnical',
#               'aesthetical',
#               'afetal',
#               'affectional',
#               'affinal',
#               'affixal',
#               'aftermeal',
#               'aftertrial',
#               'afunctional',
#               'agal',
#               'agarwal',
#               'agathokakological',
#               'agential',
#               'agentival',
#               'ageometrical',
#               'aggradational',
#               'agitational',
#               'agitatorial',
#               'aglossal',
#               'agnomical',
#               'agnominal',
#               'agonal',
#               'agral',
#               'agrammatical',
#               'agrestal',
#               'agrestial',
#               'agricultural',
#               'agriological',
#               'agrobiological',
#               'agrogeological',
#               'agrological',
#               'agronomial',
#               'agronomical',
#               'agrosteral',
#               'agrostographical',
#               'agrostological',
#               'ahwal',
#               'aionial',
#               'Akal',
#               'al',
#               'albinal',
#               'albuminoidal',
#               'alchemical',
#               'alchemistical',
#               'alcoholometrical',
#               'aldermanical',
#               'alecithal',
#               'alemmal',
#               'alexipharmical',
#               'alexiterical',
#               'algaeological',
#               'algal',
#               'algebraical',
#               'algological',
#               'algometrical',
#               'alictisal',
#               'aliethmoidal',
#               'alimental',
#               'alinasal',
#               'aliseptal',
#               'alismal',
#               'alisphenoidal',
#               'aliturgical',
#               'alkahestical',
#               'alkalimetrical',
#               'alkaloidal',
#               'allantoidal',
#               'allegorical',
#               'allheal',
#               'alliteral',
#               'alliterational',
#               'allochiral',
#               'alloquial',
#               'allotropical',
#               'allotypical',
#               'alluvial',
#               'alodial',
#               'aloetical',
#               'alogical',
#               'alpestral',
#               'alphabetical',
#               'altimetrical',
#               'altitudinal',
#               'altricial',
#               'alumnal',
#               'alveolodental',
#               'alveololabial',
#               'alveololingual',
#               'alveolonasal',
#               'alveolosubnasal',
#               'Alvissmal',
#               'amacrinal',
#               'amaroidal',
#               'amatorial',
#               'ambassadorial',
#               'ambidextral',
#               'ambilateral',
#               'ambital',
#               'amblygonal',
#               'ambomalleal',
#               'ambosexual',
#               'ambrosial',
#               'ambulacral',
#               'ambulatorial',
#               'amburbial',
#               'amenorrheal',
#               'amental',
#               'amethodical',
#               'amianthoidal',
#               'amical',
#               'amidoacetal',
#               'amidosulphonal',
#               'aminoacetal',
#               'ammonal',
#               'ammoniacal',
#               'ammonical',
#               'amniochorial',
#               'amomal',
#               'amoral',
#               'amphiarthrodial',
#               'amphibial',
#               'amphibiological',
#               'amphibological',
#               'amphicribral',
#               'amphimictical',
#               'amphipodal',
#               'amphirhinal',
#               'amphitheatral',
#               'amphitheatrical',
#               'amphithecial',
#               'amphitokal',
#               'amphitropal',
#               'amphivasal',
#               'amphoral',
#               'amputational',
#               'amygdal',
#               'amygdaloidal',
#               'amyloidal',
#               'Amytal',
#               'Anabaptistical',
#               'anachronical',
#               'anachronismatical',
#               'anachronistical',
#               'anaclinal',
#               'anaetiological',
#               'anaglyphical',
#               'anaglyptical',
#               'anagogical',
#               'anagrammatical',
#               'anal',
#               'analeptical',
#               'analogical',
#               'analphabetical',
#               'analytical',
#               'anapaestical',
#               'anaphoral',
#               'anaphorical',
#               'anapophysial',
#               'anaptyctical',
#               'anarchal',
#               'anarchial',
#               'anarchical',
#               'anaretical',
#               'anathematical',
#               'anatomical',
#               'anatomicobiological',
#               'anatomicochirurgical',
#               'anatomicomedical',
#               'anatomicopathological',
#               'anatomicophysiological',
#               'anatomicosurgical',
#               'anatomopathological',
#               'anatropal',
#               'anaxial',
#               'ancestorial',
#               'ancestral',
#               'ancestrial',
#               'anchimonomineral',
#               'anchoretical',
#               'anchoritical',
#               'ancipital',
#               'anconal',
#               'anconeal',
#               'ancoral',
#               'androecial',
#               'androgonial',
#               'androgynal',
#               'androidal',
#               'anecdotal',
#               'anecdotical',
#               'anemological',
#               'anemometrical',
#               'anemonal',
#               'anetiological',
#               'aneurysmal',
#               'Angelical',
#               'angelical',
#               'angelological',
#               'anginal',
#               'angiospermal',
#               'anguineal',
#               'angulosplenial',
#               'angustiseptal',
#               'anhedral',
#               'anidiomatical',
#               'animadversional',
#               'animal',
#               'animastical',
#               'anisal',
#               'anisocercal',
#               'anisopleural',
#               'anisopodal',
#               'anisotropal',
#               'anisotropical',
#               'annal',
#               'anneal',
#               'annexal',
#               'annexational',
#               'annual',
#               'anococcygeal',
#               'anodal',
#               'anogenital',
#               'anomalistical',
#               'anomorhomboidal',
#               'anomural',
#               'anoperineal',
#               'anorectal',
#               'anormal',
#               'anorthographical',
#               'anospinal',
#               'anovesical',
#               'antagonistical',
#               'antal',
#               'antambulacral',
#               'antarchistical',
#               'antarctical',
#               'anteal',
#               'antebaptismal',
#               'antebrachial',
#               'antebridal',
#               'antecaecal',
#               'antecedental',
#               'anteclassical',
#               'anteconsonantal',
#               'antecoxal',
#               'antecubital',
#               'antediluvial',
#               'antedorsal',
#               'antefixal',
#               'antefurcal',
#               'anteinitial',
#               'antelegal',
#               'antemarginal',
#               'antemarital',
#               'antemedial',
#               'antemillennial',
#               'antemortal',
#               'antemural',
#               'antenarial',
#               'antenatal',
#               'antenatalitial',
#               'antennal',
#               'antenodal',
#               'anteorbital',
#               'antepalatal',
#               'antepaschal',
#               'antepatriarchal',
#               'antepectoral',
#               'anteprandial',
#               'antepredicamental',
#               'antereformational',
#               'anterevolutional',
#               'anterodorsal',
#               'anteroexternal',
#               'anterofrontal',
#               'anterointernal',
#               'anterolateral',
#               'anteromedial',
#               'anteroparietal',
#               'anteropygal',
#               'anterospinal',
#               'anteroventral',
#               'antesternal',
#               'anthecological',
#               'antheral',
#               'antheridial',
#               'antherozoidal',
#               'antherozooidal',
#               'anthoecological',
#               'anthological',
#               'anthrohopobiological',
#               'anthropical',
#               'anthropogeographical',
#               'anthropoidal',
#               'anthropological',
#               'anthropometrical',
#               'anthropomorphical',
#               'anthropomorphitical',
#               'anthropomorphological',
#               'anthroponomical',
#               'anthropophagical',
#               'anthroposophical',
#               'anthropoteleological',
#               'anthropotomical',
#               'antiastronomical',
#               'antibacterial',
#               'antibridal',
#               'antical',
#               'anticapital',
#               'anticatarrhal',
#               'anticeremonial',
#               'antichronical',
#               'anticlassical',
#               'anticlerical',
#               'anticlinal',
#               'anticommercial',
#               'anticonstitutional',
#               'anticonventional',
#               'antidemocratical',
#               'antidotal',
#               'antidotical',
#               'antidromal',
#               'antiecclesiastical',
#               'antieducational',
#               'antiempirical',
#               'antiepiscopal',
#               'antiepithelial',
#               'antievangelical',
#               'antifederal',
#               'antifeudal',
#               'antifrictional',
#               'antigrammatical',
#               'antigravitational',
#               'antihemorrheidal',
#               'antihierarchical',
#               'antiliberal',
#               'antiliturgical',
#               'antilogical',
#               'antimagistratical',
#               'antimalarial',
#               'antimaniacal',
#               'antimatrimonial',
#               'antimedical',
#               'antimedieval',
#               'antimetrical',
#               'antiministerial',
#               'antimonarchial',
#               'antimonarchical',
#               'antimonial',
#               'antimoral',
#               'antimusical',
#               'antimythical',
#               'antinational',
#               'antinatural',
#               'antineutral',
#               'antinial',
#               'antinomical',
#               'antinormal',
#               'antipapal',
#               'antipapistical',
#               'antiparalytical',
#               'antiparliamental',
#               'antipathetical',
#               'antipatriarchal',
#               'antipedal',
#               'antiperistatical',
#               'antipestilential',
#               'antiphilosophical',
#               'antiphonal',
#               'antiphonical',
#               'antiphrastical',
#               'antiphthisical',
#               'antiphysical',
#               'antipodal',
#               'antipolitical',
#               'antiprotozoal',
#               'antiprudential',
#               'antiradical',
#               'antirational',
#               'antiritual',
#               'antiroyal',
#               'antisacerdotal',
#               'antiscorbutical',
#               'antiseptical',
#               'antisimoniacal',
#               'antisiphonal',
#               'antiskeptical',
#               'antisocial',
#               'antispiritual',
#               'antistreptococcal',
#               'antistrophal',
#               'antisudoral',
#               'antisymmetrical',
#               'antitheistical',
#               'antitheological',
#               'antithetical',
#               'antitobacconal',
#               'antitraditional',
#               'antitragal',
#               'antitropal',
#               'antitropical',
#               'antitypal',
#               'antitypical',
#               'antivenereal',
#               'antiviral',
#               'antonomastical',
#               'antorbital',
#               'antral',
#               'antronasal',
#               'aortal',
#               'aorticorenal',
#               'apagogical',
#               'apartmental',
#               'apathetical',
#               'apathistical',
#               'apertural',
#               'aphakial',
#               'aphicidal',
#               'aphodal',
#               'aphorismical',
#               'aphrodisiacal',
#               'aphthongal',
#               'apical',
#               'apicultural',
#               'apioidal',
#               'aplacental',
#               'apneal',
#               'apocalyptical',
#               'apocryphal',
#               'apodal',
#               'apodemal',
#               'apodematal',
#               'apodictical',
#               'apogeal',
#               'apographal',
#               'apohyal',
#               'apologal',
#               'apologetical',
#               'apomictical',
#               'apophyseal',
#               'apoplasmodial',
#               'apoplectical',
#               'aporetical',
#               'apostatical',
#               'apostolical',
#               'apostrophal',
#               'apotelesmatical',
#               'apothecal',
#               'apothecial',
#               'apothegmatical',
#               'apotracheal',
#               'apozemical',
#               'apparitional',
#               'appeal',
#               'appellational',
#               'appendical',
#               'appendicial',
#               'appetitional',
#               'appositional',
#               'appraisal',
#               'appreciational',
#               'appressorial',
#               'approval',
#               'approximal',
#               'apsidal',
#               'apsychical',
#               'Aptal',
#               'apteral',
#               'apterial',
#               'apterygial',
#               'aptitudinal',
#               'apyrexial',
#               'aquacultural',
#               'aquarial',
#               'aquatical',
#               'aqueoglacial',
#               'aqueomercurial',
#               'aquicultural',
#               'aquincubital',
#               'aquintocubital',
#               'arachnidial',
#               'arachnoidal',
#               'arachnological',
#               'arbitral',
#               'arbitrational',
#               'arboral',
#               'arboreal',
#               'arborical',
#               'arboricultural',
#               'arcanal',
#               'archaeographical',
#               'archaeological',
#               'archaical',
#               'archangelical',
#               'archcriminal',
#               'archducal',
#               'archeal',
#               'archegonial',
#               'archesporial',
#               'archetypal',
#               'archetypical',
#               'archgomeral',
#               'archibenthal',
#               'archidiaconal',
#               'archiepiscopal',
#               'archiheretical',
#               'archimperial',
#               'archipallial',
#               'archiprelatical',
#               'archipterygial',
#               'archisymbolical',
#               'architectural',
#               'architraval',
#               'archival',
#               'archmarshal',
#               'archprelatical',
#               'archradical',
#               'archrascal',
#               'Arctogaeal',
#               'arcual',
#               'areal',
#               'areographical',
#               'areological',
#               'areometrical',
#               'argal',
#               'argental',
#               'argumental',
#               'Arianistical',
#               'aristocratical',
#               'aristodemocratical',
#               'aristological',
#               'arithmetical',
#               'armigeral',
#               'armorial',
#               'arousal',
#               'arrayal',
#               'arrhenal',
#               'arrhizal',
#               'arrhythmical',
#               'arrival',
#               'arsenal',
#               'arsenical',
#               'artal',
#               'arterial',
#               'arteriococcygeal',
#               'arteriorenal',
#               'arthral',
#               'arthritical',
#               'arthrodial',
#               'arthropodal',
#               'artificial',
#               'artistical',
#               'arval',
#               'arytenoidal',
#               'asbestoidal',
#               'ascaricidal',
#               'ascensional',
#               'ascetical',
#               'ascitical',
#               'ascogonial',
#               'ascomycetal',
#               'asexual',
#               'Asiatical',
#               'asocial',
#               'aspectual',
#               'asphyxial',
#               'asqueal',
#               'assertional',
#               'assertorial',
#               'assertorical',
#               'assessorial',
#               'assidual',
#               'associational',
#               'assonantal',
#               'Assyriological',
#               'asterial',
#               'asterismal',
#               'asternal',
#               'asteroidal',
#               'asthenical',
#               'asthmatical',
#               'astigmatical',
#               'astomatal',
#               'astragal',
#               'astragalocalcaneal',
#               'astragalocentral',
#               'astragalotibial',
#               'astral',
#               'astrochronological',
#               'astrolabical',
#               'astrological',
#               'astrometeorological',
#               'astrometrical',
#               'astronomical',
#               'astrophotometrical',
#               'astrophysical',
#               'astrospectral',
#               'asyllabical',
#               'asymbolical',
#               'asymmetrical',
#               'asymptotical',
#               'atabal',
#               'Ataigal',
#               'Ataiyal',
#               'atechnical',
#               'ateleological',
#               'atemporal',
#               'atheistical',
#               'atheological',
#               'athletical',
#               'atlantal',
#               'atlantoaxial',
#               'atmological',
#               'atmospherical',
#               'atmosteal',
#               'atokal',
#               'atomical',
#               'atomistical',
#               'atonal',
#               'atramental',
#               'atrial',
#               'atrioporal',
#               'atrochal',
#               'atropal',
#               'attentional',
#               'atterminal',
#               'Attical',
#               'attitudinal',
#               'attributal',
#               'atypical',
#               'auctorial',
#               'auditorial',
#               'auditual',
#               'augural',
#               'augurial',
#               'augustal',
#               'aural',
#               'auriculocranial',
#               'auriculoparietal',
#               'auriculotemporal',
#               'auriculovertical',
#               'aurigal',
#               'aurinasal',
#               'auronal',
#               'auroral',
#               'auspicial',
#               'Austral',
#               'austral',
#               'autacoidal',
#               'autarchical',
#               'autarkical',
#               'autecological',
#               'authentical',
#               'authorial',
#               'autobiographal',
#               'autobiographical',
#               'autochemical',
#               'autochthonal',
#               'autocratical',
#               'autocratorical',
#               'autogeneal',
#               'autographal',
#               'autographical',
#               'autointellectual',
#               'autological',
#               'automanual',
#               'automatical',
#               'automechanical',
#               'autonomical',
#               'autopsical',
#               'autoptical',
#               'autoschediastical',
#               'autosomal',
#               'autosymbolical',
#               'autumnal',
#               'auxetical',
#               'aval',
#               'Avernal',
#               'averral',
#               'aviatorial',
#               'avifaunal',
#               'avital',
#               'avolitional',
#               'avowal',
#               'Awabakal',
#               'axal',
#               'axial',
#               'axifugal',
#               'axiological',
#               'axiomatical',
#               'axisymmetrical',
#               'axofugal',
#               'axonal',
#               'axopetal',
#               'azimuthal',
#               'azocochineal',
#               'azonal',
#               'Baal',
#               'baal',
#               'Baalitical',
#               'bacchanal',
#               'Bacchical',
#               'bacillicidal',
#               'backpedal',
#               'bacterial',
#               'bactericidal',
#               'bacterioidal',
#               'bacteriological',
#               'bacterioscopical',
#               'bacteroidal',
#               'bakal',
#               'Bal',
#               'bal',
#               'Balaamitical',
#               'balanopreputial',
#               'balantidial',
#               'balladeroyal',
#               'balladical',
#               'Balmoral',
#               'balneal',
#               'balneological',
#               'balsamical',
#               'banal',
#               'bancal',
#               'bandboxical',
#               'baptismal',
#               'barbal',
#               'barbarical',
#               'barbital',
#               'Barmecidal',
#               'barometrical',
#               'baronetical',
#               'baronial',
#               'baroscopical',
#               'barristerial',
#               'barwal',
#               'basal',
#               'basial',
#               'basibranchial',
#               'basicranial',
#               'basidial',
#               'basidigital',
#               'basidorsal',
#               'basifacial',
#               'basifugal',
#               'basihyal',
#               'basilateral',
#               'basilical',
#               'basinasal',
#               'basinasial',
#               'basioccipital',
#               'basipetal',
#               'basipterygial',
#               'basiradial',
#               'basirhinal',
#               'basirostral',
#               'basisphenoidal',
#               'basitemporal',
#               'basiventral',
#               'basivertebral',
#               'bathyal',
#               'bathymetrical',
#               'bathyorographical',
#               'bathysmal',
#               'bathysophical',
#               'battological',
#               'bayal',
#               'beal',
#               'beatifical',
#               'bedismal',
#               'bedral',
#               'begettal',
#               'behavioral',
#               'beheadal',
#               'Belial',
#               'bemeal',
#               'benedictional',
#               'beneficential',
#               'beneficial',
#               'Bengal',
#               'benthal',
#               'benzal',
#               'bequeathal',
#               'berascal',
#               'bestial',
#               'bestowal',
#               'betrayal',
#               'betrothal',
#               'beylical',
#               'bharal',
#               'biacromial',
#               'biannual',
#               'biaxal',
#               'biaxial',
#               'Biblical',
#               'Biblicolegal',
#               'Biblicopsychological',
#               'bibliographical',
#               'bibliological',
#               'bibliomaniacal',
#               'bibliopolical',
#               'bibliothecal',
#               'bibliothecarial',
#               'bicameral',
#               'bicaudal',
#               'bicentennial',
#               'bicipital',
#               'bicollateral',
#               'biconical',
#               'biconsonantal',
#               'bicorporal',
#               'bicorporeal',
#               'bicrural',
#               'bicursal',
#               'bicylindrical',
#               'bidental',
#               'bidential',
#               'bidimensional',
#               'bidirectional',
#               'bidiurnal',
#               'biennial',
#               'bifacial',
#               'bifocal',
#               'bifrontal',
#               'bifurcal',
#               'bigeminal',
#               'bigential',
#               'bigonial',
#               'bijasal',
#               'bilabial',
#               'bilateral',
#               'bilharzial',
#               'bilingual',
#               'biliteral',
#               'bimanal',
#               'bimanual',
#               'bimensal',
#               'bimestrial',
#               'bimodal',
#               'binal',
#               'binational',
#               'binaural',
#               'binodal',
#               'binomial',
#               ...],
#              'ii': ['aalii',
#               'Acanthodii',
#               'Acanthopterygii',
#               'Actinopterygii',
#               'Aestii',
#               'amphiscii',
#               'apii',
#               'Aquarii',
#               'ascii',
#               'ascriptitii',
#               'Autobasisii',
#               'bacchii',
#               'Boii',
#               'Charadrii',
#               'Chondropterygii',
#               'Coracii',
#               'Crossopterygii',
#               'Curiatii',
#               'Damnii',
#               'Damnonii',
#               'Darii',
#               'Daunii',
#               'Elasmobranchii',
#               'Eubasidii',
#               'Euselachii',
#               'Frisii',
#               'genii',
#               'gladii',
#               'heii',
#               'Helvetii',
#               'Hemibasidii',
#               'Hemibranchii',
#               'Hemipodii',
#               'Herodii',
#               'Holomyarii',
#               'Homalosternii',
#               'Iapygii',
#               'Labyrinthibranchii',
#               'Leptocardii',
#               'Lophobranchii',
#               'Malacopterygii',
#               'manualii',
#               'Marsipobranchii',
#               'Nervii',
#               'oii',
#               'Parisii',
#               'periscii',
#               'Peucetii',
#               'Pharyngobranchii',
#               'Picarii',
#               'Pleuropterygii',
#               'Polymyarii',
#               'Pompeii',
#               'Protobasidii',
#               'Protoselachii',
#               'radii',
#               'Ramoosii',
#               'Riparii',
#               'Sagitarii',
#               'Scorpii',
#               'Selachii',
#               'Serpentarii',
#               'sextarii',
#               'socii',
#               'torii',
#               'triarii',
#               'Ubii',
#               'Xenopterygii'],
#              'am': ['aam',
#               'abeam',
#               'Abraham',
#               'Abram',
#               'acream',
#               'actinogram',
#               'Adam',
#               'Adoniram',
#               'adream',
#               'Adullam',
#               'aerogram',
#               'aerosteam',
#               'aetheogam',
#               'afoam',
#               'Agawam',
#               'agleam',
#               'agsam',
#               'Alnilam',
#               'Alnitham',
#               'am',
#               'amalgam',
#               'ambalam',
#               'amidstream',
#               'amphigam',
#               'amunam',
#               'anagram',
#               'Anam',
#               'anam',
#               'anemogram',
#               'Annam',
#               'Antietam',
#               'antifoam',
#               'antiparallelogram',
#               'arithmogram',
#               'arteriogram',
#               'ascham',
#               'Assam',
#               'asteam',
#               'astream',
#               'ataxiagram',
#               'audiogram',
#               'autogram',
#               'auxanogram',
#               'Baham',
#               'Bairam',
#               'bairnteam',
#               'Balaam',
#               'ballam',
#               'balsam',
#               'bam',
#               'Bantam',
#               'bantam',
#               'bargham',
#               'barogram',
#               'Bartram',
#               'beam',
#               'becram',
#               'bedlam',
#               'befoam',
#               'belam',
#               'beldam',
#               'beloam',
#               'bemadam',
#               'Bertram',
#               'bertram',
#               'beseam',
#               'bestream',
#               'Biham',
#               'Bikram',
#               'Birmingham',
#               'bokadam',
#               'Bram',
#               'bream',
#               'breastbeam',
#               'brecham',
#               'brontogram',
#               'brougham',
#               'buckram',
#               'caam',
#               'cablegram',
#               'cacam',
#               'caimacam',
#               'caimakam',
#               'cam',
#               'candlebeam',
#               'cardiagram',
#               'cardiogram',
#               'cardiosphygmogram',
#               'carpogam',
#               'cartogram',
#               'centigram',
#               'cephalogram',
#               'ceraunogram',
#               'chakram',
#               'chalazogam',
#               'Cham',
#               'cham',
#               'chandam',
#               'Cheltenham',
#               'Chiam',
#               'chinnam',
#               'cholecystogram',
#               'Christogram',
#               'chromatogram',
#               'chromogram',
#               'chronanagram',
#               'chronogram',
#               'circumparallelogram',
#               'Clallam',
#               'clam',
#               'cleam',
#               'cloam',
#               'cofferdam',
#               'commendam',
#               'contraparallelogram',
#               'Coquitlam',
#               'coram',
#               'Cotonam',
#               'counterstream',
#               'cowgram',
#               'cram',
#               'cream',
#               'crossbeam',
#               'cryptogam',
#               'cryptogram',
#               'crystallogram',
#               'Cujam',
#               'custodiam',
#               'cyclogram',
#               'cystogram',
#               'dactylogram',
#               'dam',
#               'daybeam',
#               'daydream',
#               'decagram',
#               'decigram',
#               'decream',
#               'demibuckram',
#               'demiram',
#               'dewbeam',
#               'diagram',
#               'digram',
#               'dittogram',
#               'downstream',
#               'dram',
#               'drawbeam',
#               'dream',
#               'duodenogram',
#               'Durham',
#               'dygogram',
#               'Ejam',
#               'electrocardiogram',
#               'electrocorticogram',
#               'electroencephalogram',
#               'enam',
#               'encephalogram',
#               'engram',
#               'enseam',
#               'entelam',
#               'enterogram',
#               'epigram',
#               'ergogram',
#               'exam',
#               'eyebeam',
#               'faham',
#               'fam',
#               'fanam',
#               'flam',
#               'fleam',
#               'flimflam',
#               'flotsam',
#               'fluidram',
#               'fluigram',
#               'foam',
#               'fogram',
#               'foregleam',
#               'Fram',
#               'fream',
#               'fulham',
#               'fullam',
#               'gam',
#               'ganam',
#               'gingham',
#               'glam',
#               'gleam',
#               'gloam',
#               'Goddam',
#               'Gotham',
#               'Graham',
#               'graham',
#               'gram',
#               'grandam',
#               'grogram',
#               'haemogram',
#               'hakam',
#               'ham',
#               'hammam',
#               'hardbeam',
#               'harmonogram',
#               'headstream',
#               'hectogram',
#               'heliogram',
#               'hemautogram',
#               'hemogram',
#               'hexagram',
#               'hierogram',
#               'Hiram',
#               'histogram',
#               'Hohokam',
#               'Homam',
#               'hornbeam',
#               'ideogram',
#               'ihram',
#               'imam',
#               'Ingram',
#               'inseam',
#               'insteam',
#               'interstream',
#               'interteam',
#               'Islam',
#               'isogram',
#               'isosultam',
#               'Jam',
#               'jam',
#               'Jeroboam',
#               'jetsam',
#               'jimjam',
#               'kerslam',
#               'kerwham',
#               'kilogram',
#               'kinetogram',
#               'klam',
#               'kokam',
#               'kromogram',
#               'kusam',
#               'kymogram',
#               'lactam',
#               'lam',
#               'leam',
#               'lettergram',
#               'licham',
#               'limberham',
#               'lipogram',
#               'loam',
#               'lockram',
#               'logogram',
#               'lyam',
#               'maam',
#               'macadam',
#               'madam',
#               'madapollam',
#               'magnetogram',
#               'Malayalam',
#               'Mam',
#               'Maranham',
#               'marconigram',
#               'marigram',
#               'marjoram',
#               'Masulipatam',
#               'melam',
#               'melodram',
#               'melogram',
#               'metagram',
#               'meteogram',
#               'meteorogram',
#               'metergram',
#               'microgram',
#               'midstream',
#               'milldam',
#               'milligram',
#               'millstream',
#               'minicam',
#               'Miriam',
#               'Mohineyam',
#               'mokaddam',
#               'monodram',
#               'monogram',
#               'moonbeam',
#               'Muharram',
#               'myocardiogram',
#               'myogram',
#               'myrabolam',
#               'myriagram',
#               'naam',
#               'nam',
#               'needham',
#               'nephogram',
#               'neurogram',
#               'Nizam',
#               'nizam',
#               'Noam',
#               'nomogram',
#               'oam',
#               'ogam',
#               'ogham',
#               'olam',
#               'ondagram',
#               'ondogram',
#               'opobalsam',
#               'optogram',
#               'orthodiagram',
#               'oscillogram',
#               'outbeam',
#               'outdream',
#               'outgleam',
#               'outscream',
#               'outseam',
#               'outsteam',
#               'outstream',
#               'overcram',
#               'overdream',
#               'overscream',
#               'overseam',
#               'overstream',
#               'palatogram',
#               'Pam',
#               'pam',
#               'pandaram',
#               'pannam',
#               'panoram',
#               'paragram',
#               'parallelogram',
#               'param',
#               'pelmatogram',
#               'pelycogram',
#               'pentagram',
#               'periodogram',
#               'petersham',
#               'phaenogam',
#               'phanerogam',
#               'phlebogram',
#               'phonautogram',
#               'phonogram',
#               'phospham',
#               'photogram',
#               'photomicrogram',
#               'photoradiogram',
#               'phraseogram',
#               'phrenogram',
#               'pictogram',
#               'pictoradiogram',
#               'pigeongram',
#               'pistolgram',
#               'pneumatogram',
#               'pneumogram',
#               'Pokomam',
#               'polarogram',
#               'pollam',
#               'polygam',
#               'polygram',
#               'popadam',
#               'porogam',
#               'praam',
#               'pram',
#               'presteam',
#               'prickmadam',
#               'prickseam',
#               'program',
#               'psychogram',
#               'punnigram',
#               'pyelogram',
#               'pyeloureterogram',
#               'quaedam',
#               'quickbeam',
#               'quickenbeam',
#               'quondam',
#               'quoniam',
#               'radiogram',
#               'radiotelegram',
#               'Ram',
#               'ram',
#               'ramstam',
#               'ream',
#               'redream',
#               'reetam',
#               'Rehoboam',
#               'reseam',
#               'restream',
#               'riddam',
#               'roam',
#               'rodham',
#               'roentgenogram',
#               'roundseam',
#               'saddirham',
#               'salaam',
#               'Sam',
#               'sam',
#               'Samsam',
#               'scam',
#               'schematogram',
#               'Schiedam',
#               'schoolmaam',
#               'scotogram',
#               'scram',
#               'scream',
#               'Sealyham',
#               'seam',
#               'seismogram',
#               'semibeam',
#               'senam',
#               'shadowgram',
#               'Sham',
#               'sham',
#               'shigram',
#               'shisham',
#               'shram',
#               'Shyam',
#               'Siam',
#               'silicam',
#               'Sinogram',
#               'siphonogam',
#               'sisham',
#               'skiagram',
#               'skiogram',
#               'slam',
#               'smitham',
#               'soam',
#               'spectrogram',
#               'spectroheliogram',
#               'sphenogram',
#               'sphygmogram',
#               'spirogram',
#               'squam',
#               'squeam',
#               'Sriram',
#               'stam',
#               'steam',
#               'steganogram',
#               'stereogram',
#               'stereoroentgenogram',
#               'stram',
#               'stream',
#               'stroam',
#               'sultam',
#               'sunbeam',
#               'Surinam',
#               'swam',
#               'tachogram',
#               'tam',
#               'tangham',
#               'tangram',
#               'tanquam',
#               'taysaam',
#               'team',
#               'telautogram',
#               'telegram',
#               'teleoroentgenogram',
#               'telethermogram',
#               'tetragram',
#               'thermogram',
#               'thiuram',
#               'thram',
#               'Tiam',
#               'tomogram',
#               'tonogram',
#               'torsiogram',
#               'tram',
#               'trigram',
#               'trimtram',
#               'tripmadam',
#               'Tristam',
#               'Tristram',
#               'Tzaam',
#               'uncram',
#               'uncream',
#               'undam',
#               'underbeam',
#               'underream',
#               'underseam',
#               'understream',
#               'unjam',
#               'unram',
#               'unseam',
#               'unteam',
#               'upsteam',
#               'upstream',
#               'ureterogram',
#               'ureteropyelogram',
#               'urethrogram',
#               'urogram',
#               'ursigram',
#               'uterogram',
#               'utinam',
#               'vagogram',
#               'ventriculogram',
#               'viagram',
#               'weam',
#               'weathergleam',
#               'weekwam',
#               'wham',
#               'whangam',
#               'wheam',
#               'whimwham',
#               'whiteseam',
#               'widdendream',
#               'wigwam',
#               'William',
#               'Wishram',
#               'withernam',
#               'wolfram',
#               'yam'],
#              'ni': ['Aani',
#               'Acanthodini',
#               'afghani',
#               'Alamanni',
#               'alani',
#               'Alemanni',
#               'alumni',
#               'amani',
#               'amini',
#               'Anacanthini',
#               'ani',
#               'Anoplonemertini',
#               'arni',
#               'Arverni',
#               'Azerbaijani',
#               'bagani',
#               'bagattini',
#               'Bahmani',
#               'baldachini',
#               'bambini',
#               'bani',
#               'Barouni',
#               'begani',
#               'Beni',
#               'beni',
#               'Bhavani',
#               'Bhowani',
#               'bhungini',
#               'Bhutani',
#               'bikini',
#               'Bimini',
#               'Bini',
#               'Bodoni',
#               'Boni',
#               'Borani',
#               'Brahmani',
#               'campanini',
#               'Carabini',
#               'Chamkanni',
#               'ciceroni',
#               'Coelacanthini',
#               'Ctenodipterini',
#               'Dakhini',
#               'Dani',
#               'Dardani',
#               'decani',
#               'dharani',
#               'dhoni',
#               'Durani',
#               'Edoni',
#               'Epigoni',
#               'Ermani',
#               'fantoccini',
#               'Fellani',
#               'frangipani',
#               'Garshuni',
#               'Gemini',
#               'ginglyni',
#               'Giovanni',
#               'Guadagnini',
#               'Guarani',
#               'guarani',
#               'hernani',
#               'Hindustani',
#               'Hogni',
#               'Hoplonemertini',
#               'Iceni',
#               'Ioni',
#               'Ipalnemohuani',
#               'Irani',
#               'jamdani',
#               'jampani',
#               'Jatni',
#               'jinni',
#               'Joni',
#               'Kaldani',
#               'kangani',
#               'Karshuni',
#               'Khokani',
#               'Kohistani',
#               'kompeni',
#               'kongoni',
#               'konini',
#               'Konkani',
#               'kulkarni',
#               'Kullani',
#               'Kumni',
#               'lazzaroni',
#               'Macarani',
#               'macaroni',
#               'magani',
#               'maharani',
#               'mani',
#               'Marcomanni',
#               'Marconi',
#               'marconi',
#               'Mazanderani',
#               'Mesonemertini',
#               'Metanemertini',
#               'Microcyprini',
#               'mistassini',
#               'Mitanni',
#               'Monsoni',
#               'Mousoni',
#               'Multani',
#               'Musalmani',
#               'nachani',
#               'Nahani',
#               'Nazerini',
#               'Nemertini',
#               'ni',
#               'Notidani',
#               'nunni',
#               'Ogboni',
#               'Omani',
#               'Pakistani',
#               'Palaeechini',
#               'Palaeonemertini',
#               'Pani',
#               'Payni',
#               'Pelecani',
#               'penni',
#               'pepperoni',
#               'Platyrhini',
#               'Platyrrhini',
#               'Pleuracanthini',
#               'Protonemertini',
#               'quattrini',
#               'rabboni',
#               'Rajasthani',
#               'rani',
#               'Ronni',
#               'Roxolani',
#               'Safini',
#               'Sakyamuni',
#               'Samani',
#               'Samnani',
#               'Saponi',
#               'sasani',
#               'Sauraseni',
#               'scaloni',
#               'Sclerogeni',
#               'Sekani',
#               'Sequani',
#               'Shakyamuni',
#               'Sherani',
#               'Sicani',
#               'sileni',
#               'Sistani',
#               'soprani',
#               'Sudani',
#               'Sunni',
#               'synthroni',
#               'Tarkalani',
#               'Tarkani',
#               'Taurini',
#               'termini',
#               'Timani',
#               'timpani',
#               'Tinni',
#               'tiponi',
#               'Tututni',
#               'tympani',
#               'Tyranni',
#               'Tyrrheni',
#               'uncini',
#               'Vestini',
#               'Wangoni',
#               'Xenacanthini',
#               'Yemeni',
#               'yeni',
#               'zecchini',
#               'zemni',
#               'zucchini',
#               'Zuni'],
# ...
#               'whirroo',
#               'whoo',
#               'woo',
#               'woohoo',
#               'Yahoo',
#               'yahoo',
#               'Yazoo',
#               'zoo',
#               'zoozoo'],
#              'bs': ['Babs',
#               'begobs',
#               'dibs',
#               'dubs',
#               'grubs',
#               'molligrubs',
#               'mulligrubs',
#               'nabs',
#               'nibs',
#               'nobs',
#               'plebs',
#               'pobs',
#               'scobs'],
#              'fo': ['balafo',
#               'bufo',
#               'Fakofo',
#               'fifo',
#               'impofo',
#               'lifo',
#               'Ofo',
#               'Singfo'],
#              'wu': ['Balawu'],
#              'ji': ['Barkinji',
#               'basenji',
#               'bostanji',
#               'Fiji',
#               'fuji',
#               'hadji',
#               'howadji',
#               'Kanauji',
#               'Kanji',
#               'Kermanji',
#               'Koldaji',
#               'koradji',
#               'Romaji',
#               'shoji',
#               'suji',
#               'tji',
#               'uji',
#               'yammadji'],
#              'yk': ['bashlyk', 'huvelyk', 'Kumyk', 'sarlyk'],
#              'ub': ['bathtub',
#               'bedaub',
#               'bedub',
#               'Beelzebub',
#               'blub',
#               'bub',
#               'cherub',
#               'chub',
#               'club',
#               'cub',
#               'daub',
#               'disdub',
#               'drub',
#               'dub',
#               'flub',
#               'flubdub',
#               'fub',
#               'gaub',
#               'glub',
#               'grub',
#               'hub',
#               'hubbub',
#               'inrub',
#               'interclub',
#               'knub',
#               'misdaub',
#               'moneygrub',
#               'nub',
#               'ouroub',
#               'overscrub',
#               'pub',
#               'redaub',
#               'redub',
#               'rerub',
#               'rescrub',
#               'resnub',
#               'Reub',
#               'roub',
#               'rub',
#               'sandclub',
#               'scrub',
#               'semishrub',
#               'shrub',
#               'sillabub',
#               'slub',
#               'snub',
#               'strub',
#               'stub',
#               'sub',
#               'subshrub',
#               'succub',
#               'swilltub',
#               'trillibub',
#               'trub',
#               'tub',
#               'unclub',
#               'undaub',
#               'underclub',
#               'undergrub',
#               'underscrub',
#               'undershrub',
#               'undertub',
#               'undub',
#               'washtub',
#               'woodgrub',
#               'zebub',
#               'zermahbub'],
#              'bt': ['bedebt',
#               'contradebt',
#               'debt',
#               'doubt',
#               'indebt',
#               'misdoubt',
#               'overdoubt',
#               'predoubt',
#               'redoubt',
#               'superdebt'],
#              'rf': ['bedwarf',
#               'bescarf',
#               'bescurf',
#               'corf',
#               'dwarf',
#               'enserf',
#               'hippocerf',
#               'hircocerf',
#               'Hurf',
#               'kerf',
#               'orf',
#               'overscurf',
#               'returf',
#               'scarf',
#               'scharf',
#               'scurf',
#               'semiserf',
#               'serf',
#               'shurf',
#               'surf',
#               'swarf',
#               'tharf',
#               'turf',
#               'underturf',
#               'unturf',
#               'urf',
#               'warf',
#               'werf',
#               'wharf',
#               'wheelswarf',
#               'zarf'],
#              'iz': ['befriz',
#               'biz',
#               'cafiz',
#               'cahiz',
#               'extraquiz',
#               'friz',
#               'hafiz',
#               'kafiz',
#               'Kirghiz',
#               'Liz',
#               'Mustahfiz',
#               'phiz',
#               'quiz',
#               'requiz',
#               'rheumatiz',
#               'swiz',
#               'Tabriz',
#               'tafwiz',
#               'whiz',
#               'wiz'],
#              'uc': ['beglerbegluc',
#               'begluc',
#               'bonduc',
#               'caoutchouc',
#               'Coosuc',
#               'douc',
#               'eruc',
#               'gweduc',
#               'Luc',
#               'mucluc',
#               'Nipmuc'],
#              'wk': ['begowk',
#               'bowk',
#               'cawk',
#               'chawk',
#               'chowk',
#               'clawk',
#               'dorhawk',
#               'drawk',
#               'fowk',
#               'gawk',
#               'goshawk',
#               'gowk',
#               'hawk',
#               'howk',
#               'jayhawk',
#               'lawk',
#               'mawk',
#               'Mohawk',
#               'mollyhawk',
#               'mousehawk',
#               'nighthawk',
#               'owk',
#               'pawk',
#               'quawk',
#               'scrawk',
#               'snowk',
#               'sorehawk',
#               'sparhawk',
#               'squawk',
#               'tomahawk',
#               'winklehawk'],
#              'ws': ['bellows',
#               'blackfellows',
#               'braws',
#               'flews',
#               'forenews',
#               'gallows',
#               'Kabbeljaws',
#               'news',
#               'scapegallows',
#               'shallows',
#               'slows',
#               'taws',
#               'trews',
#               'yaws',
#               'yellows'],
#              'nj': ['benj', 'gunj', 'munj'],
#              'jy': ['Benjy', 'benjy', 'Takhtadjy'],
#              'ij': ['Bhumij', 'hajilij'],
#              'gg': ['bigg',
#               'egg',
#               'gegg',
#               'golliwogg',
#               'Gregg',
#               'Luggnagg',
#               'mugg',
#               'overegg',
#               'semiegg',
#               'wugg',
#               'yegg'],
#              'nh': ['binh', 'hunh', 'sinh', 'tanh', 'Vietminh'],
#              'rr': ['birr',
#               'burr',
#               'carr',
#               'charr',
#               'chirr',
#               'churr',
#               'curr',
#               'darr',
#               'err',
#               'evechurr',
#               'flurr',
#               'girr',
#               'grr',
#               'gurr',
#               'harr',
#               'hurr',
#               'narr',
#               'nightchurr',
#               'parr',
#               'pirr',
#               'porr',
#               'purr',
#               'shirr',
#               'skirr',
#               'smurr',
#               'squirr',
#               'susurr',
#               'tarr',
#               'tirr',
#               'tirrwirr',
#               'turr',
#               'Tyrr',
#               'wirr',
#               'yarr',
#               'yirr'],
#              'zy': ['blazy',
#               'bleezy',
#               'blowzy',
#               'boozy',
#               'breezy',
#               'bronzy',
#               'buzzy',
#               'Chazy',
#               'cozy',
#               'crazy',
#               'dazy',
#               'dizzy',
#               'dozy',
#               'enfrenzy',
#               'fezzy',
#               'fizzy',
#               'floozy',
#               'fozy',
#               'franzy',
#               'frenzy',
#               'friezy',
#               'frizzy',
#               'frowzy',
#               'furzy',
#               'fuzzy',
#               'gauzy',
#               'gazy',
#               'glazy',
#               'groszy',
#               'hazy',
#               'heezy',
#               'Izzy',
#               'jazzy',
#               'Jozy',
#               'lawzy',
#               'lazy',
#               'mazy',
#               'mizzy',
#               'muzzy',
#               'nizy',
#               'oozy',
#               'quartzy',
#               'quizzy',
#               'refrenzy',
#               'ritzy',
#               'Shortzy',
#               'sizy',
#               'sleazy',
#               'sneezy',
#               'snoozy',
#               'squeezy',
#               'Suzy',
#               'tanzy',
#               'tizzy',
#               'topazy',
#               'trotcozy',
#               'twazzy',
#               'unbreezy',
#               'unfrizzy',
#               'wheezy',
#               'woozy',
#               'wuzzy',
#               'yezzy'],
#              'sn': ['bosn',
#               'hisn',
#               'latitudinarianisn',
#               'lessn',
#               'shisn',
#               'thisn'],
#              'uw': ['bouw', 'dauw', 'paauw', 'spreeuw'],
#              'fs': ['briefs', 'gruffs', 'hoofs', 'ziffs'],
#              'Bu': ['Bu'],
#              'dh': ['Buddh',
#               'Budh',
#               'ceilidh',
#               'dosadh',
#               'edh',
#               'fardh',
#               'lamedh',
#               'Miledh',
#               'sadh',
#               'samadh',
#               'shradh',
#               'yodh'],
#              'hl': ['buhl', 'Kjeldahl', 'Kohl', 'kohl', 'peuhl', 'schlemihl'],
#              'hr': ['buhr',
#               'Duhr',
#               'guhr',
#               'kieselguhr',
#               'Landwehr',
#               'Lavehr',
#               'lehr',
#               'mohr',
#               'tahr',
#               'Wanderjahr'],
#              'C': ['C'],
#              'c': ['c'],
#              'xl': ['cacomixl'],
#              'fh': ['cafh'],
#              'lx': ['calx', 'falx'],
#              'ih': ['chih', 'Dabih', 'shih', 'sirih', 'Sugih'],
#              'xo': ['Cixo', 'Cotoxo', 'Moxo', 'myxo'],
#              'pr': ['copr'],
#              'ez': ['cortez',
#               'fez',
#               'Geez',
#               'gez',
#               'Inez',
#               'Jemez',
#               'jerez',
#               'knez',
#               'Martinez',
#               'Megrez',
#               'Natchez',
#               'shaatnez',
#               'slepez',
#               'terfez',
#               'tez',
#               'yez'],
#              'wm': ['crawm', 'cwm', 'gawm', 'hawm', 'scrawm', 'shawm'],
#              'yp': ['cyp',
#               'gyp',
#               'hydropolyp',
#               'hyp',
#               'machopolyp',
#               'polyp',
#               'scyphopolyp',
#               'tryp'],
#              'D': ['D'],
#              'd': ['d'],
#              'gu': ['degu',
#               'Fingu',
#               'fugu',
#               'gugu',
#               'jikungu',
#               'kagu',
#               'Kingu',
#               'Kodagu',
#               'kongu',
#               'Mosgu',
#               'Musgu',
#               'Telegu',
#               'Telugu',
#               'tengu',
#               'Wambugu'],
#              'ev': ['dev',
#               'Kislev',
#               'lev',
#               'Mev',
#               'Rajeev',
#               'rev',
#               'Rotanev',
#               'Sanjeev'],
#              'dl': ['dirndl', 'stradl'],
#              'gt': ['doigt', 'togt'],
#              'wf': ['dowf', 'gowf'],
#              'wp': ['dowp', 'mawp', 'yawp'],
#              'mm': ['dramm', 'Emm'],
#              'E': ['E'],
#              'e': ['e'],
#              'Ed': ['Ed'],
#              'Em': ['Em'],
#              'yi': ['Euahlayi', 'kiyi', 'pernyi'],
#              'F': ['F'],
#              'f': ['f'],
#              'nz': ['fackeltanz', 'Gunz', 'Heinz', 'Hienz', 'schanz'],
#              'rz': ['fahlerz', 'Feramorz', 'halerz', 'schwarz'],
#              'vn': ['favn'],
#              'lg': ['Firbolg'],
#              'Fo': ['Fo'],
#              'gr': ['Folkvangr'],
#              'md': ['fremd'],
#              'G': ['G'],
#              'g': ['g'],
#              'Ga': ['Ga'],
#              'aj': ['gaj',
#               'Kaj',
#               'kharaj',
#               'Natraj',
#               'Raj',
#               'raj',
#               'saj',
#               'samaj',
#               'swaraj',
#               'taj'],
#              'sl': ['gantsl', 'topsl'],
#              'mh': ['gascromh', 'ollamh', 'samh'],
#              'Ge': ['Ge'],
#              'kt': ['gedackt', 'gedeckt', 'takt'],
#              'pp': ['genapp',
#               'kapp',
#               'Lapp',
#               'repp',
#               'ropp',
#               'skeipp',
#               'stupp',
#               'typp',
#               'wapp',
#               'yapp'],
#              'uz': ['Ghuz', 'guz', 'hakenkreuz', 'Oghuz', 'suz', 'whuz'],
#              'Gi': ['Gi'],
#              'mr': ['Glathsheimr'],
#              'sz': ['grosz', 'kuvasz'],
#              'nl': ['gunl'],
#              'H': ['H'],
#              'h': ['h'],
#              'dj': ['hadj'],
#              'iu': ['halibiu',
#               'Keftiu',
#               'Liukiu',
#               'maniu',
#               'Sergiu',
#               'sucuriu',
#               'ushabtiu'],
#              'rv': ['Harv'],
#              'yz': ['hayz', 'koksaghyz'],
#              'ml': ['heml'],
#              'wt': ['hewt',
#               'mowt',
#               'nawt',
#               'newt',
#               'nowt',
#               'sawt',
#               'sowt',
#               'thowt',
#               'whewt',
#               'wowt',
#               'yowt'],
#              'Ho': ['Ho'],
#              'Hu': ['Hu'],
#              'Hy': ['Hy'],
#              'I': ['I'],
#              'i': ['i'],
#              'Io': ['Io'],
#              'aq': ['Iraq'],
#              'qi': ['Iraqi'],
#              'J': ['J'],
#              'j': ['j'],
#              'Ji': ['Ji'],
#              'Jo': ['Jo'],
#              'lr': ['jodelr', 'thulr'],
#              'Ju': ['Ju'],
#              'K': ['K'],
#              'k': ['k'],
#              'vu': ['kivu'],
#              'Ko': ['Ko'],
#              'pf': ['Kulturkampf'],
#              'L': ['L'],
#              'l': ['l'],
#              'iy': ['lesiy'],
#              'Lo': ['Lo'],
#              'qa': ['Louiqa'],
#              'Lu': ['Lu'],
#              'M': ['M'],
#              'm': ['m'],
#              'Ma': ['Ma'],
#              'lc': ['megotalc', 'talc'],
#              'jl': ['mijl'],
#              'Mo': ['Mo'],
#              'dv': ['Mordv'],
#              'Mr': ['Mr'],
#              'N': ['N'],
#              'n': ['n'],
#              'bk': ['nabk'],
#              'iq': ['nastaliq'],
#              'tr': ['natr', 'Petr', 'Piotr'],
#              'mk': ['naumk'],
#              'jd': ['Nejd'],
#              'No': ['No'],
#              'O': ['O'],
#              'o': ['o'],
#              'Od': ['Od'],
#              'Og': ['Og'],
#              'Ok': ['Ok'],
#              'fd': ['okshoofd', 'Wafd'],
#              'zd': ['Ormazd'],
#              'Os': ['Os'],
#              'P': ['P'],
#              'p': ['p'],
#              'Po': ['Po'],
#              'cq': ['Pontacq'],
#              'pl': ['pronpl'],
#              'Q': ['Q'],
#              'q': ['q'],
#              'R': ['R'],
#              'r': ['r'],
#              'dt': ['Rembrandt', 'veldt', 'zuurveldt'],
#              'kk': ['rikk'],
#              'Ro': ['Ro'],
#              'yt': ['royt', 'scyt', 'treckschuyt', 'tryt', 'tyt'],
#              'S': ['S'],
#              's': ['s'],
#              'dr': ['Sadr', 'sadr'],
#              'hh': ['sahh'],
#              'jk': ['satlijk'],
#              'lz': ['schmelz'],
#              'lh': ['Shilh'],
#              'oq': ['shoq'],
#              'gd': ['smaragd'],
#              'uv': ['struv', 'thruv'],
#              'uu': ['Suu'],
#              'T': ['T'],
#              't': ['t'],
#              'eq': ['Tareq'],
#              'Td': ['Td'],
#              'tn': ['thatn'],
#              'Ti': ['Ti'],
#              'yg': ['tyg'],
#              'U': ['U'],
#              'u': ['u'],
#              'Ud': ['Ud'],
#              'hd': ['unskaithd'],
#              'sg': ['uruisg'],
#              'V': ['V'],
#              'v': ['v'],
#              'Vu': ['Vu'],
#              'W': ['W'],
#              'w': ['w'],
#              'Wa': ['Wa'],
#              'kf': ['wakf'],
#              'zn': ['Wezn'],
#              'Wu': ['Wu'],
#              'X': ['X'],
#              'x': ['x'],
#              'Y': ['Y'],
#              'y': ['y'],
#              'Z': ['Z'],
#              'z': ['z']})

# %%
counts=nltk.defaultdict(int)
for word in nltk.corpus.gutenberg.words('milton-paradise.txt'):
    counts[word]+=1

# %%
[key for (key, values) in counts.items() if values==32]
# Out:
# ['mortal',
#  'Against',
#  'Him',
#  'There',
#  'brought',
#  'King',
#  'virtue',
#  'every',
#  'been',
#  'thine']

# %%
pos = {'colorless': 'ADJ', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}
pos2=dict((value,key) for (key,value) in pos.items())

# %%
pos2['N']
# Out:
# 'ideas'

# %%
pos['ideas']
# Out:
# 'N'

# %%
pos.update({'cats': 'N', 'scratch': 'V', 'peacefully': 'ADV', 'old': 'ADJ'})

# %%
pos
# Out:
# {'colorless': 'ADJ',
#  'ideas': 'N',
#  'sleep': 'V',
#  'furiously': 'ADV',
#  'cats': 'N',
#  'scratch': 'V',
#  'peacefully': 'ADV',
#  'old': 'ADJ'}

# %%
pos2=nltk.defaultdict(list)
for key,value in pos.items():
    pos2[value].append(key)

# %% [markdown]
# here we created defaultdict of list so we have done append

# %%
pos2
# Out:
# defaultdict(list,
#             {'ADJ': ['colorless', 'old'],
#              'N': ['ideas', 'cats'],
#              'V': ['sleep', 'scratch'],
#              'ADV': ['furiously', 'peacefully']})

# %%
pos2=nltk.Index((value,key) for (key,value) in pos.items())

# %%
pos2
# Out:
# Index(list,
#       {'ADJ': ['colorless', 'old'],
#        'N': ['ideas', 'cats'],
#        'V': ['sleep', 'scratch'],
#        'ADV': ['furiously', 'peacefully']})
