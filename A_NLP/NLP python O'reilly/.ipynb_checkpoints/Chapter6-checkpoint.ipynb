# %%
from nltk.corpus import brown

# %%
brown_sent=brown.tagged_sents(categories='news')
brown_sent
# Out:
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atlanta', 'NP-TL'), ("''", "''"), ('for', 'IN'), ('the', 'AT'), ('manner', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'AT'), ('election', 'NN'), ('was', 'BEDZ'), ('conducted', 'VBN'), ('.', '.')], ...]

# %%
brown_sents=brown.sents(categories='news')
brown_sents[2007]
# Out:
# ['Various',
#  'of',
#  'the',
#  'apartments',
#  'are',
#  'of',
#  'the',
#  'terrace',
#  'type',
#  ',',
#  'being',
#  'on',
#  'the',
#  'ground',
#  'floor',
#  'so',
#  'that',
#  'entrance',
#  'is',
#  'direct',
#  '.']

# %%
unigram_tagger=nltk.UnigramTagger(brown_sent)

# %%
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
brown_sent[2007]
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'CS'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
from pickle import dump
output=open('t2.pkl','wb')
dump('t2',output,-1)
output.close()

# %%
from pickle import load
input=open('t2.pkl','rb')
tagger=load(input)
input.close()

# %%
text = """The board's action shows what free enterprise
     is up against in our complex maze of regulatory laws ."""
tokens=text.split()
# tagger.tag(tokens)

# %%
def gender_features(word):
    return{'last letter':word[-1]}

gender_features('Rishav')
# Out:
# {'last letter': 'v'}

# %%
from nltk.corpus import names
import random
names=([(name,'male') for name in names.words('male.txt')]+\
       [(name,'female') for name in names.words('female.txt')])

# %%
random.shuffle(names)

# %%
featuresets=[(gender_features(n),g) for n,g in names]

# %%
train_set,test_set=featuresets[500:],featuresets[:500]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
train_set[:10]
# Out:
# [({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 't'}, 'male')]

# %%
classifier.classify(gender_features('Neo'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Rishav'))
# Out:
# 'male'

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.774

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              last letter = 'a'            female : male   =     34.1 : 1.0
#              last letter = 'k'              male : female =     32.2 : 1.0
#              last letter = 'v'              male : female =     16.4 : 1.0
#              last letter = 'f'              male : female =     15.3 : 1.0
#              last letter = 'p'              male : female =     12.5 : 1.0
#              last letter = 'd'              male : female =      9.9 : 1.0
#              last letter = 'm'              male : female =      8.3 : 1.0
#              last letter = 'o'              male : female =      7.8 : 1.0
#              last letter = 'r'              male : female =      6.6 : 1.0
#              last letter = 'g'              male : female =      5.7 : 1.0

# %%
from nltk.classify import apply_features
train_set=apply_features(gender_features,names[500:])
test_set=apply_features(gender_features,names[:500])

# %%
train_set
# Out:
# [({'last letter': 'y'}, 'male'), ({'last letter': 'a'}, 'female'), ...]

# %%
def gender_features2(name):
    features={}
    features['firstletter']=name[0].lower()
    features['lastname']=name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features['count(%s)'%letter]=name.lower().count(letter)
        features['has(%s)'%letter]=(letter in name.lower())
    return features

# %%
gender_features2('John')
# Out:
# {'firstletter': 'j',
#  'lastname': 'n',
#  'count(a)': 0,
#  'has(a)': False,
#  'count(b)': 0,
#  'has(b)': False,
#  'count(c)': 0,
#  'has(c)': False,
#  'count(d)': 0,
#  'has(d)': False,
#  'count(e)': 0,
#  'has(e)': False,
#  'count(f)': 0,
#  'has(f)': False,
#  'count(g)': 0,
#  'has(g)': False,
#  'count(h)': 1,
#  'has(h)': True,
#  'count(i)': 0,
#  'has(i)': False,
#  'count(j)': 1,
#  'has(j)': True,
#  'count(k)': 0,
#  'has(k)': False,
#  'count(l)': 0,
#  'has(l)': False,
#  'count(m)': 0,
#  'has(m)': False,
#  'count(n)': 1,
#  'has(n)': True,
#  'count(o)': 1,
#  'has(o)': True,
#  'count(p)': 0,
#  'has(p)': False,
#  'count(q)': 0,
#  'has(q)': False,
#  'count(r)': 0,
#  'has(r)': False,
#  'count(s)': 0,
#  'has(s)': False,
#  'count(t)': 0,
#  'has(t)': False,
#  'count(u)': 0,
#  'has(u)': False,
#  'count(v)': 0,
#  'has(v)': False,
#  'count(w)': 0,
#  'has(w)': False,
#  'count(x)': 0,
#  'has(x)': False,
#  'count(y)': 0,
#  'has(y)': False,
#  'count(z)': 0,
#  'has(z)': False}

# %%
featuresets=[(gender_features2(n),g) for (n,g) in names]
train_set,test_set=featuresets[500:], featuresets[:500]
classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.806

# %%
train_names=names[1500:]
devtest_names=names[500:1500]
test_names=names[:500]

# %%
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.752

# %%
errors=[]
for (name,tag) in devtest_names:
    guess=classifier.classify(gender_features(name))
    if guess!=tag:
        errors.append((tag,guess,name))

# %%
errors
# Out:
# [('male', 'female', 'Lonny'),
#  ('female', 'male', 'Fallon'),
#  ('male', 'female', 'Gerome'),
#  ('male', 'female', 'Willey'),
#  ('male', 'female', 'Dominique'),
#  ('male', 'female', 'Herby'),
#  ('female', 'male', 'Roz'),
#  ('male', 'female', 'Ozzy'),
#  ('female', 'male', 'Garland'),
#  ('female', 'male', 'Scarlet'),
#  ('female', 'male', 'Philis'),
#  ('male', 'female', 'Rodge'),
#  ('male', 'female', 'Thorpe'),
#  ('female', 'male', 'Carolyn'),
#  ('female', 'male', 'Cleo'),
#  ('male', 'female', 'Dannie'),
#  ('male', 'female', 'Westley'),
#  ('male', 'female', 'Laurance'),
#  ('male', 'female', 'Worthy'),
#  ('male', 'female', 'Carlyle'),
#  ('female', 'male', 'Lois'),
#  ('male', 'female', 'Chevy'),
#  ('male', 'female', 'Haskell'),
#  ('male', 'female', 'Royce'),
#  ('male', 'female', 'Mitch'),
#  ('male', 'female', 'Mitchell'),
#  ('female', 'male', 'Milissent'),
#  ('male', 'female', 'Mischa'),
#  ('male', 'female', 'Tirrell'),
#  ('female', 'male', 'Rosamond'),
#  ('female', 'male', 'Kaster'),
#  ('male', 'female', 'Marlowe'),
#  ('male', 'female', 'Lay'),
#  ('male', 'female', 'Zach'),
#  ('male', 'female', 'Grady'),
#  ('female', 'male', 'Chriss'),
#  ('male', 'female', 'Barnaby'),
#  ('female', 'male', 'Tiff'),
#  ('male', 'female', 'Clive'),
#  ('male', 'female', 'Cyril'),
#  ('male', 'female', 'Kelley'),
#  ('male', 'female', 'Clay'),
#  ('female', 'male', 'Carolin'),
#  ('female', 'male', 'Jo'),
#  ('female', 'male', 'Dionis'),
#  ('female', 'male', 'Glenn'),
#  ('male', 'female', 'Tracie'),
#  ('male', 'female', 'Bruce'),
#  ('female', 'male', 'Maren'),
#  ('male', 'female', 'Witty'),
#  ('female', 'male', 'LeeAnn'),
#  ('male', 'female', 'Giorgi'),
#  ('male', 'female', 'Hiralal'),
#  ('female', 'male', 'Janean'),
#  ('male', 'female', 'Taite'),
#  ('male', 'female', 'Jodie'),
#  ('male', 'female', 'Maurie'),
#  ('male', 'female', 'Demetre'),
#  ('male', 'female', 'Jeth'),
#  ('male', 'female', 'Clancy'),
#  ('female', 'male', 'Kim'),
#  ('male', 'female', 'Timothy'),
#  ('male', 'female', 'Hale'),
#  ('female', 'male', 'Frances'),
#  ('female', 'male', 'Fran'),
#  ('male', 'female', 'Clyde'),
#  ('male', 'female', 'Jake'),
#  ('female', 'male', 'Bidget'),
#  ('male', 'female', 'Meryl'),
#  ('male', 'female', 'Jere'),
#  ('male', 'female', 'Wayne'),
#  ('female', 'male', 'Alleen'),
#  ('female', 'male', 'Allyson'),
#  ('male', 'female', 'Monty'),
#  ('male', 'female', 'Douggie'),
#  ('female', 'male', 'Cristin'),
#  ('male', 'female', 'Saul'),
#  ('female', 'male', 'Marit'),
#  ('male', 'female', 'Hershel'),
#  ('male', 'female', 'Rex'),
#  ('male', 'female', 'Churchill'),
#  ('female', 'male', 'Kristyn'),
#  ('male', 'female', 'Zacharie'),
#  ('male', 'female', 'Neel'),
#  ('male', 'female', 'Addie'),
#  ('male', 'female', 'Scotty'),
#  ('male', 'female', 'Eddie'),
#  ('female', 'male', 'Karon'),
#  ('female', 'male', 'Jacquelynn'),
#  ('male', 'female', 'Rolfe'),
#  ('male', 'female', 'Granville'),
#  ('male', 'female', 'Daryle'),
#  ('female', 'male', 'Adrian'),
#  ('male', 'female', 'Dimitry'),
#  ('male', 'female', 'Jorge'),
#  ('female', 'male', 'Daloris'),
#  ('female', 'male', 'Joyan'),
#  ('male', 'female', 'Brandy'),
#  ('male', 'female', 'Marmaduke'),
#  ('male', 'female', 'Oral'),
#  ('male', 'female', 'Guthrie'),
#  ('male', 'female', 'Myke'),
#  ('male', 'female', 'Johnny'),
#  ('female', 'male', 'Cindelyn'),
#  ('female', 'male', 'Theo'),
#  ('female', 'male', 'Saraann'),
#  ('male', 'female', 'Terrence'),
#  ('male', 'female', 'Hodge'),
#  ('female', 'male', 'Bert'),
#  ('female', 'male', 'Harriett'),
#  ('male', 'female', 'Kirby'),
#  ('male', 'female', 'Odie'),
#  ('male', 'female', 'Bartholemy'),
#  ('male', 'female', 'Marshall'),
#  ('male', 'female', 'Verney'),
#  ('female', 'male', 'Fanchon'),
#  ('female', 'male', 'Jocelin'),
#  ('female', 'male', 'Ambur'),
#  ('male', 'female', 'Judah'),
#  ('male', 'female', 'Antony'),
#  ('male', 'female', 'Corky'),
#  ('female', 'male', 'Ethelyn'),
#  ('male', 'female', 'Perry'),
#  ('male', 'female', 'Udall'),
#  ('male', 'female', 'Dickey'),
#  ('female', 'male', 'Shanon'),
#  ('female', 'male', 'Katheryn'),
#  ('female', 'male', 'Joan'),
#  ('female', 'male', 'Drew'),
#  ('female', 'male', 'Marlyn'),
#  ('male', 'female', 'Ari'),
#  ('female', 'male', 'Emlyn'),
#  ('female', 'male', 'Shir'),
#  ('male', 'female', 'Abbey'),
#  ('male', 'female', 'Guillaume'),
#  ('male', 'female', 'Patrice'),
#  ('male', 'female', 'Angel'),
#  ('male', 'female', 'Pearce'),
#  ('male', 'female', 'Gale'),
#  ('male', 'female', 'Courtney'),
#  ('male', 'female', 'Rich'),
#  ('male', 'female', 'Timmy'),
#  ('male', 'female', 'Jody'),
#  ('male', 'female', 'Dudley'),
#  ('female', 'male', 'Dolores'),
#  ('male', 'female', 'Kennedy'),
#  ('male', 'female', 'Benjy'),
#  ('female', 'male', 'Fiann'),
#  ('male', 'female', 'Ambrosi'),
#  ('female', 'male', 'Caroljean'),
#  ('male', 'female', 'Kenneth'),
#  ('female', 'male', 'Meghan'),
#  ('female', 'male', 'Mercedes'),
#  ('female', 'male', 'Kevyn'),
#  ('male', 'female', 'Uri'),
#  ('male', 'female', 'Roice'),
#  ('male', 'female', 'Garvy'),
#  ('male', 'female', 'Welbie'),
#  ('male', 'female', 'Mitchel'),
#  ('female', 'male', 'Velvet'),
#  ('female', 'male', 'Flower'),
#  ('female', 'male', 'Candis'),
#  ('male', 'female', 'Johny'),
#  ('female', 'male', 'Kat'),
#  ('male', 'female', 'Andri'),
#  ('male', 'female', 'Danny'),
#  ('female', 'male', 'Clovis'),
#  ('male', 'female', 'Roddy'),
#  ('female', 'male', 'Jessalin'),
#  ('male', 'female', 'Keefe'),
#  ('male', 'female', 'Laurence'),
#  ('male', 'female', 'Zebedee'),
#  ('male', 'female', 'Udell'),
#  ('male', 'female', 'Waine'),
#  ('female', 'male', 'Dawn'),
#  ('male', 'female', 'Josh'),
#  ('female', 'male', 'Gretchen'),
#  ('male', 'female', 'Locke'),
#  ('male', 'female', 'Randal'),
#  ('female', 'male', 'Madelin'),
#  ('male', 'female', 'Udale'),
#  ('male', 'female', 'Lemmie'),
#  ('female', 'male', 'Carin'),
#  ('female', 'male', 'Ted'),
#  ('male', 'female', 'Toddy'),
#  ('male', 'female', 'Jerrie'),
#  ('male', 'female', 'Wiley'),
#  ('female', 'male', 'Bev'),
#  ('male', 'female', 'Randell'),
#  ('male', 'female', 'Anatol'),
#  ('female', 'male', 'Agnes'),
#  ('female', 'male', 'Lynnett'),
#  ('male', 'female', 'Fox'),
#  ('male', 'female', 'Jephthah'),
#  ('male', 'female', 'Artie'),
#  ('male', 'female', 'Ashish'),
#  ('female', 'male', 'Dyan'),
#  ('female', 'male', 'Nadean'),
#  ('female', 'male', 'Roseann'),
#  ('male', 'female', 'Lorne'),
#  ('male', 'female', 'Kerry'),
#  ('male', 'female', 'Kalil'),
#  ('male', 'female', 'Emile'),
#  ('female', 'male', 'Lust'),
#  ('male', 'female', 'Quill'),
#  ('female', 'male', 'Margalo'),
#  ('female', 'male', 'Margalit'),
#  ('male', 'female', 'Zechariah'),
#  ('male', 'female', 'Kory'),
#  ('male', 'female', 'Sly'),
#  ('male', 'female', 'Binky'),
#  ('female', 'male', 'Jenn'),
#  ('female', 'male', 'Kellyann'),
#  ('male', 'female', 'Zedekiah'),
#  ('female', 'male', 'Karlen'),
#  ('female', 'male', 'Aigneis'),
#  ('male', 'female', 'Ronny'),
#  ('male', 'female', 'Yardley'),
#  ('male', 'female', 'Merry'),
#  ('male', 'female', 'Durante'),
#  ('male', 'female', 'Sarge'),
#  ('female', 'male', 'Joscelin'),
#  ('male', 'female', 'Bealle'),
#  ('male', 'female', 'Duane'),
#  ('male', 'female', 'Benny'),
#  ('male', 'female', 'Tuckie'),
#  ('male', 'female', 'Rabbi'),
#  ('male', 'female', 'Leigh'),
#  ('male', 'female', 'Patel'),
#  ('male', 'female', 'Ferdy'),
#  ('female', 'male', 'Jacklyn'),
#  ('female', 'male', 'Deloris'),
#  ('male', 'female', 'Bartie'),
#  ('male', 'female', 'Hymie'),
#  ('male', 'female', 'Scotti'),
#  ('male', 'female', 'Vachel'),
#  ('female', 'male', 'Lurleen'),
#  ('female', 'male', 'Madlen'),
#  ('male', 'female', 'Haskel'),
#  ('male', 'female', 'Hasty'),
#  ('male', 'female', 'Randolph'),
#  ('male', 'female', 'Carleigh'),
#  ('female', 'male', 'Addis'),
#  ('female', 'male', 'Janis'),
#  ('male', 'female', 'Radcliffe'),
#  ('female', 'male', 'Glennis'),
#  ('male', 'female', 'Ira'),
#  ('male', 'female', 'Herschel')]

# %%
for (tag,guess,name) in sorted(errors):
    print('correct=%-8s, guess=%-8s,name=%-30s'%(tag,guess,name))
# Out:
# correct=female  , guess=male    ,name=Addis
# correct=female  , guess=male    ,name=Adrian
# correct=female  , guess=male    ,name=Agnes
# correct=female  , guess=male    ,name=Aigneis
# correct=female  , guess=male    ,name=Alleen
# correct=female  , guess=male    ,name=Allyson
# correct=female  , guess=male    ,name=Ambur
# correct=female  , guess=male    ,name=Bert
# correct=female  , guess=male    ,name=Bev
# correct=female  , guess=male    ,name=Bidget
# correct=female  , guess=male    ,name=Candis
# correct=female  , guess=male    ,name=Carin
# correct=female  , guess=male    ,name=Carolin
# correct=female  , guess=male    ,name=Caroljean
# correct=female  , guess=male    ,name=Carolyn
# correct=female  , guess=male    ,name=Chriss
# correct=female  , guess=male    ,name=Cindelyn
# correct=female  , guess=male    ,name=Cleo
# correct=female  , guess=male    ,name=Clovis
# correct=female  , guess=male    ,name=Cristin
# correct=female  , guess=male    ,name=Daloris
# correct=female  , guess=male    ,name=Dawn
# correct=female  , guess=male    ,name=Deloris
# correct=female  , guess=male    ,name=Dionis
# correct=female  , guess=male    ,name=Dolores
# correct=female  , guess=male    ,name=Drew
# correct=female  , guess=male    ,name=Dyan
# correct=female  , guess=male    ,name=Emlyn
# correct=female  , guess=male    ,name=Ethelyn
# correct=female  , guess=male    ,name=Fallon
# correct=female  , guess=male    ,name=Fanchon
# correct=female  , guess=male    ,name=Fiann
# correct=female  , guess=male    ,name=Flower
# correct=female  , guess=male    ,name=Fran
# correct=female  , guess=male    ,name=Frances
# correct=female  , guess=male    ,name=Garland
# correct=female  , guess=male    ,name=Glenn
# correct=female  , guess=male    ,name=Glennis
# correct=female  , guess=male    ,name=Gretchen
# correct=female  , guess=male    ,name=Harriett
# correct=female  , guess=male    ,name=Jacklyn
# correct=female  , guess=male    ,name=Jacquelynn
# correct=female  , guess=male    ,name=Janean
# correct=female  , guess=male    ,name=Janis
# correct=female  , guess=male    ,name=Jenn
# correct=female  , guess=male    ,name=Jessalin
# correct=female  , guess=male    ,name=Jo
# correct=female  , guess=male    ,name=Joan
# correct=female  , guess=male    ,name=Jocelin
# correct=female  , guess=male    ,name=Joscelin
# correct=female  , guess=male    ,name=Joyan
# correct=female  , guess=male    ,name=Karlen
# correct=female  , guess=male    ,name=Karon
# correct=female  , guess=male    ,name=Kaster
# correct=female  , guess=male    ,name=Kat
# correct=female  , guess=male    ,name=Katheryn
# correct=female  , guess=male    ,name=Kellyann
# correct=female  , guess=male    ,name=Kevyn
# correct=female  , guess=male    ,name=Kim
# correct=female  , guess=male    ,name=Kristyn
# correct=female  , guess=male    ,name=LeeAnn
# correct=female  , guess=male    ,name=Lois
# correct=female  , guess=male    ,name=Lurleen
# correct=female  , guess=male    ,name=Lust
# correct=female  , guess=male    ,name=Lynnett
# correct=female  , guess=male    ,name=Madelin
# correct=female  , guess=male    ,name=Madlen
# correct=female  , guess=male    ,name=Maren
# correct=female  , guess=male    ,name=Margalit
# correct=female  , guess=male    ,name=Margalo
# correct=female  , guess=male    ,name=Marit
# correct=female  , guess=male    ,name=Marlyn
# correct=female  , guess=male    ,name=Meghan
# correct=female  , guess=male    ,name=Mercedes
# correct=female  , guess=male    ,name=Milissent
# correct=female  , guess=male    ,name=Nadean
# correct=female  , guess=male    ,name=Philis
# correct=female  , guess=male    ,name=Rosamond
# correct=female  , guess=male    ,name=Roseann
# correct=female  , guess=male    ,name=Roz
# correct=female  , guess=male    ,name=Saraann
# correct=female  , guess=male    ,name=Scarlet
# correct=female  , guess=male    ,name=Shanon
# correct=female  , guess=male    ,name=Shir
# correct=female  , guess=male    ,name=Ted
# correct=female  , guess=male    ,name=Theo
# correct=female  , guess=male    ,name=Tiff
# correct=female  , guess=male    ,name=Velvet
# correct=male    , guess=female  ,name=Abbey
# correct=male    , guess=female  ,name=Addie
# correct=male    , guess=female  ,name=Ambrosi
# correct=male    , guess=female  ,name=Anatol
# correct=male    , guess=female  ,name=Andri
# correct=male    , guess=female  ,name=Angel
# correct=male    , guess=female  ,name=Antony
# correct=male    , guess=female  ,name=Ari
# correct=male    , guess=female  ,name=Artie
# correct=male    , guess=female  ,name=Ashish
# correct=male    , guess=female  ,name=Barnaby
# correct=male    , guess=female  ,name=Bartholemy
# correct=male    , guess=female  ,name=Bartie
# correct=male    , guess=female  ,name=Bealle
# correct=male    , guess=female  ,name=Benjy
# correct=male    , guess=female  ,name=Benny
# correct=male    , guess=female  ,name=Binky
# correct=male    , guess=female  ,name=Brandy
# correct=male    , guess=female  ,name=Bruce
# correct=male    , guess=female  ,name=Carleigh
# correct=male    , guess=female  ,name=Carlyle
# correct=male    , guess=female  ,name=Chevy
# correct=male    , guess=female  ,name=Churchill
# correct=male    , guess=female  ,name=Clancy
# correct=male    , guess=female  ,name=Clay
# correct=male    , guess=female  ,name=Clive
# correct=male    , guess=female  ,name=Clyde
# correct=male    , guess=female  ,name=Corky
# correct=male    , guess=female  ,name=Courtney
# correct=male    , guess=female  ,name=Cyril
# correct=male    , guess=female  ,name=Dannie
# correct=male    , guess=female  ,name=Danny
# correct=male    , guess=female  ,name=Daryle
# correct=male    , guess=female  ,name=Demetre
# correct=male    , guess=female  ,name=Dickey
# correct=male    , guess=female  ,name=Dimitry
# correct=male    , guess=female  ,name=Dominique
# correct=male    , guess=female  ,name=Douggie
# correct=male    , guess=female  ,name=Duane
# correct=male    , guess=female  ,name=Dudley
# correct=male    , guess=female  ,name=Durante
# correct=male    , guess=female  ,name=Eddie
# correct=male    , guess=female  ,name=Emile
# correct=male    , guess=female  ,name=Ferdy
# correct=male    , guess=female  ,name=Fox
# correct=male    , guess=female  ,name=Gale
# correct=male    , guess=female  ,name=Garvy
# correct=male    , guess=female  ,name=Gerome
# correct=male    , guess=female  ,name=Giorgi
# correct=male    , guess=female  ,name=Grady
# correct=male    , guess=female  ,name=Granville
# correct=male    , guess=female  ,name=Guillaume
# correct=male    , guess=female  ,name=Guthrie
# correct=male    , guess=female  ,name=Hale
# correct=male    , guess=female  ,name=Haskel
# correct=male    , guess=female  ,name=Haskell
# correct=male    , guess=female  ,name=Hasty
# correct=male    , guess=female  ,name=Herby
# correct=male    , guess=female  ,name=Herschel
# correct=male    , guess=female  ,name=Hershel
# correct=male    , guess=female  ,name=Hiralal
# correct=male    , guess=female  ,name=Hodge
# correct=male    , guess=female  ,name=Hymie
# correct=male    , guess=female  ,name=Ira
# correct=male    , guess=female  ,name=Jake
# correct=male    , guess=female  ,name=Jephthah
# correct=male    , guess=female  ,name=Jere
# correct=male    , guess=female  ,name=Jerrie
# correct=male    , guess=female  ,name=Jeth
# correct=male    , guess=female  ,name=Jodie
# correct=male    , guess=female  ,name=Jody
# correct=male    , guess=female  ,name=Johnny
# correct=male    , guess=female  ,name=Johny
# correct=male    , guess=female  ,name=Jorge
# correct=male    , guess=female  ,name=Josh
# correct=male    , guess=female  ,name=Judah
# correct=male    , guess=female  ,name=Kalil
# correct=male    , guess=female  ,name=Keefe
# correct=male    , guess=female  ,name=Kelley
# correct=male    , guess=female  ,name=Kennedy
# correct=male    , guess=female  ,name=Kenneth
# correct=male    , guess=female  ,name=Kerry
# correct=male    , guess=female  ,name=Kirby
# correct=male    , guess=female  ,name=Kory
# correct=male    , guess=female  ,name=Laurance
# correct=male    , guess=female  ,name=Laurence
# correct=male    , guess=female  ,name=Lay
# correct=male    , guess=female  ,name=Leigh
# correct=male    , guess=female  ,name=Lemmie
# correct=male    , guess=female  ,name=Locke
# correct=male    , guess=female  ,name=Lonny
# correct=male    , guess=female  ,name=Lorne
# correct=male    , guess=female  ,name=Marlowe
# correct=male    , guess=female  ,name=Marmaduke
# correct=male    , guess=female  ,name=Marshall
# correct=male    , guess=female  ,name=Maurie
# correct=male    , guess=female  ,name=Merry
# correct=male    , guess=female  ,name=Meryl
# correct=male    , guess=female  ,name=Mischa
# correct=male    , guess=female  ,name=Mitch
# correct=male    , guess=female  ,name=Mitchel
# correct=male    , guess=female  ,name=Mitchell
# correct=male    , guess=female  ,name=Monty
# correct=male    , guess=female  ,name=Myke
# correct=male    , guess=female  ,name=Neel
# correct=male    , guess=female  ,name=Odie
# correct=male    , guess=female  ,name=Oral
# correct=male    , guess=female  ,name=Ozzy
# correct=male    , guess=female  ,name=Patel
# correct=male    , guess=female  ,name=Patrice
# correct=male    , guess=female  ,name=Pearce
# correct=male    , guess=female  ,name=Perry
# correct=male    , guess=female  ,name=Quill
# correct=male    , guess=female  ,name=Rabbi
# correct=male    , guess=female  ,name=Radcliffe
# correct=male    , guess=female  ,name=Randal
# correct=male    , guess=female  ,name=Randell
# correct=male    , guess=female  ,name=Randolph
# correct=male    , guess=female  ,name=Rex
# correct=male    , guess=female  ,name=Rich
# correct=male    , guess=female  ,name=Roddy
# correct=male    , guess=female  ,name=Rodge
# correct=male    , guess=female  ,name=Roice
# correct=male    , guess=female  ,name=Rolfe
# correct=male    , guess=female  ,name=Ronny
# correct=male    , guess=female  ,name=Royce
# correct=male    , guess=female  ,name=Sarge
# correct=male    , guess=female  ,name=Saul
# correct=male    , guess=female  ,name=Scotti
# correct=male    , guess=female  ,name=Scotty
# correct=male    , guess=female  ,name=Sly
# correct=male    , guess=female  ,name=Taite
# correct=male    , guess=female  ,name=Terrence
# correct=male    , guess=female  ,name=Thorpe
# correct=male    , guess=female  ,name=Timmy
# correct=male    , guess=female  ,name=Timothy
# correct=male    , guess=female  ,name=Tirrell
# correct=male    , guess=female  ,name=Toddy
# correct=male    , guess=female  ,name=Tracie
# correct=male    , guess=female  ,name=Tuckie
# correct=male    , guess=female  ,name=Udale
# correct=male    , guess=female  ,name=Udall
# correct=male    , guess=female  ,name=Udell
# correct=male    , guess=female  ,name=Uri
# correct=male    , guess=female  ,name=Vachel
# correct=male    , guess=female  ,name=Verney
# correct=male    , guess=female  ,name=Waine
# correct=male    , guess=female  ,name=Wayne
# correct=male    , guess=female  ,name=Welbie
# correct=male    , guess=female  ,name=Westley
# correct=male    , guess=female  ,name=Wiley
# correct=male    , guess=female  ,name=Willey
# correct=male    , guess=female  ,name=Witty
# correct=male    , guess=female  ,name=Worthy
# correct=male    , guess=female  ,name=Yardley
# correct=male    , guess=female  ,name=Zach
# correct=male    , guess=female  ,name=Zacharie
# correct=male    , guess=female  ,name=Zebedee
# correct=male    , guess=female  ,name=Zechariah
# correct=male    , guess=female  ,name=Zedekiah

# %%
def gender_features(word):
    return {'suffix1':word[-1:],
            'suffix2':word[-2:]}

# %%
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.773

# %%
gender_features('Rishav')
# Out:
# {'suffix1': 'v', 'suffix2': 'av'}

# %%
train_set
# Out:
# [({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'ik'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'Vi'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ud'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'v', 'suffix2': 'av'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'no'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'hy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ga'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'eg'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'od'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ba'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'ko'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'oy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'wn'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'va'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ke'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'oo'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'hy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'rl'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'go'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'zi'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'eg'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'z', 'suffix2': 'nz'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'j', 'suffix2': 'aj'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'rl'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'os'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'to'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 've'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'ew'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'gh'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'un'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ue'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'vo'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'dd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'bi'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'ct'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ai'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'f', 'suffix2': 'ff'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ki'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'gs'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ed'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'fy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'rn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 'p', 'suffix2': 'op'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'at'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 've'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'gi'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'vi'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'to'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'be'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'go'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'my'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'tr'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'gy'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'ro'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ed'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'or'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'eo'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'gs'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'pe'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'va'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'gt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'rl'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'hn'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'oe'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'zy'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'hi'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ud'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'im'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'st'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'f', 'suffix2': 'ff'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ke'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'gy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'bi'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'female'),
#  ({'suffix1': 'x', 'suffix2': 'ix'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'oe'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'py'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'zo'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'Ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'gy'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ci'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'gi'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'nt'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ph'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ok'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ur'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ed'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'yt'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'lt'}, 'male'),
#  ({'suffix1': 'b', 'suffix2': 'ib'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 've'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'oy'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'yb'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'v', 'suffix2': 'ev'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'oh'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'nk'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'ul'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ki'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'fy'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'rl'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'pe'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'vy'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'nt'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'id'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ch'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'xe'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'oe'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'ax'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'x', 'suffix2': 'ux'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'ow'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'ss'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'ro'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'f', 'suffix2': 'if'}, 'male'),
#  ({'suffix1': 'w', 'suffix2': 'ow'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ur'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'go'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'Bo'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'yd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ph'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'ax'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ba'}, 'female'),
#  ({'suffix1': 'u', 'suffix2': 'eu'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'og'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'go'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'my'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'ab'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'rs'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'od'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'ig'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'ss'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'to'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'os'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 've'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'oe'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'my'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'or'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ci'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'co'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'hn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'female'),
#  ...]

# %%
def gender_features(word):
    return {'suffix1':word[-2:],
            'suffix2':word[-3:]}
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.793

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.814
