# %%
from nltk.corpus import brown

# %%
brown_sent=brown.tagged_sents(categories='news')
brown_sent
# Out:
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atlanta', 'NP-TL'), ("''", "''"), ('for', 'IN'), ('the', 'AT'), ('manner', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'AT'), ('election', 'NN'), ('was', 'BEDZ'), ('conducted', 'VBN'), ('.', '.')], ...]

# %%
brown_sents=brown.sents(categories='news')
brown_sents[2007]
# Out:
# ['Various',
#  'of',
#  'the',
#  'apartments',
#  'are',
#  'of',
#  'the',
#  'terrace',
#  'type',
#  ',',
#  'being',
#  'on',
#  'the',
#  'ground',
#  'floor',
#  'so',
#  'that',
#  'entrance',
#  'is',
#  'direct',
#  '.']

# %%
unigram_tagger=nltk.UnigramTagger(brown_sent)

# %%
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
brown_sent[2007]
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'CS'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
from pickle import dump
output=open('t2.pkl','wb')
dump('t2',output,-1)
output.close()

# %%
from pickle import load
input=open('t2.pkl','rb')
tagger=load(input)
input.close()

# %%
text = """The board's action shows what free enterprise
     is up against in our complex maze of regulatory laws ."""
tokens=text.split()
# tagger.tag(tokens)

# %%
def gender_features(word):
    return{'last letter':word[-1]}

gender_features('Rishav')
# Out:
# {'last letter': 'v'}

# %%
from nltk.corpus import names
import random
names=([(name,'male') for name in names.words('male.txt')]+\
       [(name,'female') for name in names.words('female.txt')])

# %%
random.shuffle(names)

# %%
featuresets=[(gender_features(n),g) for n,g in names]

# %%
train_set,test_set=featuresets[500:],featuresets[:500]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
train_set[:10]
# Out:
# [({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'o'}, 'male')]

# %%
classifier.classify(gender_features('Neo'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Rishav'))
# Out:
# 'male'

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.744

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              last letter = 'a'            female : male   =     33.4 : 1.0
#              last letter = 'k'              male : female =     33.0 : 1.0
#              last letter = 'f'              male : female =     16.5 : 1.0
#              last letter = 'v'              male : female =     11.1 : 1.0
#              last letter = 'p'              male : female =     10.5 : 1.0
#              last letter = 'd'              male : female =     10.2 : 1.0
#              last letter = 'm'              male : female =      8.3 : 1.0
#              last letter = 'o'              male : female =      7.8 : 1.0
#              last letter = 'r'              male : female =      7.1 : 1.0
#              last letter = 'g'              male : female =      6.5 : 1.0

# %%
from nltk.classify import apply_features
train_set=apply_features(gender_features,names[500:])
test_set=apply_features(gender_features,names[:500])

# %%
train_set
# Out:
# [({'last letter': 'a'}, 'female'), ({'last letter': 'a'}, 'female'), ...]

# %%
def gender_features2(name):
    features={}
    features['firstletter']=name[0].lower()
    features['lastname']=name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features['count(%s)'%letter]=name.lower().count(letter)
        features['has(%s)'%letter]=(letter in name.lower())
    return features

# %%
gender_features2('John')
# Out:
# {'firstletter': 'j',
#  'lastname': 'n',
#  'count(a)': 0,
#  'has(a)': False,
#  'count(b)': 0,
#  'has(b)': False,
#  'count(c)': 0,
#  'has(c)': False,
#  'count(d)': 0,
#  'has(d)': False,
#  'count(e)': 0,
#  'has(e)': False,
#  'count(f)': 0,
#  'has(f)': False,
#  'count(g)': 0,
#  'has(g)': False,
#  'count(h)': 1,
#  'has(h)': True,
#  'count(i)': 0,
#  'has(i)': False,
#  'count(j)': 1,
#  'has(j)': True,
#  'count(k)': 0,
#  'has(k)': False,
#  'count(l)': 0,
#  'has(l)': False,
#  'count(m)': 0,
#  'has(m)': False,
#  'count(n)': 1,
#  'has(n)': True,
#  'count(o)': 1,
#  'has(o)': True,
#  'count(p)': 0,
#  'has(p)': False,
#  'count(q)': 0,
#  'has(q)': False,
#  'count(r)': 0,
#  'has(r)': False,
#  'count(s)': 0,
#  'has(s)': False,
#  'count(t)': 0,
#  'has(t)': False,
#  'count(u)': 0,
#  'has(u)': False,
#  'count(v)': 0,
#  'has(v)': False,
#  'count(w)': 0,
#  'has(w)': False,
#  'count(x)': 0,
#  'has(x)': False,
#  'count(y)': 0,
#  'has(y)': False,
#  'count(z)': 0,
#  'has(z)': False}

# %%
featuresets=[(gender_features2(n),g) for (n,g) in names]
train_set,test_set=featuresets[500:], featuresets[:500]
classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.788

# %%
train_names=names[1500:]
devtest_names=names[500:1500]
test_names=names[:500]

# %%
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.781

# %%
errors=[]
for (name,tag) in devtest_names:
    guess=classifier.classify(gender_features(name))
    if guess!=tag:
        errors.append((tag,guess,name))

# %%
errors
# Out:
# [('male', 'female', 'Earle'),
#  ('female', 'male', 'Susann'),
#  ('female', 'male', 'Rhianon'),
#  ('female', 'male', 'Margaret'),
#  ('female', 'male', 'Kirsten'),
#  ('male', 'female', 'Joey'),
#  ('female', 'male', 'Marin'),
#  ('female', 'male', 'Devan'),
#  ('male', 'female', 'Voltaire'),
#  ('male', 'female', 'Piggy'),
#  ('female', 'male', 'Kevyn'),
#  ('male', 'female', 'Emery'),
#  ('female', 'male', 'Chrystel'),
#  ('male', 'female', 'Clemente'),
#  ('male', 'female', 'Holly'),
#  ('female', 'male', 'Jackquelin'),
#  ('male', 'female', 'Lemmy'),
#  ('male', 'female', 'Demetri'),
#  ('male', 'female', 'Zach'),
#  ('male', 'female', 'Skye'),
#  ('female', 'male', 'Renell'),
#  ('male', 'female', 'Nickie'),
#  ('male', 'female', 'Jake'),
#  ('male', 'female', 'Darth'),
#  ('male', 'female', 'Myke'),
#  ('male', 'female', 'Saundra'),
#  ('female', 'male', 'Kyrstin'),
#  ('male', 'female', 'Jermaine'),
#  ('male', 'female', 'Adlai'),
#  ('female', 'male', 'Gwenn'),
#  ('male', 'female', 'Felix'),
#  ('female', 'male', 'Corliss'),
#  ('male', 'female', 'Bartolomei'),
#  ('female', 'male', 'Vivien'),
#  ('male', 'female', 'Hezekiah'),
#  ('female', 'male', 'Nell'),
#  ('female', 'male', 'Phyllys'),
#  ('female', 'male', 'Cinnamon'),
#  ('male', 'female', 'Tracey'),
#  ('male', 'female', 'Virge'),
#  ('female', 'male', 'Dolores'),
#  ('female', 'male', 'Jolynn'),
#  ('male', 'female', 'Rabi'),
#  ('female', 'male', 'Charlott'),
#  ('male', 'female', 'Neale'),
#  ('male', 'female', 'Abbey'),
#  ('female', 'male', 'Jennifer'),
#  ('female', 'male', 'Teryl'),
#  ('male', 'female', 'Dwaine'),
#  ('male', 'female', 'Jessey'),
#  ('male', 'female', 'Stacy'),
#  ('male', 'female', 'Wally'),
#  ('female', 'male', 'Isador'),
#  ('male', 'female', 'Zedekiah'),
#  ('female', 'male', 'Alleen'),
#  ('male', 'female', 'Cole'),
#  ('female', 'male', 'Rosalind'),
#  ('female', 'male', 'Vivyan'),
#  ('male', 'female', 'Tobe'),
#  ('female', 'male', 'Gertrud'),
#  ('female', 'male', 'Eden'),
#  ('male', 'female', 'Moishe'),
#  ('male', 'female', 'Pete'),
#  ('female', 'male', 'Hazel'),
#  ('female', 'male', 'Gill'),
#  ('female', 'male', 'Rochell'),
#  ('female', 'male', 'Jacklyn'),
#  ('female', 'male', 'Cal'),
#  ('male', 'female', 'Bailey'),
#  ('male', 'female', 'Jerome'),
#  ('female', 'male', 'Kaylil'),
#  ('male', 'female', 'Fairfax'),
#  ('male', 'female', 'Sammie'),
#  ('male', 'female', 'Donny'),
#  ('female', 'male', 'Suellen'),
#  ('female', 'male', 'Ingeberg'),
#  ('female', 'male', 'Coleen'),
#  ('male', 'female', 'Godfrey'),
#  ('female', 'male', 'Ailyn'),
#  ('female', 'male', 'Cristen'),
#  ('male', 'female', 'Moore'),
#  ('female', 'male', 'Iris'),
#  ('male', 'female', 'Tymothy'),
#  ('male', 'female', 'Alex'),
#  ('female', 'male', 'Daniel'),
#  ('female', 'male', 'Cherilyn'),
#  ('female', 'male', 'Anett'),
#  ('male', 'female', 'Amery'),
#  ('female', 'male', 'Mariellen'),
#  ('female', 'male', 'Carroll'),
#  ('female', 'male', 'Elisabet'),
#  ('male', 'female', 'Rolfe'),
#  ('female', 'male', 'Jan'),
#  ('male', 'female', 'Vince'),
#  ('female', 'male', 'Anais'),
#  ('male', 'female', 'Christophe'),
#  ('female', 'male', 'Shannen'),
#  ('male', 'female', 'Sloane'),
#  ('female', 'male', 'Darryl'),
#  ('female', 'male', 'Evelyn'),
#  ('female', 'male', 'Dorian'),
#  ('male', 'female', 'Ignace'),
#  ('male', 'female', 'Garvy'),
#  ('female', 'male', 'Chantal'),
#  ('male', 'female', 'Chase'),
#  ('female', 'male', 'Allys'),
#  ('male', 'female', 'Noah'),
#  ('male', 'female', 'Barrie'),
#  ('male', 'female', 'Heath'),
#  ('male', 'female', 'Shay'),
#  ('male', 'female', 'Ramsey'),
#  ('female', 'male', 'Dagmar'),
#  ('male', 'female', 'Barty'),
#  ('male', 'female', 'Wallie'),
#  ('male', 'female', 'Judy'),
#  ('female', 'male', 'Kristien'),
#  ('female', 'male', 'Yoko'),
#  ('male', 'female', 'Towney'),
#  ('male', 'female', 'Elisha'),
#  ('female', 'male', 'Bev'),
#  ('female', 'male', 'Starr'),
#  ('female', 'male', 'Inez'),
#  ('male', 'female', 'Ozzie'),
#  ('male', 'female', 'Barclay'),
#  ('male', 'female', 'Terrence'),
#  ('female', 'male', 'Lilyan'),
#  ('male', 'female', 'Sansone'),
#  ('male', 'female', 'Sidnee'),
#  ('male', 'female', 'Hersh'),
#  ('male', 'female', 'Morty'),
#  ('male', 'female', 'Amory'),
#  ('female', 'male', 'Britt'),
#  ('male', 'female', 'Ashley'),
#  ('male', 'female', 'Burnaby'),
#  ('female', 'male', 'Fan'),
#  ('female', 'male', 'Gennifer'),
#  ('male', 'female', 'Jaime'),
#  ('female', 'male', 'Marlo'),
#  ('female', 'male', 'Sydel'),
#  ('male', 'female', 'Wolfie'),
#  ('female', 'male', 'Bo'),
#  ('female', 'male', 'Christen'),
#  ('male', 'female', 'Rory'),
#  ('female', 'male', 'Adel'),
#  ('male', 'female', 'Garth'),
#  ('female', 'male', 'Devin'),
#  ('male', 'female', 'Shayne'),
#  ('female', 'male', 'Carlynn'),
#  ('female', 'male', 'Sal'),
#  ('male', 'female', 'Leslie'),
#  ('female', 'male', 'Gert'),
#  ('male', 'female', 'Gene'),
#  ('male', 'female', 'Yancy'),
#  ('female', 'male', 'Jesselyn'),
#  ('male', 'female', 'Demetre'),
#  ('female', 'male', 'Rosaleen'),
#  ('male', 'female', 'Maurice'),
#  ('male', 'female', 'Jephthah'),
#  ('female', 'male', 'Austin'),
#  ('female', 'male', 'Leann'),
#  ('female', 'male', 'Bel'),
#  ('male', 'female', 'Sinclare'),
#  ('female', 'male', 'Clovis'),
#  ('female', 'male', 'Aileen'),
#  ('male', 'female', 'Esme'),
#  ('female', 'male', 'Dot'),
#  ('male', 'female', 'Bennie'),
#  ('male', 'female', 'Archy'),
#  ('male', 'female', 'Marsh'),
#  ('female', 'male', 'Laural'),
#  ('female', 'male', 'LeeAnn'),
#  ('female', 'male', 'Keriann'),
#  ('female', 'male', 'Cindelyn'),
#  ('male', 'female', 'Howie'),
#  ('male', 'female', 'Tabbie'),
#  ('female', 'male', 'Brittan'),
#  ('female', 'male', 'Kial'),
#  ('male', 'female', 'Westbrooke'),
#  ('male', 'female', 'Selby'),
#  ('female', 'male', 'Joyous'),
#  ('female', 'male', 'Em'),
#  ('female', 'male', 'Juliann'),
#  ('female', 'male', 'Jocelin'),
#  ('female', 'male', 'Jessalin'),
#  ('female', 'male', 'Laureen'),
#  ('female', 'male', 'Ethelyn'),
#  ('female', 'male', 'Milissent'),
#  ('female', 'male', 'Emlynn'),
#  ('female', 'male', 'Kristal'),
#  ('female', 'male', 'Janeen'),
#  ('female', 'male', 'Carolyn'),
#  ('female', 'male', 'Orel'),
#  ('male', 'female', 'Zebadiah'),
#  ('female', 'male', 'Mabel'),
#  ('male', 'female', 'Duke'),
#  ('female', 'male', 'Margalit'),
#  ('female', 'male', 'Lilian'),
#  ('male', 'female', 'Jessie'),
#  ('male', 'female', 'Hale'),
#  ('male', 'female', 'Toddy'),
#  ('female', 'male', 'Emmalynn'),
#  ('male', 'female', 'Waine'),
#  ('female', 'male', 'Marlyn'),
#  ('female', 'male', 'Rachael'),
#  ('male', 'female', 'Godfry'),
#  ('female', 'male', 'Nat'),
#  ('male', 'female', 'Thorny'),
#  ('female', 'male', 'Fleur'),
#  ('female', 'male', 'Doris'),
#  ('male', 'female', 'Hewie'),
#  ('male', 'female', 'Rodolph'),
#  ('male', 'female', 'Elijah'),
#  ('female', 'male', 'Wynn'),
#  ('male', 'female', 'Keene'),
#  ('female', 'male', 'Fawn'),
#  ('male', 'female', 'Blare'),
#  ('male', 'female', 'Elroy'),
#  ('male', 'female', 'Mace'),
#  ('female', 'male', 'Consuelo')]

# %%
for (tag,guess,name) in sorted(errors):
    print('correct=%-8s, guess=%-8s,name=%-30s'%(tag,guess,name))
# Out:
# correct=female  , guess=male    ,name=Adel
# correct=female  , guess=male    ,name=Aileen
# correct=female  , guess=male    ,name=Ailyn
# correct=female  , guess=male    ,name=Alleen
# correct=female  , guess=male    ,name=Allys
# correct=female  , guess=male    ,name=Anais
# correct=female  , guess=male    ,name=Anett
# correct=female  , guess=male    ,name=Austin
# correct=female  , guess=male    ,name=Bel
# correct=female  , guess=male    ,name=Bev
# correct=female  , guess=male    ,name=Bo
# correct=female  , guess=male    ,name=Britt
# correct=female  , guess=male    ,name=Brittan
# correct=female  , guess=male    ,name=Cal
# correct=female  , guess=male    ,name=Carlynn
# correct=female  , guess=male    ,name=Carolyn
# correct=female  , guess=male    ,name=Carroll
# correct=female  , guess=male    ,name=Chantal
# correct=female  , guess=male    ,name=Charlott
# correct=female  , guess=male    ,name=Cherilyn
# correct=female  , guess=male    ,name=Christen
# correct=female  , guess=male    ,name=Chrystel
# correct=female  , guess=male    ,name=Cindelyn
# correct=female  , guess=male    ,name=Cinnamon
# correct=female  , guess=male    ,name=Clovis
# correct=female  , guess=male    ,name=Coleen
# correct=female  , guess=male    ,name=Consuelo
# correct=female  , guess=male    ,name=Corliss
# correct=female  , guess=male    ,name=Cristen
# correct=female  , guess=male    ,name=Dagmar
# correct=female  , guess=male    ,name=Daniel
# correct=female  , guess=male    ,name=Darryl
# correct=female  , guess=male    ,name=Devan
# correct=female  , guess=male    ,name=Devin
# correct=female  , guess=male    ,name=Dolores
# correct=female  , guess=male    ,name=Dorian
# correct=female  , guess=male    ,name=Doris
# correct=female  , guess=male    ,name=Dot
# correct=female  , guess=male    ,name=Eden
# correct=female  , guess=male    ,name=Elisabet
# correct=female  , guess=male    ,name=Em
# correct=female  , guess=male    ,name=Emlynn
# correct=female  , guess=male    ,name=Emmalynn
# correct=female  , guess=male    ,name=Ethelyn
# correct=female  , guess=male    ,name=Evelyn
# correct=female  , guess=male    ,name=Fan
# correct=female  , guess=male    ,name=Fawn
# correct=female  , guess=male    ,name=Fleur
# correct=female  , guess=male    ,name=Gennifer
# correct=female  , guess=male    ,name=Gert
# correct=female  , guess=male    ,name=Gertrud
# correct=female  , guess=male    ,name=Gill
# correct=female  , guess=male    ,name=Gwenn
# correct=female  , guess=male    ,name=Hazel
# correct=female  , guess=male    ,name=Inez
# correct=female  , guess=male    ,name=Ingeberg
# correct=female  , guess=male    ,name=Iris
# correct=female  , guess=male    ,name=Isador
# correct=female  , guess=male    ,name=Jacklyn
# correct=female  , guess=male    ,name=Jackquelin
# correct=female  , guess=male    ,name=Jan
# correct=female  , guess=male    ,name=Janeen
# correct=female  , guess=male    ,name=Jennifer
# correct=female  , guess=male    ,name=Jessalin
# correct=female  , guess=male    ,name=Jesselyn
# correct=female  , guess=male    ,name=Jocelin
# correct=female  , guess=male    ,name=Jolynn
# correct=female  , guess=male    ,name=Joyous
# correct=female  , guess=male    ,name=Juliann
# correct=female  , guess=male    ,name=Kaylil
# correct=female  , guess=male    ,name=Keriann
# correct=female  , guess=male    ,name=Kevyn
# correct=female  , guess=male    ,name=Kial
# correct=female  , guess=male    ,name=Kirsten
# correct=female  , guess=male    ,name=Kristal
# correct=female  , guess=male    ,name=Kristien
# correct=female  , guess=male    ,name=Kyrstin
# correct=female  , guess=male    ,name=Laural
# correct=female  , guess=male    ,name=Laureen
# correct=female  , guess=male    ,name=Leann
# correct=female  , guess=male    ,name=LeeAnn
# correct=female  , guess=male    ,name=Lilian
# correct=female  , guess=male    ,name=Lilyan
# correct=female  , guess=male    ,name=Mabel
# correct=female  , guess=male    ,name=Margalit
# correct=female  , guess=male    ,name=Margaret
# correct=female  , guess=male    ,name=Mariellen
# correct=female  , guess=male    ,name=Marin
# correct=female  , guess=male    ,name=Marlo
# correct=female  , guess=male    ,name=Marlyn
# correct=female  , guess=male    ,name=Milissent
# correct=female  , guess=male    ,name=Nat
# correct=female  , guess=male    ,name=Nell
# correct=female  , guess=male    ,name=Orel
# correct=female  , guess=male    ,name=Phyllys
# correct=female  , guess=male    ,name=Rachael
# correct=female  , guess=male    ,name=Renell
# correct=female  , guess=male    ,name=Rhianon
# correct=female  , guess=male    ,name=Rochell
# correct=female  , guess=male    ,name=Rosaleen
# correct=female  , guess=male    ,name=Rosalind
# correct=female  , guess=male    ,name=Sal
# correct=female  , guess=male    ,name=Shannen
# correct=female  , guess=male    ,name=Starr
# correct=female  , guess=male    ,name=Suellen
# correct=female  , guess=male    ,name=Susann
# correct=female  , guess=male    ,name=Sydel
# correct=female  , guess=male    ,name=Teryl
# correct=female  , guess=male    ,name=Vivien
# correct=female  , guess=male    ,name=Vivyan
# correct=female  , guess=male    ,name=Wynn
# correct=female  , guess=male    ,name=Yoko
# correct=male    , guess=female  ,name=Abbey
# correct=male    , guess=female  ,name=Adlai
# correct=male    , guess=female  ,name=Alex
# correct=male    , guess=female  ,name=Amery
# correct=male    , guess=female  ,name=Amory
# correct=male    , guess=female  ,name=Archy
# correct=male    , guess=female  ,name=Ashley
# correct=male    , guess=female  ,name=Bailey
# correct=male    , guess=female  ,name=Barclay
# correct=male    , guess=female  ,name=Barrie
# correct=male    , guess=female  ,name=Bartolomei
# correct=male    , guess=female  ,name=Barty
# correct=male    , guess=female  ,name=Bennie
# correct=male    , guess=female  ,name=Blare
# correct=male    , guess=female  ,name=Burnaby
# correct=male    , guess=female  ,name=Chase
# correct=male    , guess=female  ,name=Christophe
# correct=male    , guess=female  ,name=Clemente
# correct=male    , guess=female  ,name=Cole
# correct=male    , guess=female  ,name=Darth
# correct=male    , guess=female  ,name=Demetre
# correct=male    , guess=female  ,name=Demetri
# correct=male    , guess=female  ,name=Donny
# correct=male    , guess=female  ,name=Duke
# correct=male    , guess=female  ,name=Dwaine
# correct=male    , guess=female  ,name=Earle
# correct=male    , guess=female  ,name=Elijah
# correct=male    , guess=female  ,name=Elisha
# correct=male    , guess=female  ,name=Elroy
# correct=male    , guess=female  ,name=Emery
# correct=male    , guess=female  ,name=Esme
# correct=male    , guess=female  ,name=Fairfax
# correct=male    , guess=female  ,name=Felix
# correct=male    , guess=female  ,name=Garth
# correct=male    , guess=female  ,name=Garvy
# correct=male    , guess=female  ,name=Gene
# correct=male    , guess=female  ,name=Godfrey
# correct=male    , guess=female  ,name=Godfry
# correct=male    , guess=female  ,name=Hale
# correct=male    , guess=female  ,name=Heath
# correct=male    , guess=female  ,name=Hersh
# correct=male    , guess=female  ,name=Hewie
# correct=male    , guess=female  ,name=Hezekiah
# correct=male    , guess=female  ,name=Holly
# correct=male    , guess=female  ,name=Howie
# correct=male    , guess=female  ,name=Ignace
# correct=male    , guess=female  ,name=Jaime
# correct=male    , guess=female  ,name=Jake
# correct=male    , guess=female  ,name=Jephthah
# correct=male    , guess=female  ,name=Jermaine
# correct=male    , guess=female  ,name=Jerome
# correct=male    , guess=female  ,name=Jessey
# correct=male    , guess=female  ,name=Jessie
# correct=male    , guess=female  ,name=Joey
# correct=male    , guess=female  ,name=Judy
# correct=male    , guess=female  ,name=Keene
# correct=male    , guess=female  ,name=Lemmy
# correct=male    , guess=female  ,name=Leslie
# correct=male    , guess=female  ,name=Mace
# correct=male    , guess=female  ,name=Marsh
# correct=male    , guess=female  ,name=Maurice
# correct=male    , guess=female  ,name=Moishe
# correct=male    , guess=female  ,name=Moore
# correct=male    , guess=female  ,name=Morty
# correct=male    , guess=female  ,name=Myke
# correct=male    , guess=female  ,name=Neale
# correct=male    , guess=female  ,name=Nickie
# correct=male    , guess=female  ,name=Noah
# correct=male    , guess=female  ,name=Ozzie
# correct=male    , guess=female  ,name=Pete
# correct=male    , guess=female  ,name=Piggy
# correct=male    , guess=female  ,name=Rabi
# correct=male    , guess=female  ,name=Ramsey
# correct=male    , guess=female  ,name=Rodolph
# correct=male    , guess=female  ,name=Rolfe
# correct=male    , guess=female  ,name=Rory
# correct=male    , guess=female  ,name=Sammie
# correct=male    , guess=female  ,name=Sansone
# correct=male    , guess=female  ,name=Saundra
# correct=male    , guess=female  ,name=Selby
# correct=male    , guess=female  ,name=Shay
# correct=male    , guess=female  ,name=Shayne
# correct=male    , guess=female  ,name=Sidnee
# correct=male    , guess=female  ,name=Sinclare
# correct=male    , guess=female  ,name=Skye
# correct=male    , guess=female  ,name=Sloane
# correct=male    , guess=female  ,name=Stacy
# correct=male    , guess=female  ,name=Tabbie
# correct=male    , guess=female  ,name=Terrence
# correct=male    , guess=female  ,name=Thorny
# correct=male    , guess=female  ,name=Tobe
# correct=male    , guess=female  ,name=Toddy
# correct=male    , guess=female  ,name=Towney
# correct=male    , guess=female  ,name=Tracey
# correct=male    , guess=female  ,name=Tymothy
# correct=male    , guess=female  ,name=Vince
# correct=male    , guess=female  ,name=Virge
# correct=male    , guess=female  ,name=Voltaire
# correct=male    , guess=female  ,name=Waine
# correct=male    , guess=female  ,name=Wallie
# correct=male    , guess=female  ,name=Wally
# correct=male    , guess=female  ,name=Westbrooke
# correct=male    , guess=female  ,name=Wolfie
# correct=male    , guess=female  ,name=Yancy
# correct=male    , guess=female  ,name=Zach
# correct=male    , guess=female  ,name=Zebadiah
# correct=male    , guess=female  ,name=Zedekiah

# %%
def gender_features(word):
    return {'suffix1':word[-1:],
            'suffix2':word[-2:]}

# %%
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.801

# %%
gender_features('Rishav')
# Out:
# {'suffix1': 'v', 'suffix2': 'av'}

# %%
train_set
# Out:
# [({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ek'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'ab'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'x', 'suffix2': 'ax'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'lm'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'be'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'so'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'rm'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'ns'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'gy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ue'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'eg'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'eo'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'mo'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'os'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'xy'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'zy'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'ro'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'z', 'suffix2': 'nz'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'male'),
#  ({'suffix1': 'u', 'suffix2': 'hu'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'nt'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'Er'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'ol'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'vy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'va'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'do'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ki'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'fe'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ud'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'bb'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'fo'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'yd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'cy'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'fy'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'vy'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'es'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ld'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'my'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'ig'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'vy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'eo'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'rk'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'ng'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'be'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'zo'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ut'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'v', 'suffix2': 'rv'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'im'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'bo'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'u', 'suffix2': 'lu'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ge'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'to'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'go'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'rn'}, 'male'),
#  ({'suffix1': 'b', 'suffix2': 'bb'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'ys'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'vo'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'fy'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ue'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'eo'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'ck'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'ow'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'st'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'be'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'os'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ce'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'py'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'eh'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'rl'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'rt'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ei'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ky'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'zy'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'th'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'x', 'suffix2': 'ix'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'tr'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ad'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'io'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ae'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'ir'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'va'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'nk'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'oe'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'ax'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'gh'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'id'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'ro'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'fi'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'lt'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'ob'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ny'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'yl'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'x', 'suffix2': 'ix'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'ed'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'b', 'suffix2': 'ub'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'to'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'rk'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'sh'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'or'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'lo'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'ar'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'b', 'suffix2': 'ob'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ke'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'ok'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'nt'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ft'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ye'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'iy'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'me'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'eo'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ci'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ea'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ha'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'or'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'ed'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'bi'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'ic'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'v', 'suffix2': 'ev'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'se'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'fo'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ke'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ay'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ni'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'or'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'f', 'suffix2': 'ff'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'gs'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'p', 'suffix2': 'ip'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ma'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'in'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'ah'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'rg'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'id'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ya'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ai'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ja'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'di'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'my'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ra'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'z', 'suffix2': 'iz'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'za'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'de'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'mi'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ga'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'si'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'yn'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'dy'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'al'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'as'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ga'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'ol'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'nn'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'sa'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'sy'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'ig'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'li'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ka'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'da'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'hi'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ci'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'ow'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'gh'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'ot'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'la'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'bi'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ry'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'b', 'suffix2': 'ib'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'he'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ta'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'us'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'tt'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'male'),
#  ({'suffix1': 'v', 'suffix2': 'rv'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'it'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'ex'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'et'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'nd'}, 'female'),
#  ({'suffix1': 'v', 'suffix2': 'ev'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'am'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'rs'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'be'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'is'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ke'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ca'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'rd'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'ba'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'il'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'ti'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'le'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'ia'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'by'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ty'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ie'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'ly'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 're'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ee'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'en'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'ne'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'an'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'ri'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'er'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'll'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'ey'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'na'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'el'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'on'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'te'}, 'female'),
#  ...]

# %%
def gender_features(word):
    return {'suffix1':word[-2:],
            'suffix2':word[-3:]}
train_set=[(gender_features(n),g) for (n,g) in train_names]
devtest_set=[(gender_features(n),g) for (n,g) in devtest_names]
test_set=[(gender_features(n),g) for (n,g) in test_names]

classifier=nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,devtest_set)
# Out:
# 0.798

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.784

# %% [markdown]
# Document Classification

# %%
from nltk.corpus import movie_reviews
documents=[(list(movie_reviews.words(fileid)),category)
          for category in movie_reviews.categories()
          for fileid in movie_reviews.fileids(category)]

# %%
len(documents)
# Out:
# 2000

# %%
all_words=nltk.FreqDist(w.lower() for w in movie_reviews.words())

# %%
word_features=list(all_words.keys())[:2000]

# %%
word_features[:10]
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party']

# %%
def document_features(document):
    document_words=set(document)
    features={}
    for word in word_features:
        features['contains (%s)'%word]=(word in document_words)
    return features

# %%
document_features(movie_reviews.words('pos/cv957_8737.txt'))
# Out:
# {'contains (plot)': True,
#  'contains (:)': True,
#  'contains (two)': True,
#  'contains (teen)': False,
#  'contains (couples)': False,
#  'contains (go)': False,
#  'contains (to)': True,
#  'contains (a)': True,
#  'contains (church)': False,
#  'contains (party)': False,
#  'contains (,)': True,
#  'contains (drink)': False,
#  'contains (and)': True,
#  'contains (then)': True,
#  'contains (drive)': False,
#  'contains (.)': True,
#  'contains (they)': True,
#  'contains (get)': True,
#  'contains (into)': True,
#  'contains (an)': True,
#  'contains (accident)': False,
#  'contains (one)': True,
#  'contains (of)': True,
#  'contains (the)': True,
#  'contains (guys)': False,
#  'contains (dies)': False,
#  'contains (but)': True,
#  'contains (his)': True,
#  'contains (girlfriend)': True,
#  'contains (continues)': False,
#  'contains (see)': False,
#  'contains (him)': True,
#  'contains (in)': True,
#  'contains (her)': False,
#  'contains (life)': False,
#  'contains (has)': True,
#  'contains (nightmares)': False,
#  'contains (what)': True,
#  "contains (')": True,
#  'contains (s)': True,
#  'contains (deal)': False,
#  'contains (?)': False,
#  'contains (watch)': True,
#  'contains (movie)': True,
#  'contains (")': True,
#  'contains (sorta)': False,
#  'contains (find)': False,
#  'contains (out)': True,
#  'contains (critique)': False,
#  'contains (mind)': False,
#  'contains (-)': True,
#  'contains (fuck)': False,
#  'contains (for)': True,
#  'contains (generation)': False,
#  'contains (that)': True,
#  'contains (touches)': False,
#  'contains (on)': True,
#  'contains (very)': True,
#  'contains (cool)': False,
#  'contains (idea)': True,
#  'contains (presents)': False,
#  'contains (it)': True,
#  'contains (bad)': False,
#  'contains (package)': False,
#  'contains (which)': True,
#  'contains (is)': True,
#  'contains (makes)': False,
#  'contains (this)': True,
#  'contains (review)': False,
#  'contains (even)': False,
#  'contains (harder)': False,
#  'contains (write)': False,
#  'contains (since)': False,
#  'contains (i)': False,
#  'contains (generally)': False,
#  'contains (applaud)': False,
#  'contains (films)': False,
#  'contains (attempt)': False,
#  'contains (break)': False,
#  'contains (mold)': False,
#  'contains (mess)': False,
#  'contains (with)': True,
#  'contains (your)': False,
#  'contains (head)': False,
#  'contains (such)': False,
#  'contains (()': True,
#  'contains (lost)': False,
#  'contains (highway)': False,
#  'contains (&)': False,
#  'contains (memento)': False,
#  'contains ())': True,
#  'contains (there)': True,
#  'contains (are)': True,
#  'contains (good)': False,
#  'contains (ways)': False,
#  'contains (making)': True,
#  'contains (all)': True,
#  'contains (types)': False,
#  'contains (these)': False,
#  'contains (folks)': False,
#  'contains (just)': True,
#  'contains (didn)': False,
#  'contains (t)': False,
#  'contains (snag)': False,
#  'contains (correctly)': False,
#  'contains (seem)': False,
#  'contains (have)': True,
#  'contains (taken)': False,
#  'contains (pretty)': False,
#  'contains (neat)': False,
#  'contains (concept)': False,
#  'contains (executed)': False,
#  'contains (terribly)': False,
#  'contains (so)': False,
#  'contains (problems)': True,
#  'contains (well)': True,
#  'contains (its)': False,
#  'contains (main)': False,
#  'contains (problem)': False,
#  'contains (simply)': False,
#  'contains (too)': False,
#  'contains (jumbled)': False,
#  'contains (starts)': False,
#  'contains (off)': False,
#  'contains (normal)': False,
#  'contains (downshifts)': False,
#  'contains (fantasy)': False,
#  'contains (world)': True,
#  'contains (you)': True,
#  'contains (as)': True,
#  'contains (audience)': False,
#  'contains (member)': False,
#  'contains (no)': False,
#  'contains (going)': False,
#  'contains (dreams)': False,
#  'contains (characters)': False,
#  'contains (coming)': False,
#  'contains (back)': False,
#  'contains (from)': True,
#  'contains (dead)': False,
#  'contains (others)': True,
#  'contains (who)': True,
#  'contains (look)': True,
#  'contains (like)': True,
#  'contains (strange)': False,
#  'contains (apparitions)': False,
#  'contains (disappearances)': False,
#  'contains (looooot)': False,
#  'contains (chase)': True,
#  'contains (scenes)': False,
#  'contains (tons)': False,
#  'contains (weird)': False,
#  'contains (things)': True,
#  'contains (happen)': False,
#  'contains (most)': True,
#  'contains (not)': True,
#  'contains (explained)': False,
#  'contains (now)': False,
#  'contains (personally)': False,
#  'contains (don)': False,
#  'contains (trying)': False,
#  'contains (unravel)': False,
#  'contains (film)': False,
#  'contains (every)': False,
#  'contains (when)': True,
#  'contains (does)': False,
#  'contains (give)': False,
#  'contains (me)': True,
#  'contains (same)': True,
#  'contains (clue)': False,
#  'contains (over)': False,
#  'contains (again)': False,
#  'contains (kind)': True,
#  'contains (fed)': False,
#  'contains (up)': False,
#  'contains (after)': False,
#  'contains (while)': True,
#  'contains (biggest)': False,
#  'contains (obviously)': False,
#  'contains (got)': True,
#  'contains (big)': False,
#  'contains (secret)': False,
#  'contains (hide)': False,
#  'contains (seems)': False,
#  'contains (want)': False,
#  'contains (completely)': False,
#  'contains (until)': False,
#  'contains (final)': False,
#  'contains (five)': False,
#  'contains (minutes)': False,
#  'contains (do)': True,
#  'contains (make)': True,
#  'contains (entertaining)': False,
#  'contains (thrilling)': False,
#  'contains (or)': False,
#  'contains (engaging)': False,
#  'contains (meantime)': False,
#  'contains (really)': False,
#  'contains (sad)': False,
#  'contains (part)': False,
#  'contains (arrow)': False,
#  'contains (both)': False,
#  'contains (dig)': False,
#  'contains (flicks)': False,
#  'contains (we)': False,
#  'contains (actually)': True,
#  'contains (figured)': False,
#  'contains (by)': True,
#  'contains (half)': False,
#  'contains (way)': True,
#  'contains (point)': False,
#  'contains (strangeness)': False,
#  'contains (did)': False,
#  'contains (start)': True,
#  'contains (little)': True,
#  'contains (bit)': False,
#  'contains (sense)': False,
#  'contains (still)': False,
#  'contains (more)': False,
#  'contains (guess)': False,
#  'contains (bottom)': False,
#  'contains (line)': False,
#  'contains (movies)': True,
#  'contains (should)': False,
#  'contains (always)': False,
#  'contains (sure)': False,
#  'contains (before)': False,
#  'contains (given)': False,
#  'contains (password)': False,
#  'contains (enter)': False,
#  'contains (understanding)': False,
#  'contains (mean)': False,
#  'contains (showing)': False,
#  'contains (melissa)': False,
#  'contains (sagemiller)': False,
#  'contains (running)': False,
#  'contains (away)': False,
#  'contains (visions)': False,
#  'contains (about)': True,
#  'contains (20)': False,
#  'contains (throughout)': False,
#  'contains (plain)': False,
#  'contains (lazy)': False,
#  'contains (!)': True,
#  'contains (okay)': False,
#  'contains (people)': False,
#  'contains (chasing)': False,
#  'contains (know)': False,
#  'contains (need)': False,
#  'contains (how)': True,
#  'contains (giving)': False,
#  'contains (us)': True,
#  'contains (different)': False,
#  'contains (offering)': False,
#  'contains (further)': False,
#  'contains (insight)': False,
#  'contains (down)': False,
#  'contains (apparently)': False,
#  'contains (studio)': False,
#  'contains (took)': False,
#  'contains (director)': False,
#  'contains (chopped)': False,
#  'contains (themselves)': False,
#  'contains (shows)': False,
#  'contains (might)': False,
#  'contains (ve)': False,
#  'contains (been)': False,
#  'contains (decent)': False,
#  'contains (here)': True,
#  'contains (somewhere)': False,
#  'contains (suits)': False,
#  'contains (decided)': False,
#  'contains (turning)': False,
#  'contains (music)': False,
#  'contains (video)': False,
#  'contains (edge)': False,
#  'contains (would)': False,
#  'contains (actors)': False,
#  'contains (although)': False,
#  'contains (wes)': False,
#  'contains (bentley)': False,
#  'contains (seemed)': False,
#  'contains (be)': True,
#  'contains (playing)': True,
#  'contains (exact)': False,
#  'contains (character)': False,
#  'contains (he)': True,
#  'contains (american)': False,
#  'contains (beauty)': False,
#  'contains (only)': True,
#  'contains (new)': False,
#  'contains (neighborhood)': False,
#  'contains (my)': False,
#  'contains (kudos)': False,
#  'contains (holds)': False,
#  'contains (own)': True,
#  'contains (entire)': False,
#  'contains (feeling)': False,
#  'contains (unraveling)': False,
#  'contains (overall)': False,
#  'contains (doesn)': False,
#  'contains (stick)': False,
#  'contains (because)': False,
#  'contains (entertain)': False,
#  'contains (confusing)': False,
#  'contains (rarely)': False,
#  'contains (excites)': False,
#  'contains (feels)': False,
#  'contains (redundant)': False,
#  'contains (runtime)': False,
#  'contains (despite)': False,
#  'contains (ending)': False,
#  'contains (explanation)': False,
#  'contains (craziness)': False,
#  'contains (came)': False,
#  'contains (oh)': False,
#  'contains (horror)': False,
#  'contains (slasher)': False,
#  'contains (flick)': False,
#  'contains (packaged)': False,
#  'contains (someone)': False,
#  'contains (assuming)': False,
#  'contains (genre)': False,
#  'contains (hot)': False,
#  'contains (kids)': False,
#  'contains (also)': True,
#  'contains (wrapped)': False,
#  'contains (production)': False,
#  'contains (years)': False,
#  'contains (ago)': False,
#  'contains (sitting)': False,
#  'contains (shelves)': False,
#  'contains (ever)': True,
#  'contains (whatever)': False,
#  'contains (skip)': False,
#  'contains (where)': True,
#  'contains (joblo)': False,
#  'contains (nightmare)': False,
#  'contains (elm)': False,
#  'contains (street)': False,
#  'contains (3)': False,
#  'contains (7)': False,
#  'contains (/)': False,
#  'contains (10)': False,
#  'contains (blair)': False,
#  'contains (witch)': False,
#  'contains (2)': False,
#  'contains (crow)': False,
#  'contains (9)': False,
#  'contains (salvation)': False,
#  'contains (4)': False,
#  'contains (stir)': False,
#  'contains (echoes)': False,
#  'contains (8)': False,
#  'contains (happy)': False,
#  'contains (bastard)': False,
#  'contains (quick)': True,
#  'contains (damn)': False,
#  'contains (y2k)': False,
#  'contains (bug)': False,
#  'contains (starring)': False,
#  'contains (jamie)': False,
#  'contains (lee)': False,
#  'contains (curtis)': False,
#  'contains (another)': False,
#  'contains (baldwin)': False,
#  'contains (brother)': False,
#  'contains (william)': False,
#  'contains (time)': False,
#  'contains (story)': False,
#  'contains (regarding)': False,
#  'contains (crew)': False,
#  'contains (tugboat)': False,
#  'contains (comes)': False,
#  'contains (across)': False,
#  'contains (deserted)': False,
#  'contains (russian)': False,
#  'contains (tech)': False,
#  'contains (ship)': False,
#  'contains (kick)': False,
#  'contains (power)': False,
#  'contains (within)': False,
#  'contains (gore)': False,
#  'contains (bringing)': False,
#  'contains (few)': False,
#  'contains (action)': True,
#  'contains (sequences)': False,
#  'contains (virus)': False,
#  'contains (empty)': False,
#  'contains (flash)': False,
#  'contains (substance)': False,
#  'contains (why)': False,
#  'contains (was)': False,
#  'contains (middle)': False,
#  'contains (nowhere)': False,
#  'contains (origin)': False,
#  'contains (pink)': False,
#  'contains (flashy)': False,
#  'contains (thing)': False,
#  'contains (hit)': False,
#  'contains (mir)': False,
#  'contains (course)': True,
#  'contains (donald)': False,
#  'contains (sutherland)': False,
#  'contains (stumbling)': False,
#  'contains (around)': False,
#  'contains (drunkenly)': False,
#  'contains (hey)': False,
#  'contains (let)': False,
#  'contains (some)': False,
#  'contains (robots)': False,
#  'contains (acting)': False,
#  'contains (below)': False,
#  'contains (average)': False,
#  'contains (likes)': False,
#  'contains (re)': True,
#  'contains (likely)': False,
#  'contains (work)': False,
#  'contains (halloween)': False,
#  'contains (h20)': False,
#  'contains (wasted)': False,
#  'contains (real)': False,
#  'contains (star)': False,
#  'contains (stan)': False,
#  'contains (winston)': False,
#  'contains (robot)': False,
#  'contains (design)': False,
#  'contains (schnazzy)': False,
#  'contains (cgi)': False,
#  'contains (occasional)': False,
#  'contains (shot)': False,
#  'contains (picking)': False,
#  'contains (brain)': False,
#  'contains (if)': True,
#  'contains (body)': False,
#  'contains (parts)': False,
#  'contains (turn)': False,
#  'contains (otherwise)': False,
#  'contains (much)': False,
#  'contains (sunken)': False,
#  'contains (jaded)': False,
#  'contains (viewer)': False,
#  'contains (thankful)': False,
#  'contains (invention)': False,
#  'contains (timex)': False,
#  'contains (indiglo)': False,
#  'contains (based)': False,
#  'contains (late)': False,
#  'contains (1960)': False,
#  'contains (television)': False,
#  'contains (show)': False,
#  'contains (name)': False,
#  'contains (mod)': False,
#  'contains (squad)': False,
#  'contains (tells)': False,
#  'contains (tale)': False,
#  'contains (three)': False,
#  'contains (reformed)': False,
#  'contains (criminals)': False,
#  'contains (under)': False,
#  'contains (employ)': False,
#  'contains (police)': False,
#  'contains (undercover)': True,
#  'contains (however)': True,
#  'contains (wrong)': True,
#  'contains (evidence)': False,
#  'contains (gets)': True,
#  'contains (stolen)': False,
#  'contains (immediately)': False,
#  'contains (suspicion)': False,
#  'contains (ads)': False,
#  'contains (cuts)': False,
#  'contains (claire)': False,
#  'contains (dane)': False,
#  'contains (nice)': False,
#  'contains (hair)': False,
#  'contains (cute)': False,
#  'contains (outfits)': False,
#  'contains (car)': False,
#  'contains (chases)': False,
#  'contains (stuff)': False,
#  'contains (blowing)': False,
#  'contains (sounds)': False,
#  'contains (first)': False,
#  'contains (fifteen)': False,
#  'contains (quickly)': False,
#  'contains (becomes)': False,
#  'contains (apparent)': False,
#  'contains (certainly)': False,
#  'contains (slick)': False,
#  'contains (looking)': False,
#  'contains (complete)': False,
#  'contains (costumes)': False,
#  'contains (isn)': False,
#  'contains (enough)': False,
#  'contains (best)': True,
#  'contains (described)': False,
#  'contains (cross)': False,
#  'contains (between)': True,
#  'contains (hour)': False,
#  'contains (long)': False,
#  'contains (cop)': False,
#  'contains (stretched)': False,
#  'contains (span)': False,
#  'contains (single)': False,
#  'contains (clich)': False,
#  'contains (matter)': False,
#  'contains (elements)': False,
#  'contains (recycled)': False,
#  'contains (everything)': True,
#  'contains (already)': False,
#  'contains (seen)': False,
#  'contains (nothing)': False,
#  'contains (spectacular)': False,
#  'contains (sometimes)': False,
#  'contains (bordering)': False,
#  'contains (wooden)': False,
#  'contains (danes)': False,
#  'contains (omar)': False,
#  'contains (epps)': False,
#  'contains (deliver)': False,
#  'contains (their)': False,
#  'contains (lines)': False,
#  'contains (bored)': False,
#  'contains (transfers)': False,
#  'contains (onto)': False,
#  'contains (escape)': False,
#  'contains (relatively)': False,
#  'contains (unscathed)': False,
#  'contains (giovanni)': False,
#  'contains (ribisi)': False,
#  'contains (plays)': False,
#  'contains (resident)': False,
#  'contains (crazy)': False,
#  'contains (man)': False,
#  'contains (ultimately)': False,
#  'contains (being)': False,
#  'contains (worth)': True,
#  'contains (watching)': False,
#  'contains (unfortunately)': False,
#  'contains (save)': False,
#  'contains (convoluted)': False,
#  'contains (apart)': False,
#  'contains (occupying)': False,
#  'contains (screen)': True,
#  'contains (young)': False,
#  'contains (cast)': False,
#  'contains (clothes)': False,
#  'contains (hip)': False,
#  'contains (soundtrack)': False,
#  'contains (appears)': False,
#  'contains (geared)': False,
#  'contains (towards)': False,
#  'contains (teenage)': False,
#  'contains (mindset)': False,
#  'contains (r)': False,
#  'contains (rating)': False,
#  'contains (content)': False,
#  'contains (justify)': False,
#  'contains (juvenile)': False,
#  'contains (older)': False,
#  'contains (information)': False,
#  'contains (literally)': False,
#  'contains (spoon)': False,
#  'contains (hard)': False,
#  'contains (instead)': False,
#  'contains (telling)': False,
#  'contains (dialogue)': False,
#  'contains (poorly)': False,
#  'contains (written)': False,
#  'contains (extremely)': False,
#  'contains (predictable)': False,
#  'contains (progresses)': False,
#  'contains (won)': False,
#  'contains (care)': False,
#  'contains (heroes)': False,
#  'contains (any)': False,
#  'contains (jeopardy)': False,
#  'contains (ll)': False,
#  'contains (aren)': False,
#  'contains (basing)': False,
#  'contains (nobody)': False,
#  'contains (remembers)': False,
#  'contains (questionable)': False,
#  'contains (wisdom)': False,
#  'contains (especially)': True,
#  'contains (considers)': False,
#  'contains (target)': False,
#  'contains (fact)': False,
#  'contains (number)': False,
#  'contains (memorable)': False,
#  'contains (can)': False,
#  'contains (counted)': False,
#  'contains (hand)': False,
#  'contains (missing)': False,
#  'contains (finger)': False,
#  'contains (times)': False,
#  'contains (checked)': False,
#  'contains (six)': False,
#  'contains (clear)': False,
#  'contains (indication)': False,
#  'contains (them)': True,
#  'contains (than)': False,
#  'contains (cash)': False,
#  'contains (spending)': False,
#  'contains (dollar)': False,
#  'contains (judging)': False,
#  'contains (rash)': False,
#  'contains (awful)': False,
#  'contains (seeing)': True,
#  'contains (avoid)': False,
#  'contains (at)': False,
#  'contains (costs)': False,
#  'contains (quest)': False,
#  'contains (camelot)': False,
#  'contains (warner)': False,
#  'contains (bros)': False,
#  'contains (feature)': False,
#  'contains (length)': False,
#  'contains (fully)': False,
#  'contains (animated)': False,
#  'contains (steal)': False,
#  'contains (clout)': False,
#  'contains (disney)': False,
#  'contains (cartoon)': False,
#  'contains (empire)': False,
#  'contains (mouse)': False,
#  'contains (reason)': False,
#  'contains (worried)': False,
#  'contains (other)': True,
#  'contains (recent)': False,
#  'contains (challenger)': False,
#  'contains (throne)': False,
#  'contains (last)': False,
#  'contains (fall)': False,
#  'contains (promising)': False,
#  'contains (flawed)': False,
#  'contains (20th)': False,
#  'contains (century)': False,
#  'contains (fox)': False,
#  'contains (anastasia)': False,
#  'contains (hercules)': False,
#  'contains (lively)': False,
#  'contains (colorful)': False,
#  'contains (palate)': False,
#  'contains (had)': False,
#  'contains (beat)': False,
#  'contains (hands)': False,
#  'contains (crown)': False,
#  'contains (1997)': False,
#  'contains (piece)': False,
#  'contains (animation)': False,
#  'contains (year)': False,
#  'contains (contest)': False,
#  'contains (arrival)': False,
#  'contains (magic)': False,
#  'contains (kingdom)': False,
#  'contains (mediocre)': False,
#  'contains (--)': True,
#  'contains (d)': False,
#  'contains (pocahontas)': False,
#  'contains (those)': False,
#  'contains (keeping)': False,
#  'contains (score)': False,
#  'contains (nearly)': False,
#  'contains (dull)': False,
#  'contains (revolves)': False,
#  'contains (adventures)': False,
#  'contains (free)': False,
#  'contains (spirited)': False,
#  'contains (kayley)': False,
#  'contains (voiced)': False,
#  'contains (jessalyn)': False,
#  'contains (gilsig)': False,
#  'contains (early)': True,
#  'contains (daughter)': False,
#  'contains (belated)': False,
#  'contains (knight)': False,
#  'contains (king)': False,
#  'contains (arthur)': False,
#  'contains (round)': False,
#  'contains (table)': False,
#  'contains (dream)': False,
#  'contains (follow)': False,
#  'contains (father)': False,
#  'contains (footsteps)': False,
#  'contains (she)': True,
#  'contains (chance)': False,
#  'contains (evil)': False,
#  'contains (warlord)': False,
#  'contains (ruber)': False,
#  'contains (gary)': False,
#  'contains (oldman)': False,
#  'contains (ex)': False,
#  'contains (gone)': False,
#  'contains (steals)': False,
#  'contains (magical)': False,
#  'contains (sword)': False,
#  'contains (excalibur)': False,
#  'contains (accidentally)': False,
#  'contains (loses)': False,
#  'contains (dangerous)': True,
#  'contains (booby)': False,
#  'contains (trapped)': False,
#  'contains (forest)': False,
#  'contains (help)': True,
#  'contains (hunky)': False,
#  'contains (blind)': False,
#  'contains (timberland)': False,
#  'contains (dweller)': False,
#  'contains (garrett)': False,
#  'contains (carey)': False,
#  'contains (elwes)': False,
#  'contains (headed)': False,
#  'contains (dragon)': False,
#  'contains (eric)': False,
#  'contains (idle)': False,
#  'contains (rickles)': False,
#  'contains (arguing)': False,
#  'contains (itself)': False,
#  'contains (able)': False,
#  'contains (medieval)': False,
#  'contains (sexist)': False,
#  'contains (prove)': False,
#  'contains (fighter)': False,
#  'contains (side)': False,
#  'contains (pure)': False,
#  'contains (showmanship)': False,
#  'contains (essential)': False,
#  'contains (element)': False,
#  'contains (expected)': False,
#  'contains (climb)': False,
#  'contains (high)': False,
#  'contains (ranks)': False,
#  'contains (differentiates)': False,
#  'contains (something)': False,
#  'contains (saturday)': False,
#  'contains (morning)': False,
#  'contains (subpar)': False,
#  'contains (instantly)': False,
#  'contains (forgettable)': False,
#  'contains (songs)': False,
#  'contains (integrated)': False,
#  'contains (computerized)': False,
#  'contains (footage)': False,
#  'contains (compare)': False,
#  'contains (run)': False,
#  'contains (angry)': False,
#  'contains (ogre)': False,
#  'contains (herc)': False,
#  'contains (battle)': False,
#  'contains (hydra)': False,
#  'contains (rest)': False,
#  'contains (case)': False,
#  'contains (stink)': False,
#  'contains (none)': False,
#  'contains (remotely)': False,
#  'contains (interesting)': False,
#  'contains (race)': False,
#  'contains (bland)': False,
#  'contains (end)': False,
#  'contains (tie)': False,
#  'contains (win)': False,
#  'contains (comedy)': True,
#  'contains (shtick)': False,
#  'contains (awfully)': False,
#  'contains (cloying)': False,
#  'contains (least)': True,
#  'contains (signs)': False,
#  'contains (pulse)': False,
#  'contains (fans)': False,
#  "contains (-')": False,
#  'contains (90s)': False,
#  'contains (tgif)': False,
#  'contains (will)': True,
#  'contains (thrilled)': False,
#  'contains (jaleel)': False,
#  'contains (urkel)': False,
#  'contains (white)': False,
#  'contains (bronson)': False,
#  'contains (balki)': False,
#  'contains (pinchot)': False,
#  'contains (sharing)': False,
#  'contains (nicely)': False,
#  'contains (realized)': False,
#  'contains (though)': False,
#  'contains (m)': False,
#  'contains (loss)': False,
#  'contains (recall)': False,
#  'contains (specific)': False,
#  'contains (providing)': False,
#  'contains (voice)': False,
#  'contains (talent)': False,
#  'contains (enthusiastic)': False,
#  'contains (paired)': False,
#  'contains (singers)': False,
#  'contains (sound)': False,
#  'contains (musical)': False,
#  'contains (moments)': False,
#  'contains (jane)': False,
#  'contains (seymour)': False,
#  'contains (celine)': False,
#  'contains (dion)': False,
#  'contains (must)': False,
#  'contains (strain)': False,
#  'contains (through)': False,
#  'contains (aside)': False,
#  'contains (children)': False,
#  'contains (probably)': False,
#  'contains (adults)': False,
#  'contains (grievous)': False,
#  'contains (error)': False,
#  'contains (lack)': False,
#  'contains (personality)': False,
#  'contains (learn)': False,
#  'contains (goes)': False,
#  'contains (synopsis)': False,
#  'contains (mentally)': False,
#  'contains (unstable)': False,
#  'contains (undergoing)': False,
#  'contains (psychotherapy)': False,
#  'contains (saves)': False,
#  'contains (boy)': False,
#  'contains (potentially)': False,
#  'contains (fatal)': False,
#  'contains (falls)': False,
#  'contains (love)': False,
#  'contains (mother)': False,
#  'contains (fledgling)': False,
#  'contains (restauranteur)': False,
#  'contains (unsuccessfully)': False,
#  'contains (attempting)': False,
#  'contains (gain)': False,
#  'contains (woman)': True,
#  'contains (favor)': False,
#  'contains (takes)': False,
#  'contains (pictures)': False,
#  'contains (kills)': False,
#  'contains (comments)': True,
#  'contains (stalked)': False,
#  'contains (yet)': False,
#  'contains (seemingly)': False,
#  'contains (endless)': True,
#  'contains (string)': False,
#  'contains (spurned)': False,
#  'contains (psychos)': False,
#  'contains (getting)': True,
#  'contains (revenge)': False,
#  'contains (type)': False,
#  'contains (stable)': False,
#  'contains (category)': False,
#  'contains (1990s)': False,
#  'contains (industry)': False,
#  'contains (theatrical)': False,
#  'contains (direct)': False,
#  'contains (proliferation)': False,
#  'contains (may)': False,
#  'contains (due)': False,
#  'contains (typically)': False,
#  'contains (inexpensive)': False,
#  'contains (produce)': False,
#  'contains (special)': False,
#  'contains (effects)': False,
#  'contains (stars)': False,
#  'contains (serve)': False,
#  'contains (vehicles)': False,
#  'contains (nudity)': False,
#  'contains (allowing)': False,
#  'contains (frequent)': False,
#  'contains (night)': False,
#  'contains (cable)': False,
#  'contains (wavers)': False,
#  'contains (slightly)': False,
#  'contains (norm)': False,
#  'contains (respect)': False,
#  'contains (psycho)': False,
#  'contains (never)': True,
#  'contains (affair)': False,
#  'contains (;)': False,
#  'contains (contrary)': False,
#  'contains (rejected)': False,
#  'contains (rather)': False,
#  'contains (lover)': False,
#  'contains (wife)': True,
#  'contains (husband)': False,
#  'contains (entry)': False,
#  'contains (doomed)': False,
#  'contains (collect)': False,
#  'contains (dust)': False,
#  'contains (viewed)': False,
#  'contains (midnight)': False,
#  'contains (provide)': False,
#  'contains (suspense)': False,
#  'contains (sets)': False,
#  'contains (interspersed)': False,
#  'contains (opening)': False,
#  'contains (credits)': False,
#  'contains (instance)': False,
#  'contains (serious)': False,
#  'contains (sounding)': False,
#  'contains (narrator)': False,
#  'contains (spouts)': False,
#  'contains (statistics)': False,
#  'contains (stalkers)': False,
#  'contains (ponders)': False,
#  'contains (cause)': False,
#  'contains (stalk)': False,
#  'contains (implicitly)': False,
#  'contains (implied)': False,
#  'contains (men)': False,
#  'contains (shown)': False,
#  'contains (snapshot)': False,
#  'contains (actor)': False,
#  'contains (jay)': False,
#  'contains (underwood)': False,
#  'contains (states)': False,
#  'contains (daryl)': False,
#  'contains (gleason)': False,
#  'contains (stalker)': False,
#  'contains (brooke)': False,
#  'contains (daniels)': False,
#  'contains (meant)': False,
#  'contains (called)': False,
#  'contains (guesswork)': False,
#  'contains (required)': False,
#  'contains (proceeds)': False,
#  'contains (begins)': False,
#  'contains (obvious)': False,
#  'contains (sequence)': False,
#  'contains (contrived)': False,
#  'contains (quite)': False,
#  'contains (brings)': False,
#  'contains (victim)': False,
#  'contains (together)': False,
#  'contains (obsesses)': False,
#  'contains (follows)': False,
#  'contains (tries)': True,
#  'contains (woo)': False,
#  'contains (plans)': False,
#  'contains (become)': False,
#  'contains (desperate)': False,
#  'contains (elaborate)': False,
#  'contains (include)': False,
#  'contains (cliche)': False,
#  'contains (murdered)': False,
#  'contains (pet)': False,
#  'contains (require)': False,
#  'contains (found)': False,
#  'contains (exception)': False,
#  'contains (cat)': False,
#  'contains (shower)': False,
#  'contains (events)': False,
#  'contains (lead)': True,
#  'contains (inevitable)': False,
#  'contains (showdown)': False,
#  'contains (survives)': False,
#  'contains (invariably)': False,
#  'contains (conclusion)': False,
#  'contains (turkey)': False,
#  'contains (uniformly)': False,
#  'contains (adequate)': False,
#  'contains (anything)': False,
#  'contains (home)': False,
#  'contains (either)': False,
#  'contains (turns)': False,
#  'contains (toward)': False,
#  'contains (melodrama)': False,
#  'contains (overdoes)': False,
#  'contains (words)': False,
#  'contains (manages)': False,
#  'contains (creepy)': False,
#  'contains (pass)': False,
#  'contains (demands)': False,
#  'contains (maryam)': False,
#  'contains (abo)': False,
#  'contains (close)': False,
#  'contains (played)': True,
#  'contains (bond)': False,
#  'contains (chick)': False,
#  'contains (living)': False,
#  'contains (daylights)': False,
#  'contains (equally)': False,
#  'contains (title)': False,
#  'contains (ditzy)': False,
#  'contains (strong)': False,
#  'contains (independent)': False,
#  'contains (business)': False,
#  'contains (owner)': False,
#  'contains (needs)': False,
#  'contains (proceed)': False,
#  'contains (example)': False,
#  'contains (suspicions)': False,
#  'contains (ensure)': False,
#  'contains (use)': False,
#  'contains (excuse)': False,
#  'contains (decides)': False,
#  'contains (return)': False,
#  'contains (toolbox)': False,
#  'contains (left)': False,
#  'contains (place)': True,
#  ...}

# %%
featuresets=[(document_features(d),c) for (d,c) in documents]

# %%
featuresets[:2]
# Out:
# [({'contains (plot)': True,
#    'contains (:)': True,
#    'contains (two)': True,
#    'contains (teen)': True,
#    'contains (couples)': True,
#    'contains (go)': True,
#    'contains (to)': True,
#    'contains (a)': True,
#    'contains (church)': True,
#    'contains (party)': True,
#    'contains (,)': True,
#    'contains (drink)': True,
#    'contains (and)': True,
#    'contains (then)': True,
#    'contains (drive)': True,
#    'contains (.)': True,
#    'contains (they)': True,
#    'contains (get)': True,
#    'contains (into)': True,
#    'contains (an)': True,
#    'contains (accident)': True,
#    'contains (one)': True,
#    'contains (of)': True,
#    'contains (the)': True,
#    'contains (guys)': True,
#    'contains (dies)': True,
#    'contains (but)': True,
#    'contains (his)': True,
#    'contains (girlfriend)': True,
#    'contains (continues)': True,
#    'contains (see)': True,
#    'contains (him)': True,
#    'contains (in)': True,
#    'contains (her)': True,
#    'contains (life)': True,
#    'contains (has)': True,
#    'contains (nightmares)': True,
#    'contains (what)': True,
#    "contains (')": True,
#    'contains (s)': True,
#    'contains (deal)': True,
#    'contains (?)': True,
#    'contains (watch)': True,
#    'contains (movie)': True,
#    'contains (")': True,
#    'contains (sorta)': True,
#    'contains (find)': True,
#    'contains (out)': True,
#    'contains (critique)': True,
#    'contains (mind)': True,
#    'contains (-)': True,
#    'contains (fuck)': True,
#    'contains (for)': True,
#    'contains (generation)': True,
#    'contains (that)': True,
#    'contains (touches)': True,
#    'contains (on)': True,
#    'contains (very)': True,
#    'contains (cool)': True,
#    'contains (idea)': True,
#    'contains (presents)': True,
#    'contains (it)': True,
#    'contains (bad)': True,
#    'contains (package)': True,
#    'contains (which)': True,
#    'contains (is)': True,
#    'contains (makes)': True,
#    'contains (this)': True,
#    'contains (review)': True,
#    'contains (even)': True,
#    'contains (harder)': True,
#    'contains (write)': True,
#    'contains (since)': True,
#    'contains (i)': True,
#    'contains (generally)': True,
#    'contains (applaud)': True,
#    'contains (films)': True,
#    'contains (attempt)': True,
#    'contains (break)': True,
#    'contains (mold)': True,
#    'contains (mess)': True,
#    'contains (with)': True,
#    'contains (your)': True,
#    'contains (head)': True,
#    'contains (such)': True,
#    'contains (()': True,
#    'contains (lost)': True,
#    'contains (highway)': True,
#    'contains (&)': True,
#    'contains (memento)': True,
#    'contains ())': True,
#    'contains (there)': True,
#    'contains (are)': True,
#    'contains (good)': True,
#    'contains (ways)': True,
#    'contains (making)': True,
#    'contains (all)': True,
#    'contains (types)': True,
#    'contains (these)': True,
#    'contains (folks)': True,
#    'contains (just)': True,
#    'contains (didn)': True,
#    'contains (t)': True,
#    'contains (snag)': True,
#    'contains (correctly)': True,
#    'contains (seem)': True,
#    'contains (have)': True,
#    'contains (taken)': True,
#    'contains (pretty)': True,
#    'contains (neat)': True,
#    'contains (concept)': True,
#    'contains (executed)': True,
#    'contains (terribly)': True,
#    'contains (so)': True,
#    'contains (problems)': True,
#    'contains (well)': True,
#    'contains (its)': True,
#    'contains (main)': True,
#    'contains (problem)': True,
#    'contains (simply)': True,
#    'contains (too)': True,
#    'contains (jumbled)': True,
#    'contains (starts)': True,
#    'contains (off)': True,
#    'contains (normal)': True,
#    'contains (downshifts)': True,
#    'contains (fantasy)': True,
#    'contains (world)': True,
#    'contains (you)': True,
#    'contains (as)': True,
#    'contains (audience)': True,
#    'contains (member)': True,
#    'contains (no)': True,
#    'contains (going)': True,
#    'contains (dreams)': True,
#    'contains (characters)': True,
#    'contains (coming)': True,
#    'contains (back)': True,
#    'contains (from)': True,
#    'contains (dead)': True,
#    'contains (others)': True,
#    'contains (who)': True,
#    'contains (look)': True,
#    'contains (like)': True,
#    'contains (strange)': True,
#    'contains (apparitions)': True,
#    'contains (disappearances)': True,
#    'contains (looooot)': True,
#    'contains (chase)': True,
#    'contains (scenes)': True,
#    'contains (tons)': True,
#    'contains (weird)': True,
#    'contains (things)': True,
#    'contains (happen)': True,
#    'contains (most)': True,
#    'contains (not)': True,
#    'contains (explained)': True,
#    'contains (now)': True,
#    'contains (personally)': True,
#    'contains (don)': True,
#    'contains (trying)': True,
#    'contains (unravel)': True,
#    'contains (film)': True,
#    'contains (every)': True,
#    'contains (when)': True,
#    'contains (does)': True,
#    'contains (give)': True,
#    'contains (me)': True,
#    'contains (same)': True,
#    'contains (clue)': True,
#    'contains (over)': True,
#    'contains (again)': True,
#    'contains (kind)': True,
#    'contains (fed)': True,
#    'contains (up)': True,
#    'contains (after)': True,
#    'contains (while)': True,
#    'contains (biggest)': True,
#    'contains (obviously)': True,
#    'contains (got)': True,
#    'contains (big)': True,
#    'contains (secret)': True,
#    'contains (hide)': True,
#    'contains (seems)': True,
#    'contains (want)': True,
#    'contains (completely)': True,
#    'contains (until)': True,
#    'contains (final)': True,
#    'contains (five)': True,
#    'contains (minutes)': True,
#    'contains (do)': True,
#    'contains (make)': True,
#    'contains (entertaining)': True,
#    'contains (thrilling)': True,
#    'contains (or)': True,
#    'contains (engaging)': True,
#    'contains (meantime)': True,
#    'contains (really)': True,
#    'contains (sad)': True,
#    'contains (part)': True,
#    'contains (arrow)': True,
#    'contains (both)': True,
#    'contains (dig)': True,
#    'contains (flicks)': True,
#    'contains (we)': True,
#    'contains (actually)': True,
#    'contains (figured)': True,
#    'contains (by)': True,
#    'contains (half)': True,
#    'contains (way)': True,
#    'contains (point)': True,
#    'contains (strangeness)': True,
#    'contains (did)': True,
#    'contains (start)': True,
#    'contains (little)': True,
#    'contains (bit)': True,
#    'contains (sense)': True,
#    'contains (still)': True,
#    'contains (more)': True,
#    'contains (guess)': True,
#    'contains (bottom)': True,
#    'contains (line)': True,
#    'contains (movies)': True,
#    'contains (should)': True,
#    'contains (always)': True,
#    'contains (sure)': True,
#    'contains (before)': True,
#    'contains (given)': True,
#    'contains (password)': True,
#    'contains (enter)': True,
#    'contains (understanding)': True,
#    'contains (mean)': True,
#    'contains (showing)': True,
#    'contains (melissa)': True,
#    'contains (sagemiller)': True,
#    'contains (running)': True,
#    'contains (away)': True,
#    'contains (visions)': True,
#    'contains (about)': True,
#    'contains (20)': True,
#    'contains (throughout)': True,
#    'contains (plain)': True,
#    'contains (lazy)': True,
#    'contains (!)': True,
#    'contains (okay)': True,
#    'contains (people)': True,
#    'contains (chasing)': True,
#    'contains (know)': True,
#    'contains (need)': True,
#    'contains (how)': True,
#    'contains (giving)': True,
#    'contains (us)': True,
#    'contains (different)': True,
#    'contains (offering)': True,
#    'contains (further)': True,
#    'contains (insight)': True,
#    'contains (down)': True,
#    'contains (apparently)': True,
#    'contains (studio)': True,
#    'contains (took)': True,
#    'contains (director)': True,
#    'contains (chopped)': True,
#    'contains (themselves)': True,
#    'contains (shows)': True,
#    'contains (might)': True,
#    'contains (ve)': True,
#    'contains (been)': True,
#    'contains (decent)': True,
#    'contains (here)': True,
#    'contains (somewhere)': True,
#    'contains (suits)': True,
#    'contains (decided)': True,
#    'contains (turning)': True,
#    'contains (music)': True,
#    'contains (video)': True,
#    'contains (edge)': True,
#    'contains (would)': True,
#    'contains (actors)': True,
#    'contains (although)': True,
#    'contains (wes)': True,
#    'contains (bentley)': True,
#    'contains (seemed)': True,
#    'contains (be)': True,
#    'contains (playing)': True,
#    'contains (exact)': True,
#    'contains (character)': True,
#    'contains (he)': True,
#    'contains (american)': True,
#    'contains (beauty)': True,
#    'contains (only)': True,
#    'contains (new)': True,
#    'contains (neighborhood)': True,
#    'contains (my)': True,
#    'contains (kudos)': True,
#    'contains (holds)': True,
#    'contains (own)': True,
#    'contains (entire)': True,
#    'contains (feeling)': True,
#    'contains (unraveling)': True,
#    'contains (overall)': True,
#    'contains (doesn)': True,
#    'contains (stick)': True,
#    'contains (because)': True,
#    'contains (entertain)': True,
#    'contains (confusing)': True,
#    'contains (rarely)': True,
#    'contains (excites)': True,
#    'contains (feels)': True,
#    'contains (redundant)': True,
#    'contains (runtime)': True,
#    'contains (despite)': True,
#    'contains (ending)': True,
#    'contains (explanation)': True,
#    'contains (craziness)': True,
#    'contains (came)': True,
#    'contains (oh)': True,
#    'contains (horror)': True,
#    'contains (slasher)': True,
#    'contains (flick)': True,
#    'contains (packaged)': True,
#    'contains (someone)': True,
#    'contains (assuming)': True,
#    'contains (genre)': True,
#    'contains (hot)': True,
#    'contains (kids)': True,
#    'contains (also)': True,
#    'contains (wrapped)': True,
#    'contains (production)': True,
#    'contains (years)': True,
#    'contains (ago)': True,
#    'contains (sitting)': True,
#    'contains (shelves)': True,
#    'contains (ever)': True,
#    'contains (whatever)': True,
#    'contains (skip)': True,
#    'contains (where)': True,
#    'contains (joblo)': True,
#    'contains (nightmare)': True,
#    'contains (elm)': True,
#    'contains (street)': True,
#    'contains (3)': True,
#    'contains (7)': True,
#    'contains (/)': True,
#    'contains (10)': True,
#    'contains (blair)': True,
#    'contains (witch)': True,
#    'contains (2)': True,
#    'contains (crow)': True,
#    'contains (9)': True,
#    'contains (salvation)': True,
#    'contains (4)': True,
#    'contains (stir)': True,
#    'contains (echoes)': True,
#    'contains (8)': True,
#    'contains (happy)': False,
#    'contains (bastard)': False,
#    'contains (quick)': False,
#    'contains (damn)': False,
#    'contains (y2k)': False,
#    'contains (bug)': False,
#    'contains (starring)': False,
#    'contains (jamie)': False,
#    'contains (lee)': False,
#    'contains (curtis)': False,
#    'contains (another)': False,
#    'contains (baldwin)': False,
#    'contains (brother)': False,
#    'contains (william)': False,
#    'contains (time)': False,
#    'contains (story)': False,
#    'contains (regarding)': False,
#    'contains (crew)': False,
#    'contains (tugboat)': False,
#    'contains (comes)': False,
#    'contains (across)': False,
#    'contains (deserted)': False,
#    'contains (russian)': False,
#    'contains (tech)': False,
#    'contains (ship)': False,
#    'contains (kick)': False,
#    'contains (power)': False,
#    'contains (within)': False,
#    'contains (gore)': False,
#    'contains (bringing)': False,
#    'contains (few)': False,
#    'contains (action)': False,
#    'contains (sequences)': False,
#    'contains (virus)': False,
#    'contains (empty)': False,
#    'contains (flash)': False,
#    'contains (substance)': False,
#    'contains (why)': False,
#    'contains (was)': False,
#    'contains (middle)': False,
#    'contains (nowhere)': False,
#    'contains (origin)': False,
#    'contains (pink)': False,
#    'contains (flashy)': False,
#    'contains (thing)': False,
#    'contains (hit)': False,
#    'contains (mir)': False,
#    'contains (course)': False,
#    'contains (donald)': False,
#    'contains (sutherland)': False,
#    'contains (stumbling)': False,
#    'contains (around)': False,
#    'contains (drunkenly)': False,
#    'contains (hey)': False,
#    'contains (let)': False,
#    'contains (some)': False,
#    'contains (robots)': False,
#    'contains (acting)': False,
#    'contains (below)': False,
#    'contains (average)': False,
#    'contains (likes)': False,
#    'contains (re)': False,
#    'contains (likely)': False,
#    'contains (work)': False,
#    'contains (halloween)': False,
#    'contains (h20)': False,
#    'contains (wasted)': False,
#    'contains (real)': False,
#    'contains (star)': False,
#    'contains (stan)': False,
#    'contains (winston)': False,
#    'contains (robot)': False,
#    'contains (design)': False,
#    'contains (schnazzy)': False,
#    'contains (cgi)': False,
#    'contains (occasional)': False,
#    'contains (shot)': False,
#    'contains (picking)': False,
#    'contains (brain)': False,
#    'contains (if)': False,
#    'contains (body)': False,
#    'contains (parts)': False,
#    'contains (turn)': False,
#    'contains (otherwise)': False,
#    'contains (much)': False,
#    'contains (sunken)': False,
#    'contains (jaded)': False,
#    'contains (viewer)': False,
#    'contains (thankful)': False,
#    'contains (invention)': False,
#    'contains (timex)': False,
#    'contains (indiglo)': False,
#    'contains (based)': False,
#    'contains (late)': False,
#    'contains (1960)': False,
#    'contains (television)': False,
#    'contains (show)': False,
#    'contains (name)': False,
#    'contains (mod)': False,
#    'contains (squad)': False,
#    'contains (tells)': False,
#    'contains (tale)': False,
#    'contains (three)': False,
#    'contains (reformed)': False,
#    'contains (criminals)': False,
#    'contains (under)': False,
#    'contains (employ)': False,
#    'contains (police)': False,
#    'contains (undercover)': False,
#    'contains (however)': False,
#    'contains (wrong)': False,
#    'contains (evidence)': False,
#    'contains (gets)': False,
#    'contains (stolen)': False,
#    'contains (immediately)': False,
#    'contains (suspicion)': False,
#    'contains (ads)': False,
#    'contains (cuts)': False,
#    'contains (claire)': False,
#    'contains (dane)': False,
#    'contains (nice)': False,
#    'contains (hair)': False,
#    'contains (cute)': False,
#    'contains (outfits)': False,
#    'contains (car)': False,
#    'contains (chases)': False,
#    'contains (stuff)': False,
#    'contains (blowing)': False,
#    'contains (sounds)': False,
#    'contains (first)': False,
#    'contains (fifteen)': False,
#    'contains (quickly)': False,
#    'contains (becomes)': False,
#    'contains (apparent)': False,
#    'contains (certainly)': False,
#    'contains (slick)': False,
#    'contains (looking)': False,
#    'contains (complete)': False,
#    'contains (costumes)': False,
#    'contains (isn)': False,
#    'contains (enough)': False,
#    'contains (best)': False,
#    'contains (described)': False,
#    'contains (cross)': False,
#    'contains (between)': False,
#    'contains (hour)': False,
#    'contains (long)': False,
#    'contains (cop)': False,
#    'contains (stretched)': False,
#    'contains (span)': False,
#    'contains (single)': False,
#    'contains (clich)': False,
#    'contains (matter)': False,
#    'contains (elements)': False,
#    'contains (recycled)': False,
#    'contains (everything)': False,
#    'contains (already)': False,
#    'contains (seen)': False,
#    'contains (nothing)': False,
#    'contains (spectacular)': False,
#    'contains (sometimes)': False,
#    'contains (bordering)': False,
#    'contains (wooden)': False,
#    'contains (danes)': False,
#    'contains (omar)': False,
#    'contains (epps)': False,
#    'contains (deliver)': False,
#    'contains (their)': False,
#    'contains (lines)': False,
#    'contains (bored)': False,
#    'contains (transfers)': False,
#    'contains (onto)': False,
#    'contains (escape)': False,
#    'contains (relatively)': False,
#    'contains (unscathed)': False,
#    'contains (giovanni)': False,
#    'contains (ribisi)': False,
#    'contains (plays)': False,
#    'contains (resident)': False,
#    'contains (crazy)': False,
#    'contains (man)': False,
#    'contains (ultimately)': False,
#    'contains (being)': False,
#    'contains (worth)': False,
#    'contains (watching)': False,
#    'contains (unfortunately)': False,
#    'contains (save)': False,
#    'contains (convoluted)': False,
#    'contains (apart)': False,
#    'contains (occupying)': False,
#    'contains (screen)': False,
#    'contains (young)': False,
#    'contains (cast)': False,
#    'contains (clothes)': False,
#    'contains (hip)': False,
#    'contains (soundtrack)': False,
#    'contains (appears)': False,
#    'contains (geared)': False,
#    'contains (towards)': False,
#    'contains (teenage)': False,
#    'contains (mindset)': False,
#    'contains (r)': False,
#    'contains (rating)': False,
#    'contains (content)': False,
#    'contains (justify)': False,
#    'contains (juvenile)': False,
#    'contains (older)': False,
#    'contains (information)': False,
#    'contains (literally)': False,
#    'contains (spoon)': False,
#    'contains (hard)': False,
#    'contains (instead)': False,
#    'contains (telling)': False,
#    'contains (dialogue)': False,
#    'contains (poorly)': False,
#    'contains (written)': False,
#    'contains (extremely)': False,
#    'contains (predictable)': False,
#    'contains (progresses)': False,
#    'contains (won)': False,
#    'contains (care)': False,
#    'contains (heroes)': False,
#    'contains (any)': False,
#    'contains (jeopardy)': False,
#    'contains (ll)': False,
#    'contains (aren)': False,
#    'contains (basing)': False,
#    'contains (nobody)': False,
#    'contains (remembers)': False,
#    'contains (questionable)': False,
#    'contains (wisdom)': False,
#    'contains (especially)': False,
#    'contains (considers)': False,
#    'contains (target)': False,
#    'contains (fact)': False,
#    'contains (number)': False,
#    'contains (memorable)': False,
#    'contains (can)': False,
#    'contains (counted)': False,
#    'contains (hand)': False,
#    'contains (missing)': False,
#    'contains (finger)': False,
#    'contains (times)': False,
#    'contains (checked)': False,
#    'contains (six)': False,
#    'contains (clear)': False,
#    'contains (indication)': False,
#    'contains (them)': False,
#    'contains (than)': False,
#    'contains (cash)': False,
#    'contains (spending)': False,
#    'contains (dollar)': False,
#    'contains (judging)': False,
#    'contains (rash)': False,
#    'contains (awful)': False,
#    'contains (seeing)': False,
#    'contains (avoid)': False,
#    'contains (at)': False,
#    'contains (costs)': False,
#    'contains (quest)': False,
#    'contains (camelot)': False,
#    'contains (warner)': False,
#    'contains (bros)': False,
#    'contains (feature)': False,
#    'contains (length)': False,
#    'contains (fully)': False,
#    'contains (animated)': False,
#    'contains (steal)': False,
#    'contains (clout)': False,
#    'contains (disney)': False,
#    'contains (cartoon)': False,
#    'contains (empire)': False,
#    'contains (mouse)': False,
#    'contains (reason)': False,
#    'contains (worried)': False,
#    'contains (other)': False,
#    'contains (recent)': False,
#    'contains (challenger)': False,
#    'contains (throne)': False,
#    'contains (last)': False,
#    'contains (fall)': False,
#    'contains (promising)': False,
#    'contains (flawed)': False,
#    'contains (20th)': False,
#    'contains (century)': False,
#    'contains (fox)': False,
#    'contains (anastasia)': False,
#    'contains (hercules)': False,
#    'contains (lively)': False,
#    'contains (colorful)': False,
#    'contains (palate)': False,
#    'contains (had)': False,
#    'contains (beat)': False,
#    'contains (hands)': False,
#    'contains (crown)': False,
#    'contains (1997)': False,
#    'contains (piece)': False,
#    'contains (animation)': False,
#    'contains (year)': False,
#    'contains (contest)': False,
#    'contains (arrival)': False,
#    'contains (magic)': False,
#    'contains (kingdom)': False,
#    'contains (mediocre)': False,
#    'contains (--)': False,
#    'contains (d)': False,
#    'contains (pocahontas)': False,
#    'contains (those)': False,
#    'contains (keeping)': False,
#    'contains (score)': False,
#    'contains (nearly)': False,
#    'contains (dull)': False,
#    'contains (revolves)': False,
#    'contains (adventures)': False,
#    'contains (free)': False,
#    'contains (spirited)': False,
#    'contains (kayley)': False,
#    'contains (voiced)': False,
#    'contains (jessalyn)': False,
#    'contains (gilsig)': False,
#    'contains (early)': False,
#    'contains (daughter)': False,
#    'contains (belated)': False,
#    'contains (knight)': False,
#    'contains (king)': False,
#    'contains (arthur)': False,
#    'contains (round)': False,
#    'contains (table)': False,
#    'contains (dream)': False,
#    'contains (follow)': False,
#    'contains (father)': False,
#    'contains (footsteps)': False,
#    'contains (she)': False,
#    'contains (chance)': False,
#    'contains (evil)': False,
#    'contains (warlord)': False,
#    'contains (ruber)': False,
#    'contains (gary)': False,
#    'contains (oldman)': False,
#    'contains (ex)': False,
#    'contains (gone)': False,
#    'contains (steals)': False,
#    'contains (magical)': False,
#    'contains (sword)': False,
#    'contains (excalibur)': False,
#    'contains (accidentally)': False,
#    'contains (loses)': False,
#    'contains (dangerous)': False,
#    'contains (booby)': False,
#    'contains (trapped)': False,
#    'contains (forest)': False,
#    'contains (help)': False,
#    'contains (hunky)': False,
#    'contains (blind)': False,
#    'contains (timberland)': False,
#    'contains (dweller)': False,
#    'contains (garrett)': False,
#    'contains (carey)': False,
#    'contains (elwes)': False,
#    'contains (headed)': False,
#    'contains (dragon)': False,
#    'contains (eric)': False,
#    'contains (idle)': False,
#    'contains (rickles)': False,
#    'contains (arguing)': False,
#    'contains (itself)': False,
#    'contains (able)': False,
#    'contains (medieval)': False,
#    'contains (sexist)': False,
#    'contains (prove)': False,
#    'contains (fighter)': False,
#    'contains (side)': False,
#    'contains (pure)': False,
#    'contains (showmanship)': False,
#    'contains (essential)': False,
#    'contains (element)': False,
#    'contains (expected)': False,
#    'contains (climb)': False,
#    'contains (high)': False,
#    'contains (ranks)': False,
#    'contains (differentiates)': False,
#    'contains (something)': False,
#    'contains (saturday)': False,
#    'contains (morning)': False,
#    'contains (subpar)': False,
#    'contains (instantly)': False,
#    'contains (forgettable)': False,
#    'contains (songs)': False,
#    'contains (integrated)': False,
#    'contains (computerized)': False,
#    'contains (footage)': False,
#    'contains (compare)': False,
#    'contains (run)': False,
#    'contains (angry)': False,
#    'contains (ogre)': False,
#    'contains (herc)': False,
#    'contains (battle)': False,
#    'contains (hydra)': False,
#    'contains (rest)': False,
#    'contains (case)': False,
#    'contains (stink)': False,
#    'contains (none)': False,
#    'contains (remotely)': False,
#    'contains (interesting)': False,
#    'contains (race)': False,
#    'contains (bland)': False,
#    'contains (end)': False,
#    'contains (tie)': False,
#    'contains (win)': False,
#    'contains (comedy)': False,
#    'contains (shtick)': False,
#    'contains (awfully)': False,
#    'contains (cloying)': False,
#    'contains (least)': False,
#    'contains (signs)': False,
#    'contains (pulse)': False,
#    'contains (fans)': False,
#    "contains (-')": False,
#    'contains (90s)': False,
#    'contains (tgif)': False,
#    'contains (will)': False,
#    'contains (thrilled)': False,
#    'contains (jaleel)': False,
#    'contains (urkel)': False,
#    'contains (white)': False,
#    'contains (bronson)': False,
#    'contains (balki)': False,
#    'contains (pinchot)': False,
#    'contains (sharing)': False,
#    'contains (nicely)': False,
#    'contains (realized)': False,
#    'contains (though)': False,
#    'contains (m)': False,
#    'contains (loss)': False,
#    'contains (recall)': False,
#    'contains (specific)': False,
#    'contains (providing)': False,
#    'contains (voice)': False,
#    'contains (talent)': False,
#    'contains (enthusiastic)': False,
#    'contains (paired)': False,
#    'contains (singers)': False,
#    'contains (sound)': False,
#    'contains (musical)': False,
#    'contains (moments)': False,
#    'contains (jane)': False,
#    'contains (seymour)': False,
#    'contains (celine)': False,
#    'contains (dion)': False,
#    'contains (must)': False,
#    'contains (strain)': False,
#    'contains (through)': False,
#    'contains (aside)': False,
#    'contains (children)': False,
#    'contains (probably)': False,
#    'contains (adults)': False,
#    'contains (grievous)': False,
#    'contains (error)': False,
#    'contains (lack)': False,
#    'contains (personality)': False,
#    'contains (learn)': False,
#    'contains (goes)': False,
#    'contains (synopsis)': False,
#    'contains (mentally)': False,
#    'contains (unstable)': False,
#    'contains (undergoing)': False,
#    'contains (psychotherapy)': False,
#    'contains (saves)': False,
#    'contains (boy)': False,
#    'contains (potentially)': False,
#    'contains (fatal)': False,
#    'contains (falls)': False,
#    'contains (love)': False,
#    'contains (mother)': False,
#    'contains (fledgling)': False,
#    'contains (restauranteur)': False,
#    'contains (unsuccessfully)': False,
#    'contains (attempting)': False,
#    'contains (gain)': False,
#    'contains (woman)': False,
#    'contains (favor)': False,
#    'contains (takes)': False,
#    'contains (pictures)': False,
#    'contains (kills)': False,
#    'contains (comments)': False,
#    'contains (stalked)': False,
#    'contains (yet)': False,
#    'contains (seemingly)': False,
#    'contains (endless)': False,
#    'contains (string)': False,
#    'contains (spurned)': False,
#    'contains (psychos)': False,
#    'contains (getting)': False,
#    'contains (revenge)': False,
#    'contains (type)': False,
#    'contains (stable)': False,
#    'contains (category)': False,
#    'contains (1990s)': False,
#    'contains (industry)': False,
#    'contains (theatrical)': False,
#    'contains (direct)': False,
#    'contains (proliferation)': False,
#    'contains (may)': False,
#    'contains (due)': False,
#    'contains (typically)': False,
#    'contains (inexpensive)': False,
#    'contains (produce)': False,
#    'contains (special)': False,
#    'contains (effects)': False,
#    'contains (stars)': False,
#    'contains (serve)': False,
#    'contains (vehicles)': False,
#    'contains (nudity)': False,
#    'contains (allowing)': False,
#    'contains (frequent)': False,
#    'contains (night)': False,
#    'contains (cable)': False,
#    'contains (wavers)': False,
#    'contains (slightly)': False,
#    'contains (norm)': False,
#    'contains (respect)': False,
#    'contains (psycho)': False,
#    'contains (never)': False,
#    'contains (affair)': False,
#    'contains (;)': False,
#    'contains (contrary)': False,
#    'contains (rejected)': False,
#    'contains (rather)': False,
#    'contains (lover)': False,
#    'contains (wife)': False,
#    'contains (husband)': False,
#    'contains (entry)': False,
#    'contains (doomed)': False,
#    'contains (collect)': False,
#    'contains (dust)': False,
#    'contains (viewed)': False,
#    'contains (midnight)': False,
#    'contains (provide)': False,
#    'contains (suspense)': False,
#    'contains (sets)': False,
#    'contains (interspersed)': False,
#    'contains (opening)': False,
#    'contains (credits)': False,
#    'contains (instance)': False,
#    'contains (serious)': False,
#    'contains (sounding)': False,
#    'contains (narrator)': False,
#    'contains (spouts)': False,
#    'contains (statistics)': False,
#    'contains (stalkers)': False,
#    'contains (ponders)': False,
#    'contains (cause)': False,
#    'contains (stalk)': False,
#    'contains (implicitly)': False,
#    'contains (implied)': False,
#    'contains (men)': False,
#    'contains (shown)': False,
#    'contains (snapshot)': False,
#    'contains (actor)': False,
#    'contains (jay)': False,
#    'contains (underwood)': False,
#    'contains (states)': False,
#    'contains (daryl)': False,
#    'contains (gleason)': False,
#    'contains (stalker)': False,
#    'contains (brooke)': False,
#    'contains (daniels)': False,
#    'contains (meant)': False,
#    'contains (called)': False,
#    'contains (guesswork)': False,
#    'contains (required)': False,
#    'contains (proceeds)': False,
#    'contains (begins)': False,
#    'contains (obvious)': False,
#    'contains (sequence)': False,
#    'contains (contrived)': False,
#    'contains (quite)': False,
#    'contains (brings)': False,
#    'contains (victim)': False,
#    'contains (together)': False,
#    'contains (obsesses)': False,
#    'contains (follows)': False,
#    'contains (tries)': False,
#    'contains (woo)': False,
#    'contains (plans)': False,
#    'contains (become)': False,
#    'contains (desperate)': False,
#    'contains (elaborate)': False,
#    'contains (include)': False,
#    'contains (cliche)': False,
#    'contains (murdered)': False,
#    'contains (pet)': False,
#    'contains (require)': False,
#    'contains (found)': False,
#    'contains (exception)': False,
#    'contains (cat)': False,
#    'contains (shower)': False,
#    'contains (events)': False,
#    'contains (lead)': False,
#    'contains (inevitable)': False,
#    'contains (showdown)': False,
#    'contains (survives)': False,
#    'contains (invariably)': False,
#    'contains (conclusion)': False,
#    'contains (turkey)': False,
#    'contains (uniformly)': False,
#    'contains (adequate)': False,
#    'contains (anything)': False,
#    'contains (home)': False,
#    'contains (either)': False,
#    'contains (turns)': False,
#    'contains (toward)': False,
#    'contains (melodrama)': False,
#    'contains (overdoes)': False,
#    'contains (words)': False,
#    'contains (manages)': False,
#    'contains (creepy)': False,
#    'contains (pass)': False,
#    'contains (demands)': False,
#    'contains (maryam)': False,
#    'contains (abo)': False,
#    'contains (close)': False,
#    'contains (played)': False,
#    'contains (bond)': False,
#    'contains (chick)': False,
#    'contains (living)': False,
#    'contains (daylights)': False,
#    'contains (equally)': False,
#    'contains (title)': False,
#    'contains (ditzy)': False,
#    'contains (strong)': False,
#    'contains (independent)': False,
#    'contains (business)': False,
#    'contains (owner)': False,
#    'contains (needs)': False,
#    'contains (proceed)': False,
#    'contains (example)': False,
#    'contains (suspicions)': False,
#    'contains (ensure)': False,
#    'contains (use)': False,
#    'contains (excuse)': False,
#    'contains (decides)': False,
#    'contains (return)': False,
#    'contains (toolbox)': False,
#    'contains (left)': False,
#    'contains (place)': False,
#    ...},
#   'neg'),
#  ({'contains (plot)': False,
#    'contains (:)': False,
#    'contains (two)': False,
#    'contains (teen)': False,
#    'contains (couples)': False,
#    'contains (go)': False,
#    'contains (to)': True,
#    'contains (a)': True,
#    'contains (church)': False,
#    'contains (party)': False,
#    'contains (,)': True,
#    'contains (drink)': False,
#    'contains (and)': True,
#    'contains (then)': False,
#    'contains (drive)': False,
#    'contains (.)': True,
#    'contains (they)': True,
#    'contains (get)': True,
#    'contains (into)': True,
#    'contains (an)': False,
#    'contains (accident)': False,
#    'contains (one)': False,
#    'contains (of)': True,
#    'contains (the)': True,
#    'contains (guys)': False,
#    'contains (dies)': False,
#    'contains (but)': False,
#    'contains (his)': False,
#    'contains (girlfriend)': False,
#    'contains (continues)': False,
#    'contains (see)': False,
#    'contains (him)': False,
#    'contains (in)': True,
#    'contains (her)': True,
#    'contains (life)': False,
#    'contains (has)': True,
#    'contains (nightmares)': False,
#    'contains (what)': True,
#    "contains (')": True,
#    'contains (s)': True,
#    'contains (deal)': False,
#    'contains (?)': False,
#    'contains (watch)': False,
#    'contains (movie)': True,
#    'contains (")': True,
#    'contains (sorta)': False,
#    'contains (find)': False,
#    'contains (out)': True,
#    'contains (critique)': False,
#    'contains (mind)': False,
#    'contains (-)': False,
#    'contains (fuck)': False,
#    'contains (for)': True,
#    'contains (generation)': False,
#    'contains (that)': True,
#    'contains (touches)': False,
#    'contains (on)': True,
#    'contains (very)': True,
#    'contains (cool)': False,
#    'contains (idea)': False,
#    'contains (presents)': False,
#    'contains (it)': True,
#    'contains (bad)': False,
#    'contains (package)': False,
#    'contains (which)': False,
#    'contains (is)': True,
#    'contains (makes)': False,
#    'contains (this)': True,
#    'contains (review)': True,
#    'contains (even)': True,
#    'contains (harder)': False,
#    'contains (write)': False,
#    'contains (since)': False,
#    'contains (i)': False,
#    'contains (generally)': False,
#    'contains (applaud)': False,
#    'contains (films)': False,
#    'contains (attempt)': False,
#    'contains (break)': False,
#    'contains (mold)': False,
#    'contains (mess)': False,
#    'contains (with)': True,
#    'contains (your)': True,
#    'contains (head)': True,
#    'contains (such)': False,
#    'contains (()': True,
#    'contains (lost)': False,
#    'contains (highway)': False,
#    'contains (&)': False,
#    'contains (memento)': False,
#    'contains ())': True,
#    'contains (there)': True,
#    'contains (are)': True,
#    'contains (good)': True,
#    'contains (ways)': False,
#    'contains (making)': False,
#    'contains (all)': True,
#    'contains (types)': False,
#    'contains (these)': True,
#    'contains (folks)': False,
#    'contains (just)': True,
#    'contains (didn)': False,
#    'contains (t)': True,
#    'contains (snag)': False,
#    'contains (correctly)': False,
#    'contains (seem)': False,
#    'contains (have)': False,
#    'contains (taken)': False,
#    'contains (pretty)': True,
#    'contains (neat)': False,
#    'contains (concept)': False,
#    'contains (executed)': False,
#    'contains (terribly)': False,
#    'contains (so)': True,
#    'contains (problems)': False,
#    'contains (well)': True,
#    'contains (its)': False,
#    'contains (main)': False,
#    'contains (problem)': False,
#    'contains (simply)': False,
#    'contains (too)': False,
#    'contains (jumbled)': False,
#    'contains (starts)': False,
#    'contains (off)': False,
#    'contains (normal)': False,
#    'contains (downshifts)': False,
#    'contains (fantasy)': False,
#    'contains (world)': False,
#    'contains (you)': True,
#    'contains (as)': False,
#    'contains (audience)': False,
#    'contains (member)': False,
#    'contains (no)': True,
#    'contains (going)': True,
#    'contains (dreams)': False,
#    'contains (characters)': False,
#    'contains (coming)': False,
#    'contains (back)': True,
#    'contains (from)': True,
#    'contains (dead)': False,
#    'contains (others)': False,
#    'contains (who)': False,
#    'contains (look)': False,
#    'contains (like)': True,
#    'contains (strange)': False,
#    'contains (apparitions)': False,
#    'contains (disappearances)': False,
#    'contains (looooot)': False,
#    'contains (chase)': True,
#    'contains (scenes)': False,
#    'contains (tons)': False,
#    'contains (weird)': False,
#    'contains (things)': False,
#    'contains (happen)': False,
#    'contains (most)': False,
#    'contains (not)': False,
#    'contains (explained)': False,
#    'contains (now)': False,
#    'contains (personally)': False,
#    'contains (don)': True,
#    'contains (trying)': False,
#    'contains (unravel)': False,
#    'contains (film)': False,
#    'contains (every)': False,
#    'contains (when)': True,
#    'contains (does)': False,
#    'contains (give)': False,
#    'contains (me)': False,
#    'contains (same)': False,
#    'contains (clue)': False,
#    'contains (over)': True,
#    'contains (again)': False,
#    'contains (kind)': False,
#    'contains (fed)': False,
#    'contains (up)': False,
#    'contains (after)': False,
#    'contains (while)': False,
#    'contains (biggest)': False,
#    'contains (obviously)': False,
#    'contains (got)': True,
#    'contains (big)': True,
#    'contains (secret)': False,
#    'contains (hide)': False,
#    'contains (seems)': False,
#    'contains (want)': False,
#    'contains (completely)': False,
#    'contains (until)': False,
#    'contains (final)': False,
#    'contains (five)': False,
#    'contains (minutes)': False,
#    'contains (do)': True,
#    'contains (make)': False,
#    'contains (entertaining)': False,
#    'contains (thrilling)': False,
#    'contains (or)': False,
#    'contains (engaging)': False,
#    'contains (meantime)': False,
#    'contains (really)': True,
#    'contains (sad)': False,
#    'contains (part)': False,
#    'contains (arrow)': False,
#    'contains (both)': False,
#    'contains (dig)': False,
#    'contains (flicks)': False,
#    'contains (we)': True,
#    'contains (actually)': False,
#    'contains (figured)': False,
#    'contains (by)': False,
#    'contains (half)': False,
#    'contains (way)': False,
#    'contains (point)': False,
#    'contains (strangeness)': True,
#    'contains (did)': False,
#    'contains (start)': True,
#    'contains (little)': True,
#    'contains (bit)': False,
#    'contains (sense)': False,
#    'contains (still)': True,
#    'contains (more)': True,
#    'contains (guess)': False,
#    'contains (bottom)': False,
#    'contains (line)': False,
#    'contains (movies)': False,
#    'contains (should)': False,
#    'contains (always)': False,
#    'contains (sure)': False,
#    'contains (before)': False,
#    'contains (given)': False,
#    'contains (password)': False,
#    'contains (enter)': False,
#    'contains (understanding)': False,
#    'contains (mean)': False,
#    'contains (showing)': False,
#    'contains (melissa)': False,
#    'contains (sagemiller)': False,
#    'contains (running)': False,
#    'contains (away)': False,
#    'contains (visions)': False,
#    'contains (about)': False,
#    'contains (20)': False,
#    'contains (throughout)': True,
#    'contains (plain)': False,
#    'contains (lazy)': False,
#    'contains (!)': False,
#    'contains (okay)': False,
#    'contains (people)': True,
#    'contains (chasing)': False,
#    'contains (know)': True,
#    'contains (need)': False,
#    'contains (how)': False,
#    'contains (giving)': False,
#    'contains (us)': False,
#    'contains (different)': False,
#    'contains (offering)': False,
#    'contains (further)': False,
#    'contains (insight)': False,
#    'contains (down)': False,
#    'contains (apparently)': False,
#    'contains (studio)': False,
#    'contains (took)': True,
#    'contains (director)': False,
#    'contains (chopped)': False,
#    'contains (themselves)': False,
#    'contains (shows)': False,
#    'contains (might)': False,
#    'contains (ve)': False,
#    'contains (been)': False,
#    'contains (decent)': False,
#    'contains (here)': True,
#    'contains (somewhere)': False,
#    'contains (suits)': False,
#    'contains (decided)': False,
#    'contains (turning)': False,
#    'contains (music)': False,
#    'contains (video)': False,
#    'contains (edge)': False,
#    'contains (would)': False,
#    'contains (actors)': False,
#    'contains (although)': False,
#    'contains (wes)': False,
#    'contains (bentley)': False,
#    'contains (seemed)': False,
#    'contains (be)': False,
#    'contains (playing)': False,
#    'contains (exact)': False,
#    'contains (character)': False,
#    'contains (he)': True,
#    'contains (american)': False,
#    'contains (beauty)': False,
#    'contains (only)': False,
#    'contains (new)': False,
#    'contains (neighborhood)': False,
#    'contains (my)': False,
#    'contains (kudos)': False,
#    'contains (holds)': False,
#    'contains (own)': False,
#    'contains (entire)': False,
#    'contains (feeling)': False,
#    'contains (unraveling)': False,
#    'contains (overall)': False,
#    'contains (doesn)': False,
#    'contains (stick)': False,
#    'contains (because)': False,
#    'contains (entertain)': False,
#    'contains (confusing)': False,
#    'contains (rarely)': False,
#    'contains (excites)': False,
#    'contains (feels)': True,
#    'contains (redundant)': False,
#    'contains (runtime)': False,
#    'contains (despite)': False,
#    'contains (ending)': False,
#    'contains (explanation)': False,
#    'contains (craziness)': False,
#    'contains (came)': False,
#    'contains (oh)': False,
#    'contains (horror)': False,
#    'contains (slasher)': False,
#    'contains (flick)': False,
#    'contains (packaged)': False,
#    'contains (someone)': True,
#    'contains (assuming)': False,
#    'contains (genre)': False,
#    'contains (hot)': False,
#    'contains (kids)': False,
#    'contains (also)': False,
#    'contains (wrapped)': False,
#    'contains (production)': False,
#    'contains (years)': False,
#    'contains (ago)': False,
#    'contains (sitting)': False,
#    'contains (shelves)': False,
#    'contains (ever)': False,
#    'contains (whatever)': False,
#    'contains (skip)': False,
#    'contains (where)': False,
#    'contains (joblo)': False,
#    'contains (nightmare)': False,
#    'contains (elm)': False,
#    'contains (street)': False,
#    'contains (3)': False,
#    'contains (7)': False,
#    'contains (/)': False,
#    'contains (10)': False,
#    'contains (blair)': False,
#    'contains (witch)': False,
#    'contains (2)': False,
#    'contains (crow)': False,
#    'contains (9)': False,
#    'contains (salvation)': False,
#    'contains (4)': False,
#    'contains (stir)': False,
#    'contains (echoes)': False,
#    'contains (8)': False,
#    'contains (happy)': True,
#    'contains (bastard)': True,
#    'contains (quick)': True,
#    'contains (damn)': True,
#    'contains (y2k)': True,
#    'contains (bug)': True,
#    'contains (starring)': True,
#    'contains (jamie)': True,
#    'contains (lee)': True,
#    'contains (curtis)': True,
#    'contains (another)': True,
#    'contains (baldwin)': True,
#    'contains (brother)': True,
#    'contains (william)': True,
#    'contains (time)': True,
#    'contains (story)': True,
#    'contains (regarding)': True,
#    'contains (crew)': True,
#    'contains (tugboat)': True,
#    'contains (comes)': True,
#    'contains (across)': True,
#    'contains (deserted)': True,
#    'contains (russian)': True,
#    'contains (tech)': True,
#    'contains (ship)': True,
#    'contains (kick)': True,
#    'contains (power)': True,
#    'contains (within)': True,
#    'contains (gore)': True,
#    'contains (bringing)': True,
#    'contains (few)': True,
#    'contains (action)': True,
#    'contains (sequences)': True,
#    'contains (virus)': True,
#    'contains (empty)': True,
#    'contains (flash)': True,
#    'contains (substance)': True,
#    'contains (why)': True,
#    'contains (was)': True,
#    'contains (middle)': True,
#    'contains (nowhere)': True,
#    'contains (origin)': True,
#    'contains (pink)': True,
#    'contains (flashy)': True,
#    'contains (thing)': True,
#    'contains (hit)': True,
#    'contains (mir)': True,
#    'contains (course)': True,
#    'contains (donald)': True,
#    'contains (sutherland)': True,
#    'contains (stumbling)': True,
#    'contains (around)': True,
#    'contains (drunkenly)': True,
#    'contains (hey)': True,
#    'contains (let)': True,
#    'contains (some)': True,
#    'contains (robots)': True,
#    'contains (acting)': True,
#    'contains (below)': True,
#    'contains (average)': True,
#    'contains (likes)': True,
#    'contains (re)': True,
#    'contains (likely)': True,
#    'contains (work)': True,
#    'contains (halloween)': True,
#    'contains (h20)': True,
#    'contains (wasted)': True,
#    'contains (real)': True,
#    'contains (star)': True,
#    'contains (stan)': True,
#    'contains (winston)': True,
#    'contains (robot)': True,
#    'contains (design)': True,
#    'contains (schnazzy)': True,
#    'contains (cgi)': True,
#    'contains (occasional)': True,
#    'contains (shot)': True,
#    'contains (picking)': True,
#    'contains (brain)': True,
#    'contains (if)': True,
#    'contains (body)': True,
#    'contains (parts)': True,
#    'contains (turn)': True,
#    'contains (otherwise)': True,
#    'contains (much)': True,
#    'contains (sunken)': True,
#    'contains (jaded)': False,
#    'contains (viewer)': False,
#    'contains (thankful)': False,
#    'contains (invention)': False,
#    'contains (timex)': False,
#    'contains (indiglo)': False,
#    'contains (based)': False,
#    'contains (late)': False,
#    'contains (1960)': False,
#    'contains (television)': False,
#    'contains (show)': False,
#    'contains (name)': False,
#    'contains (mod)': False,
#    'contains (squad)': False,
#    'contains (tells)': False,
#    'contains (tale)': False,
#    'contains (three)': False,
#    'contains (reformed)': False,
#    'contains (criminals)': False,
#    'contains (under)': False,
#    'contains (employ)': False,
#    'contains (police)': False,
#    'contains (undercover)': False,
#    'contains (however)': False,
#    'contains (wrong)': False,
#    'contains (evidence)': False,
#    'contains (gets)': False,
#    'contains (stolen)': False,
#    'contains (immediately)': False,
#    'contains (suspicion)': False,
#    'contains (ads)': False,
#    'contains (cuts)': False,
#    'contains (claire)': False,
#    'contains (dane)': False,
#    'contains (nice)': False,
#    'contains (hair)': False,
#    'contains (cute)': False,
#    'contains (outfits)': False,
#    'contains (car)': False,
#    'contains (chases)': False,
#    'contains (stuff)': False,
#    'contains (blowing)': False,
#    'contains (sounds)': False,
#    'contains (first)': False,
#    'contains (fifteen)': False,
#    'contains (quickly)': False,
#    'contains (becomes)': False,
#    'contains (apparent)': False,
#    'contains (certainly)': False,
#    'contains (slick)': False,
#    'contains (looking)': False,
#    'contains (complete)': False,
#    'contains (costumes)': False,
#    'contains (isn)': False,
#    'contains (enough)': False,
#    'contains (best)': False,
#    'contains (described)': False,
#    'contains (cross)': False,
#    'contains (between)': False,
#    'contains (hour)': False,
#    'contains (long)': False,
#    'contains (cop)': False,
#    'contains (stretched)': False,
#    'contains (span)': False,
#    'contains (single)': False,
#    'contains (clich)': False,
#    'contains (matter)': False,
#    'contains (elements)': False,
#    'contains (recycled)': False,
#    'contains (everything)': False,
#    'contains (already)': False,
#    'contains (seen)': False,
#    'contains (nothing)': False,
#    'contains (spectacular)': False,
#    'contains (sometimes)': False,
#    'contains (bordering)': False,
#    'contains (wooden)': False,
#    'contains (danes)': False,
#    'contains (omar)': False,
#    'contains (epps)': False,
#    'contains (deliver)': False,
#    'contains (their)': False,
#    'contains (lines)': False,
#    'contains (bored)': False,
#    'contains (transfers)': False,
#    'contains (onto)': False,
#    'contains (escape)': False,
#    'contains (relatively)': False,
#    'contains (unscathed)': False,
#    'contains (giovanni)': False,
#    'contains (ribisi)': False,
#    'contains (plays)': False,
#    'contains (resident)': False,
#    'contains (crazy)': False,
#    'contains (man)': False,
#    'contains (ultimately)': False,
#    'contains (being)': False,
#    'contains (worth)': False,
#    'contains (watching)': False,
#    'contains (unfortunately)': False,
#    'contains (save)': False,
#    'contains (convoluted)': False,
#    'contains (apart)': False,
#    'contains (occupying)': False,
#    'contains (screen)': False,
#    'contains (young)': False,
#    'contains (cast)': False,
#    'contains (clothes)': False,
#    'contains (hip)': False,
#    'contains (soundtrack)': False,
#    'contains (appears)': False,
#    'contains (geared)': False,
#    'contains (towards)': False,
#    'contains (teenage)': False,
#    'contains (mindset)': False,
#    'contains (r)': False,
#    'contains (rating)': False,
#    'contains (content)': False,
#    'contains (justify)': False,
#    'contains (juvenile)': False,
#    'contains (older)': False,
#    'contains (information)': False,
#    'contains (literally)': False,
#    'contains (spoon)': False,
#    'contains (hard)': False,
#    'contains (instead)': False,
#    'contains (telling)': False,
#    'contains (dialogue)': False,
#    'contains (poorly)': False,
#    'contains (written)': False,
#    'contains (extremely)': False,
#    'contains (predictable)': False,
#    'contains (progresses)': False,
#    'contains (won)': False,
#    'contains (care)': False,
#    'contains (heroes)': False,
#    'contains (any)': False,
#    'contains (jeopardy)': False,
#    'contains (ll)': False,
#    'contains (aren)': False,
#    'contains (basing)': False,
#    'contains (nobody)': False,
#    'contains (remembers)': False,
#    'contains (questionable)': False,
#    'contains (wisdom)': False,
#    'contains (especially)': False,
#    'contains (considers)': False,
#    'contains (target)': False,
#    'contains (fact)': False,
#    'contains (number)': False,
#    'contains (memorable)': False,
#    'contains (can)': False,
#    'contains (counted)': False,
#    'contains (hand)': False,
#    'contains (missing)': False,
#    'contains (finger)': False,
#    'contains (times)': False,
#    'contains (checked)': False,
#    'contains (six)': False,
#    'contains (clear)': False,
#    'contains (indication)': False,
#    'contains (them)': False,
#    'contains (than)': False,
#    'contains (cash)': False,
#    'contains (spending)': False,
#    'contains (dollar)': False,
#    'contains (judging)': False,
#    'contains (rash)': False,
#    'contains (awful)': False,
#    'contains (seeing)': False,
#    'contains (avoid)': False,
#    'contains (at)': False,
#    'contains (costs)': False,
#    'contains (quest)': False,
#    'contains (camelot)': False,
#    'contains (warner)': False,
#    'contains (bros)': False,
#    'contains (feature)': False,
#    'contains (length)': False,
#    'contains (fully)': False,
#    'contains (animated)': False,
#    'contains (steal)': False,
#    'contains (clout)': False,
#    'contains (disney)': False,
#    'contains (cartoon)': False,
#    'contains (empire)': False,
#    'contains (mouse)': False,
#    'contains (reason)': False,
#    'contains (worried)': False,
#    'contains (other)': False,
#    'contains (recent)': False,
#    'contains (challenger)': False,
#    'contains (throne)': False,
#    'contains (last)': False,
#    'contains (fall)': False,
#    'contains (promising)': False,
#    'contains (flawed)': False,
#    'contains (20th)': False,
#    'contains (century)': False,
#    'contains (fox)': False,
#    'contains (anastasia)': False,
#    'contains (hercules)': False,
#    'contains (lively)': False,
#    'contains (colorful)': False,
#    'contains (palate)': False,
#    'contains (had)': False,
#    'contains (beat)': False,
#    'contains (hands)': False,
#    'contains (crown)': False,
#    'contains (1997)': False,
#    'contains (piece)': False,
#    'contains (animation)': False,
#    'contains (year)': False,
#    'contains (contest)': False,
#    'contains (arrival)': False,
#    'contains (magic)': False,
#    'contains (kingdom)': False,
#    'contains (mediocre)': False,
#    'contains (--)': False,
#    'contains (d)': False,
#    'contains (pocahontas)': False,
#    'contains (those)': False,
#    'contains (keeping)': False,
#    'contains (score)': False,
#    'contains (nearly)': False,
#    'contains (dull)': False,
#    'contains (revolves)': False,
#    'contains (adventures)': False,
#    'contains (free)': False,
#    'contains (spirited)': False,
#    'contains (kayley)': False,
#    'contains (voiced)': False,
#    'contains (jessalyn)': False,
#    'contains (gilsig)': False,
#    'contains (early)': False,
#    'contains (daughter)': False,
#    'contains (belated)': False,
#    'contains (knight)': False,
#    'contains (king)': False,
#    'contains (arthur)': False,
#    'contains (round)': False,
#    'contains (table)': False,
#    'contains (dream)': False,
#    'contains (follow)': False,
#    'contains (father)': False,
#    'contains (footsteps)': False,
#    'contains (she)': False,
#    'contains (chance)': False,
#    'contains (evil)': False,
#    'contains (warlord)': False,
#    'contains (ruber)': False,
#    'contains (gary)': False,
#    'contains (oldman)': False,
#    'contains (ex)': False,
#    'contains (gone)': False,
#    'contains (steals)': False,
#    'contains (magical)': False,
#    'contains (sword)': False,
#    'contains (excalibur)': False,
#    'contains (accidentally)': False,
#    'contains (loses)': False,
#    'contains (dangerous)': False,
#    'contains (booby)': False,
#    'contains (trapped)': False,
#    'contains (forest)': False,
#    'contains (help)': False,
#    'contains (hunky)': False,
#    'contains (blind)': False,
#    'contains (timberland)': False,
#    'contains (dweller)': False,
#    'contains (garrett)': False,
#    'contains (carey)': False,
#    'contains (elwes)': False,
#    'contains (headed)': False,
#    'contains (dragon)': False,
#    'contains (eric)': False,
#    'contains (idle)': False,
#    'contains (rickles)': False,
#    'contains (arguing)': False,
#    'contains (itself)': False,
#    'contains (able)': False,
#    'contains (medieval)': False,
#    'contains (sexist)': False,
#    'contains (prove)': False,
#    'contains (fighter)': False,
#    'contains (side)': False,
#    'contains (pure)': False,
#    'contains (showmanship)': False,
#    'contains (essential)': False,
#    'contains (element)': False,
#    'contains (expected)': False,
#    'contains (climb)': False,
#    'contains (high)': False,
#    'contains (ranks)': False,
#    'contains (differentiates)': False,
#    'contains (something)': False,
#    'contains (saturday)': False,
#    'contains (morning)': False,
#    'contains (subpar)': False,
#    'contains (instantly)': False,
#    'contains (forgettable)': False,
#    'contains (songs)': False,
#    'contains (integrated)': False,
#    'contains (computerized)': False,
#    'contains (footage)': False,
#    'contains (compare)': False,
#    'contains (run)': False,
#    'contains (angry)': False,
#    'contains (ogre)': False,
#    'contains (herc)': False,
#    'contains (battle)': False,
#    'contains (hydra)': False,
#    'contains (rest)': False,
#    'contains (case)': False,
#    'contains (stink)': False,
#    'contains (none)': False,
#    'contains (remotely)': False,
#    'contains (interesting)': False,
#    'contains (race)': False,
#    'contains (bland)': False,
#    'contains (end)': False,
#    'contains (tie)': False,
#    'contains (win)': False,
#    'contains (comedy)': False,
#    'contains (shtick)': False,
#    'contains (awfully)': False,
#    'contains (cloying)': False,
#    'contains (least)': False,
#    'contains (signs)': False,
#    'contains (pulse)': False,
#    'contains (fans)': False,
#    "contains (-')": False,
#    'contains (90s)': False,
#    'contains (tgif)': False,
#    'contains (will)': False,
#    'contains (thrilled)': False,
#    'contains (jaleel)': False,
#    'contains (urkel)': False,
#    'contains (white)': False,
#    'contains (bronson)': False,
#    'contains (balki)': False,
#    'contains (pinchot)': False,
#    'contains (sharing)': False,
#    'contains (nicely)': False,
#    'contains (realized)': False,
#    'contains (though)': False,
#    'contains (m)': False,
#    'contains (loss)': False,
#    'contains (recall)': False,
#    'contains (specific)': False,
#    'contains (providing)': False,
#    'contains (voice)': False,
#    'contains (talent)': False,
#    'contains (enthusiastic)': False,
#    'contains (paired)': False,
#    'contains (singers)': False,
#    'contains (sound)': False,
#    'contains (musical)': False,
#    'contains (moments)': False,
#    'contains (jane)': False,
#    'contains (seymour)': False,
#    'contains (celine)': False,
#    'contains (dion)': False,
#    'contains (must)': False,
#    'contains (strain)': False,
#    'contains (through)': False,
#    'contains (aside)': False,
#    'contains (children)': False,
#    'contains (probably)': False,
#    'contains (adults)': False,
#    'contains (grievous)': False,
#    'contains (error)': False,
#    'contains (lack)': False,
#    'contains (personality)': False,
#    'contains (learn)': False,
#    'contains (goes)': False,
#    'contains (synopsis)': False,
#    'contains (mentally)': False,
#    'contains (unstable)': False,
#    'contains (undergoing)': False,
#    'contains (psychotherapy)': False,
#    'contains (saves)': False,
#    'contains (boy)': False,
#    'contains (potentially)': False,
#    'contains (fatal)': False,
#    'contains (falls)': False,
#    'contains (love)': False,
#    'contains (mother)': False,
#    'contains (fledgling)': False,
#    'contains (restauranteur)': False,
#    'contains (unsuccessfully)': False,
#    'contains (attempting)': False,
#    'contains (gain)': False,
#    'contains (woman)': False,
#    'contains (favor)': False,
#    'contains (takes)': False,
#    'contains (pictures)': False,
#    'contains (kills)': False,
#    'contains (comments)': False,
#    'contains (stalked)': False,
#    'contains (yet)': False,
#    'contains (seemingly)': False,
#    'contains (endless)': False,
#    'contains (string)': False,
#    'contains (spurned)': False,
#    'contains (psychos)': False,
#    'contains (getting)': False,
#    'contains (revenge)': False,
#    'contains (type)': False,
#    'contains (stable)': False,
#    'contains (category)': False,
#    'contains (1990s)': False,
#    'contains (industry)': False,
#    'contains (theatrical)': False,
#    'contains (direct)': False,
#    'contains (proliferation)': False,
#    'contains (may)': False,
#    'contains (due)': False,
#    'contains (typically)': False,
#    'contains (inexpensive)': False,
#    'contains (produce)': False,
#    'contains (special)': False,
#    'contains (effects)': False,
#    'contains (stars)': False,
#    'contains (serve)': False,
#    'contains (vehicles)': False,
#    'contains (nudity)': False,
#    'contains (allowing)': False,
#    'contains (frequent)': False,
#    'contains (night)': False,
#    'contains (cable)': False,
#    'contains (wavers)': False,
#    'contains (slightly)': False,
#    'contains (norm)': False,
#    'contains (respect)': False,
#    'contains (psycho)': False,
#    'contains (never)': False,
#    'contains (affair)': False,
#    'contains (;)': False,
#    'contains (contrary)': False,
#    'contains (rejected)': False,
#    'contains (rather)': False,
#    'contains (lover)': False,
#    'contains (wife)': False,
#    'contains (husband)': False,
#    'contains (entry)': False,
#    'contains (doomed)': False,
#    'contains (collect)': False,
#    'contains (dust)': False,
#    'contains (viewed)': False,
#    'contains (midnight)': False,
#    'contains (provide)': False,
#    'contains (suspense)': False,
#    'contains (sets)': False,
#    'contains (interspersed)': False,
#    'contains (opening)': False,
#    'contains (credits)': False,
#    'contains (instance)': False,
#    'contains (serious)': False,
#    'contains (sounding)': False,
#    'contains (narrator)': False,
#    'contains (spouts)': False,
#    'contains (statistics)': False,
#    'contains (stalkers)': False,
#    'contains (ponders)': False,
#    'contains (cause)': False,
#    'contains (stalk)': False,
#    'contains (implicitly)': False,
#    'contains (implied)': False,
#    'contains (men)': False,
#    'contains (shown)': False,
#    'contains (snapshot)': False,
#    'contains (actor)': False,
#    'contains (jay)': False,
#    'contains (underwood)': False,
#    'contains (states)': False,
#    'contains (daryl)': False,
#    'contains (gleason)': False,
#    'contains (stalker)': False,
#    'contains (brooke)': False,
#    'contains (daniels)': False,
#    'contains (meant)': False,
#    'contains (called)': False,
#    'contains (guesswork)': False,
#    'contains (required)': False,
#    'contains (proceeds)': False,
#    'contains (begins)': False,
#    'contains (obvious)': False,
#    'contains (sequence)': False,
#    'contains (contrived)': False,
#    'contains (quite)': False,
#    'contains (brings)': False,
#    'contains (victim)': False,
#    'contains (together)': False,
#    'contains (obsesses)': False,
#    'contains (follows)': False,
#    'contains (tries)': False,
#    'contains (woo)': False,
#    'contains (plans)': False,
#    'contains (become)': False,
#    'contains (desperate)': False,
#    'contains (elaborate)': False,
#    'contains (include)': False,
#    'contains (cliche)': False,
#    'contains (murdered)': False,
#    'contains (pet)': False,
#    'contains (require)': False,
#    'contains (found)': False,
#    'contains (exception)': False,
#    'contains (cat)': False,
#    'contains (shower)': False,
#    'contains (events)': False,
#    'contains (lead)': False,
#    'contains (inevitable)': False,
#    'contains (showdown)': False,
#    'contains (survives)': False,
#    'contains (invariably)': False,
#    'contains (conclusion)': False,
#    'contains (turkey)': False,
#    'contains (uniformly)': False,
#    'contains (adequate)': False,
#    'contains (anything)': False,
#    'contains (home)': False,
#    'contains (either)': False,
#    'contains (turns)': False,
#    'contains (toward)': False,
#    'contains (melodrama)': False,
#    'contains (overdoes)': False,
#    'contains (words)': False,
#    'contains (manages)': False,
#    'contains (creepy)': False,
#    'contains (pass)': False,
#    'contains (demands)': False,
#    'contains (maryam)': False,
#    'contains (abo)': False,
#    'contains (close)': False,
#    'contains (played)': False,
#    'contains (bond)': False,
#    'contains (chick)': False,
#    'contains (living)': False,
#    'contains (daylights)': False,
#    'contains (equally)': False,
#    'contains (title)': False,
#    'contains (ditzy)': False,
#    'contains (strong)': False,
#    'contains (independent)': False,
#    'contains (business)': False,
#    'contains (owner)': False,
#    'contains (needs)': False,
#    'contains (proceed)': False,
#    'contains (example)': False,
#    'contains (suspicions)': False,
#    'contains (ensure)': False,
#    'contains (use)': False,
#    'contains (excuse)': False,
#    'contains (decides)': False,
#    'contains (return)': False,
#    'contains (toolbox)': False,
#    'contains (left)': False,
#    'contains (place)': False,
#    ...},
#   'neg')]

# %%
train_set,test_set=featuresets[100:],featuresets[:100]

# %%
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.78

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#    contains (recognizes) = True              pos : neg    =      8.1 : 1.0
#    contains (schumacher) = True              neg : pos    =      7.8 : 1.0
# contains (unimaginative) = True              neg : pos    =      7.8 : 1.0
#        contains (turkey) = True              neg : pos    =      6.5 : 1.0
#     contains (atrocious) = True              neg : pos    =      6.4 : 1.0
#          contains (mena) = True              neg : pos    =      6.3 : 1.0
#        contains (shoddy) = True              neg : pos    =      6.3 : 1.0
#        contains (suvari) = True              neg : pos    =      6.3 : 1.0
#         contains (kudos) = True              pos : neg    =      5.9 : 1.0
#        contains (wasted) = True              neg : pos    =      5.6 : 1.0

# %%
from nltk.corpus import brown
suffix_fdist=nltk.FreqDist()

# %%
import math
def entropy(labels):
    freqdist=nltk.FreqDist(labels)
    probs=[freqdist.freq(l) for l in nltk.FreqDist(labels)]
    return -sum([p*math.log(p,2) for p in probs])

entropy(['male','male','male','female'])
# Out:
# 0.8112781244591328

# %%
entropy(['male','male','female','female'])
# Out:
# 1.0

# %%
entropy(['female','female','male','female'])
# Out:
# 0.8112781244591328

# %%
entropy(['male','male','male','male'])
# Out:
# -0.0

# %%
entropy(['male','fmale','male','female'])
# Out:
# 1.5
